# %% [markdown]
# # Agent Development
# ##### *Final Agent Development Notebook*

# %% [markdown]
# ## Table of Contents
#
# - [0. Set Up Testing](#0-set-up-testing)
#   - [0.1 Load Testing JSON data](#0.1-load-testing-json-data)
#   - [0.2 Save Testing Data](#0.2-save-testing-data)
# - [1. Agent A: Database Selector](#1-agent-a-database-selector)
#   - [1.1 OpenAI Setup](#11-openai-setup)
#   - [1.2 Load Schemas from tables.json](#12-load-schemas-from-tablesjson)
#   - [1.3 Extract Schemas](#13-extract-schemas)
#   - [1.4 Redefine Schemas for LLM](#14-redefine-schemas-for-llm)
#   - [1.5 Save Redefined Schemas](#15-save-redefined-schemas)
#   - [1.6 Create and Save Schema Embeddings](#16-create-and-save-schema-embeddings)
#   - [1.7 Set up Agent A](#17-set-up-agent-a)
#   - [1.8 Apply Agent A](#18-apply-agent-a)
#   - [1.9 Test Agent A](#19-test-agent-a)
# - [2. Agent B: Table & Column Selector](#2-agent-b-table--column-selector)
#   - [2.1 Setup for Testing](#21-setup-for-testing)
#   - [2.2 Setup Agent B](#22-setup-agent-b)
#   - [2.3 Apply Agent B](#23-apply-agent-b)
#   - [2.4 Test Agent B](#24-test-agent-b)
# - [3. Agent C: SQL Generator](#3-agent-c-sql-generator)
#   - [3.1 Setup for Testing](#31-setup-for-testing)
#   - [3.2 Setup Agent C](#32-setup-agent-c)
#   - [3.3 Apply Agent C](#33-apply-agent-c)
# - [4. Archive](#4-archive)

# %%
import os
import sys
import sqlite3
import json
import pandas as pd
from pathlib import Path
import pprint
import textwrap
from typing import Dict, Any, List, Tuple, Union
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.vectorstores import FAISS
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from openai import OpenAI

# %%
PROJECT_ROOT = Path(__file__).parent.parent.parent if '__file__' in globals() else Path.cwd().parent.parent.parent  
sys.path.append(PROJECT_ROOT)

# %% [markdown]
# ## 0 Set Up Testing

# %% [markdown]
# ### 0.1 Load Testing JSON data

# %%
SQL_DATA_PATH = PROJECT_ROOT / "data" / "spider_data" / "train_spider.json"  
SQL_TESTING = PROJECT_ROOT / "data" / "test" / "spider_query_answers.json"

# %%
def load_sql_dataset(file_path: Union[str, Path]) -> pd.DataFrame:
    """
    Load the Spider dataset (JSON with a list of records) and return a DataFrame with 
    db_id, query, question.
    """
    file_path = Path(file_path)
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)  # load entire JSON list

    records = [
        {
            "db_id": rec.get("db_id"),
            "question": rec.get("question"),
            "query": rec.get("query"),
            "guery_toks": rec.get("query_toks") # list
        }
        for rec in data
    ]

    df = pd.DataFrame(records)
    return df

sql_answers_df = load_sql_dataset(SQL_DATA_PATH)
sql_answers_df.head()
# Out:
#                    db_id                                           question  \
# 0  department_management  How many heads of the departments are older th...
# 1  department_management  List the name, born state and age of the heads...
# 2  department_management  List the creation year, name and budget of eac...
# 3  department_management  What are the maximum and minimum budget of the...
# 4  department_management  What is the average number of employees of the...
#
#                                                query  \
# 0         SELECT count(*) FROM head WHERE age  >  56
# 1  SELECT name ,  born_state ,  age FROM head ORD...
# 2  SELECT creation ,  name ,  budget_in_billions ...
# 3  SELECT max(budget_in_billions) ,  min(budget_i...
# 4  SELECT avg(num_employees) FROM department WHER...
#
#                                           guery_toks
# 0  [SELECT, count, (, *, ), FROM, head, WHERE, ag...
# 1  [SELECT, name, ,, born_state, ,, age, FROM, he...
# 2  [SELECT, creation, ,, name, ,, budget_in_billi...
# 3  [SELECT, max, (, budget_in_billions, ), ,, min...
# 4  [SELECT, avg, (, num_employees, ), FROM, depar...

# %% [markdown]
# ### 0.2 Save Testing Data

# %%
SQL_TESTING.parent.mkdir(parents=True, exist_ok=True)
df.to_json(SQL_TESTING, orient="records", indent=2)
print(f"Saved simplified queries to {SQL_TESTING}")
# Out:
# Saved simplified queries to /Users/lainemulvay/Desktop/Projects/UNI/Capstone/Explainable-Query-Interface-for-Relational-Databases/data/test/spider_query_answers.json

# %% [markdown]
# ## 1 Agent  A:  Database  Selector:
# `Chooses  the  most  relevant  database  based  on  the  user’s  natural
# language query.`

# %% [markdown]
# ### 1.1 OpenAI Setup

# %% [markdown]
# Import OpenAI API key

# %%
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY", "not-set")
print("OpenAI API key used:", OPENAI_API_KEY[:5] + "****")
# Out:
# OpenAI API key used: sk-pr****

# %% [markdown]
# Test OpenAI API

# %%
client = OpenAI()
response = client.responses.create (
    model = "gpt-5-mini",
    input = "how much gold would it take to coat the statue of liberty in a 1mm layer? Answer concisely",
    reasoning = {
        "effort": "minimal"
    }
)
print(response.output[1].content[0].text)
# Out:
# Rough estimate:
#
# - Surface area of Statue of Liberty (figure + torch + pedestal excluded) ≈ 11,000 ft² ≈ 1,022 m² (common cited range 1,000–1,200 m²). Use 1,000 m² for simplicity.
# - Volume of 1 mm (0.001 m) layer = area × thickness = 1,000 m² × 0.001 m = 1 m³.
# - Gold density ≈ 19,320 kg/m³ → mass ≈ 19,320 kg ≈ 19.3 metric tonnes.
# - Current gold price (approx) ≈ $65,000 per kg (price fluctuates; using ≈ $65k/kg → $1.25 billion). More commonly quoted spot ~$60–70k/kg; at $65k/kg 19,320 kg ≈ $1.26 billion.
#
# So about 19 tonnes of gold (≈1 m³), costing on the order of $1–1.5 billion depending on spot price.

# %% [markdown]
# ### 1.2 Load Schemas from tables.json

# %%
SCHEMA_PATH = PROJECT_ROOT / "data" / "spider_data" / "tables.json"

# read schema file with debug prints and file not found handling
def load_schemas(path: Path) -> Dict[str, Dict[str, Any]]:
    """
    Load the schema file from the given path and return a dictionary of schema objects.
    Includes debug output and file not found handling.
    """
    try:
        with open(path, "r", encoding="utf-8") as f:
            schemas_json = json.load(f)
        print(f"Loaded {len(schemas_json)} schema entries from file '{path}'.")
        return schemas_json
    except FileNotFoundError:
        print(f"Error: Schema file '{path}' not found.")
        return {}

schemas_json = load_schemas(SCHEMA_PATH)

# get db_ids from the schemas_json
db_ids = [entry.get('db_id', 'undefined') for entry in schemas_json if isinstance(entry, dict)]

if db_ids:
    print("First 10 Database ids:", db_ids[:10])
else:
    print("Schema loading failed. No database ids available.")
# Out:
# Loaded 166 schema entries from file '/Users/lainemulvay/Desktop/Projects/UNI/Capstone/Explainable-Query-Interface-for-Relational-Databases/data/spider_data/tables.json'.
# First 10 Database ids: ['perpetrator', 'college_2', 'flight_company', 'icfp_1', 'body_builder', 'storm_record', 'pilot_record', 'race_track', 'academic', 'department_store']

# %% [markdown]
# ### 1.3 Extract Schemas

# %%
# Here I've extract only the db_id, table_names, and column_names from tables.json
def extract_essential_schema(tables_data):
    essential_data = []
    for entry in tables_data:
        simplified_entry = {
            'database_name': entry.get('db_id', 'undefined'),
            'table_names': entry.get('table_names', []),
            'column_names': entry.get('column_names', [])
        }
        essential_data.append(simplified_entry)
    return essential_data

# Apply the extraction if tables_data is loaded
if 'schemas_json' in locals():
    essential_schemas = extract_essential_schema(schemas_json)
    print(f" Extracted data for {len(essential_schemas)} database schemas")

print("\nFirst datbase schema:")
essential_schemas[0]

#     # Show example of the simplified structure
#     if essential_schemas:
#         print(f"\n Example of simplified entry:")
#         example = essential_schemas[0]
#         print(f"  database_name: {example['database_name']}")
#         print(f"  table_names: {example['table_names']}")
#         print(f"  column_names (first 3): {example['column_names'][:3]}...")
#         print(f"  Total columns: {len(example['column_names'])}")
    
# else:
#     print("tables_data not found.")
# Out:
#  Extracted data for 166 database schemas
#
# First datbase schema:
# {'database_name': 'perpetrator',
#  'table_names': ['perpetrator', 'people'],
#  'column_names': [[-1, '*'],
#   [0, 'perpetrator id'],
#   [0, 'people id'],
#   [0, 'date'],
#   [0, 'year'],
#   [0, 'location'],
#   [0, 'country'],
#   [0, 'killed'],
#   [0, 'injured'],
#   [1, 'people id'],
#   [1, 'name'],
#   [1, 'height'],
#   [1, 'weight'],
#   [1, 'home town']]}

# %% [markdown]
# ### 1.4 Redefine Schemas for LLM

# %%
def reshape_with_headings(essential_schemas):
    """Add descriptive headings to make schema more LLM-friendly"""
    out = {}
    for db in essential_schemas:
        db_name = db.get("database_name", "unknown")
        table_names = list(db.get("table_names", []))
        col_specs = list(db.get("column_names", []))
        tables = []
        
        for idx, table_name in enumerate(table_names):
            cols = []
            for pair in col_specs:
                if not isinstance(pair, (list, tuple)) or len(pair) != 2:
                    continue
                t_idx, col = pair
                try:
                    t_idx = int(t_idx)
                except (ValueError, TypeError):
                    continue
                if t_idx != idx:
                    continue
                if col is None or str(col).strip() == "*" or t_idx < 0:
                    continue
                cols.append(str(col))

            tables.append({
                "table_name": table_name,
                "columns": cols,
            })

        out[db_name] = {
           "database_name": db_name,
            "tables": tables
        }
    return out


# Reshape with headings
reshaped_schemas = reshape_with_headings(essential_schemas)
print(f"Reshaped {len(reshaped_schemas)} databases with descriptive headings")
reshaped_schemas
# Out:
# Reshaped 166 databases with descriptive headings
# {'perpetrator': {'database_name': 'perpetrator',
#   'tables': [{'table_name': 'perpetrator',
#     'columns': ['perpetrator id',
#      'people id',
#      'date',
#      'year',
#      'location',
#      'country',
#      'killed',
#      'injured']},
#    {'table_name': 'people',
#     'columns': ['people id', 'name', 'height', 'weight', 'home town']}]},
#  'college_2': {'database_name': 'college_2',
#   'tables': [{'table_name': 'classroom',
#     'columns': ['building', 'room number', 'capacity']},
#    {'table_name': 'department',
#     'columns': ['department name', 'building', 'budget']},
#    {'table_name': 'course',
#     'columns': ['course id', 'title', 'department name', 'credits']},
#    {'table_name': 'instructor',
#     'columns': ['id', 'name', 'department name', 'salary']},
#    {'table_name': 'section',
#     'columns': ['course id',
#      'section id',
#      'semester',
#      'year',
#      'building',
#      'room number',
#      'time slot id']},
#    {'table_name': 'teaches',
#     'columns': ['id', 'course id', 'section id', 'semester', 'year']},
#    {'table_name': 'student',
#     'columns': ['id', 'name', 'department name', 'total credits']},
#    {'table_name': 'takes classes',
#     'columns': ['id', 'course id', 'section id', 'semester', 'year', 'grade']},
#    {'table_name': 'advisor', 'columns': ['student id', 'instructor id']},
#    {'table_name': 'time slot',
#     'columns': ['time slot id',
#      'day',
#      'start hour',
#      'start minute',
#      'end hour',
#      'end minute']},
#    {'table_name': 'prerequisite',
#     'columns': ['course id', 'prerequisite id']}]},
#  'flight_company': {'database_name': 'flight_company',
#   'tables': [{'table_name': 'airport',
#     'columns': ['id', 'city', 'country', 'iata', 'icao', 'name']},
#    {'table_name': 'operate company',
#     'columns': ['id',
#      'name',
#      'type',
#      'principal activities',
#      'incorporated in',
#      'group equity shareholding']},
#    {'table_name': 'flight',
#     'columns': ['id',
#      'vehicle flight number',
#      'date',
#      'pilot',
#      'velocity',
#      'altitude',
#      'airport id',
#      'company id']}]},
#  'icfp_1': {'database_name': 'icfp_1',
#   'tables': [{'table_name': 'institution',
#     'columns': ['institution id', 'name', 'country']},
#    {'table_name': 'authors',
#     'columns': ['author id', 'last name', 'first name']},
#    {'table_name': 'papers', 'columns': ['paper id', 'title']},
#    {'table_name': 'authorship count',
#     'columns': ['author id', 'institution id', 'paper id', 'author count']}]},
#  'body_builder': {'database_name': 'body_builder',
#   'tables': [{'table_name': 'body builder',
#     'columns': ['body builder id',
#      'people id',
#      'snatch',
#      'clean jerk',
#      'total']},
#    {'table_name': 'people',
#     'columns': ['people id',
#      'name',
#      'height',
#      'weight',
#      'birth date',
#      'birth place']}]},
#  'storm_record': {'database_name': 'storm_record',
#   'tables': [{'table_name': 'storm',
#     'columns': ['storm id',
#      'name',
#      'dates active',
#      'max speed',
#      'damage millions usd',
#      'number deaths']},
#    {'table_name': 'region',
#     'columns': ['region id', 'region code', 'region name']},
#    {'table_name': 'affected region',
#     'columns': ['region id', 'storm id', 'number city affected']}]},
#  'pilot_record': {'database_name': 'pilot_record',
#   'tables': [{'table_name': 'aircraft',
#     'columns': ['aircraft id',
#      'order year',
#      'manufacturer',
#      'model',
#      'fleet series',
#      'powertrain',
#      'fuel propulsion']},
#    {'table_name': 'pilot',
#     'columns': ['pilot id',
#      'pilot name',
#      'rank',
#      'age',
#      'nationality',
#      'position',
#      'join year',
#      'team']},
#    {'table_name': 'pilot record',
#     'columns': ['record id', 'pilot id', 'aircraft id', 'date']}]},
#  'race_track': {'database_name': 'race_track',
#   'tables': [{'table_name': 'race',
#     'columns': ['race id', 'name', 'class', 'date', 'track id']},
#    {'table_name': 'track',
#     'columns': ['track id', 'name', 'location', 'seating', 'year opened']}]},
#  'academic': {'database_name': 'academic',
#   'tables': [{'table_name': 'author',
#     'columns': ['aid', 'homepage', 'name', 'oid']},
#    {'table_name': 'conference', 'columns': ['cid', 'homepage', 'name']},
#    {'table_name': 'domain', 'columns': ['did', 'name']},
#    {'table_name': 'domain author', 'columns': ['aid', 'did']},
#    {'table_name': 'domain conference', 'columns': ['cid', 'did']},
#    {'table_name': 'journal', 'columns': ['homepage', 'jid', 'name']},
#    {'table_name': 'domain journal', 'columns': ['did', 'jid']},
#    {'table_name': 'keyword', 'columns': ['keyword', 'kid']},
#    {'table_name': 'domain keyword', 'columns': ['did', 'kid']},
#    {'table_name': 'publication',
#     'columns': ['abstract',
#      'cid',
#      'citation num',
#      'jid',
#      'pid',
#      'reference num',
#      'title',
#      'year']},
#    {'table_name': 'domain publication', 'columns': ['did', 'pid']},
#    {'table_name': 'organization',
#     'columns': ['continent', 'homepage', 'name', 'oid']},
#    {'table_name': 'publication keyword', 'columns': ['pid', 'kid']},
#    {'table_name': 'writes', 'columns': ['aid', 'pid']},
#    {'table_name': 'cite', 'columns': ['cited', 'citing']}]},
#  'department_store': {'database_name': 'department_store',
#   'tables': [{'table_name': 'addresses',
#     'columns': ['address id', 'address details']},
#    {'table_name': 'staff',
#     'columns': ['staff id', 'staff gender', 'staff name']},
#    {'table_name': 'suppliers',
#     'columns': ['supplier id', 'supplier name', 'supplier phone']},
#    {'table_name': 'department store chain',
#     'columns': ['department store chain id', 'department store chain name']},
#    {'table_name': 'customers',
#     'columns': ['customer id',
#      'payment method code',
#      'customer code',
#      'customer name',
#      'customer address',
#      'customer phone',
#      'customer email']},
#    {'table_name': 'products',
#     'columns': ['product id',
#      'product type code',
#      'product name',
#      'product price']},
#    {'table_name': 'supplier addresses',
#     'columns': ['supplier id', 'address id', 'date from', 'date to']},
#    {'table_name': 'customer addresses',
#     'columns': ['customer id', 'address id', 'date from', 'date to']},
#    {'table_name': 'customer orders',
#     'columns': ['order id', 'customer id', 'order status code', 'order date']},
#    {'table_name': 'department stores',
#     'columns': ['department store id',
#      'department store chain id',
#      'store name',
#      'store address',
#      'store phone',
#      'store email']},
#    {'table_name': 'departments',
#     'columns': ['department id', 'department store id', 'department name']},
#    {'table_name': 'order items',
#     'columns': ['order item id', 'order id', 'product id']},
#    {'table_name': 'product suppliers',
#     'columns': ['product id',
#      'supplier id',
#      'date supplied from',
#      'date supplied to',
#      'total amount purchased',
#      'total value purchased']},
#    {'table_name': 'staff department assignments',
#     'columns': ['staff id',
#      'department id',
#      'date assigned from',
#      'job title code',
#      'date assigned to']}]},
#  'music_4': {'database_name': 'music_4',
#   'tables': [{'table_name': 'artist',
#     'columns': ['artist id',
#      'artist',
#      'age',
#      'famous title',
#      'famous release date']},
#    {'table_name': 'volume',
#     'columns': ['volume id',
#      'volume issue',
#      'issue date',
#      'weeks on top',
#      'song',
#      'artist id']},
#    {'table_name': 'music festival',
#     'columns': ['id',
#      'music festival',
#      'date of ceremony',
#      'category',
#      'volume',
#      'result']}]},
#  'insurance_fnol': {'database_name': 'insurance_fnol',
#   'tables': [{'table_name': 'customers',
#     'columns': ['customer id', 'customer name']},
#    {'table_name': 'services', 'columns': ['service id', 'service name']},
#    {'table_name': 'available policies',
#     'columns': ['policy id', 'policy type code', 'customer phone']},
#    {'table_name': 'customers policies',
#     'columns': ['customer id', 'policy id', 'date opened', 'date closed']},
#    {'table_name': 'first notification of loss',
#     'columns': ['fnol id', 'customer id', 'policy id', 'service id']},
#    {'table_name': 'claims',
#     'columns': ['claim id', 'fnol id', 'effective date']},
#    {'table_name': 'settlements',
#     'columns': ['settlement id',
#      'claim id',
#      'effective date',
#      'settlement amount']}]},
#  'cinema': {'database_name': 'cinema',
#   'tables': [{'table_name': 'film',
#     'columns': ['film id',
#      'rank in series',
#      'number in season',
#      'title',
#      'directed by',
#      'original air date',
#      'production code']},
#    {'table_name': 'cinema',
#     'columns': ['cinema id', 'name', 'openning year', 'capacity', 'location']},
#    {'table_name': 'schedule',
#     'columns': ['cinema id',
#      'film id',
#      'date',
#      'show times per day',
#      'price']}]},
#  'decoration_competition': {'database_name': 'decoration_competition',
#   'tables': [{'table_name': 'college',
#     'columns': ['college id', 'name', 'leader name', 'college location']},
#    {'table_name': 'member',
#     'columns': ['member id', 'name', 'country', 'college id']},
#    {'table_name': 'round',
#     'columns': ['round id',
#      'member id',
#      'decoration theme',
#      'rank in round']}]},
#  'phone_market': {'database_name': 'phone_market',
#   'tables': [{'table_name': 'phone',
#     'columns': ['name', 'phone id', 'memory in g', 'carrier', 'price']},
#    {'table_name': 'market',
#     'columns': ['market id',
#      'district',
#      'num of employees',
#      'num of shops',
#      'ranking']},
#    {'table_name': 'phone market',
#     'columns': ['market id', 'phone id', 'num of stock']}]},
#  'store_product': {'database_name': 'store_product',
#   'tables': [{'table_name': 'product',
#     'columns': ['product id',
#      'product',
#      'dimensions',
#      'dpi',
#      'pages per minute color',
#      'max page size',
#      'interface']},
#    {'table_name': 'store',
#     'columns': ['store id',
#      'store name',
#      'type',
#      'area size',
#      'number of product category',
#      'ranking']},
#    {'table_name': 'district',
#     'columns': ['district id',
#      'district name',
#      'headquartered city',
#      'city population',
#      'city area']},
#    {'table_name': 'store product', 'columns': ['store id', 'product id']},
#    {'table_name': 'store district', 'columns': ['store id', 'district id']}]},
#  'assets_maintenance': {'database_name': 'assets_maintenance',
#   'tables': [{'table_name': 'third party companies',
#     'columns': ['company id',
#      'company type',
#      'company name',
#      'company address',
#      'other company details']},
#    {'table_name': 'maintenance contracts',
#     'columns': ['maintenance contract id',
#      'maintenance contract company id',
#      'contract start date',
#      'contract end date',
#      'other contract details']},
#    {'table_name': 'parts',
#     'columns': ['part id',
#      'part name',
#      'chargeable yn',
#      'chargeable amount',
#      'other part details']},
#    {'table_name': 'skills',
#     'columns': ['skill id', 'skill code', 'skill description']},
#    {'table_name': 'staff',
#     'columns': ['staff id', 'staff name', 'gender', 'other staff details']},
#    {'table_name': 'assets',
#     'columns': ['asset id',
#      'maintenance contract id',
#      'supplier company id',
#      'asset details',
#      'asset make',
#      'asset model',
#      'asset acquired date',
#      'asset disposed date',
#      'other asset details']},
#    {'table_name': 'asset parts', 'columns': ['asset id', 'part id']},
#    {'table_name': 'maintenance engineers',
#     'columns': ['engineer id',
#      'company id',
#      'first name',
#      'last name',
#      'other details']},
#    {'table_name': 'engineer skills', 'columns': ['engineer id', 'skill id']},
#    {'table_name': 'fault log',
#     'columns': ['fault log entry id',
#      'asset id',
#      'recorded by staff id',
#      'fault log entry datetime',
#      'fault description',
#      'other fault details']},
#    {'table_name': 'engineer visits',
#     'columns': ['engineer visit id',
#      'contact staff id',
#      'engineer id',
#      'fault log entry id',
#      'fault status',
#      'visit start datetime',
#      'visit end datetime',
#      'other visit details']},
#    {'table_name': 'part faults',
#     'columns': ['part fault id',
#      'part id',
#      'fault short name',
#      'fault description',
#      'other fault details']},
#    {'table_name': 'fault log parts',
#     'columns': ['fault log entry id', 'part fault id', 'fault status']},
#    {'table_name': 'skills required to fix',
#     'columns': ['part fault id', 'skill id']}]},
#  'student_assessment': {'database_name': 'student_assessment',
#   'tables': [{'table_name': 'addresses',
#     'columns': ['address id',
#      'line 1',
#      'line 2',
#      'city',
#      'zip postcode',
#      'state province county',
#      'country']},
#    {'table_name': 'people',
#     'columns': ['person id',
#      'first name',
#      'middle name',
#      'last name',
#      'cell mobile number',
#      'email address',
#      'login name',
#      'password']},
#    {'table_name': 'students', 'columns': ['student id', 'student details']},
#    {'table_name': 'courses',
#     'columns': ['course id',
#      'course name',
#      'course description',
#      'other details']},
#    {'table_name': 'people addresses',
#     'columns': ['person address id',
#      'person id',
#      'address id',
#      'date from',
#      'date to']},
#    {'table_name': 'student course registrations',
#     'columns': ['student id', 'course id', 'registration date']},
#    {'table_name': 'student course attendance',
#     'columns': ['student id', 'course id', 'date of attendance']},
#    {'table_name': 'candidates',
#     'columns': ['candidate id', 'candidate details']},
#    {'table_name': 'candidate assessments',
#     'columns': ['candidate id',
#      'qualification',
#      'assessment date',
#      'asessment outcome code']}]},
#  'dog_kennels': {'database_name': 'dog_kennels',
#   'tables': [{'table_name': 'breeds', 'columns': ['breed code', 'breed name']},
#    {'table_name': 'charges',
#     'columns': ['charge id', 'charge type', 'charge amount']},
#    {'table_name': 'sizes', 'columns': ['size code', 'size description']},
#    {'table_name': 'treatment types',
#     'columns': ['treatment type code', 'treatment type description']},
#    {'table_name': 'owners',
#     'columns': ['owner id',
#      'first name',
#      'last name',
#      'street',
#      'city',
#      'state',
#      'zip code',
#      'email address',
#      'home phone',
#      'cell number']},
#    {'table_name': 'dogs',
#     'columns': ['dog id',
#      'owner id',
#      'abandoned yes or no',
#      'breed code',
#      'size code',
#      'name',
#      'age',
#      'date of birth',
#      'gender',
#      'weight',
#      'date arrived',
#      'date adopted',
#      'date departed']},
#    {'table_name': 'professionals',
#     'columns': ['professional id',
#      'role code',
#      'first name',
#      'street',
#      'city',
#      'state',
#      'zip code',
#      'last name',
#      'email address',
#      'home phone',
#      'cell number']},
#    {'table_name': 'treatments',
#     'columns': ['treatment id',
#      'dog id',
#      'professional id',
#      'treatment type code',
#      'date of treatment',
#      'cost of treatment']}]},
#  'music_1': {'database_name': 'music_1',
#   'tables': [{'table_name': 'genre',
#     'columns': ['genre name', 'rating', 'most popular in']},
#    {'table_name': 'artist',
#     'columns': ['artist name', 'country', 'gender', 'preferred genre']},
#    {'table_name': 'files',
#     'columns': ['song id', 'artist name', 'file size', 'duration', 'formats']},
#    {'table_name': 'song',
#     'columns': ['song name',
#      'artist name',
#      'country',
#      'song id',
#      'genre is',
#      'rating',
#      'languages',
#      'releasedate',
#      'resolution']}]},
#  'company_employee': {'database_name': 'company_employee',
#   'tables': [{'table_name': 'people',
#     'columns': ['people id',
#      'age',
#      'name',
#      'nationality',
#      'graduation college']},
#    {'table_name': 'company',
#     'columns': ['company id',
#      'name',
#      'headquarters',
#      'industry',
#      'sales in billion',
#      'profits in billion',
#      'assets in billion',
#      'market value in billion']},
#    {'table_name': 'employment',
#     'columns': ['company id', 'people id', 'year working']}]},
#  'farm': {'database_name': 'farm',
#   'tables': [{'table_name': 'city',
#     'columns': ['city id',
#      'official name',
#      'status',
#      'area km 2',
#      'population',
#      'census ranking']},
#    {'table_name': 'farm',
#     'columns': ['farm id',
#      'year',
#      'total horses',
#      'working horses',
#      'total cattle',
#      'oxen',
#      'bulls',
#      'cows',
#      'pigs',
#      'sheep and goats']},
#    {'table_name': 'farm competition',
#     'columns': ['competition id', 'year', 'theme', 'host city id', 'hosts']},
#    {'table_name': 'competition record',
#     'columns': ['competition id', 'farm id', 'rank']}]},
#  'solvency_ii': {'database_name': 'solvency_ii',
#   'tables': [{'table_name': 'addresses',
#     'columns': ['address id', 'address details']},
#    {'table_name': 'locations', 'columns': ['location id', 'other details']},
#    {'table_name': 'products',
#     'columns': ['product id',
#      'product type code',
#      'product name',
#      'product price']},
#    {'table_name': 'parties', 'columns': ['party id', 'party details']},
#    {'table_name': 'assets', 'columns': ['asset id', 'other details']},
#    {'table_name': 'channels', 'columns': ['channel id', 'other details']},
#    {'table_name': 'finances', 'columns': ['finance id', 'other details']},
#    {'table_name': 'events',
#     'columns': ['event id',
#      'address id',
#      'channel id',
#      'event type code',
#      'finance id',
#      'location id']},
#    {'table_name': 'products in events',
#     'columns': ['product in event id', 'event id', 'product id']},
#    {'table_name': 'parties in events',
#     'columns': ['party id', 'event id', 'role code']},
#    {'table_name': 'agreements', 'columns': ['document id', 'event id']},
#    {'table_name': 'assets in events', 'columns': ['asset id', 'event id']}]},
#  'city_record': {'database_name': 'city_record',
#   'tables': [{'table_name': 'city',
#     'columns': ['city id',
#      'city',
#      'hanzi',
#      'hanyu pinyin',
#      'regional population',
#      'gdp']},
#    {'table_name': 'match',
#     'columns': ['match id',
#      'date',
#      'venue',
#      'score',
#      'result',
#      'competition']},
#    {'table_name': 'temperature',
#     'columns': ['city id',
#      'jan',
#      'feb',
#      'mar',
#      'apr',
#      'jun',
#      'jul',
#      'aug',
#      'sep',
#      'oct',
#      'nov',
#      'dec']},
#    {'table_name': 'hosting city',
#     'columns': ['year', 'match id', 'host city']}]},
#  'swimming': {'database_name': 'swimming',
#   'tables': [{'table_name': 'swimmer',
#     'columns': ['id',
#      'name',
#      'nationality',
#      'meter 100',
#      'meter 200',
#      'meter 300',
#      'meter 400',
#      'meter 500',
#      'meter 600',
#      'meter 700',
#      'time']},
#    {'table_name': 'stadium',
#     'columns': ['id', 'name', 'capacity', 'city', 'country', 'opening year']},
#    {'table_name': 'event', 'columns': ['id', 'name', 'stadium id', 'year']},
#    {'table_name': 'record',
#     'columns': ['id', 'result', 'swimmer id', 'event id']}]},
#  'flight_2': {'database_name': 'flight_2',
#   'tables': [{'table_name': 'airlines',
#     'columns': ['airline id', 'airline name', 'abbreviation', 'country']},
#    {'table_name': 'airports',
#     'columns': ['city',
#      'airport code',
#      'airport name',
#      'country',
#      'country abbrev']},
#    {'table_name': 'flights',
#     'columns': ['airline',
#      'flight number',
#      'source airport',
#      'destination airport']}]},
#  'election': {'database_name': 'election',
#   'tables': [{'table_name': 'county',
#     'columns': ['county id', 'county name', 'population', 'zip code']},
#    {'table_name': 'party',
#     'columns': ['party id',
#      'year',
#      'party',
#      'governor',
#      'lieutenant governor',
#      'comptroller',
#      'attorney general',
#      'us senate']},
#    {'table_name': 'election',
#     'columns': ['election id',
#      'counties represented',
#      'district',
#      'delegate',
#      'party',
#      'first elected',
#      'committee']}]},
#  'manufactory_1': {'database_name': 'manufactory_1',
#   'tables': [{'table_name': 'manufacturers',
#     'columns': ['code', 'name', 'headquarter', 'founder', 'revenue']},
#    {'table_name': 'products',
#     'columns': ['code', 'name', 'price', 'manufacturer']}]},
#  'debate': {'database_name': 'debate',
#   'tables': [{'table_name': 'people',
#     'columns': ['people id', 'district', 'name', 'party', 'age']},
#    {'table_name': 'debate',
#     'columns': ['debate id', 'date', 'venue', 'num of audience']},
#    {'table_name': 'debate people',
#     'columns': ['debate id',
#      'affirmative',
#      'negative',
#      'if affirmative win']}]},
#  'network_2': {'database_name': 'network_2',
#   'tables': [{'table_name': 'person',
#     'columns': ['name', 'age', 'city', 'gender', 'job']},
#    {'table_name': 'person friend', 'columns': ['name', 'friend', 'year']}]},
#  'local_govt_in_alabama': {'database_name': 'local_govt_in_alabama',
#   'tables': [{'table_name': 'services',
#     'columns': ['service id', 'service type code']},
#    {'table_name': 'participants',
#     'columns': ['participant id',
#      'participant type code',
#      'participant details']},
#    {'table_name': 'events',
#     'columns': ['event id', 'service id', 'event details']},
#    {'table_name': 'participants in events',
#     'columns': ['event id', 'participant id']}]},
#  'climbing': {'database_name': 'climbing',
#   'tables': [{'table_name': 'mountain',
#     'columns': ['mountain id',
#      'name',
#      'height',
#      'prominence',
#      'range',
#      'country']},
#    {'table_name': 'climber',
#     'columns': ['climber id',
#      'name',
#      'country',
#      'time',
#      'points',
#      'mountain id']}]},
#  'e_learning': {'database_name': 'e_learning',
#   'tables': [{'table_name': 'course authors and tutors',
#     'columns': ['author id',
#      'author tutor atb',
#      'login name',
#      'password',
#      'personal name',
#      'middle name',
#      'family name',
#      'gender mf',
#      'address line 1']},
#    {'table_name': 'students',
#     'columns': ['student id',
#      'date of registration',
#      'date of latest logon',
#      'login name',
#      'password',
#      'personal name',
#      'middle name',
#      'family name']},
#    {'table_name': 'subjects', 'columns': ['subject id', 'subject name']},
#    {'table_name': 'courses',
#     'columns': ['course id',
#      'author id',
#      'subject id',
#      'course name',
#      'course description']},
#    {'table_name': 'student course enrolment',
#     'columns': ['registration id',
#      'student id',
#      'course id',
#      'date of enrolment',
#      'date of completion']},
#    {'table_name': 'student tests taken',
#     'columns': ['registration id', 'date test taken', 'test result']}]},
#  'scientist_1': {'database_name': 'scientist_1',
#   'tables': [{'table_name': 'scientists', 'columns': ['ssn', 'name']},
#    {'table_name': 'projects', 'columns': ['code', 'name', 'hours']},
#    {'table_name': 'assigned to', 'columns': ['scientist', 'project']}]},
#  'ship_1': {'database_name': 'ship_1',
#   'tables': [{'table_name': 'captain',
#     'columns': ['captain id', 'name', 'ship id', 'age', 'class', 'rank']},
#    {'table_name': 'ship',
#     'columns': ['ship id', 'name', 'type', 'built year', 'class', 'flag']}]},
#  'entertainment_awards': {'database_name': 'entertainment_awards',
#   'tables': [{'table_name': 'festival detail',
#     'columns': ['festival id',
#      'festival name',
#      'chair name',
#      'location',
#      'year',
#      'num of audience']},
#    {'table_name': 'artwork', 'columns': ['artwork id', 'type', 'name']},
#    {'table_name': 'nomination',
#     'columns': ['artwork id', 'festival id', 'result']}]},
#  'allergy_1': {'database_name': 'allergy_1',
#   'tables': [{'table_name': 'allergy type',
#     'columns': ['allergy name', 'allergy type']},
#    {'table_name': 'has allergy', 'columns': ['stuid', 'allergy']},
#    {'table_name': 'student',
#     'columns': ['stuid',
#      'last name',
#      'first name',
#      'age',
#      'sex',
#      'major',
#      'advisor',
#      'city code']}]},
#  'imdb': {'database_name': 'imdb',
#   'tables': [{'table_name': 'actor',
#     'columns': ['aid',
#      'gender',
#      'name',
#      'nationality',
#      'birth city',
#      'birth year']},
#    {'table_name': 'copyright', 'columns': ['id', 'msid', 'cid']},
#    {'table_name': 'cast', 'columns': ['id', 'msid', 'aid', 'role']},
#    {'table_name': 'genre', 'columns': ['gid', 'genre']},
#    {'table_name': 'classification', 'columns': ['id', 'msid', 'gid']},
#    {'table_name': 'company', 'columns': ['id', 'name', 'country code']},
#    {'table_name': 'director',
#     'columns': ['did',
#      'gender',
#      'name',
#      'nationality',
#      'birth city',
#      'birth year']},
#    {'table_name': 'producer',
#     'columns': ['pid',
#      'gender',
#      'name',
#      'nationality',
#      'birth city',
#      'birth year']},
#    {'table_name': 'directed by', 'columns': ['id', 'msid', 'did']},
#    {'table_name': 'keyword', 'columns': ['id', 'keyword']},
#    {'table_name': 'made by', 'columns': ['id', 'msid', 'pid']},
#    {'table_name': 'movie',
#     'columns': ['mid', 'title', 'release year', 'title aka', 'budget']},
#    {'table_name': 'tags', 'columns': ['id', 'msid', 'kid']},
#    {'table_name': 'tv series',
#     'columns': ['sid',
#      'title',
#      'release year',
#      'num of seasons',
#      'num of episodes',
#      'title aka',
#      'budget']},
#    {'table_name': 'writer',
#     'columns': ['wid',
#      'gender',
#      'name',
#      'nationality',
#      'num of episodes',
#      'birth city',
#      'birth year']},
#    {'table_name': 'written by', 'columns': ['id', 'msid', 'wid']}]},
#  'products_for_hire': {'database_name': 'products_for_hire',
#   'tables': [{'table_name': 'discount coupons',
#     'columns': ['coupon id', 'date issued', 'coupon amount']},
#    {'table_name': 'customers',
#     'columns': ['customer id',
#      'coupon id',
#      'good or bad customer',
#      'first name',
#      'last name',
#      'gender',
#      'date became customer',
#      'date last hire']},
#    {'table_name': 'bookings',
#     'columns': ['booking id',
#      'customer id',
#      'booking status code',
#      'returned damaged yes or no',
#      'booking start date',
#      'booking end date',
#      'count hired',
#      'amount payable',
#      'amount of discount',
#      'amount outstanding',
#      'amount of refund']},
#    {'table_name': 'products for hire',
#     'columns': ['product id',
#      'product type code',
#      'daily hire cost',
#      'product name',
#      'product description']},
#    {'table_name': 'payments',
#     'columns': ['payment id',
#      'booking id',
#      'customer id',
#      'payment type code',
#      'amount paid in full yn',
#      'payment date',
#      'amount due',
#      'amount paid']},
#    {'table_name': 'products booked',
#     'columns': ['booking id',
#      'product id',
#      'returned yes or no',
#      'returned late yes or no',
#      'booked count',
#      'booked amount']},
#    {'table_name': 'view product availability',
#     'columns': ['product id',
#      'booking id',
#      'status date',
#      'available yes or no']}]},
#  'candidate_poll': {'database_name': 'candidate_poll',
#   'tables': [{'table_name': 'candidate',
#     'columns': ['candidate id',
#      'people id',
#      'poll source',
#      'date',
#      'support rate',
#      'consider rate',
#      'oppose rate',
#      'unsure rate']},
#    {'table_name': 'people',
#     'columns': ['people id',
#      'sex',
#      'name',
#      'date of birth',
#      'height',
#      'weight']}]},
#  'chinook_1': {'database_name': 'chinook_1',
#   'tables': [{'table_name': 'album',
#     'columns': ['album id', 'title', 'artist id']},
#    {'table_name': 'artist', 'columns': ['artist id', 'name']},
#    {'table_name': 'customer',
#     'columns': ['customer id',
#      'first name',
#      'last name',
#      'company',
#      'address',
#      'city',
#      'state',
#      'country',
#      'postal code',
#      'phone',
#      'fax',
#      'email',
#      'support representative id']},
#    {'table_name': 'employee',
#     'columns': ['employee id',
#      'last name',
#      'first name',
#      'title',
#      'reports to',
#      'birth date',
#      'hire date',
#      'address',
#      'city',
#      'state',
#      'country',
#      'postal code',
#      'phone',
#      'fax',
#      'email']},
#    {'table_name': 'genre', 'columns': ['genre id', 'name']},
#    {'table_name': 'invoice',
#     'columns': ['invoice id',
#      'customer id',
#      'invoice date',
#      'billing address',
#      'billing city',
#      'billing state',
#      'billing country',
#      'billing postal code',
#      'total']},
#    {'table_name': 'invoice line',
#     'columns': ['invoice line id',
#      'invoice id',
#      'track id',
#      'unit price',
#      'quantity']},
#    {'table_name': 'media type', 'columns': ['media type id', 'name']},
#    {'table_name': 'playlist', 'columns': ['play list id', 'name']},
#    {'table_name': 'playlist track', 'columns': ['play list id', 'track id']},
#    {'table_name': 'track',
#     'columns': ['track id',
#      'name',
#      'album id',
#      'media type id',
#      'genre id',
#      'composer',
#      'milliseconds',
#      'bytes',
#      'unit price']}]},
#  'flight_4': {'database_name': 'flight_4',
#   'tables': [{'table_name': 'routes',
#     'columns': ['route id',
#      'destination airport id',
#      'destination airport',
#      'source airport id',
#      'source airport',
#      'airline id',
#      'airline',
#      'code share']},
#    {'table_name': 'airports',
#     'columns': ['airport id',
#      'name',
#      'city',
#      'country',
#      'x',
#      'y',
#      'elevation',
#      'iata',
#      'icao']},
#    {'table_name': 'airlines',
#     'columns': ['airline id',
#      'name',
#      'iata',
#      'icao',
#      'call sign',
#      'country',
#      'active']}]},
#  'pets_1': {'database_name': 'pets_1',
#   'tables': [{'table_name': 'student',
#     'columns': ['student id',
#      'last name',
#      'first name',
#      'age',
#      'sex',
#      'major',
#      'advisor',
#      'city code']},
#    {'table_name': 'has pet', 'columns': ['student id', 'pet id']},
#    {'table_name': 'pets',
#     'columns': ['pet id', 'pet type', 'pet age', 'weight']}]},
#  'dorm_1': {'database_name': 'dorm_1',
#   'tables': [{'table_name': 'student',
#     'columns': ['student id',
#      'last name',
#      'first name',
#      'age',
#      'sex',
#      'major',
#      'advisor',
#      'city code']},
#    {'table_name': 'dorm',
#     'columns': ['dorm id', 'dorm name', 'student capacity', 'gender']},
#    {'table_name': 'dorm amenity', 'columns': ['amenity id', 'amenity name']},
#    {'table_name': 'has amenity', 'columns': ['dorm id', 'amenity id']},
#    {'table_name': 'lives in',
#     'columns': ['student id', 'dorm id', 'room number']}]},
#  'journal_committee': {'database_name': 'journal_committee',
#   'tables': [{'table_name': 'journal',
#     'columns': ['journal id', 'date', 'theme', 'sales']},
#    {'table_name': 'editor', 'columns': ['editor id', 'name', 'age']},
#    {'table_name': 'journal committee',
#     'columns': ['editor id', 'journal id', 'work type']}]},
#  'flight_1': {'database_name': 'flight_1',
#   'tables': [{'table_name': 'flight',
#     'columns': ['flight number',
#      'origin',
#      'destination',
#      'distance',
#      'departure date',
#      'arrival date',
#      'price',
#      'airline id']},
#    {'table_name': 'aircraft', 'columns': ['airline id', 'name', 'distance']},
#    {'table_name': 'employee', 'columns': ['employee id', 'name', 'salary']},
#    {'table_name': 'certificate', 'columns': ['employee id', 'airline id']}]},
#  'medicine_enzyme_interaction': {'database_name': 'medicine_enzyme_interaction',
#   'tables': [{'table_name': 'medicine',
#     'columns': ['id', 'name', 'trade name', 'fda approved']},
#    {'table_name': 'enzyme',
#     'columns': ['id',
#      'name',
#      'location',
#      'product',
#      'chromosome',
#      'omim',
#      'porphyria']},
#    {'table_name': 'medicine enzyme interaction',
#     'columns': ['enzyme id', 'medicine id', 'interaction type']}]},
#  'local_govt_and_lot': {'database_name': 'local_govt_and_lot',
#   'tables': [{'table_name': 'customers',
#     'columns': ['customer id', 'customer details']},
#    {'table_name': 'properties',
#     'columns': ['property id',
#      'property type code',
#      'property address',
#      'other details']},
#    {'table_name': 'residents',
#     'columns': ['resident id',
#      'property id',
#      'date moved in',
#      'date moved out',
#      'other details']},
#    {'table_name': 'organizations',
#     'columns': ['organization id',
#      'parent organization id',
#      'organization details']},
#    {'table_name': 'services',
#     'columns': ['service id',
#      'organization id',
#      'service type code',
#      'service details']},
#    {'table_name': 'residents services',
#     'columns': ['resident id',
#      'service id',
#      'date moved in',
#      'property id',
#      'date requested',
#      'date provided',
#      'other details']},
#    {'table_name': 'things',
#     'columns': ['thing id',
#      'organization id',
#      'type of thing code',
#      'service type code',
#      'service details']},
#    {'table_name': 'customer events',
#     'columns': ['customer event id',
#      'customer id',
#      'date moved in',
#      'property id',
#      'resident id',
#      'thing id']},
#    {'table_name': 'customer event notes',
#     'columns': ['customer event note id',
#      'customer event id',
#      'service type code',
#      'resident id',
#      'property id',
#      'date moved in']},
#    {'table_name': 'timed status of things',
#     'columns': ['thing id', 'date and date', 'status of thing code']},
#    {'table_name': 'timed locations of things',
#     'columns': ['thing id', 'date and time', 'location code']}]},
#  'station_weather': {'database_name': 'station_weather',
#   'tables': [{'table_name': 'train',
#     'columns': ['id',
#      'train number',
#      'name',
#      'origin',
#      'destination',
#      'time',
#      'interval']},
#    {'table_name': 'station',
#     'columns': ['id', 'network name', 'services', 'local authority']},
#    {'table_name': 'route', 'columns': ['train id', 'station id']},
#    {'table_name': 'weekly weather',
#     'columns': ['station id',
#      'day of week',
#      'high temperature',
#      'low temperature',
#      'precipitation',
#      'wind speed mph']}]},
#  'shop_membership': {'database_name': 'shop_membership',
#   'tables': [{'table_name': 'member',
#     'columns': ['member id', 'card number', 'name', 'hometown', 'level']},
#    {'table_name': 'branch',
#     'columns': ['branch id',
#      'name',
#      'open year',
#      'address road',
#      'city',
#      'membership amount']},
#    {'table_name': 'membership register branch',
#     'columns': ['member id', 'branch id', 'register year']},
#    {'table_name': 'purchase',
#     'columns': ['member id', 'branch id', 'year', 'total pounds']}]},
#  'driving_school': {'database_name': 'driving_school',
#   'tables': [{'table_name': 'addresses',
#     'columns': ['address id',
#      'line 1 number building',
#      'city',
#      'zip postcode',
#      'state province county',
#      'country']},
#    {'table_name': 'staff',
#     'columns': ['staff id',
#      'staff address id',
#      'nickname',
#      'first name',
#      'middle name',
#      'last name',
#      'date of birth',
#      'date joined staff',
#      'date left staff']},
#    {'table_name': 'vehicles', 'columns': ['vehicle id', 'vehicle details']},
#    {'table_name': 'customers',
#     'columns': ['customer id',
#      'customer address id',
#      'customer status code',
#      'date became customer',
#      'date of birth',
#      'first name',
#      'last name',
#      'amount outstanding',
#      'email address',
#      'phone number',
#      'cell mobile phone number']},
#    {'table_name': 'customer payments',
#     'columns': ['customer id',
#      'datetime payment',
#      'payment method code',
#      'amount payment']},
#    {'table_name': 'lessons',
#     'columns': ['lesson id',
#      'customer id',
#      'lesson status code',
#      'staff id',
#      'vehicle id',
#      'lesson date',
#      'lesson time',
#      'price']}]},
#  'concert_singer': {'database_name': 'concert_singer',
#   'tables': [{'table_name': 'stadium',
#     'columns': ['stadium id',
#      'location',
#      'name',
#      'capacity',
#      'highest',
#      'lowest',
#      'average']},
#    {'table_name': 'singer',
#     'columns': ['singer id',
#      'name',
#      'country',
#      'song name',
#      'song release year',
#      'age',
#      'is male']},
#    {'table_name': 'concert',
#     'columns': ['concert id', 'concert name', 'theme', 'stadium id', 'year']},
#    {'table_name': 'singer in concert',
#     'columns': ['concert id', 'singer id']}]},
#  'music_2': {'database_name': 'music_2',
#   'tables': [{'table_name': 'songs', 'columns': ['song id', 'title']},
#    {'table_name': 'albums',
#     'columns': ['aid', 'title', 'year', 'label', 'type']},
#    {'table_name': 'band', 'columns': ['id', 'first name', 'last name']},
#    {'table_name': 'instruments',
#     'columns': ['song id', 'bandmate id', 'instrument']},
#    {'table_name': 'performance',
#     'columns': ['song id', 'bandmate', 'stage position']},
#    {'table_name': 'track lists',
#     'columns': ['album id', 'position', 'song id']},
#    {'table_name': 'vocals', 'columns': ['song id', 'bandmate', 'type']}]},
#  'sports_competition': {'database_name': 'sports_competition',
#   'tables': [{'table_name': 'club',
#     'columns': ['club id', 'name', 'region', 'start year']},
#    {'table_name': 'club rank',
#     'columns': ['rank', 'club id', 'gold', 'silver', 'bronze', 'total']},
#    {'table_name': 'player',
#     'columns': ['player id',
#      'name',
#      'position',
#      'club id',
#      'apps',
#      'tries',
#      'goals',
#      'points']},
#    {'table_name': 'competition',
#     'columns': ['competition id', 'year', 'competition type', 'country']},
#    {'table_name': 'competition result',
#     'columns': ['competition id', 'club id 1', 'club id 2', 'score']}]},
#  'railway': {'database_name': 'railway',
#   'tables': [{'table_name': 'railway',
#     'columns': ['railway id',
#      'railway',
#      'builder',
#      'built',
#      'wheels',
#      'location',
#      'objectnumber']},
#    {'table_name': 'train',
#     'columns': ['train id',
#      'train num',
#      'name',
#      'from',
#      'arrival',
#      'railway id']},
#    {'table_name': 'manager',
#     'columns': ['manager id',
#      'name',
#      'country',
#      'working year starts',
#      'age',
#      'level']},
#    {'table_name': 'railway manage',
#     'columns': ['railway id', 'manager id', 'from year']}]},
#  'inn_1': {'database_name': 'inn_1',
#   'tables': [{'table_name': 'rooms',
#     'columns': ['room id',
#      'room name',
#      'beds',
#      'bed type',
#      'max occupancy',
#      'base price',
#      'decor']},
#    {'table_name': 'reservations',
#     'columns': ['code',
#      'room',
#      'check in',
#      'check out',
#      'rate',
#      'last name',
#      'first name',
#      'adults',
#      'kids']}]},
#  'museum_visit': {'database_name': 'museum_visit',
#   'tables': [{'table_name': 'museum',
#     'columns': ['museum id', 'name', 'num of staff', 'open year']},
#    {'table_name': 'customer',
#     'columns': ['customer id', 'name', 'level of membership', 'age']},
#    {'table_name': 'visit',
#     'columns': ['museum id', 'customer id', 'num of ticket', 'total spent']}]},
#  'browser_web': {'database_name': 'browser_web',
#   'tables': [{'table_name': 'web client accelerator',
#     'columns': ['id', 'name', 'operating system', 'client', 'connection']},
#    {'table_name': 'browser', 'columns': ['id', 'name', 'market share']},
#    {'table_name': 'accelerator compatible browser',
#     'columns': ['accelerator id', 'browser id', 'compatible since year']}]},
#  'baseball_1': {'database_name': 'baseball_1',
#   'tables': [{'table_name': 'all star',
#     'columns': ['player id',
#      'year',
#      'game num',
#      'game id',
#      'team id',
#      'league id',
#      'gp',
#      'starting pos']},
#    {'table_name': 'appearances',
#     'columns': ['year',
#      'team id',
#      'league id',
#      'player id',
#      'g all',
#      'gs',
#      'g batting',
#      'g defense',
#      'g p',
#      'g c',
#      'g 1b',
#      'g 2b',
#      'g 3b',
#      'g ss',
#      'g lf',
#      'g cf',
#      'g rf',
#      'g of',
#      'g dh',
#      'g ph',
#      'g pr']},
#    {'table_name': 'manager award',
#     'columns': ['player id', 'award id', 'year', 'league id', 'tie', 'notes']},
#    {'table_name': 'player award',
#     'columns': ['player id', 'award id', 'year', 'league id', 'tie', 'notes']},
#    {'table_name': 'manager award vote',
#     'columns': ['award id',
#      'year',
#      'league id',
#      'player id',
#      'points won',
#      'points max',
#      'votes first']},
#    {'table_name': 'player award vote',
#     'columns': ['award id',
#      'year',
#      'league id',
#      'player id',
#      'points won',
#      'points max',
#      'votes first']},
#    {'table_name': 'batting',
#     'columns': ['player id',
#      'year',
#      'stint',
#      'team id',
#      'league id',
#      'g',
#      'ab',
#      'r',
#      'h',
#      'double',
#      'triple',
#      'hr',
#      'rbi',
#      'sb',
#      'cs',
#      'bb',
#      'so',
#      'ibb',
#      'hbp',
#      'sh',
#      'sf',
#      'g idp']},
#    {'table_name': 'batting postseason',
#     'columns': ['year',
#      'round',
#      'player id',
#      'team id',
#      'league id',
#      'g',
#      'ab',
#      'r',
#      'h',
#      'double',
#      'triple',
#      'hr',
#      'rbi',
#      'sb',
#      'cs',
#      'bb',
#      'so',
#      'ibb',
#      'hbp',
#      'sh',
#      'sf',
#      'g idp']},
#    {'table_name': 'player college',
#     'columns': ['player id', 'college id', 'year']},
#    {'table_name': 'fielding',
#     'columns': ['player id',
#      'year',
#      'stint',
#      'team id',
#      'league id',
#      'pos',
#      'g',
#      'gs',
#      'inn outs',
#      'po',
#      'a',
#      'e',
#      'dp',
#      'pb',
#      'wp',
#      'sb',
#      'cs',
#      'zr']},
#    {'table_name': 'fielding outfield',
#     'columns': ['player id', 'year', 'stint', 'glf', 'gcf', 'grf']},
#    {'table_name': 'fielding postseason',
#     'columns': ['player id',
#      'year',
#      'team id',
#      'league id',
#      'round',
#      'pos',
#      'g',
#      'gs',
#      'inn outs',
#      'po',
#      'a',
#      'e',
#      'dp',
#      'tp',
#      'pb',
#      'sb',
#      'cs']},
#    {'table_name': 'hall of fame',
#     'columns': ['player id',
#      'yearid',
#      'votedby',
#      'ballots',
#      'needed',
#      'votes',
#      'inducted',
#      'category',
#      'needed note']},
#    {'table_name': 'home game',
#     'columns': ['year',
#      'league id',
#      'team id',
#      'park id',
#      'span first',
#      'span last',
#      'games',
#      'openings',
#      'attendance']},
#    {'table_name': 'manager',
#     'columns': ['player id',
#      'year',
#      'team id',
#      'league id',
#      'inseason',
#      'g',
#      'w',
#      'l',
#      'rank',
#      'plyr mgr']},
#    {'table_name': 'manager half',
#     'columns': ['player id',
#      'year',
#      'team id',
#      'league id',
#      'inseason',
#      'half',
#      'g',
#      'w',
#      'l',
#      'rank']},
#    {'table_name': 'player',
#     'columns': ['player id',
#      'birth year',
#      'birth month',
#      'birth day',
#      'birth country',
#      'birth state',
#      'birth city',
#      'death year',
#      'death month',
#      'death day',
#      'death country',
#      'death state',
#      'death city',
#      'name first',
#      'name last',
#      'name given',
#      'weight',
#      'height',
#      'bats',
#      'throws',
#      'debut',
#      'final game',
#      'retro id',
#      'bbref id']},
#    {'table_name': 'park',
#     'columns': ['park id',
#      'park name',
#      'park alias',
#      'city',
#      'state',
#      'country']},
#    {'table_name': 'pitching',
#     'columns': ['player id',
#      'year',
#      'stint',
#      'team id',
#      'league id',
#      'w',
#      'l',
#      'g',
#      'gs',
#      'cg',
#      'sho',
#      'sv',
#      'ipouts',
#      'h',
#      'er',
#      'hr',
#      'bb',
#      'so',
#      'baopp',
#      'era',
#      'ibb',
#      'wp',
#      'hbp',
#      'bk',
#      'bfp',
#      'gf',
#      'r',
#      'sh',
#      'sf',
#      'g idp']},
#    {'table_name': 'pitching postseason',
#     'columns': ['player id',
#      'year',
#      'round',
#      'team id',
#      'league id',
#      'w',
#      'l',
#      'g',
#      'gs',
#      'cg',
#      'sho',
#      'sv',
#      'ipouts',
#      'h',
#      'er',
#      'hr',
#      'bb',
#      'so',
#      'baopp',
#      'era',
#      'ibb',
#      'wp',
#      'hbp',
#      'bk',
#      'bfp',
#      'gf',
#      'r',
#      'sh',
#      'sf',
#      'g idp']},
#    {'table_name': 'salary',
#     'columns': ['year', 'team id', 'league id', 'player id', 'salary']},
#    {'table_name': 'college',
#     'columns': ['college id', 'name full', 'city', 'state', 'country']},
#    {'table_name': 'postseason',
#     'columns': ['year',
#      'round',
#      'team id winner',
#      'league id winner',
#      'team id loser',
#      'league id loser',
#      'wins',
#      'losses',
#      'ties']},
#    {'table_name': 'team',
#     'columns': ['year',
#      'league id',
#      'team id',
#      'franchise id',
#      'div id',
#      'rank',
#      'g',
#      'ghome',
#      'w',
#      'l',
#      'div win',
#      'wc win',
#      'lg win',
#      'ws win',
#      'r',
#      'ab',
#      'h',
#      'double',
#      'triple',
#      'hr',
#      'bb',
#      'so',
#      'sb',
#      'cs',
#      'hbp',
#      'sf',
#      'ra',
#      'er',
#      'era',
#      'cg',
#      'sho',
#      'sv',
#      'ipouts',
#      'ha',
#      'hra',
#      'bba',
#      'soa',
#      'e',
#      'dp',
#      'fp',
#      'name',
#      'park',
#      'attendance',
#      'bpf',
#      'ppf',
#      'team id br',
#      'team id lahman45',
#      'team id retro']},
#    {'table_name': 'team franchise',
#     'columns': ['franchise id', 'franchise name', 'active', 'na assoc']},
#    {'table_name': 'team half',
#     'columns': ['year',
#      'league id',
#      'team id',
#      'half',
#      'div id',
#      'div win',
#      'rank',
#      'g',
#      'w',
#      'l']}]},
#  'architecture': {'database_name': 'architecture',
#   'tables': [{'table_name': 'architect',
#     'columns': ['id', 'name', 'nationality', 'gender']},
#    {'table_name': 'bridge',
#     'columns': ['architect id',
#      'id',
#      'name',
#      'location',
#      'length meters',
#      'length feet']},
#    {'table_name': 'mill',
#     'columns': ['architect id',
#      'id',
#      'location',
#      'name',
#      'type',
#      'built year',
#      'notes']}]},
#  'csu_1': {'database_name': 'csu_1',
#   'tables': [{'table_name': 'campuses',
#     'columns': ['id', 'campus', 'location', 'county', 'year']},
#    {'table_name': 'csu fees', 'columns': ['campus', 'year', 'campus fee']},
#    {'table_name': 'degrees', 'columns': ['year', 'campus', 'degrees']},
#    {'table_name': 'discipline enrollments',
#     'columns': ['campus', 'discipline', 'year', 'undergraduate', 'graduate']},
#    {'table_name': 'enrollments',
#     'columns': ['campus', 'year', 'totalenrollment ay', 'fte ay']},
#    {'table_name': 'faculty', 'columns': ['campus', 'year', 'faculty']}]},
#  'tracking_orders': {'database_name': 'tracking_orders',
#   'tables': [{'table_name': 'customers',
#     'columns': ['customer id', 'customer name', 'customer details']},
#    {'table_name': 'invoices',
#     'columns': ['invoice number', 'invoice date', 'invoice details']},
#    {'table_name': 'orders',
#     'columns': ['order id',
#      'customer id',
#      'order status',
#      'date order placed',
#      'order details']},
#    {'table_name': 'products',
#     'columns': ['product id', 'product name', 'product details']},
#    {'table_name': 'order items',
#     'columns': ['order item id',
#      'product id',
#      'order id',
#      'order item status',
#      'order item details']},
#    {'table_name': 'shipments',
#     'columns': ['shipment id',
#      'order id',
#      'invoice number',
#      'shipment tracking number',
#      'shipment date',
#      'other shipment details']},
#    {'table_name': 'shipment items',
#     'columns': ['shipment id', 'order item id']}]},
#  'insurance_policies': {'database_name': 'insurance_policies',
#   'tables': [{'table_name': 'customers',
#     'columns': ['customer id', 'customer details']},
#    {'table_name': 'customer policies',
#     'columns': ['policy id',
#      'customer id',
#      'policy type code',
#      'start date',
#      'end date']},
#    {'table_name': 'claims',
#     'columns': ['claim id',
#      'policy id',
#      'date claim made',
#      'date claim settled',
#      'amount claimed',
# ...
#      'other details']},
#    {'table_name': 'employees',
#     'columns': ['employee id',
#      'role code',
#      'employee name',
#      'gender mfu',
#      'date of birth',
#      'other details']},
#    {'table_name': 'document locations',
#     'columns': ['document id',
#      'location code',
#      'date in location from',
#      'date in locaton to']},
#    {'table_name': 'documents to be destroyed',
#     'columns': ['document id',
#      'destruction authorised by employee id',
#      'destroyed by employee id',
#      'planned destruction date',
#      'actual destruction date',
#      'other details']}]},
#  'university_basketball': {'database_name': 'university_basketball',
#   'tables': [{'table_name': 'basketball match',
#     'columns': ['team id',
#      'school id',
#      'team name',
#      'acc regular season',
#      'acc percent',
#      'acc home',
#      'acc road',
#      'all games',
#      'all games percent',
#      'all home',
#      'all road',
#      'all neutral']},
#    {'table_name': 'university',
#     'columns': ['school id',
#      'school',
#      'location',
#      'founded',
#      'affiliation',
#      'enrollment',
#      'nickname',
#      'primary conference']}]},
#  'soccer_2': {'database_name': 'soccer_2',
#   'tables': [{'table_name': 'college',
#     'columns': ['college name', 'state', 'enrollment']},
#    {'table_name': 'player',
#     'columns': ['player id', 'player name', 'yes card', 'training hours']},
#    {'table_name': 'tryout',
#     'columns': ['player id', 'college name', 'player position', 'decision']}]},
#  'activity_1': {'database_name': 'activity_1',
#   'tables': [{'table_name': 'activity',
#     'columns': ['activity id', 'activity name']},
#    {'table_name': 'participates in', 'columns': ['student id', 'activity id']},
#    {'table_name': 'faculty participates in',
#     'columns': ['faculty id', 'activity id']},
#    {'table_name': 'student',
#     'columns': ['student id',
#      'last name',
#      'first name',
#      'age',
#      'sex',
#      'major',
#      'advisor',
#      'city code']},
#    {'table_name': 'faculty',
#     'columns': ['faculty id',
#      'last name',
#      'first name',
#      'rank',
#      'sex',
#      'phone',
#      'room',
#      'building']}]},
#  'cre_Theme_park': {'database_name': 'cre_Theme_park',
#   'tables': [{'table_name': 'ref hotel star ratings',
#     'columns': ['star rating code', 'star rating description']},
#    {'table_name': 'locations',
#     'columns': ['location id', 'location name', 'address', 'other details']},
#    {'table_name': 'ref attraction types',
#     'columns': ['attraction type code', 'attraction type description']},
#    {'table_name': 'visitors', 'columns': ['tourist id', 'tourist details']},
#    {'table_name': 'features', 'columns': ['feature id', 'feature details']},
#    {'table_name': 'hotels',
#     'columns': ['hotel id',
#      'star rating code',
#      'pets allowed yn',
#      'price range',
#      'other hotel details']},
#    {'table_name': 'tourist attractions',
#     'columns': ['tourist attraction id',
#      'attraction type code',
#      'location id',
#      'how to get there',
#      'name',
#      'description',
#      'opening hours',
#      'other details']},
#    {'table_name': 'street markets',
#     'columns': ['market id', 'market details']},
#    {'table_name': 'shops', 'columns': ['shop id', 'shop details']},
#    {'table_name': 'museums', 'columns': ['museum id', 'museum details']},
#    {'table_name': 'royal family',
#     'columns': ['royal family id', 'royal family details']},
#    {'table_name': 'theme parks',
#     'columns': ['theme park id', 'theme park details']},
#    {'table_name': 'visits',
#     'columns': ['visit id',
#      'tourist attraction id',
#      'tourist id',
#      'visit date',
#      'visit details']},
#    {'table_name': 'photos',
#     'columns': ['photo id',
#      'tourist attraction id',
#      'name',
#      'description',
#      'filename',
#      'other details']},
#    {'table_name': 'staff',
#     'columns': ['staff id', 'tourist attraction id', 'name', 'other details']},
#    {'table_name': 'tourist attraction features',
#     'columns': ['tourist attraction id', 'feature id']}]},
#  'twitter_1': {'database_name': 'twitter_1',
#   'tables': [{'table_name': 'follows', 'columns': ['user id', 'follower id']},
#    {'table_name': 'tweets',
#     'columns': ['id', 'user id', 'text', 'create date']},
#    {'table_name': 'user profiles',
#     'columns': ['uid', 'name', 'email', 'partition id', 'followers']}]},
#  'election_representative': {'database_name': 'election_representative',
#   'tables': [{'table_name': 'election',
#     'columns': ['election id',
#      'representative id',
#      'date',
#      'votes',
#      'vote percent',
#      'seats',
#      'place']},
#    {'table_name': 'representative',
#     'columns': ['representative id', 'name', 'state', 'party', 'lifespan']}]},
#  'voter_2': {'database_name': 'voter_2',
#   'tables': [{'table_name': 'student',
#     'columns': ['student id',
#      'last name',
#      'first name',
#      'age',
#      'sex',
#      'major',
#      'advisor',
#      'city code']},
#    {'table_name': 'voting record',
#     'columns': ['student id',
#      'registration date',
#      'election cycle',
#      'president vote',
#      'vice president vote',
#      'secretary vote',
#      'treasurer vote',
#      'class president vote',
#      'class senator vote']}]},
#  'wedding': {'database_name': 'wedding',
#   'tables': [{'table_name': 'people',
#     'columns': ['people id', 'name', 'country', 'is male', 'age']},
#    {'table_name': 'church',
#     'columns': ['church id',
#      'name',
#      'organized by',
#      'open date',
#      'continuation of']},
#    {'table_name': 'wedding',
#     'columns': ['church id', 'male id', 'female id', 'year']}]},
#  'news_report': {'database_name': 'news_report',
#   'tables': [{'table_name': 'event',
#     'columns': ['event id', 'date', 'venue', 'name', 'event attendance']},
#    {'table_name': 'journalist',
#     'columns': ['journalist id',
#      'name',
#      'nationality',
#      'age',
#      'years working']},
#    {'table_name': 'news report',
#     'columns': ['journalist id', 'event id', 'work type']}]},
#  'wine_1': {'database_name': 'wine_1',
#   'tables': [{'table_name': 'grapes', 'columns': ['id', 'grape', 'color']},
#    {'table_name': 'appellations',
#     'columns': ['no', 'appelation', 'county', 'state', 'area', 'isava']},
#    {'table_name': 'wine',
#     'columns': ['no',
#      'grape',
#      'winery',
#      'appelation',
#      'state',
#      'name',
#      'year',
#      'price',
#      'score',
#      'cases',
#      'drink']}]},
#  'customers_and_addresses': {'database_name': 'customers_and_addresses',
#   'tables': [{'table_name': 'addresses',
#     'columns': ['address id',
#      'address content',
#      'city',
#      'zip postcode',
#      'state province county',
#      'country',
#      'other address details']},
#    {'table_name': 'products', 'columns': ['product id', 'product details']},
#    {'table_name': 'customers',
#     'columns': ['customer id',
#      'payment method',
#      'customer name',
#      'date became customer',
#      'other customer details']},
#    {'table_name': 'customer addresses',
#     'columns': ['customer id',
#      'address id',
#      'date address from',
#      'address type',
#      'date address to']},
#    {'table_name': 'customer contact channels',
#     'columns': ['customer id',
#      'channel code',
#      'active from date',
#      'active to date',
#      'contact number']},
#    {'table_name': 'customer orders',
#     'columns': ['order id',
#      'customer id',
#      'order status',
#      'order date',
#      'order details']},
#    {'table_name': 'order items',
#     'columns': ['order id', 'product id', 'order quantity']}]},
#  'protein_institute': {'database_name': 'protein_institute',
#   'tables': [{'table_name': 'building',
#     'columns': ['building id',
#      'name',
#      'street address',
#      'years as tallest',
#      'height feet',
#      'floors']},
#    {'table_name': 'institution',
#     'columns': ['institution id',
#      'institution',
#      'location',
#      'founded',
#      'type',
#      'enrollment',
#      'team',
#      'primary conference',
#      'building id']},
#    {'table_name': 'protein',
#     'columns': ['common name',
#      'protein name',
#      'divergence from human lineage',
#      'accession number',
#      'sequence length',
#      'sequence identity to human protein',
#      'institution id']}]},
#  'school_player': {'database_name': 'school_player',
#   'tables': [{'table_name': 'school',
#     'columns': ['school id',
#      'school',
#      'location',
#      'enrollment',
#      'founded',
#      'denomination',
#      'boys or girls',
#      'day or boarding',
#      'year entered competition',
#      'school colors']},
#    {'table_name': 'school details',
#     'columns': ['school id',
#      'nickname',
#      'colors',
#      'league',
#      'class',
#      'division']},
#    {'table_name': 'school performance',
#     'columns': ['school id', 'school year', 'class a', 'class aa']},
#    {'table_name': 'player',
#     'columns': ['player id',
#      'player',
#      'team',
#      'age',
#      'position',
#      'school id']}]},
#  'phone_1': {'database_name': 'phone_1',
#   'tables': [{'table_name': 'chip model',
#     'columns': ['model name',
#      'launch year',
#      'ram mib',
#      'rom mib',
#      'slots',
#      'wifi',
#      'bluetooth']},
#    {'table_name': 'screen mode',
#     'columns': ['graphics mode',
#      'char cells',
#      'pixels',
#      'hardware colours',
#      'used kb',
#      'map',
#      'type']},
#    {'table_name': 'phone',
#     'columns': ['company name',
#      'hardware model name',
#      'accreditation type',
#      'accreditation level',
#      'date',
#      'chip model',
#      'screen mode']}]},
#  'tvshow': {'database_name': 'tvshow',
#   'tables': [{'table_name': 'tv channel',
#     'columns': ['id',
#      'series name',
#      'country',
#      'language',
#      'content',
#      'pixel aspect ratio par',
#      'hight definition tv',
#      'pay per view ppv',
#      'package option']},
#    {'table_name': 'tv series',
#     'columns': ['id',
#      'episode',
#      'air date',
#      'rating',
#      'share',
#      '18 49 rating share',
#      'viewers m',
#      'weekly rank',
#      'channel']},
#    {'table_name': 'cartoon',
#     'columns': ['id',
#      'title',
#      'directed by',
#      'written by',
#      'original air date',
#      'production code',
#      'channel']}]},
#  'wrestler': {'database_name': 'wrestler',
#   'tables': [{'table_name': 'wrestler',
#     'columns': ['wrestler id',
#      'name',
#      'reign',
#      'days held',
#      'location',
#      'event']},
#    {'table_name': 'elimination',
#     'columns': ['elimination id',
#      'wrestler id',
#      'team',
#      'eliminated by',
#      'elimination move',
#      'time']}]},
#  'customer_complaints': {'database_name': 'customer_complaints',
#   'tables': [{'table_name': 'staff',
#     'columns': ['staff id',
#      'gender',
#      'first name',
#      'last name',
#      'email address',
#      'phone number']},
#    {'table_name': 'customers',
#     'columns': ['customer id',
#      'customer type code',
#      'address line 1',
#      'address line 2',
#      'town city',
#      'state',
#      'email address',
#      'phone number']},
#    {'table_name': 'products',
#     'columns': ['product id',
#      'parent product id',
#      'product category code',
#      'date product first available',
#      'date product discontinued',
#      'product name',
#      'product description',
#      'product price']},
#    {'table_name': 'complaints',
#     'columns': ['complaint id',
#      'product id',
#      'customer id',
#      'complaint outcome code',
#      'complaint status code',
#      'complaint type code',
#      'date complaint raised',
#      'date complaint closed',
#      'staff id']}]},
#  'department_management': {'database_name': 'department_management',
#   'tables': [{'table_name': 'department',
#     'columns': ['department id',
#      'name',
#      'creation',
#      'ranking',
#      'budget in billions',
#      'num employees']},
#    {'table_name': 'head', 'columns': ['head id', 'name', 'born state', 'age']},
#    {'table_name': 'management',
#     'columns': ['department id', 'head id', 'temporary acting']}]},
#  'customers_and_products_contacts': {'database_name': 'customers_and_products_contacts',
#   'tables': [{'table_name': 'addresses',
#     'columns': ['address id',
#      'line 1 number building',
#      'city',
#      'zip postcode',
#      'state province county',
#      'country']},
#    {'table_name': 'products',
#     'columns': ['product id',
#      'product type code',
#      'product name',
#      'product price']},
#    {'table_name': 'customers',
#     'columns': ['customer id',
#      'payment method code',
#      'customer number',
#      'customer name',
#      'customer address',
#      'customer phone',
#      'customer email']},
#    {'table_name': 'contacts',
#     'columns': ['contact id',
#      'customer id',
#      'gender',
#      'first name',
#      'last name',
#      'contact phone']},
#    {'table_name': 'customer address history',
#     'columns': ['customer id', 'address id', 'date from', 'date to']},
#    {'table_name': 'customer orders',
#     'columns': ['order id', 'customer id', 'order date', 'order status code']},
#    {'table_name': 'order items',
#     'columns': ['order item id',
#      'order id',
#      'product id',
#      'order quantity']}]},
#  'company_1': {'database_name': 'company_1',
#   'tables': [{'table_name': 'works on',
#     'columns': ['employee ssn', 'project number', 'hours']},
#    {'table_name': 'employee',
#     'columns': ['first name',
#      'minit',
#      'last name',
#      'ssn',
#      'birth date',
#      'address',
#      'sex',
#      'salary',
#      'super ssn',
#      'department no']},
#    {'table_name': 'department',
#     'columns': ['department name',
#      'department number',
#      'manager ssn',
#      'manager start date']},
#    {'table_name': 'project',
#     'columns': ['dependent name',
#      'dependent number',
#      'dependent location',
#      'department number']},
#    {'table_name': 'dependent',
#     'columns': ['employee ssn',
#      'dependent name',
#      'sex',
#      'birth date',
#      'relationship']},
#    {'table_name': 'department locations',
#     'columns': ['department number', 'department location']}]},
#  'workshop_paper': {'database_name': 'workshop_paper',
#   'tables': [{'table_name': 'workshop',
#     'columns': ['workshop id', 'date', 'venue', 'name']},
#    {'table_name': 'submission',
#     'columns': ['submission id', 'scores', 'author', 'college']},
#    {'table_name': 'acceptance',
#     'columns': ['submission id', 'workshop id', 'result']}]},
#  'epinions_1': {'database_name': 'epinions_1',
#   'tables': [{'table_name': 'item', 'columns': ['item id', 'title']},
#    {'table_name': 'review',
#     'columns': ['a id', 'user id', 'item id', 'rating', 'rank']},
#    {'table_name': 'useracct', 'columns': ['user id', 'name']},
#    {'table_name': 'trust',
#     'columns': ['source user id', 'target user id', 'trust']}]},
#  'party_host': {'database_name': 'party_host',
#   'tables': [{'table_name': 'party',
#     'columns': ['party id',
#      'party theme',
#      'location',
#      'first year',
#      'last year',
#      'number of hosts']},
#    {'table_name': 'host',
#     'columns': ['host id', 'name', 'nationality', 'age']},
#    {'table_name': 'party host',
#     'columns': ['party id', 'host id', 'is main in charge']}]},
#  'product_catalog': {'database_name': 'product_catalog',
#   'tables': [{'table_name': 'attribute definitions',
#     'columns': ['attribute id', 'attribute name', 'attribute data type']},
#    {'table_name': 'catalogs',
#     'columns': ['catalog id',
#      'catalog name',
#      'catalog publisher',
#      'date of publication',
#      'date of latest revision']},
#    {'table_name': 'catalog structure',
#     'columns': ['catalog level number', 'catalog id', 'catalog level name']},
#    {'table_name': 'catalog contents',
#     'columns': ['catalog entry id',
#      'catalog level number',
#      'parent entry id',
#      'previous entry id',
#      'next entry id',
#      'catalog entry name',
#      'product stock number',
#      'price in dollars',
#      'price in euros',
#      'price in pounds',
#      'capacity',
#      'length',
#      'height',
#      'width']},
#    {'table_name': 'catalog contents additional attributes',
#     'columns': ['catalog entry id',
#      'catalog level number',
#      'attribute id',
#      'attribute value']}]}}

# %%
#Below function to finalise the format of the schema, into DB-TABLE-Column names format
def format_schema_jsonish(reshaped_essential_schemas):
    lines = []
    for _, db in reshaped_essential_schemas.items():
        db_name = db.get("database_name", "unknown")
        for t in db.get("tables", []):
            obj = {
                "database": db_name,
                "table": t.get("table_name", "unknown"),
                "columns": t.get("columns", [])
            }
            lines.append(json.dumps(obj, ensure_ascii=False, separators=(",", ":")))
    return lines

format_schema_jsonish(reshaped_schemas)
# Out:
# ['{"database":"perpetrator","table":"perpetrator","columns":["perpetrator id","people id","date","year","location","country","killed","injured"]}',
#  '{"database":"perpetrator","table":"people","columns":["people id","name","height","weight","home town"]}',
#  '{"database":"college_2","table":"classroom","columns":["building","room number","capacity"]}',
#  '{"database":"college_2","table":"department","columns":["department name","building","budget"]}',
#  '{"database":"college_2","table":"course","columns":["course id","title","department name","credits"]}',
#  '{"database":"college_2","table":"instructor","columns":["id","name","department name","salary"]}',
#  '{"database":"college_2","table":"section","columns":["course id","section id","semester","year","building","room number","time slot id"]}',
#  '{"database":"college_2","table":"teaches","columns":["id","course id","section id","semester","year"]}',
#  '{"database":"college_2","table":"student","columns":["id","name","department name","total credits"]}',
#  '{"database":"college_2","table":"takes classes","columns":["id","course id","section id","semester","year","grade"]}',
#  '{"database":"college_2","table":"advisor","columns":["student id","instructor id"]}',
#  '{"database":"college_2","table":"time slot","columns":["time slot id","day","start hour","start minute","end hour","end minute"]}',
#  '{"database":"college_2","table":"prerequisite","columns":["course id","prerequisite id"]}',
#  '{"database":"flight_company","table":"airport","columns":["id","city","country","iata","icao","name"]}',
#  '{"database":"flight_company","table":"operate company","columns":["id","name","type","principal activities","incorporated in","group equity shareholding"]}',
#  '{"database":"flight_company","table":"flight","columns":["id","vehicle flight number","date","pilot","velocity","altitude","airport id","company id"]}',
#  '{"database":"icfp_1","table":"institution","columns":["institution id","name","country"]}',
#  '{"database":"icfp_1","table":"authors","columns":["author id","last name","first name"]}',
#  '{"database":"icfp_1","table":"papers","columns":["paper id","title"]}',
#  '{"database":"icfp_1","table":"authorship count","columns":["author id","institution id","paper id","author count"]}',
#  '{"database":"body_builder","table":"body builder","columns":["body builder id","people id","snatch","clean jerk","total"]}',
#  '{"database":"body_builder","table":"people","columns":["people id","name","height","weight","birth date","birth place"]}',
#  '{"database":"storm_record","table":"storm","columns":["storm id","name","dates active","max speed","damage millions usd","number deaths"]}',
#  '{"database":"storm_record","table":"region","columns":["region id","region code","region name"]}',
#  '{"database":"storm_record","table":"affected region","columns":["region id","storm id","number city affected"]}',
#  '{"database":"pilot_record","table":"aircraft","columns":["aircraft id","order year","manufacturer","model","fleet series","powertrain","fuel propulsion"]}',
#  '{"database":"pilot_record","table":"pilot","columns":["pilot id","pilot name","rank","age","nationality","position","join year","team"]}',
#  '{"database":"pilot_record","table":"pilot record","columns":["record id","pilot id","aircraft id","date"]}',
#  '{"database":"race_track","table":"race","columns":["race id","name","class","date","track id"]}',
#  '{"database":"race_track","table":"track","columns":["track id","name","location","seating","year opened"]}',
#  '{"database":"academic","table":"author","columns":["aid","homepage","name","oid"]}',
#  '{"database":"academic","table":"conference","columns":["cid","homepage","name"]}',
#  '{"database":"academic","table":"domain","columns":["did","name"]}',
#  '{"database":"academic","table":"domain author","columns":["aid","did"]}',
#  '{"database":"academic","table":"domain conference","columns":["cid","did"]}',
#  '{"database":"academic","table":"journal","columns":["homepage","jid","name"]}',
#  '{"database":"academic","table":"domain journal","columns":["did","jid"]}',
#  '{"database":"academic","table":"keyword","columns":["keyword","kid"]}',
#  '{"database":"academic","table":"domain keyword","columns":["did","kid"]}',
#  '{"database":"academic","table":"publication","columns":["abstract","cid","citation num","jid","pid","reference num","title","year"]}',
#  '{"database":"academic","table":"domain publication","columns":["did","pid"]}',
#  '{"database":"academic","table":"organization","columns":["continent","homepage","name","oid"]}',
#  '{"database":"academic","table":"publication keyword","columns":["pid","kid"]}',
#  '{"database":"academic","table":"writes","columns":["aid","pid"]}',
#  '{"database":"academic","table":"cite","columns":["cited","citing"]}',
#  '{"database":"department_store","table":"addresses","columns":["address id","address details"]}',
#  '{"database":"department_store","table":"staff","columns":["staff id","staff gender","staff name"]}',
#  '{"database":"department_store","table":"suppliers","columns":["supplier id","supplier name","supplier phone"]}',
#  '{"database":"department_store","table":"department store chain","columns":["department store chain id","department store chain name"]}',
#  '{"database":"department_store","table":"customers","columns":["customer id","payment method code","customer code","customer name","customer address","customer phone","customer email"]}',
#  '{"database":"department_store","table":"products","columns":["product id","product type code","product name","product price"]}',
#  '{"database":"department_store","table":"supplier addresses","columns":["supplier id","address id","date from","date to"]}',
#  '{"database":"department_store","table":"customer addresses","columns":["customer id","address id","date from","date to"]}',
#  '{"database":"department_store","table":"customer orders","columns":["order id","customer id","order status code","order date"]}',
#  '{"database":"department_store","table":"department stores","columns":["department store id","department store chain id","store name","store address","store phone","store email"]}',
#  '{"database":"department_store","table":"departments","columns":["department id","department store id","department name"]}',
#  '{"database":"department_store","table":"order items","columns":["order item id","order id","product id"]}',
#  '{"database":"department_store","table":"product suppliers","columns":["product id","supplier id","date supplied from","date supplied to","total amount purchased","total value purchased"]}',
#  '{"database":"department_store","table":"staff department assignments","columns":["staff id","department id","date assigned from","job title code","date assigned to"]}',
#  '{"database":"music_4","table":"artist","columns":["artist id","artist","age","famous title","famous release date"]}',
#  '{"database":"music_4","table":"volume","columns":["volume id","volume issue","issue date","weeks on top","song","artist id"]}',
#  '{"database":"music_4","table":"music festival","columns":["id","music festival","date of ceremony","category","volume","result"]}',
#  '{"database":"insurance_fnol","table":"customers","columns":["customer id","customer name"]}',
#  '{"database":"insurance_fnol","table":"services","columns":["service id","service name"]}',
#  '{"database":"insurance_fnol","table":"available policies","columns":["policy id","policy type code","customer phone"]}',
#  '{"database":"insurance_fnol","table":"customers policies","columns":["customer id","policy id","date opened","date closed"]}',
#  '{"database":"insurance_fnol","table":"first notification of loss","columns":["fnol id","customer id","policy id","service id"]}',
#  '{"database":"insurance_fnol","table":"claims","columns":["claim id","fnol id","effective date"]}',
#  '{"database":"insurance_fnol","table":"settlements","columns":["settlement id","claim id","effective date","settlement amount"]}',
#  '{"database":"cinema","table":"film","columns":["film id","rank in series","number in season","title","directed by","original air date","production code"]}',
#  '{"database":"cinema","table":"cinema","columns":["cinema id","name","openning year","capacity","location"]}',
#  '{"database":"cinema","table":"schedule","columns":["cinema id","film id","date","show times per day","price"]}',
#  '{"database":"decoration_competition","table":"college","columns":["college id","name","leader name","college location"]}',
#  '{"database":"decoration_competition","table":"member","columns":["member id","name","country","college id"]}',
#  '{"database":"decoration_competition","table":"round","columns":["round id","member id","decoration theme","rank in round"]}',
#  '{"database":"phone_market","table":"phone","columns":["name","phone id","memory in g","carrier","price"]}',
#  '{"database":"phone_market","table":"market","columns":["market id","district","num of employees","num of shops","ranking"]}',
#  '{"database":"phone_market","table":"phone market","columns":["market id","phone id","num of stock"]}',
#  '{"database":"store_product","table":"product","columns":["product id","product","dimensions","dpi","pages per minute color","max page size","interface"]}',
#  '{"database":"store_product","table":"store","columns":["store id","store name","type","area size","number of product category","ranking"]}',
#  '{"database":"store_product","table":"district","columns":["district id","district name","headquartered city","city population","city area"]}',
#  '{"database":"store_product","table":"store product","columns":["store id","product id"]}',
#  '{"database":"store_product","table":"store district","columns":["store id","district id"]}',
#  '{"database":"assets_maintenance","table":"third party companies","columns":["company id","company type","company name","company address","other company details"]}',
#  '{"database":"assets_maintenance","table":"maintenance contracts","columns":["maintenance contract id","maintenance contract company id","contract start date","contract end date","other contract details"]}',
#  '{"database":"assets_maintenance","table":"parts","columns":["part id","part name","chargeable yn","chargeable amount","other part details"]}',
#  '{"database":"assets_maintenance","table":"skills","columns":["skill id","skill code","skill description"]}',
#  '{"database":"assets_maintenance","table":"staff","columns":["staff id","staff name","gender","other staff details"]}',
#  '{"database":"assets_maintenance","table":"assets","columns":["asset id","maintenance contract id","supplier company id","asset details","asset make","asset model","asset acquired date","asset disposed date","other asset details"]}',
#  '{"database":"assets_maintenance","table":"asset parts","columns":["asset id","part id"]}',
#  '{"database":"assets_maintenance","table":"maintenance engineers","columns":["engineer id","company id","first name","last name","other details"]}',
#  '{"database":"assets_maintenance","table":"engineer skills","columns":["engineer id","skill id"]}',
#  '{"database":"assets_maintenance","table":"fault log","columns":["fault log entry id","asset id","recorded by staff id","fault log entry datetime","fault description","other fault details"]}',
#  '{"database":"assets_maintenance","table":"engineer visits","columns":["engineer visit id","contact staff id","engineer id","fault log entry id","fault status","visit start datetime","visit end datetime","other visit details"]}',
#  '{"database":"assets_maintenance","table":"part faults","columns":["part fault id","part id","fault short name","fault description","other fault details"]}',
#  '{"database":"assets_maintenance","table":"fault log parts","columns":["fault log entry id","part fault id","fault status"]}',
#  '{"database":"assets_maintenance","table":"skills required to fix","columns":["part fault id","skill id"]}',
#  '{"database":"student_assessment","table":"addresses","columns":["address id","line 1","line 2","city","zip postcode","state province county","country"]}',
#  '{"database":"student_assessment","table":"people","columns":["person id","first name","middle name","last name","cell mobile number","email address","login name","password"]}',
#  '{"database":"student_assessment","table":"students","columns":["student id","student details"]}',
#  '{"database":"student_assessment","table":"courses","columns":["course id","course name","course description","other details"]}',
#  '{"database":"student_assessment","table":"people addresses","columns":["person address id","person id","address id","date from","date to"]}',
#  '{"database":"student_assessment","table":"student course registrations","columns":["student id","course id","registration date"]}',
#  '{"database":"student_assessment","table":"student course attendance","columns":["student id","course id","date of attendance"]}',
#  '{"database":"student_assessment","table":"candidates","columns":["candidate id","candidate details"]}',
#  '{"database":"student_assessment","table":"candidate assessments","columns":["candidate id","qualification","assessment date","asessment outcome code"]}',
#  '{"database":"dog_kennels","table":"breeds","columns":["breed code","breed name"]}',
#  '{"database":"dog_kennels","table":"charges","columns":["charge id","charge type","charge amount"]}',
#  '{"database":"dog_kennels","table":"sizes","columns":["size code","size description"]}',
#  '{"database":"dog_kennels","table":"treatment types","columns":["treatment type code","treatment type description"]}',
#  '{"database":"dog_kennels","table":"owners","columns":["owner id","first name","last name","street","city","state","zip code","email address","home phone","cell number"]}',
#  '{"database":"dog_kennels","table":"dogs","columns":["dog id","owner id","abandoned yes or no","breed code","size code","name","age","date of birth","gender","weight","date arrived","date adopted","date departed"]}',
#  '{"database":"dog_kennels","table":"professionals","columns":["professional id","role code","first name","street","city","state","zip code","last name","email address","home phone","cell number"]}',
#  '{"database":"dog_kennels","table":"treatments","columns":["treatment id","dog id","professional id","treatment type code","date of treatment","cost of treatment"]}',
#  '{"database":"music_1","table":"genre","columns":["genre name","rating","most popular in"]}',
#  '{"database":"music_1","table":"artist","columns":["artist name","country","gender","preferred genre"]}',
#  '{"database":"music_1","table":"files","columns":["song id","artist name","file size","duration","formats"]}',
#  '{"database":"music_1","table":"song","columns":["song name","artist name","country","song id","genre is","rating","languages","releasedate","resolution"]}',
#  '{"database":"company_employee","table":"people","columns":["people id","age","name","nationality","graduation college"]}',
#  '{"database":"company_employee","table":"company","columns":["company id","name","headquarters","industry","sales in billion","profits in billion","assets in billion","market value in billion"]}',
#  '{"database":"company_employee","table":"employment","columns":["company id","people id","year working"]}',
#  '{"database":"farm","table":"city","columns":["city id","official name","status","area km 2","population","census ranking"]}',
#  '{"database":"farm","table":"farm","columns":["farm id","year","total horses","working horses","total cattle","oxen","bulls","cows","pigs","sheep and goats"]}',
#  '{"database":"farm","table":"farm competition","columns":["competition id","year","theme","host city id","hosts"]}',
#  '{"database":"farm","table":"competition record","columns":["competition id","farm id","rank"]}',
#  '{"database":"solvency_ii","table":"addresses","columns":["address id","address details"]}',
#  '{"database":"solvency_ii","table":"locations","columns":["location id","other details"]}',
#  '{"database":"solvency_ii","table":"products","columns":["product id","product type code","product name","product price"]}',
#  '{"database":"solvency_ii","table":"parties","columns":["party id","party details"]}',
#  '{"database":"solvency_ii","table":"assets","columns":["asset id","other details"]}',
#  '{"database":"solvency_ii","table":"channels","columns":["channel id","other details"]}',
#  '{"database":"solvency_ii","table":"finances","columns":["finance id","other details"]}',
#  '{"database":"solvency_ii","table":"events","columns":["event id","address id","channel id","event type code","finance id","location id"]}',
#  '{"database":"solvency_ii","table":"products in events","columns":["product in event id","event id","product id"]}',
#  '{"database":"solvency_ii","table":"parties in events","columns":["party id","event id","role code"]}',
#  '{"database":"solvency_ii","table":"agreements","columns":["document id","event id"]}',
#  '{"database":"solvency_ii","table":"assets in events","columns":["asset id","event id"]}',
#  '{"database":"city_record","table":"city","columns":["city id","city","hanzi","hanyu pinyin","regional population","gdp"]}',
#  '{"database":"city_record","table":"match","columns":["match id","date","venue","score","result","competition"]}',
#  '{"database":"city_record","table":"temperature","columns":["city id","jan","feb","mar","apr","jun","jul","aug","sep","oct","nov","dec"]}',
#  '{"database":"city_record","table":"hosting city","columns":["year","match id","host city"]}',
#  '{"database":"swimming","table":"swimmer","columns":["id","name","nationality","meter 100","meter 200","meter 300","meter 400","meter 500","meter 600","meter 700","time"]}',
#  '{"database":"swimming","table":"stadium","columns":["id","name","capacity","city","country","opening year"]}',
#  '{"database":"swimming","table":"event","columns":["id","name","stadium id","year"]}',
#  '{"database":"swimming","table":"record","columns":["id","result","swimmer id","event id"]}',
#  '{"database":"flight_2","table":"airlines","columns":["airline id","airline name","abbreviation","country"]}',
#  '{"database":"flight_2","table":"airports","columns":["city","airport code","airport name","country","country abbrev"]}',
#  '{"database":"flight_2","table":"flights","columns":["airline","flight number","source airport","destination airport"]}',
#  '{"database":"election","table":"county","columns":["county id","county name","population","zip code"]}',
#  '{"database":"election","table":"party","columns":["party id","year","party","governor","lieutenant governor","comptroller","attorney general","us senate"]}',
#  '{"database":"election","table":"election","columns":["election id","counties represented","district","delegate","party","first elected","committee"]}',
#  '{"database":"manufactory_1","table":"manufacturers","columns":["code","name","headquarter","founder","revenue"]}',
#  '{"database":"manufactory_1","table":"products","columns":["code","name","price","manufacturer"]}',
#  '{"database":"debate","table":"people","columns":["people id","district","name","party","age"]}',
#  '{"database":"debate","table":"debate","columns":["debate id","date","venue","num of audience"]}',
#  '{"database":"debate","table":"debate people","columns":["debate id","affirmative","negative","if affirmative win"]}',
#  '{"database":"network_2","table":"person","columns":["name","age","city","gender","job"]}',
#  '{"database":"network_2","table":"person friend","columns":["name","friend","year"]}',
#  '{"database":"local_govt_in_alabama","table":"services","columns":["service id","service type code"]}',
#  '{"database":"local_govt_in_alabama","table":"participants","columns":["participant id","participant type code","participant details"]}',
#  '{"database":"local_govt_in_alabama","table":"events","columns":["event id","service id","event details"]}',
#  '{"database":"local_govt_in_alabama","table":"participants in events","columns":["event id","participant id"]}',
#  '{"database":"climbing","table":"mountain","columns":["mountain id","name","height","prominence","range","country"]}',
#  '{"database":"climbing","table":"climber","columns":["climber id","name","country","time","points","mountain id"]}',
#  '{"database":"e_learning","table":"course authors and tutors","columns":["author id","author tutor atb","login name","password","personal name","middle name","family name","gender mf","address line 1"]}',
#  '{"database":"e_learning","table":"students","columns":["student id","date of registration","date of latest logon","login name","password","personal name","middle name","family name"]}',
#  '{"database":"e_learning","table":"subjects","columns":["subject id","subject name"]}',
#  '{"database":"e_learning","table":"courses","columns":["course id","author id","subject id","course name","course description"]}',
#  '{"database":"e_learning","table":"student course enrolment","columns":["registration id","student id","course id","date of enrolment","date of completion"]}',
#  '{"database":"e_learning","table":"student tests taken","columns":["registration id","date test taken","test result"]}',
#  '{"database":"scientist_1","table":"scientists","columns":["ssn","name"]}',
#  '{"database":"scientist_1","table":"projects","columns":["code","name","hours"]}',
#  '{"database":"scientist_1","table":"assigned to","columns":["scientist","project"]}',
#  '{"database":"ship_1","table":"captain","columns":["captain id","name","ship id","age","class","rank"]}',
#  '{"database":"ship_1","table":"ship","columns":["ship id","name","type","built year","class","flag"]}',
#  '{"database":"entertainment_awards","table":"festival detail","columns":["festival id","festival name","chair name","location","year","num of audience"]}',
#  '{"database":"entertainment_awards","table":"artwork","columns":["artwork id","type","name"]}',
#  '{"database":"entertainment_awards","table":"nomination","columns":["artwork id","festival id","result"]}',
#  '{"database":"allergy_1","table":"allergy type","columns":["allergy name","allergy type"]}',
#  '{"database":"allergy_1","table":"has allergy","columns":["stuid","allergy"]}',
#  '{"database":"allergy_1","table":"student","columns":["stuid","last name","first name","age","sex","major","advisor","city code"]}',
#  '{"database":"imdb","table":"actor","columns":["aid","gender","name","nationality","birth city","birth year"]}',
#  '{"database":"imdb","table":"copyright","columns":["id","msid","cid"]}',
#  '{"database":"imdb","table":"cast","columns":["id","msid","aid","role"]}',
#  '{"database":"imdb","table":"genre","columns":["gid","genre"]}',
#  '{"database":"imdb","table":"classification","columns":["id","msid","gid"]}',
#  '{"database":"imdb","table":"company","columns":["id","name","country code"]}',
#  '{"database":"imdb","table":"director","columns":["did","gender","name","nationality","birth city","birth year"]}',
#  '{"database":"imdb","table":"producer","columns":["pid","gender","name","nationality","birth city","birth year"]}',
#  '{"database":"imdb","table":"directed by","columns":["id","msid","did"]}',
#  '{"database":"imdb","table":"keyword","columns":["id","keyword"]}',
#  '{"database":"imdb","table":"made by","columns":["id","msid","pid"]}',
#  '{"database":"imdb","table":"movie","columns":["mid","title","release year","title aka","budget"]}',
#  '{"database":"imdb","table":"tags","columns":["id","msid","kid"]}',
#  '{"database":"imdb","table":"tv series","columns":["sid","title","release year","num of seasons","num of episodes","title aka","budget"]}',
#  '{"database":"imdb","table":"writer","columns":["wid","gender","name","nationality","num of episodes","birth city","birth year"]}',
#  '{"database":"imdb","table":"written by","columns":["id","msid","wid"]}',
#  '{"database":"products_for_hire","table":"discount coupons","columns":["coupon id","date issued","coupon amount"]}',
#  '{"database":"products_for_hire","table":"customers","columns":["customer id","coupon id","good or bad customer","first name","last name","gender","date became customer","date last hire"]}',
#  '{"database":"products_for_hire","table":"bookings","columns":["booking id","customer id","booking status code","returned damaged yes or no","booking start date","booking end date","count hired","amount payable","amount of discount","amount outstanding","amount of refund"]}',
#  '{"database":"products_for_hire","table":"products for hire","columns":["product id","product type code","daily hire cost","product name","product description"]}',
#  '{"database":"products_for_hire","table":"payments","columns":["payment id","booking id","customer id","payment type code","amount paid in full yn","payment date","amount due","amount paid"]}',
#  '{"database":"products_for_hire","table":"products booked","columns":["booking id","product id","returned yes or no","returned late yes or no","booked count","booked amount"]}',
#  '{"database":"products_for_hire","table":"view product availability","columns":["product id","booking id","status date","available yes or no"]}',
#  '{"database":"candidate_poll","table":"candidate","columns":["candidate id","people id","poll source","date","support rate","consider rate","oppose rate","unsure rate"]}',
#  '{"database":"candidate_poll","table":"people","columns":["people id","sex","name","date of birth","height","weight"]}',
#  '{"database":"chinook_1","table":"album","columns":["album id","title","artist id"]}',
#  '{"database":"chinook_1","table":"artist","columns":["artist id","name"]}',
#  '{"database":"chinook_1","table":"customer","columns":["customer id","first name","last name","company","address","city","state","country","postal code","phone","fax","email","support representative id"]}',
#  '{"database":"chinook_1","table":"employee","columns":["employee id","last name","first name","title","reports to","birth date","hire date","address","city","state","country","postal code","phone","fax","email"]}',
#  '{"database":"chinook_1","table":"genre","columns":["genre id","name"]}',
#  '{"database":"chinook_1","table":"invoice","columns":["invoice id","customer id","invoice date","billing address","billing city","billing state","billing country","billing postal code","total"]}',
#  '{"database":"chinook_1","table":"invoice line","columns":["invoice line id","invoice id","track id","unit price","quantity"]}',
#  '{"database":"chinook_1","table":"media type","columns":["media type id","name"]}',
#  '{"database":"chinook_1","table":"playlist","columns":["play list id","name"]}',
#  '{"database":"chinook_1","table":"playlist track","columns":["play list id","track id"]}',
#  '{"database":"chinook_1","table":"track","columns":["track id","name","album id","media type id","genre id","composer","milliseconds","bytes","unit price"]}',
#  '{"database":"flight_4","table":"routes","columns":["route id","destination airport id","destination airport","source airport id","source airport","airline id","airline","code share"]}',
#  '{"database":"flight_4","table":"airports","columns":["airport id","name","city","country","x","y","elevation","iata","icao"]}',
#  '{"database":"flight_4","table":"airlines","columns":["airline id","name","iata","icao","call sign","country","active"]}',
#  '{"database":"pets_1","table":"student","columns":["student id","last name","first name","age","sex","major","advisor","city code"]}',
#  '{"database":"pets_1","table":"has pet","columns":["student id","pet id"]}',
#  '{"database":"pets_1","table":"pets","columns":["pet id","pet type","pet age","weight"]}',
#  '{"database":"dorm_1","table":"student","columns":["student id","last name","first name","age","sex","major","advisor","city code"]}',
#  '{"database":"dorm_1","table":"dorm","columns":["dorm id","dorm name","student capacity","gender"]}',
#  '{"database":"dorm_1","table":"dorm amenity","columns":["amenity id","amenity name"]}',
#  '{"database":"dorm_1","table":"has amenity","columns":["dorm id","amenity id"]}',
#  '{"database":"dorm_1","table":"lives in","columns":["student id","dorm id","room number"]}',
#  '{"database":"journal_committee","table":"journal","columns":["journal id","date","theme","sales"]}',
#  '{"database":"journal_committee","table":"editor","columns":["editor id","name","age"]}',
#  '{"database":"journal_committee","table":"journal committee","columns":["editor id","journal id","work type"]}',
#  '{"database":"flight_1","table":"flight","columns":["flight number","origin","destination","distance","departure date","arrival date","price","airline id"]}',
#  '{"database":"flight_1","table":"aircraft","columns":["airline id","name","distance"]}',
#  '{"database":"flight_1","table":"employee","columns":["employee id","name","salary"]}',
#  '{"database":"flight_1","table":"certificate","columns":["employee id","airline id"]}',
#  '{"database":"medicine_enzyme_interaction","table":"medicine","columns":["id","name","trade name","fda approved"]}',
#  '{"database":"medicine_enzyme_interaction","table":"enzyme","columns":["id","name","location","product","chromosome","omim","porphyria"]}',
#  '{"database":"medicine_enzyme_interaction","table":"medicine enzyme interaction","columns":["enzyme id","medicine id","interaction type"]}',
#  '{"database":"local_govt_and_lot","table":"customers","columns":["customer id","customer details"]}',
#  '{"database":"local_govt_and_lot","table":"properties","columns":["property id","property type code","property address","other details"]}',
#  '{"database":"local_govt_and_lot","table":"residents","columns":["resident id","property id","date moved in","date moved out","other details"]}',
#  '{"database":"local_govt_and_lot","table":"organizations","columns":["organization id","parent organization id","organization details"]}',
#  '{"database":"local_govt_and_lot","table":"services","columns":["service id","organization id","service type code","service details"]}',
#  '{"database":"local_govt_and_lot","table":"residents services","columns":["resident id","service id","date moved in","property id","date requested","date provided","other details"]}',
#  '{"database":"local_govt_and_lot","table":"things","columns":["thing id","organization id","type of thing code","service type code","service details"]}',
#  '{"database":"local_govt_and_lot","table":"customer events","columns":["customer event id","customer id","date moved in","property id","resident id","thing id"]}',
#  '{"database":"local_govt_and_lot","table":"customer event notes","columns":["customer event note id","customer event id","service type code","resident id","property id","date moved in"]}',
#  '{"database":"local_govt_and_lot","table":"timed status of things","columns":["thing id","date and date","status of thing code"]}',
#  '{"database":"local_govt_and_lot","table":"timed locations of things","columns":["thing id","date and time","location code"]}',
#  '{"database":"station_weather","table":"train","columns":["id","train number","name","origin","destination","time","interval"]}',
#  '{"database":"station_weather","table":"station","columns":["id","network name","services","local authority"]}',
#  '{"database":"station_weather","table":"route","columns":["train id","station id"]}',
#  '{"database":"station_weather","table":"weekly weather","columns":["station id","day of week","high temperature","low temperature","precipitation","wind speed mph"]}',
#  '{"database":"shop_membership","table":"member","columns":["member id","card number","name","hometown","level"]}',
#  '{"database":"shop_membership","table":"branch","columns":["branch id","name","open year","address road","city","membership amount"]}',
#  '{"database":"shop_membership","table":"membership register branch","columns":["member id","branch id","register year"]}',
#  '{"database":"shop_membership","table":"purchase","columns":["member id","branch id","year","total pounds"]}',
#  '{"database":"driving_school","table":"addresses","columns":["address id","line 1 number building","city","zip postcode","state province county","country"]}',
#  '{"database":"driving_school","table":"staff","columns":["staff id","staff address id","nickname","first name","middle name","last name","date of birth","date joined staff","date left staff"]}',
#  '{"database":"driving_school","table":"vehicles","columns":["vehicle id","vehicle details"]}',
#  '{"database":"driving_school","table":"customers","columns":["customer id","customer address id","customer status code","date became customer","date of birth","first name","last name","amount outstanding","email address","phone number","cell mobile phone number"]}',
#  '{"database":"driving_school","table":"customer payments","columns":["customer id","datetime payment","payment method code","amount payment"]}',
#  '{"database":"driving_school","table":"lessons","columns":["lesson id","customer id","lesson status code","staff id","vehicle id","lesson date","lesson time","price"]}',
#  '{"database":"concert_singer","table":"stadium","columns":["stadium id","location","name","capacity","highest","lowest","average"]}',
#  '{"database":"concert_singer","table":"singer","columns":["singer id","name","country","song name","song release year","age","is male"]}',
#  '{"database":"concert_singer","table":"concert","columns":["concert id","concert name","theme","stadium id","year"]}',
#  '{"database":"concert_singer","table":"singer in concert","columns":["concert id","singer id"]}',
#  '{"database":"music_2","table":"songs","columns":["song id","title"]}',
#  '{"database":"music_2","table":"albums","columns":["aid","title","year","label","type"]}',
#  '{"database":"music_2","table":"band","columns":["id","first name","last name"]}',
#  '{"database":"music_2","table":"instruments","columns":["song id","bandmate id","instrument"]}',
#  '{"database":"music_2","table":"performance","columns":["song id","bandmate","stage position"]}',
#  '{"database":"music_2","table":"track lists","columns":["album id","position","song id"]}',
#  '{"database":"music_2","table":"vocals","columns":["song id","bandmate","type"]}',
#  '{"database":"sports_competition","table":"club","columns":["club id","name","region","start year"]}',
#  '{"database":"sports_competition","table":"club rank","columns":["rank","club id","gold","silver","bronze","total"]}',
#  '{"database":"sports_competition","table":"player","columns":["player id","name","position","club id","apps","tries","goals","points"]}',
#  '{"database":"sports_competition","table":"competition","columns":["competition id","year","competition type","country"]}',
#  '{"database":"sports_competition","table":"competition result","columns":["competition id","club id 1","club id 2","score"]}',
#  '{"database":"railway","table":"railway","columns":["railway id","railway","builder","built","wheels","location","objectnumber"]}',
#  '{"database":"railway","table":"train","columns":["train id","train num","name","from","arrival","railway id"]}',
#  '{"database":"railway","table":"manager","columns":["manager id","name","country","working year starts","age","level"]}',
#  '{"database":"railway","table":"railway manage","columns":["railway id","manager id","from year"]}',
#  '{"database":"inn_1","table":"rooms","columns":["room id","room name","beds","bed type","max occupancy","base price","decor"]}',
#  '{"database":"inn_1","table":"reservations","columns":["code","room","check in","check out","rate","last name","first name","adults","kids"]}',
#  '{"database":"museum_visit","table":"museum","columns":["museum id","name","num of staff","open year"]}',
#  '{"database":"museum_visit","table":"customer","columns":["customer id","name","level of membership","age"]}',
#  '{"database":"museum_visit","table":"visit","columns":["museum id","customer id","num of ticket","total spent"]}',
#  '{"database":"browser_web","table":"web client accelerator","columns":["id","name","operating system","client","connection"]}',
#  '{"database":"browser_web","table":"browser","columns":["id","name","market share"]}',
#  '{"database":"browser_web","table":"accelerator compatible browser","columns":["accelerator id","browser id","compatible since year"]}',
#  '{"database":"baseball_1","table":"all star","columns":["player id","year","game num","game id","team id","league id","gp","starting pos"]}',
#  '{"database":"baseball_1","table":"appearances","columns":["year","team id","league id","player id","g all","gs","g batting","g defense","g p","g c","g 1b","g 2b","g 3b","g ss","g lf","g cf","g rf","g of","g dh","g ph","g pr"]}',
#  '{"database":"baseball_1","table":"manager award","columns":["player id","award id","year","league id","tie","notes"]}',
#  '{"database":"baseball_1","table":"player award","columns":["player id","award id","year","league id","tie","notes"]}',
#  '{"database":"baseball_1","table":"manager award vote","columns":["award id","year","league id","player id","points won","points max","votes first"]}',
#  '{"database":"baseball_1","table":"player award vote","columns":["award id","year","league id","player id","points won","points max","votes first"]}',
#  '{"database":"baseball_1","table":"batting","columns":["player id","year","stint","team id","league id","g","ab","r","h","double","triple","hr","rbi","sb","cs","bb","so","ibb","hbp","sh","sf","g idp"]}',
#  '{"database":"baseball_1","table":"batting postseason","columns":["year","round","player id","team id","league id","g","ab","r","h","double","triple","hr","rbi","sb","cs","bb","so","ibb","hbp","sh","sf","g idp"]}',
#  '{"database":"baseball_1","table":"player college","columns":["player id","college id","year"]}',
#  '{"database":"baseball_1","table":"fielding","columns":["player id","year","stint","team id","league id","pos","g","gs","inn outs","po","a","e","dp","pb","wp","sb","cs","zr"]}',
#  '{"database":"baseball_1","table":"fielding outfield","columns":["player id","year","stint","glf","gcf","grf"]}',
#  '{"database":"baseball_1","table":"fielding postseason","columns":["player id","year","team id","league id","round","pos","g","gs","inn outs","po","a","e","dp","tp","pb","sb","cs"]}',
#  '{"database":"baseball_1","table":"hall of fame","columns":["player id","yearid","votedby","ballots","needed","votes","inducted","category","needed note"]}',
#  '{"database":"baseball_1","table":"home game","columns":["year","league id","team id","park id","span first","span last","games","openings","attendance"]}',
#  '{"database":"baseball_1","table":"manager","columns":["player id","year","team id","league id","inseason","g","w","l","rank","plyr mgr"]}',
#  '{"database":"baseball_1","table":"manager half","columns":["player id","year","team id","league id","inseason","half","g","w","l","rank"]}',
#  '{"database":"baseball_1","table":"player","columns":["player id","birth year","birth month","birth day","birth country","birth state","birth city","death year","death month","death day","death country","death state","death city","name first","name last","name given","weight","height","bats","throws","debut","final game","retro id","bbref id"]}',
#  '{"database":"baseball_1","table":"park","columns":["park id","park name","park alias","city","state","country"]}',
#  '{"database":"baseball_1","table":"pitching","columns":["player id","year","stint","team id","league id","w","l","g","gs","cg","sho","sv","ipouts","h","er","hr","bb","so","baopp","era","ibb","wp","hbp","bk","bfp","gf","r","sh","sf","g idp"]}',
#  '{"database":"baseball_1","table":"pitching postseason","columns":["player id","year","round","team id","league id","w","l","g","gs","cg","sho","sv","ipouts","h","er","hr","bb","so","baopp","era","ibb","wp","hbp","bk","bfp","gf","r","sh","sf","g idp"]}',
#  '{"database":"baseball_1","table":"salary","columns":["year","team id","league id","player id","salary"]}',
#  '{"database":"baseball_1","table":"college","columns":["college id","name full","city","state","country"]}',
#  '{"database":"baseball_1","table":"postseason","columns":["year","round","team id winner","league id winner","team id loser","league id loser","wins","losses","ties"]}',
#  '{"database":"baseball_1","table":"team","columns":["year","league id","team id","franchise id","div id","rank","g","ghome","w","l","div win","wc win","lg win","ws win","r","ab","h","double","triple","hr","bb","so","sb","cs","hbp","sf","ra","er","era","cg","sho","sv","ipouts","ha","hra","bba","soa","e","dp","fp","name","park","attendance","bpf","ppf","team id br","team id lahman45","team id retro"]}',
#  '{"database":"baseball_1","table":"team franchise","columns":["franchise id","franchise name","active","na assoc"]}',
#  '{"database":"baseball_1","table":"team half","columns":["year","league id","team id","half","div id","div win","rank","g","w","l"]}',
#  '{"database":"architecture","table":"architect","columns":["id","name","nationality","gender"]}',
#  '{"database":"architecture","table":"bridge","columns":["architect id","id","name","location","length meters","length feet"]}',
#  '{"database":"architecture","table":"mill","columns":["architect id","id","location","name","type","built year","notes"]}',
#  '{"database":"csu_1","table":"campuses","columns":["id","campus","location","county","year"]}',
#  '{"database":"csu_1","table":"csu fees","columns":["campus","year","campus fee"]}',
#  '{"database":"csu_1","table":"degrees","columns":["year","campus","degrees"]}',
#  '{"database":"csu_1","table":"discipline enrollments","columns":["campus","discipline","year","undergraduate","graduate"]}',
#  '{"database":"csu_1","table":"enrollments","columns":["campus","year","totalenrollment ay","fte ay"]}',
#  '{"database":"csu_1","table":"faculty","columns":["campus","year","faculty"]}',
#  '{"database":"tracking_orders","table":"customers","columns":["customer id","customer name","customer details"]}',
#  '{"database":"tracking_orders","table":"invoices","columns":["invoice number","invoice date","invoice details"]}',
#  '{"database":"tracking_orders","table":"orders","columns":["order id","customer id","order status","date order placed","order details"]}',
#  '{"database":"tracking_orders","table":"products","columns":["product id","product name","product details"]}',
#  '{"database":"tracking_orders","table":"order items","columns":["order item id","product id","order id","order item status","order item details"]}',
#  '{"database":"tracking_orders","table":"shipments","columns":["shipment id","order id","invoice number","shipment tracking number","shipment date","other shipment details"]}',
#  '{"database":"tracking_orders","table":"shipment items","columns":["shipment id","order item id"]}',
#  '{"database":"insurance_policies","table":"customers","columns":["customer id","customer details"]}',
#  '{"database":"insurance_policies","table":"customer policies","columns":["policy id","customer id","policy type code","start date","end date"]}',
#  '{"database":"insurance_policies","table":"claims","columns":["claim id","policy id","date claim made","date claim settled","amount claimed","amount settled"]}',
#  '{"database":"insurance_policies","table":"settlements","columns":["settlement id","claim id","date claim made","date claim settled","amount claimed","amount settled","customer policy id"]}',
#  '{"database":"insurance_policies","table":"payments","columns":["payment id","settlement id","payment method code","date payment made","amount payment"]}',
#  '{"database":"gas_company","table":"company","columns":["company id","rank","company","headquarters","main industry","sales billion","profits billion","assets billion","market value"]}',
#  '{"database":"gas_company","table":"gas station","columns":["station id","open year","location","manager name","vice manager name","representative name"]}',
#  '{"database":"gas_company","table":"station company","columns":["station id","company id","rank of the year"]}',
#  '{"database":"e_government","table":"addresses","columns":["address id","line 1 number building","town city","zip postcode","state province county","country"]}',
#  '{"database":"e_government","table":"services","columns":["service id","service type code","service name","service descriptio"]}',
#  '{"database":"e_government","table":"forms","columns":["form id","form type code","service id","form number","form name","form description"]}',
#  '{"database":"e_government","table":"individuals","columns":["individual id","individual first name","individual middle name","inidividual phone","individual email","individual address","individual last name"]}',
#  '{"database":"e_government","table":"organizations","columns":["organization id","date formed","organization name","uk vat number"]}',
#  '{"database":"e_government","table":"parties","columns":["party id","payment method code","party phone","party email"]}',
#  '{"database":"e_government","table":"organization contact individuals","columns":["individual id","organization id","date contact from","date contact to"]}',
#  '{"database":"e_government","table":"party addresses","columns":["party id","address id","date address from","address type code","date address to"]}',
#  '{"database":"e_government","table":"party forms","columns":["party id","form id","date completion started","form status code","date fully completed"]}',
#  '{"database":"e_government","table":"party services","columns":["booking id","customer id","service id","service datetime","booking made date"]}',
#  '{"database":"school_bus","table":"driver","columns":["driver id","name","party","home city","age"]}',
#  '{"database":"school_bus","table":"school","columns":["school id","grade","school","location","type"]}',
#  '{"database":"school_bus","table":"school bus","columns":["school id","driver id","years working","if full time"]}',
#  '{"database":"machine_repair","table":"repair","columns":["repair id","name","launch date","notes"]}',
#  '{"database":"machine_repair","table":"machine","columns":["machine id","making year","class","team","machine series","value points","quality rank"]}',
#  '{"database":"machine_repair","table":"technician","columns":["technician id","name","team","starting year","age"]}',
#  '{"database":"machine_repair","table":"repair assignment","columns":["technician id","repair id","machine id"]}',
#  '{"database":"theme_gallery","table":"artist","columns":["artist id","name","country","year join","age"]}',
#  '{"database":"theme_gallery","table":"exhibition","columns":["exhibition id","year","theme","artist id","ticket price"]}',
#  '{"database":"theme_gallery","table":"exhibition record","columns":["exhibition id","date","attendance"]}',
#  '{"database":"film_rank","table":"film","columns":["film id","title","studio","director","gross in dollar"]}',
#  '{"database":"film_rank","table":"market","columns":["market id","country","number cities"]}',
#  '{"database":"film_rank","table":"film market estimation","columns":["estimation id","low estimate","high estimate","film id","type","market id","year"]}',
#  '{"database":"party_people","table":"region","columns":["region id","region name","date","label","format","catalogue"]}',
#  '{"database":"party_people","table":"party","columns":["party id","minister","took office","left office","region id","party name"]}',
#  '{"database":"party_people","table":"member","columns":["member id","member name","party id","in office"]}',
#  '{"database":"party_people","table":"party events","columns":["event id","event name","party id","member in charge id"]}',
#  '{"database":"hospital_1","table":"physician","columns":["employee id","name","position","ssn"]}',
#  '{"database":"hospital_1","table":"department","columns":["departmentid","name","head"]}',
#  '{"database":"hospital_1","table":"affiliated with","columns":["physician","department","primary affiliation"]}',
#  '{"database":"hospital_1","table":"procedures","columns":["code","name","cost"]}',
#  '{"database":"hospital_1","table":"trained in","columns":["physician","treatment","certification date","certification expires"]}',
#  '{"database":"hospital_1","table":"patient","columns":["ssn","name","address","phone","insurance id","pcp"]}',
#  '{"database":"hospital_1","table":"nurse","columns":["employee id","name","position","registered","ssn"]}',
#  '{"database":"hospital_1","table":"appointment","columns":["appointment id","patient","prep nurse","physician","start","end","examination room"]}',
#  '{"database":"hospital_1","table":"medication","columns":["code","name","brand","description"]}',
#  '{"database":"hospital_1","table":"prescribes","columns":["physician","patient","medication","date","appointment","dose"]}',
#  '{"database":"hospital_1","table":"block","columns":["block floor","block code"]}',
# ...
#  '{"database":"behavior_monitoring","table":"teachers","columns":["teacher id","address id","first name","middle name","last name","gender","cell mobile number","email address","other details"]}',
#  '{"database":"behavior_monitoring","table":"assessment notes","columns":["notes id","student id","teacher id","date of notes","text of notes","other details"]}',
#  '{"database":"behavior_monitoring","table":"behavior incident","columns":["incident id","incident type code","student id","date incident start","date incident end","incident summary","recommendations","other details"]}',
#  '{"database":"behavior_monitoring","table":"detention","columns":["detention id","detention type code","teacher id","datetime detention start","datetime detention end","detention summary","other details"]}',
#  '{"database":"behavior_monitoring","table":"student addresses","columns":["student id","address id","date address from","date address to","monthly rental","other details"]}',
#  '{"database":"behavior_monitoring","table":"students in detention","columns":["student id","detention id","incident id"]}',
#  '{"database":"cre_Doc_Tracking_DB","table":"reference document types","columns":["document type code","document type name","document type description"]}',
#  '{"database":"cre_Doc_Tracking_DB","table":"reference calendar","columns":["calendar date","day number"]}',
#  '{"database":"cre_Doc_Tracking_DB","table":"reference locations","columns":["location code","location name","location description"]}',
#  '{"database":"cre_Doc_Tracking_DB","table":"roles","columns":["role code","role name","role description"]}',
#  '{"database":"cre_Doc_Tracking_DB","table":"all documents","columns":["document id","date stored","document type code","document name","document description","other details"]}',
#  '{"database":"cre_Doc_Tracking_DB","table":"employees","columns":["employee id","role code","employee name","gender mfu","date of birth","other details"]}',
#  '{"database":"cre_Doc_Tracking_DB","table":"document locations","columns":["document id","location code","date in location from","date in locaton to"]}',
#  '{"database":"cre_Doc_Tracking_DB","table":"documents to be destroyed","columns":["document id","destruction authorised by employee id","destroyed by employee id","planned destruction date","actual destruction date","other details"]}',
#  '{"database":"university_basketball","table":"basketball match","columns":["team id","school id","team name","acc regular season","acc percent","acc home","acc road","all games","all games percent","all home","all road","all neutral"]}',
#  '{"database":"university_basketball","table":"university","columns":["school id","school","location","founded","affiliation","enrollment","nickname","primary conference"]}',
#  '{"database":"soccer_2","table":"college","columns":["college name","state","enrollment"]}',
#  '{"database":"soccer_2","table":"player","columns":["player id","player name","yes card","training hours"]}',
#  '{"database":"soccer_2","table":"tryout","columns":["player id","college name","player position","decision"]}',
#  '{"database":"activity_1","table":"activity","columns":["activity id","activity name"]}',
#  '{"database":"activity_1","table":"participates in","columns":["student id","activity id"]}',
#  '{"database":"activity_1","table":"faculty participates in","columns":["faculty id","activity id"]}',
#  '{"database":"activity_1","table":"student","columns":["student id","last name","first name","age","sex","major","advisor","city code"]}',
#  '{"database":"activity_1","table":"faculty","columns":["faculty id","last name","first name","rank","sex","phone","room","building"]}',
#  '{"database":"cre_Theme_park","table":"ref hotel star ratings","columns":["star rating code","star rating description"]}',
#  '{"database":"cre_Theme_park","table":"locations","columns":["location id","location name","address","other details"]}',
#  '{"database":"cre_Theme_park","table":"ref attraction types","columns":["attraction type code","attraction type description"]}',
#  '{"database":"cre_Theme_park","table":"visitors","columns":["tourist id","tourist details"]}',
#  '{"database":"cre_Theme_park","table":"features","columns":["feature id","feature details"]}',
#  '{"database":"cre_Theme_park","table":"hotels","columns":["hotel id","star rating code","pets allowed yn","price range","other hotel details"]}',
#  '{"database":"cre_Theme_park","table":"tourist attractions","columns":["tourist attraction id","attraction type code","location id","how to get there","name","description","opening hours","other details"]}',
#  '{"database":"cre_Theme_park","table":"street markets","columns":["market id","market details"]}',
#  '{"database":"cre_Theme_park","table":"shops","columns":["shop id","shop details"]}',
#  '{"database":"cre_Theme_park","table":"museums","columns":["museum id","museum details"]}',
#  '{"database":"cre_Theme_park","table":"royal family","columns":["royal family id","royal family details"]}',
#  '{"database":"cre_Theme_park","table":"theme parks","columns":["theme park id","theme park details"]}',
#  '{"database":"cre_Theme_park","table":"visits","columns":["visit id","tourist attraction id","tourist id","visit date","visit details"]}',
#  '{"database":"cre_Theme_park","table":"photos","columns":["photo id","tourist attraction id","name","description","filename","other details"]}',
#  '{"database":"cre_Theme_park","table":"staff","columns":["staff id","tourist attraction id","name","other details"]}',
#  '{"database":"cre_Theme_park","table":"tourist attraction features","columns":["tourist attraction id","feature id"]}',
#  '{"database":"twitter_1","table":"follows","columns":["user id","follower id"]}',
#  '{"database":"twitter_1","table":"tweets","columns":["id","user id","text","create date"]}',
#  '{"database":"twitter_1","table":"user profiles","columns":["uid","name","email","partition id","followers"]}',
#  '{"database":"election_representative","table":"election","columns":["election id","representative id","date","votes","vote percent","seats","place"]}',
#  '{"database":"election_representative","table":"representative","columns":["representative id","name","state","party","lifespan"]}',
#  '{"database":"voter_2","table":"student","columns":["student id","last name","first name","age","sex","major","advisor","city code"]}',
#  '{"database":"voter_2","table":"voting record","columns":["student id","registration date","election cycle","president vote","vice president vote","secretary vote","treasurer vote","class president vote","class senator vote"]}',
#  '{"database":"wedding","table":"people","columns":["people id","name","country","is male","age"]}',
#  '{"database":"wedding","table":"church","columns":["church id","name","organized by","open date","continuation of"]}',
#  '{"database":"wedding","table":"wedding","columns":["church id","male id","female id","year"]}',
#  '{"database":"news_report","table":"event","columns":["event id","date","venue","name","event attendance"]}',
#  '{"database":"news_report","table":"journalist","columns":["journalist id","name","nationality","age","years working"]}',
#  '{"database":"news_report","table":"news report","columns":["journalist id","event id","work type"]}',
#  '{"database":"wine_1","table":"grapes","columns":["id","grape","color"]}',
#  '{"database":"wine_1","table":"appellations","columns":["no","appelation","county","state","area","isava"]}',
#  '{"database":"wine_1","table":"wine","columns":["no","grape","winery","appelation","state","name","year","price","score","cases","drink"]}',
#  '{"database":"customers_and_addresses","table":"addresses","columns":["address id","address content","city","zip postcode","state province county","country","other address details"]}',
#  '{"database":"customers_and_addresses","table":"products","columns":["product id","product details"]}',
#  '{"database":"customers_and_addresses","table":"customers","columns":["customer id","payment method","customer name","date became customer","other customer details"]}',
#  '{"database":"customers_and_addresses","table":"customer addresses","columns":["customer id","address id","date address from","address type","date address to"]}',
#  '{"database":"customers_and_addresses","table":"customer contact channels","columns":["customer id","channel code","active from date","active to date","contact number"]}',
#  '{"database":"customers_and_addresses","table":"customer orders","columns":["order id","customer id","order status","order date","order details"]}',
#  '{"database":"customers_and_addresses","table":"order items","columns":["order id","product id","order quantity"]}',
#  '{"database":"protein_institute","table":"building","columns":["building id","name","street address","years as tallest","height feet","floors"]}',
#  '{"database":"protein_institute","table":"institution","columns":["institution id","institution","location","founded","type","enrollment","team","primary conference","building id"]}',
#  '{"database":"protein_institute","table":"protein","columns":["common name","protein name","divergence from human lineage","accession number","sequence length","sequence identity to human protein","institution id"]}',
#  '{"database":"school_player","table":"school","columns":["school id","school","location","enrollment","founded","denomination","boys or girls","day or boarding","year entered competition","school colors"]}',
#  '{"database":"school_player","table":"school details","columns":["school id","nickname","colors","league","class","division"]}',
#  '{"database":"school_player","table":"school performance","columns":["school id","school year","class a","class aa"]}',
#  '{"database":"school_player","table":"player","columns":["player id","player","team","age","position","school id"]}',
#  '{"database":"phone_1","table":"chip model","columns":["model name","launch year","ram mib","rom mib","slots","wifi","bluetooth"]}',
#  '{"database":"phone_1","table":"screen mode","columns":["graphics mode","char cells","pixels","hardware colours","used kb","map","type"]}',
#  '{"database":"phone_1","table":"phone","columns":["company name","hardware model name","accreditation type","accreditation level","date","chip model","screen mode"]}',
#  '{"database":"tvshow","table":"tv channel","columns":["id","series name","country","language","content","pixel aspect ratio par","hight definition tv","pay per view ppv","package option"]}',
#  '{"database":"tvshow","table":"tv series","columns":["id","episode","air date","rating","share","18 49 rating share","viewers m","weekly rank","channel"]}',
#  '{"database":"tvshow","table":"cartoon","columns":["id","title","directed by","written by","original air date","production code","channel"]}',
#  '{"database":"wrestler","table":"wrestler","columns":["wrestler id","name","reign","days held","location","event"]}',
#  '{"database":"wrestler","table":"elimination","columns":["elimination id","wrestler id","team","eliminated by","elimination move","time"]}',
#  '{"database":"customer_complaints","table":"staff","columns":["staff id","gender","first name","last name","email address","phone number"]}',
#  '{"database":"customer_complaints","table":"customers","columns":["customer id","customer type code","address line 1","address line 2","town city","state","email address","phone number"]}',
#  '{"database":"customer_complaints","table":"products","columns":["product id","parent product id","product category code","date product first available","date product discontinued","product name","product description","product price"]}',
#  '{"database":"customer_complaints","table":"complaints","columns":["complaint id","product id","customer id","complaint outcome code","complaint status code","complaint type code","date complaint raised","date complaint closed","staff id"]}',
#  '{"database":"department_management","table":"department","columns":["department id","name","creation","ranking","budget in billions","num employees"]}',
#  '{"database":"department_management","table":"head","columns":["head id","name","born state","age"]}',
#  '{"database":"department_management","table":"management","columns":["department id","head id","temporary acting"]}',
#  '{"database":"customers_and_products_contacts","table":"addresses","columns":["address id","line 1 number building","city","zip postcode","state province county","country"]}',
#  '{"database":"customers_and_products_contacts","table":"products","columns":["product id","product type code","product name","product price"]}',
#  '{"database":"customers_and_products_contacts","table":"customers","columns":["customer id","payment method code","customer number","customer name","customer address","customer phone","customer email"]}',
#  '{"database":"customers_and_products_contacts","table":"contacts","columns":["contact id","customer id","gender","first name","last name","contact phone"]}',
#  '{"database":"customers_and_products_contacts","table":"customer address history","columns":["customer id","address id","date from","date to"]}',
#  '{"database":"customers_and_products_contacts","table":"customer orders","columns":["order id","customer id","order date","order status code"]}',
#  '{"database":"customers_and_products_contacts","table":"order items","columns":["order item id","order id","product id","order quantity"]}',
#  '{"database":"company_1","table":"works on","columns":["employee ssn","project number","hours"]}',
#  '{"database":"company_1","table":"employee","columns":["first name","minit","last name","ssn","birth date","address","sex","salary","super ssn","department no"]}',
#  '{"database":"company_1","table":"department","columns":["department name","department number","manager ssn","manager start date"]}',
#  '{"database":"company_1","table":"project","columns":["dependent name","dependent number","dependent location","department number"]}',
#  '{"database":"company_1","table":"dependent","columns":["employee ssn","dependent name","sex","birth date","relationship"]}',
#  '{"database":"company_1","table":"department locations","columns":["department number","department location"]}',
#  '{"database":"workshop_paper","table":"workshop","columns":["workshop id","date","venue","name"]}',
#  '{"database":"workshop_paper","table":"submission","columns":["submission id","scores","author","college"]}',
#  '{"database":"workshop_paper","table":"acceptance","columns":["submission id","workshop id","result"]}',
#  '{"database":"epinions_1","table":"item","columns":["item id","title"]}',
#  '{"database":"epinions_1","table":"review","columns":["a id","user id","item id","rating","rank"]}',
#  '{"database":"epinions_1","table":"useracct","columns":["user id","name"]}',
#  '{"database":"epinions_1","table":"trust","columns":["source user id","target user id","trust"]}',
#  '{"database":"party_host","table":"party","columns":["party id","party theme","location","first year","last year","number of hosts"]}',
#  '{"database":"party_host","table":"host","columns":["host id","name","nationality","age"]}',
#  '{"database":"party_host","table":"party host","columns":["party id","host id","is main in charge"]}',
#  '{"database":"product_catalog","table":"attribute definitions","columns":["attribute id","attribute name","attribute data type"]}',
#  '{"database":"product_catalog","table":"catalogs","columns":["catalog id","catalog name","catalog publisher","date of publication","date of latest revision"]}',
#  '{"database":"product_catalog","table":"catalog structure","columns":["catalog level number","catalog id","catalog level name"]}',
#  '{"database":"product_catalog","table":"catalog contents","columns":["catalog entry id","catalog level number","parent entry id","previous entry id","next entry id","catalog entry name","product stock number","price in dollars","price in euros","price in pounds","capacity","length","height","width"]}',
#  '{"database":"product_catalog","table":"catalog contents additional attributes","columns":["catalog entry id","catalog level number","attribute id","attribute value"]}']

# %% [markdown]
# ### 1.5 Save Redefined Schemas

# %%
SCHEMA_OUTPUT_DIR = PROJECT_ROOT / "data" / "processed"
SCHEMA_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
SCHEMA_PROCESSED_FILE = SCHEMA_OUTPUT_DIR / "spider_schemas_processed.jsonl"  # output

# %%
def save_processed_schema(reshaped_essential_schemas, output_file):
    """Save formatted schema into a JSONL file (one table per line)."""
    lines = format_schema_jsonish(reshaped_essential_schemas)
    with open(output_file, "w", encoding="utf-8") as f:
        for line in lines:
            f.write(line + "\n")
    print(f"Saved {len(lines)} schema entries to {output_file}")

save_processed_schema(reshaped_schemas, SCHEMA_PROCESSED_FILE)
# Out:
# Saved 876 schema entries to /Users/lainemulvay/Desktop/Projects/UNI/Capstone/Explainable-Query-Interface-for-Relational-Databases/data/processed/spider_schemas_processed.jsonl

# %% [markdown]
# ### 1.6 Create and Save Schema Embeddings from Redefined Schema

# %%
EMBEDDINGS_FOLDER = SCHEMA_OUTPUT_DIR / "spider_schemas_embeddings"

# %%
# Load processed schema from JSONL
def load_processed_schema(input_file):
    """Load processed schema JSONL back into a list of strings."""
    with open(input_file, "r", encoding="utf-8") as f:
        lines = [line.strip() for line in f if line.strip()]
    return lines

# Use it
final_schema_result = load_processed_schema(SCHEMA_PROCESSED_FILE)
print(f"Loaded {len(final_schema_result)} entries from {SCHEMA_PROCESSED_FILE}")

# Step 1: create embeddings + vectorstore
embeddings = OpenAIEmbeddings()
vectorstore = FAISS.from_texts(final_schema_result, embeddings)

# Step 2: save embeddings
vectorstore.save_local(str(EMBEDDINGS_FOLDER))
print(f"Saved schema embeddings to {EMBEDDINGS_FOLDER}")
# Out:
# Loaded 876 entries from /Users/lainemulvay/Desktop/Projects/UNI/Capstone/Explainable-Query-Interface-for-Relational-Databases/data/processed/spider_schemas_processed.jsonl
# Saved schema embeddings to /Users/lainemulvay/Desktop/Projects/UNI/Capstone/Explainable-Query-Interface-for-Relational-Databases/data/processed/spider_schemas_embeddings

# %% [markdown]
# ### 1.7 Set up Agent A

# %%
def create_database_selection_agent(top_k):
    """Create the database selection agent using a prebuilt FAISS vectorstore"""
    
    prompt_db = PromptTemplate(
        input_variables=["query", "retrieved_schema"],
        template="""
Please select the single most relevant database and table to answer the user's query.

User query: {query}
Schema info: {retrieved_schema}

Respond **only** with a valid JSON object (no backticks, no extra text). 
The JSON must include the following keys: "db_name", "tables", "columns", and "reasons". 
Each key should appear on its own line for readability.

Example format:

{{
  "db_name": "...",
  "tables": ["..."],
  "columns": ["..."],
  "reasons": "..."
}}
"""
    )

    db_chain = prompt_db | llm

    def database_selection_agent(user_query, top_k, mode="medium"):
        # Retrieve relevant schemas
        relevant_docs = vectorstore.similarity_search_with_score(user_query, k=top_k)
        retrieved_schema = ""
        for doc, score in relevant_docs:
            retrieved_schema += f"score: {score:.4f}, content: {doc.page_content}\n"

        # Invoke LLM
        response = db_chain.invoke({
            "query": user_query,
            "retrieved_schema": retrieved_schema
        })

        # Parse JSON output safely
        llm_content = response.content if hasattr(response, "content") else str(response)
        try:
            parsed = json.loads(llm_content)
        except json.JSONDecodeError:
            parsed = {}

        # Transform retrieved_schema string into structured list
        structured_schema = []
        for doc, score in relevant_docs:
            try:
                schema_json = json.loads(doc.page_content)
                structured_schema.append({
                    "score": round(score, 4),
                    "database": schema_json.get("database"),
                    "table": schema_json.get("table"),
                    "columns": schema_json.get("columns", [])
                })
            except json.JSONDecodeError:
                structured_schema.append({
                    "score": round(score, 4),
                    "raw_content": doc.page_content
                })

        # Then in your return block
        if mode == "light":
            return parsed.get("db_name")
        elif mode == "medium":
            return {
                "retrieved_schema": structured_schema,
                "db_name": parsed.get("db_name"),
                "tables": parsed.get("tables", []),
                "columns": parsed.get("columns", []),
                "reasons": parsed.get("reasons", ""),
            }
        else:  # heavy
            return {
                "db_name": parsed.get("db_name"),
                "retrieved_schema": structured_schema,
                "tables": parsed.get("tables", []),
                "columns": parsed.get("columns", []),
                "reasons": parsed.get("reasons", ""),
                "llm_raw": response,
            }

    return database_selection_agent, vectorstore

# %% [markdown]
# ### 1.8 Apply Agent A

# %%
test_queries = [
    "Find the name of all students who were in the tryout sorted in alphabetic order",
    "Find the average price of all product clothes.",
    "Show the names of artworks in ascending order of the year they are nominated in.",
    "What is the name of the department with the student that has the lowest GPA?",
    "What are the names and years of the movies that has the top 3 highest rating star?",
    "How many students does each advisor have?",
    "Count flights departing from Dallas in 2017",
    "What are the distinct creation years of the departments managed by a secretary born in state 'Alabama'?",
    "List courses worth more than 3 credits and their departments",
    "For each customer, compute total order value and sort desc.",
    "select all the deaths caused by ship",
    "Show me information about singers and their concerts",
    "I want to see student enrollment data",
    "Find information about car manufacturers and models",
    "What data do you have about movies and actors?",
    "Show me employee salary information",
    "Which produce has the most complaints where the status are still open"
]

# %%
# Load embeddings/vectorstore from folder using the new function
vectorstore = load_schema_embeddings(EMBEDDINGS_FOLDER)

# Set up LLM
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
# Out:
# Embeddings loaded with 876 entries

# %%
def apply_database_selector(query_numbers=None, mode="medium"):
    """
    Apply the database selection agent to one or more queries.

    Parameters:
        query_numbers (list or int, optional): 
            - int: apply to that single test query (1-based index)
            - list of ints: apply to multiple test queries
            - None: apply to all test queries
        mode (str): "light", "medium", or "heavy" for the agent output
    """
    # Create the agent
    db_agent, vectorstore = create_database_selection_agent(top_k=5)
    
    print("="*60)
    print("APPLYING DATABASE SELECTION AGENT")
    print("="*60)
    
    # Determine which queries to run
    if query_numbers is None:
        query_indices = range(len(test_queries))
    elif isinstance(query_numbers, int):
        query_indices = [query_numbers - 1]
    else:
        query_indices = [i-1 for i in query_numbers]
    
    # Apply the agent to the selected queries
    for i in query_indices:
        query = test_queries[i]
        print(f"\nApplying to Query {i+1}: {query}")
        print("-" * 50)
        
        # Call the agent with the selected mode
        result = db_agent(query, top_k=5, mode=mode)
        
        print("Agent A Selection:")
        pprint.pprint(result)
        
        print("\n" + "="*60)

apply_database_selector(query_numbers=2, mode="medium")
# Out:
# ============================================================
# APPLYING DATABASE SELECTION AGENT
# ============================================================
#
# Applying to Query 2: Find the average price of all product clothes.
# --------------------------------------------------
# Agent A Selection:
# {'columns': ['product id',
#              'product type code',
#              'product name',
#              'product price'],
#  'db_name': 'department_store',
#  'reasons': 'This table contains the product price information specifically '
#             'for clothing products, which is needed to calculate the average '
#             'price.',
#  'retrieved_schema': [{'columns': ['product id',
#                                    'color code',
#                                    'product category code',
#                                    'product name',
#                                    'typical buying price',
#                                    'typical selling price',
#                                    'product description',
#                                    'other product details'],
#                        'database': 'products_gen_characteristics',
#                        'score': 0.5144,
#                        'table': 'products'},
#                       {'columns': ['product id',
#                                    'product',
#                                    'dimensions',
#                                    'dpi',
#                                    'pages per minute color',
#                                    'max page size',
#                                    'interface'],
#                        'database': 'store_product',
#                        'score': 0.5283,
#                        'table': 'product'},
#                       {'columns': ['product id',
#                                    'product name',
#                                    'product price',
#                                    'product description',
#                                    'other product service details'],
#                        'database': 'cre_Drama_Workshop_Groups',
#                        'score': 0.5485,
#                        'table': 'products'},
#                       {'columns': ['product id',
#                                    'product type code',
#                                    'product name',
#                                    'product price'],
#                        'database': 'department_store',
#                        'score': 0.5512,
#                        'table': 'products'},
#                       {'columns': ['product id',
#                                    'parent product id',
#                                    'production type code',
#                                    'unit price',
#                                    'product name',
#                                    'product color',
#                                    'product size'],
#                        'database': 'customers_and_invoices',
#                        'score': 0.5514,
#                        'table': 'products'}],
#  'tables': ['products']}
#
# ============================================================

# %% [markdown]
# ### 1.9 Test Agent A

# %%
# Pick every X questions
every_x_th = 250
questions_subset = sql_answers_df.iloc[::every_x_th]["question"]
print(f"Number of questions we are testing: {len(questions_subset)}")
print(f"Total number of questions: {len(sql_answers_df)}")
# Out:
# Number of questions we are testing: 28
# Total number of questions: 7000

# %%
def apply_agent_a_on_test_set(every_x_th):
    """
    Picks every Xth question from sql_answers_df, applies the database selection agent,
    and returns a list of results with question, db_name, and reason.
    Also prints a progress tracker showing how many questions have been processed out of the total.
    """
    questions_subset = sql_answers_df.iloc[::every_x_th].to_dict(orient="records")
    total = len(questions_subset)
    db_name_results = []

    for idx, item in enumerate(questions_subset, 1):
        question = item['question']
        #print(f"Question: {question}")
        # Database selection
        db_agent, _ = create_database_selection_agent(top_k=5)
        result_1 = db_agent(question, top_k=5)
        llm_output_1 = (
            result_1['llm_selection'].content
            if hasattr(result_1['llm_selection'], 'content')
            else str(result_1['llm_selection'])
        )
        #print(f"LLM Output: {llm_output_1}")
        llm_output_json = json.loads(llm_output_1)
        db_name = str(llm_output_json["db_name"])
        reason = llm_output_json.get("reasons", "")
        #print(f"DB Name: {db_name}")
        # Store results
        db_name_results.append({
            'question': question,
            'db_name': db_name,
            'reason': reason
        })
        # Progress tracker
        print(f"Applied Agent A (selected databases) on {idx}/{total} test questions")

    return db_name_results

# Call the function and print results
db_name_results = apply_agent_a_on_test_set(every_x_th)
print("-" * 50)
pprint.pprint(db_name_results[:5])
# Out:
# Applied Agent A (selected databases) on 1/28 test questions
# Applied Agent A (selected databases) on 2/28 test questions
# Applied Agent A (selected databases) on 3/28 test questions
# Applied Agent A (selected databases) on 4/28 test questions
# Applied Agent A (selected databases) on 5/28 test questions
# Applied Agent A (selected databases) on 6/28 test questions
# Applied Agent A (selected databases) on 7/28 test questions
# Applied Agent A (selected databases) on 8/28 test questions
# Applied Agent A (selected databases) on 9/28 test questions
# Applied Agent A (selected databases) on 10/28 test questions
# Applied Agent A (selected databases) on 11/28 test questions
# Applied Agent A (selected databases) on 12/28 test questions
# Applied Agent A (selected databases) on 13/28 test questions
# Applied Agent A (selected databases) on 14/28 test questions
# Applied Agent A (selected databases) on 15/28 test questions
# Applied Agent A (selected databases) on 16/28 test questions
# Applied Agent A (selected databases) on 17/28 test questions
# Applied Agent A (selected databases) on 18/28 test questions
# Applied Agent A (selected databases) on 19/28 test questions
# Applied Agent A (selected databases) on 20/28 test questions
# Applied Agent A (selected databases) on 21/28 test questions
# Applied Agent A (selected databases) on 22/28 test questions
# Applied Agent A (selected databases) on 23/28 test questions
# Applied Agent A (selected databases) on 24/28 test questions
# Applied Agent A (selected databases) on 25/28 test questions
# Applied Agent A (selected databases) on 26/28 test questions
# Applied Agent A (selected databases) on 27/28 test questions
# Applied Agent A (selected databases) on 28/28 test questions
# --------------------------------------------------
# [{'db_name': 'department_management',
#   'question': 'How many heads of the departments are older than 56 ?',
#   'reason': 'The query specifically asks about the heads of departments and '
#             "their ages, which is directly related to the 'head' table in the "
#             "'department_management' database."},
#  {'db_name': 'musical',
#   'question': 'Show names of actors and names of musicals they are in.',
#   'reason': "The 'actor' table contains actor names and their associated "
#             "musical IDs, which can be used to link to the 'musical' table for "
#             'musical names.'},
#  {'db_name': 'dorm_1',
#   'question': 'How many students does each advisor have?',
#   'reason': 'The student table contains the advisor information needed to '
#             'count how many students each advisor has.'},
#  {'db_name': 'race_track',
#   'question': 'What are the names and locations of all tracks?',
#   'reason': 'The query specifically asks for the names and locations of '
#             "tracks, which are found in the 'track' table of the 'race_track' "
#             'database.'},
#  {'db_name': 'school_player',
#   'question': 'Return the total and minimum enrollments across all schools.',
#   'reason': "The 'school' table contains an 'enrollment' column which is "
#             'relevant for calculating total and minimum enrollments across all '
#             'schools.'}]

# %%
# Extract ground truth answers for Agent A - ground truth database names
ground_truth = sql_answers_df.iloc[::every_x_th][["question", "db_id"]].reset_index(drop=True)
# print(ground_truth.head())

# compare results from agent a test set with ground truth
agent_a_test_results_df = pd.DataFrame({
    'question': [row['question'] for row in db_name_results],
    'predicted_db': [row['db_name'] for row in db_name_results],
    'ground_truth_db': ground_truth['db_id'],
})

agent_a_test_results_df['is_correct'] = agent_a_test_results_df['predicted_db'] == agent_a_test_results_df['ground_truth_db']
agent_a_test_results_df = agent_a_test_results_df[['is_correct', 'question', 'predicted_db', 'ground_truth_db']]

agent_a_test_results_df
# Out:
#     is_correct                                           question  \
# 0         True  How many heads of the departments are older th...
# 1         True  Show names of actors and names of musicals the...
# 2        False          How many students does each advisor have?
# 3         True    What are the names and locations of all tracks?
# 4        False  Return the total and minimum enrollments acros...
# 5         True  Return all the apartment numbers sorted by the...
# 6         True                Show the distinct venues of debates
# 7         True             What is the age of the tallest person?
# 8        False  What are the names and headquarters of all com...
# 9         True      What is the team with at least 2 technicians?
# 10       False  What are the names and years of the movies tha...
# 11        True             How many distinct governors are there?
# 12        True                What is the largest payment amount?
# 13        True  What is the total number of professors with a ...
# 14        True  What are the full names and hire dates for emp...
# 15        True  find the number of different programs that are...
# 16        True  List the name of ships in ascending order of t...
# 17       False                          How many clubs are there?
# 18        True  What are the names of all the documents, as we...
# 19        True  What is the id and name of the staff who has b...
# 20        True  Find the name of all students who were in the ...
# 21        True                How many songs have a shared vocal?
# 22       False  For each advisor, report the total number of s...
# 23        True   Find the name of amenities Smith Hall dorm have.
# 24       False    How many different types of sports do we offer?
# 25        True    Which flag is most widely used among all ships?
# 26        True  What are the names of the scientists, and how ...
# 27       False  Who is the advisor of Linda Smith? Give me the...
#
#              predicted_db        ground_truth_db
# 0   department_management  department_management
# 1                 musical                musical
# 2                  dorm_1              allergy_1
# 3              race_track             race_track
# 4           school_player  university_basketball
# 5       apartment_rentals      apartment_rentals
# 6                  debate                 debate
# 7                 gymnast                gymnast
# 8          company_office            gas_company
# 9          machine_repair         machine_repair
# 10                   imdb                movie_1
# 11               election               election
# 12               sakila_1               sakila_1
# 13              college_1              college_1
# 14                   hr_1                   hr_1
# 15          program_share          program_share
# 16           ship_mission           ship_mission
# 17            riding_club                 club_1
# 18    document_management    document_management
# 19       department_store       department_store
# 20               soccer_2               soccer_2
# 21                music_2                music_2
# 22              college_2                voter_2
# 23                 dorm_1                 dorm_1
# 24     sports_competition                 game_1
# 25                 ship_1                 ship_1
# 26            scientist_1            scientist_1
# 27              college_2             activity_1

# %%
# print the percentage of correct predictions
print(f"Percentage correct: {agent_a_test_results_df['is_correct'].mean():.2%}")
# Out:
# Percentage correct: 71.43%

# %%
# Print all incorrect predictions for database selection using the new results DataFrame
incorrect = agent_a_test_results_df[~agent_a_test_results_df['is_correct']]
for idx, row in incorrect.iterrows():
    question = row['question']
    ground_truth = row['ground_truth_db']
    prediction = row['predicted_db']
    print(f"Q: {question}\nTruth: {ground_truth} | Pred: {prediction}\n{'-'*60}")
# Out:
# Q: How many students does each advisor have?
# Truth: allergy_1 | Pred: dorm_1
# ------------------------------------------------------------
# Q: Return the total and minimum enrollments across all schools.
# Truth: university_basketball | Pred: school_player
# ------------------------------------------------------------
# Q: What are the names and headquarters of all companies ordered by descending market value?
# Truth: gas_company | Pred: company_office
# ------------------------------------------------------------
# Q: What are the names and years of the movies that has the top 3 highest rating star?
# Truth: movie_1 | Pred: imdb
# ------------------------------------------------------------
# Q: How many clubs are there?
# Truth: club_1 | Pred: riding_club
# ------------------------------------------------------------
# Q: For each advisor, report the total number of students advised by him or her.
# Truth: voter_2 | Pred: college_2
# ------------------------------------------------------------
# Q: How many different types of sports do we offer?
# Truth: game_1 | Pred: sports_competition
# ------------------------------------------------------------
# Q: Who is the advisor of Linda Smith? Give me the first name and last name.
# Truth: activity_1 | Pred: college_2
# ------------------------------------------------------------

# %% [markdown]
# ## 2 Agent B: Table & Column Selector
# `Identifies the appropriate tables and columns within the selected
# schema that are needed to answer the query.`

# %% [markdown]
# ### 2.1 Setup for Testing

# %% [markdown]
# Not possible yet, no gorund truth for tables and column selection

# %% [markdown]
# ### 2.2 Setup Agent B

# %%
list_tables_prompt = PromptTemplate(
    input_variables=["user_query", "db_schema_json"],
    template = """
Given the relevant database schema, return the tables that are most relevant to the user's query.

User query: {user_query}
DB schema JSON: {db_schema_json}

Respond ONLY with a valid JSON object (no extra text, no backticks). 
The JSON must include the following keys: "db_name", "tables", "columns", and "reasons". 
Each key should appear on its own line for readability. 

Example format (output must match this structure exactly): 

{{
  "relevant_tables": ["..."],
  "reasons": "..."
}}


Do not include any text outside the JSON object.
"""
)
#db_chain_2 = LLMChain(llm=llm, prompt=list_tables_prompt)
db_chain_2 = list_tables_prompt | llm

# %%
SCHEMA_PROCESSED_FILE = SCHEMA_OUTPUT_DIR / "spider_schemas_processed.jsonl"

# %%
def agent_b(user_query, db_name, mode="medium"):
    """
    mode options:
      - "light": only tables and columns
      - "medium": user query, db_name, tables, columns, reasons
      - "heavy": full schema + raw LLM response
    """

    # Load schema lines
    with open(SCHEMA_PROCESSED_FILE, "r", encoding="utf-8") as f:
        schema_lines = f.readlines()

    # Parse JSON lines and filter for the selected database
    full_schema = [
        json.loads(line)
        for line in schema_lines
        if json.loads(line)["database"] == db_name
    ]

    # Run LLM
    response_2 = db_chain_2.invoke({
        "user_query": user_query,
        "db_schema_json": full_schema
    })

    # Parse LLM output into dict
    llm_selection_content = (
        response_2.content if hasattr(response_2, "content") else str(response_2)
    )
    parsed = json.loads(llm_selection_content)

    if mode == "light":
        return {
            "Tables": parsed.get("tables", []),
            "Columns": parsed.get("columns", []),
        }

    elif mode == "medium":  # fixed spelling
        return {
            "User Query": user_query,
            "Database Name": parsed.get("db_name", db_name),
            "Tables": parsed.get("tables", []),
            "Columns": parsed.get("columns", []),
            "Reasons": parsed.get("reasons", "")
        }

    elif mode == "heavy":
        return {
            "User Query": user_query,
            "Database Name": db_name,
            "schema": full_schema,
            "llm_result_raw": response_2,
        }

    else:
        raise ValueError(f"Unknown mode: {mode}")

# %% [markdown]
# ### 2.3 Apply Agent B

# %%
agent_b("How many heads of the departments are older than 56 ?", 'department_management', mode="heavy")
# Out:
# {'User Query': 'How many heads of the departments are older than 56 ?',
#  'Database Name': 'department_management',
#  'schema': [{'database': 'department_management',
#    'table': 'department',
#    'columns': ['department id',
#     'name',
#     'creation',
#     'ranking',
#     'budget in billions',
#     'num employees']},
#   {'database': 'department_management',
#    'table': 'head',
#    'columns': ['head id', 'name', 'born state', 'age']},
#   {'database': 'department_management',
#    'table': 'management',
#    'columns': ['department id', 'head id', 'temporary acting']}],
#  'llm_result_raw': AIMessage(content='{\n  "db_name": "department_management",\n  "tables": ["head"],\n  "columns": ["head id", "name", "age"],\n  "reasons": "The query specifically asks about the heads of departments and their ages, making the \'head\' table the most relevant."\n}', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 236, 'total_tokens': 297, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_8bda4d3a2c', 'id': 'chatcmpl-CEIrns6BJo7eiQrPALXuNAS3OzDTf', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--0a203cd4-26a8-4c50-ac0f-90024db5604a-0', usage_metadata={'input_tokens': 236, 'output_tokens': 61, 'total_tokens': 297, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})}

# %%
# Pick every X questions
every_y_th = 2500
questions_subset = sql_answers_df.iloc[::every_y_th]
print(f"Number of questions we are testing: {len(questions_subset)}")
print(f"Total number of questions: {len(sql_answers_df)}")
# Out:
# Number of questions we are testing: 3
# Total number of questions: 7000

# %%
for idx, row in questions_subset.iterrows():
    question = row['question']
    db_id = row['db_id']
    result = agent_b(question, db_id, mode="medium")
    print("\nAgent B Table Selection:")
    pprint.pprint(result, sort_dicts=False)  # keeps insertion order
    print("\n" + "="*60)
# Out:
# Agent B Table Selection:
# {'User Query': 'How many heads of the departments are older than 56 ?',
#  'Database Name': 'department_management',
#  'Tables': ['head'],
#  'Columns': ['head id', 'name', 'age'],
#  'Reasons': 'The query specifically asks about the heads of departments and '
#             "their ages, making the 'head' table the most relevant."}
#
# ============================================================
#
# Agent B Table Selection:
# {'User Query': 'What are the names and years of the movies that has the top 3 '
#                'highest rating star?',
#  'Database Name': 'movie_1',
#  'Tables': ['movie', 'rating'],
#  'Columns': ['title', 'year', 'rating stars'],
#  'Reasons': "The 'movie' table contains the movie titles and years, while the "
#             "'rating' table contains the rating stars needed to identify the "
#             'top rated movies.'}
#
# ============================================================
#
# Agent B Table Selection:
# {'User Query': 'Find the name of all students who were in the tryout sorted in '
#                'alphabetic order.',
#  'Database Name': 'soccer_2',
#  'Tables': ['player', 'tryout'],
#  'Columns': ['player name'],
#  'Reasons': "The 'player' table contains the names of students, and the "
#             "'tryout' table links players to their tryout participation."}
#
# ============================================================

# %% [markdown]
# ### 2.4 Test Agent B

# %% [markdown]
# Not possible yet, no gorund truth for tables and column selection

# %% [markdown]
# ## 3 Agent C: SQL Generator
# `Generates an SQL query tailored to natural language query and selected schema.`

# %% [markdown]
# ### 3.1 Setup for Testing

# %%
SQL_TESTING = PROJECT_ROOT / "data" / "test" / "spider_query_answers.json"

# %%
with open(SQL_TESTING, "r") as f:
    data = json.load(f)
df = pd.DataFrame(data)
df.head()
# Out:
#                    db_id                                           question  \
# 0  department_management  How many heads of the departments are older th...
# 1  department_management  List the name, born state and age of the heads...
# 2  department_management  List the creation year, name and budget of eac...
# 3  department_management  What are the maximum and minimum budget of the...
# 4  department_management  What is the average number of employees of the...
#
#                                                query  \
# 0         SELECT count(*) FROM head WHERE age  >  56
# 1  SELECT name ,  born_state ,  age FROM head ORD...
# 2  SELECT creation ,  name ,  budget_in_billions ...
# 3  SELECT max(budget_in_billions) ,  min(budget_i...
# 4  SELECT avg(num_employees) FROM department WHER...
#
#                                           guery_toks
# 0  [SELECT, count, (, *, ), FROM, head, WHERE, ag...
# 1  [SELECT, name, ,, born_state, ,, age, FROM, he...
# 2  [SELECT, creation, ,, name, ,, budget_in_billi...
# 3  [SELECT, max, (, budget_in_billions, ), ,, min...
# 4  [SELECT, avg, (, num_employees, ), FROM, depar...

# %%
def get_true_query_toks(db_id, question, data=SQL_TESTING):
    """
    Retrieve the 'guery_toks' for a given db_id and question from the test data file.

    Args:
        db_id (str): The database ID to match.
        question (str): The question string to match.
        data_file (str or Path): Path to the JSON test data file.

    Returns:
        list: The list of SQL tokens ('guery_toks') if found, else None.
    """
    import json

    with open(data, "r") as f:
        data = json.load(f)

    for item in data:
        if item.get("db_id") == db_id and item.get("question") == question:
            return item.get("guery_toks")
    return None

# %%
def compare_sql_to_ground_truth(sql_query, db_id, question, data=SQL_TESTING):
    """
    Tokenizes the given SQL query and compares its tokens to the ground truth tokens
    for the specified db_id and question.

    Args:
        sql_query (str): The SQL query to compare.
        db_id (str): The database ID.
        question (str): The natural language question.
        data (str or Path): Path to the JSON test data file.

    Returns:
        bool: True if the tokenized SQL matches the ground truth tokens, False otherwise.
    """
    import re

    def tokenize_sql(sql):
        # Simple SQL tokenizer: split on whitespace and punctuation
        return [tok for tok in re.split(r"(\W)", sql) if tok.strip()]

    gt_tokens = get_true_query_toks(db_id, question, data)
    if gt_tokens is None:
        raise ValueError(f"No ground truth found for db_id={db_id}, question={question}")

    sql_tokens = tokenize_sql(sql_query)
    return sql_tokens == gt_tokens

# %% [markdown]
# ### 3.2 Setup Agent C

# %%
generate_sql_prompt = PromptTemplate(
    input_variables=["user_query", "db_schema_json", "reccomended_tables"],
    template = """
You are an SQL expert. Given the following database schema:

DB schema JSON: {db_schema_json}

You are also provided with a list of recommended tables from the schema that are likely to be relevant for answering the question.

Recommended tables: {reccomended_tables}

Write a SQL query that answers the following question:

User query: {user_query}

Only return the SQL query, nothing else.

Make sure your SQL is formatted so that it is easily tokenizable: 
- Use clear spacing around punctuation (e.g., SELECT name , age FROM table WHERE id = 5).
- Avoid unnecessary line breaks or indentation.
- Do not include comments or explanations.
"""
)

db_chain_3 = generate_sql_prompt | llm

# %%
SCHEMA_PROCESSED_FILE = SCHEMA_OUTPUT_DIR / "spider_schemas_processed.jsonl"

# %%
def clean_sql(sql_string):
    # Remove code fences if present
    sql_string = sql_string.strip()
    if sql_string.startswith("```") and sql_string.endswith("```"):
        sql_string = "\n".join(sql_string.splitlines()[1:-1])  # remove ```sql and ```
    # Remove surrounding parentheses if it's a tuple string
    if sql_string.startswith("(") and sql_string.endswith(")"):
        sql_string = sql_string[1:-1].strip().strip("'").strip('"')
    return sql_string

def agent_c(user_query, db_name, reccomended_tables, mode="medium"):
    """
    mode options:
      - "light": only the generated SQL
      - "medium": user query, db_name, recommended tables, SQL
      - "heavy": everything + schema + raw LLM result
    """

    # Read all lines from the processed schema file
    with open(SCHEMA_PROCESSED_FILE, "r", encoding="utf-8") as f:
        schema_lines = f.readlines()

    # Parse JSON lines and filter for the selected database
    full_schema = [
        json.loads(line)
        for line in schema_lines
        if json.loads(line)["database"] == db_name
    ]

    # Run LLM
    response_3 = db_chain_3.invoke({
        "user_query": user_query,
        "db_schema_json": full_schema,
        "reccomended_tables": reccomended_tables
    })

    # Safely parse LLM output
    llm_selection_content = (
        response_3.content if hasattr(response_3, "content") else str(response_3)
    )
    try:
        parsed = json.loads(llm_selection_content)
        sql = parsed.get("sql", "")
    except json.JSONDecodeError:
        sql = llm_selection_content.strip()

    # Clean SQL
    sql = clean_sql(sql)

    if mode == "light":
        return sql  # just the SQL string

    elif mode == "medium":
        return {
            "User Query": user_query,
            "Database Name": db_name,
            "Reccomended Tables": reccomended_tables,
            "SQL": sql
        }

    elif mode == "heavy":
        return {
            "User Query": user_query,
            "Database Name": db_name,
            "Reccomended Tables": reccomended_tables,
            "SQL": sql,
            "schema": full_schema,
            "llm_result_raw": response_3
        }

    else:
        raise ValueError(f"Unknown mode: {mode}")

# %% [markdown]
# ### 3.3 Apply Agent C

# %%
# Pick every X questions
every_z_th = 2500
questions_subset = sql_answers_df.iloc[::every_z_th]
print(f"Number of questions we are testing: {len(questions_subset)}")
print(f"Total number of questions: {len(sql_answers_df)}")
# Out:
# Number of questions we are testing: 3
# Total number of questions: 7000

# %% [markdown]
# Note we have to run Agent B to feed the reccomended tables to Agent C

# %%
for idx, row in questions_subset.iterrows():
    question = row['question']
    db_id = row['db_id']
    
    # Step 1: Use Agent B to get recommended tables (light mode for clean output)
    agent_b_result = agent_b(question, db_id, mode="light")
    print("\nAgent B Table Selection:")
    pprint.pprint(agent_b_result)

    # Step 2: Extract recommended tables from Agent B's output
    recommended_tables = agent_b_result.get("Tables", [])

    # Step 3: Use Agent C to generate SQL using recommended tables
    agent_c_result = agent_c(question, db_id, recommended_tables, mode="light")
    print("\nAgent C SQL Generation:")
    pprint.pprint(agent_c_result)

    print("\n" + "="*60)
# Out:
# Agent B Table Selection:
# {'Columns': ['head id', 'name', 'age'], 'Tables': ['head']}
#
# Agent C SQL Generation:
# 'SELECT COUNT(*) FROM head WHERE age > 56;'
#
# ============================================================
#
# Agent B Table Selection:
# {'Columns': ['title', 'year', 'rating stars'], 'Tables': ['movie', 'rating']}
#
# Agent C SQL Generation:
# ('SELECT m.title , m.year FROM movie m JOIN rating r ON m."movie id" = '
#  'r."movie id" GROUP BY m."movie id" ORDER BY AVG(r."rating stars") DESC LIMIT '
#  '3;')
#
# ============================================================
#
# Agent B Table Selection:
# {'Columns': ['player name'], 'Tables': ['player', 'tryout']}
#
# Agent C SQL Generation:
# ('SELECT DISTINCT player_name FROM player INNER JOIN tryout ON '
#  'player.player_id = tryout.player_id ORDER BY player_name;')
#
# ============================================================

# %% [markdown]
# # 4. Archive

# %%
# def fetch_schema_for_db(db_id, schema_file=SCHEMA_PROCESSED_FILE):
#     """
#     Fetch the schema (list of tables and columns) for a given db_id from the processed schema file.
#     Returns a list of dicts: [{ "table": ..., "columns": [...] }, ...]
#     """
#     schema = []
#     with open(schema_file, "r") as f:
#         for line in f:
#             entry = json.loads(line)
#             if entry["database"] == db_id:
#                 schema.append({
#                     "table": entry["table"],
#                     "columns": entry["columns"]
#                 })
#     return schema

# # Example usage:
# db_schema = fetch_schema_for_db("perpetrator")
# print(db_schema)
# Out:
# [{'table': 'perpetrator', 'columns': ['perpetrator id', 'people id', 'date', 'year', 'location', 'country', 'killed', 'injured']}, {'table': 'people', 'columns': ['people id', 'name', 'height', 'weight', 'home town']}]

# %%
# Read the schema file and build a mapping from db_id to list of tables
db_to_tables = {}

# Get all unique db_ids from sql_answers_df
db_ids_needed = set(sql_answers_df["db_id"].tolist())


db_to_tables = {}

with open(SCHEMA_PROCESSED_FILE, "r") as f:
    for line in f:
        entry = json.loads(line)
        db_id = entry["database"]
        table = entry["table"]
        columns = entry["columns"]
        # Only process db_ids that are in our needed set
        if db_id in db_ids_needed:
            if db_id not in db_to_tables:
                db_to_tables[db_id] = []
            db_to_tables[db_id].append({
                "table": table,
                "columns": columns
            })

print(db_to_tables)
# Out:
# {'perpetrator': [{'table': 'perpetrator', 'columns': ['perpetrator id', 'people id', 'date', 'year', 'location', 'country', 'killed', 'injured']}, {'table': 'people', 'columns': ['people id', 'name', 'height', 'weight', 'home town']}], 'college_2': [{'table': 'classroom', 'columns': ['building', 'room number', 'capacity']}, {'table': 'department', 'columns': ['department name', 'building', 'budget']}, {'table': 'course', 'columns': ['course id', 'title', 'department name', 'credits']}, {'table': 'instructor', 'columns': ['id', 'name', 'department name', 'salary']}, {'table': 'section', 'columns': ['course id', 'section id', 'semester', 'year', 'building', 'room number', 'time slot id']}, {'table': 'teaches', 'columns': ['id', 'course id', 'section id', 'semester', 'year']}, {'table': 'student', 'columns': ['id', 'name', 'department name', 'total credits']}, {'table': 'takes classes', 'columns': ['id', 'course id', 'section id', 'semester', 'year', 'grade']}, {'table': 'advisor', 'columns': ['student id', 'instructor id']}, {'table': 'time slot', 'columns': ['time slot id', 'day', 'start hour', 'start minute', 'end hour', 'end minute']}, {'table': 'prerequisite', 'columns': ['course id', 'prerequisite id']}], 'flight_company': [{'table': 'airport', 'columns': ['id', 'city', 'country', 'iata', 'icao', 'name']}, {'table': 'operate company', 'columns': ['id', 'name', 'type', 'principal activities', 'incorporated in', 'group equity shareholding']}, {'table': 'flight', 'columns': ['id', 'vehicle flight number', 'date', 'pilot', 'velocity', 'altitude', 'airport id', 'company id']}], 'icfp_1': [{'table': 'institution', 'columns': ['institution id', 'name', 'country']}, {'table': 'authors', 'columns': ['author id', 'last name', 'first name']}, {'table': 'papers', 'columns': ['paper id', 'title']}, {'table': 'authorship count', 'columns': ['author id', 'institution id', 'paper id', 'author count']}], 'body_builder': [{'table': 'body builder', 'columns': ['body builder id', 'people id', 'snatch', 'clean jerk', 'total']}, {'table': 'people', 'columns': ['people id', 'name', 'height', 'weight', 'birth date', 'birth place']}], 'storm_record': [{'table': 'storm', 'columns': ['storm id', 'name', 'dates active', 'max speed', 'damage millions usd', 'number deaths']}, {'table': 'region', 'columns': ['region id', 'region code', 'region name']}, {'table': 'affected region', 'columns': ['region id', 'storm id', 'number city affected']}], 'pilot_record': [{'table': 'aircraft', 'columns': ['aircraft id', 'order year', 'manufacturer', 'model', 'fleet series', 'powertrain', 'fuel propulsion']}, {'table': 'pilot', 'columns': ['pilot id', 'pilot name', 'rank', 'age', 'nationality', 'position', 'join year', 'team']}, {'table': 'pilot record', 'columns': ['record id', 'pilot id', 'aircraft id', 'date']}], 'race_track': [{'table': 'race', 'columns': ['race id', 'name', 'class', 'date', 'track id']}, {'table': 'track', 'columns': ['track id', 'name', 'location', 'seating', 'year opened']}], 'department_store': [{'table': 'addresses', 'columns': ['address id', 'address details']}, {'table': 'staff', 'columns': ['staff id', 'staff gender', 'staff name']}, {'table': 'suppliers', 'columns': ['supplier id', 'supplier name', 'supplier phone']}, {'table': 'department store chain', 'columns': ['department store chain id', 'department store chain name']}, {'table': 'customers', 'columns': ['customer id', 'payment method code', 'customer code', 'customer name', 'customer address', 'customer phone', 'customer email']}, {'table': 'products', 'columns': ['product id', 'product type code', 'product name', 'product price']}, {'table': 'supplier addresses', 'columns': ['supplier id', 'address id', 'date from', 'date to']}, {'table': 'customer addresses', 'columns': ['customer id', 'address id', 'date from', 'date to']}, {'table': 'customer orders', 'columns': ['order id', 'customer id', 'order status code', 'order date']}, {'table': 'department stores', 'columns': ['departm ...
