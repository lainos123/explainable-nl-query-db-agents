# %% [markdown]
# # Explainable NL Query Database Agents

# %% [markdown]
# ### Team 9

# %%
# Import necessary libraries
import sqlite3
import json
import pandas as pd
import os
import textwrap
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.vectorstores import FAISS
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from openai import OpenAI

# %%
#set up environment with OpenAI API Key
os.environ["OPENAI_API_KEY"] = "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"
client = OpenAI()

# %%
#loading JSON (schema file) from my local drive
tables_json_path = r"C:\Users\Sachith\OneDrive - UWA\SEM4\CITS5553-Group_Project\project\spider_data\tables.json"
if os.path.exists(tables_json_path):
    with open(tables_json_path, 'r', encoding='utf-8') as f:
        tables_data = json.load(f)
    print(f"Number of tables/schemas: {len(tables_data)}")
    
    # Show column name
    if tables_data:
        first_entry = tables_data[5] 
        print(f"Keys: {list(first_entry.keys()) if isinstance(first_entry, dict) else 'Not a dictionary'}")
else:
    print("error.")
# Out:
# Number of tables/schemas: 166
# Keys: ['column_names', 'column_names_original', 'column_types', 'db_id', 'foreign_keys', 'primary_keys', 'table_names', 'table_names_original']

# %%
# Here I've extract only the db_id, table_names, and column_names from tables.json
def extract_essential_schema(tables_data):
    essential_data = []
    for entry in tables_data:
        simplified_entry = {
            'database_name': entry.get('db_id', 'undefined'),
            'table_names': entry.get('table_names', []),
            'column_names': entry.get('column_names', [])
        }
        essential_data.append(simplified_entry)
    return essential_data

# Apply the extraction if tables_data is loaded
if 'tables_data' in locals():
    essential_schemas = extract_essential_schema(tables_data)
    print(f" Extracted data for {len(essential_schemas)} database schemas")
    
    # Show example of the simplified structure
    if essential_schemas:
        print(f"\n Example of simplified entry:")
        example = essential_schemas[0]
        print(f"  database_name: {example['database_name']}")
        print(f"  table_names: {example['table_names']}")
        print(f"  column_names (first 3): {example['column_names'][:3]}...")
        print(f"  Total columns: {len(example['column_names'])}")
    
else:
    print("tables_data not found.")
# Out:
#  Extracted data for 166 database schemas
#
#  Example of simplified entry:
#   database_name: perpetrator
#   table_names: ['perpetrator', 'people']
#   column_names (first 3): [[-1, '*'], [0, 'perpetrator id'], [0, 'people id']]...
#   Total columns: 14

# %%
#Examples of schemas
essential_schemas[0]
# Out:
# {'database_name': 'perpetrator',
#  'table_names': ['perpetrator', 'people'],
#  'column_names': [[-1, '*'],
#   [0, 'perpetrator id'],
#   [0, 'people id'],
#   [0, 'date'],
#   [0, 'year'],
#   [0, 'location'],
#   [0, 'country'],
#   [0, 'killed'],
#   [0, 'injured'],
#   [1, 'people id'],
#   [1, 'name'],
#   [1, 'height'],
#   [1, 'weight'],
#   [1, 'home town']]}

# %%
#below is iterating each database getting db name , table name and column names, then print in a easy to read format.
#This block is not being used for any agents, only for visually inspection of the schema file. 

for db in essential_schemas:  # Iterate through each database
    db_name = db["database_name"]
    table_names = db["table_names"]
    column_names = db["column_names"]
    
    print(f"Database: {db_name}")
    
    # Create a dictionary for this database's tables and columns
    essential_schemas_reshape = {}
    for idx, table_name in enumerate(table_names):
        # Collect all columns belonging to this table
        # column_names format: [(table_index, column_name), ...]
        cols = [col_name for table_idx, col_name in column_names if table_idx == idx]
        essential_schemas_reshape[table_name] = cols

    # Pretty print for this database
    for table, cols in essential_schemas_reshape.items():
        print(f"  Table: {table}")
        print(f"    Columns: {', '.join(cols)}")
    print("="*50)
# Out:
# Database: perpetrator
#   Table: perpetrator
#     Columns: perpetrator id, people id, date, year, location, country, killed, injured
#   Table: people
#     Columns: people id, name, height, weight, home town
# ==================================================
# Database: college_2
#   Table: classroom
#     Columns: building, room number, capacity
#   Table: department
#     Columns: department name, building, budget
#   Table: course
#     Columns: course id, title, department name, credits
#   Table: instructor
#     Columns: id, name, department name, salary
#   Table: section
#     Columns: course id, section id, semester, year, building, room number, time slot id
#   Table: teaches
#     Columns: id, course id, section id, semester, year
#   Table: student
#     Columns: id, name, department name, total credits
#   Table: takes classes
#     Columns: id, course id, section id, semester, year, grade
#   Table: advisor
#     Columns: student id, instructor id
#   Table: time slot
#     Columns: time slot id, day, start hour, start minute, end hour, end minute
#   Table: prerequisite
#     Columns: course id, prerequisite id
# ==================================================
# Database: flight_company
#   Table: airport
#     Columns: id, city, country, iata, icao, name
#   Table: operate company
#     Columns: id, name, type, principal activities, incorporated in, group equity shareholding
#   Table: flight
#     Columns: id, vehicle flight number, date, pilot, velocity, altitude, airport id, company id
# ==================================================
# Database: icfp_1
#   Table: institution
#     Columns: institution id, name, country
#   Table: authors
#     Columns: author id, last name, first name
#   Table: papers
#     Columns: paper id, title
#   Table: authorship count
#     Columns: author id, institution id, paper id, author count
# ==================================================
# Database: body_builder
#   Table: body builder
#     Columns: body builder id, people id, snatch, clean jerk, total
#   Table: people
#     Columns: people id, name, height, weight, birth date, birth place
# ==================================================
# Database: storm_record
#   Table: storm
#     Columns: storm id, name, dates active, max speed, damage millions usd, number deaths
#   Table: region
#     Columns: region id, region code, region name
#   Table: affected region
#     Columns: region id, storm id, number city affected
# ==================================================
# Database: pilot_record
#   Table: aircraft
#     Columns: aircraft id, order year, manufacturer, model, fleet series, powertrain, fuel propulsion
#   Table: pilot
#     Columns: pilot id, pilot name, rank, age, nationality, position, join year, team
#   Table: pilot record
#     Columns: record id, pilot id, aircraft id, date
# ==================================================
# Database: race_track
#   Table: race
#     Columns: race id, name, class, date, track id
#   Table: track
#     Columns: track id, name, location, seating, year opened
# ==================================================
# Database: academic
#   Table: author
#     Columns: aid, homepage, name, oid
#   Table: conference
#     Columns: cid, homepage, name
#   Table: domain
#     Columns: did, name
#   Table: domain author
#     Columns: aid, did
#   Table: domain conference
#     Columns: cid, did
#   Table: journal
#     Columns: homepage, jid, name
#   Table: domain journal
#     Columns: did, jid
#   Table: keyword
#     Columns: keyword, kid
#   Table: domain keyword
#     Columns: did, kid
#   Table: publication
#     Columns: abstract, cid, citation num, jid, pid, reference num, title, year
#   Table: domain publication
#     Columns: did, pid
#   Table: organization
#     Columns: continent, homepage, name, oid
#   Table: publication keyword
#     Columns: pid, kid
#   Table: writes
#     Columns: aid, pid
#   Table: cite
#     Columns: cited, citing
# ==================================================
# Database: department_store
#   Table: addresses
#     Columns: address id, address details
#   Table: staff
#     Columns: staff id, staff gender, staff name
#   Table: suppliers
#     Columns: supplier id, supplier name, supplier phone
#   Table: department store chain
#     Columns: department store chain id, department store chain name
#   Table: customers
#     Columns: customer id, payment method code, customer code, customer name, customer address, customer phone, customer email
#   Table: products
#     Columns: product id, product type code, product name, product price
#   Table: supplier addresses
#     Columns: supplier id, address id, date from, date to
#   Table: customer addresses
#     Columns: customer id, address id, date from, date to
#   Table: customer orders
#     Columns: order id, customer id, order status code, order date
#   Table: department stores
#     Columns: department store id, department store chain id, store name, store address, store phone, store email
#   Table: departments
#     Columns: department id, department store id, department name
#   Table: order items
#     Columns: order item id, order id, product id
#   Table: product suppliers
#     Columns: product id, supplier id, date supplied from, date supplied to, total amount purchased, total value purchased
#   Table: staff department assignments
#     Columns: staff id, department id, date assigned from, job title code, date assigned to
# ==================================================
# Database: music_4
#   Table: artist
#     Columns: artist id, artist, age, famous title, famous release date
#   Table: volume
#     Columns: volume id, volume issue, issue date, weeks on top, song, artist id
#   Table: music festival
#     Columns: id, music festival, date of ceremony, category, volume, result
# ==================================================
# Database: insurance_fnol
#   Table: customers
#     Columns: customer id, customer name
#   Table: services
#     Columns: service id, service name
#   Table: available policies
#     Columns: policy id, policy type code, customer phone
#   Table: customers policies
#     Columns: customer id, policy id, date opened, date closed
#   Table: first notification of loss
#     Columns: fnol id, customer id, policy id, service id
#   Table: claims
#     Columns: claim id, fnol id, effective date
#   Table: settlements
#     Columns: settlement id, claim id, effective date, settlement amount
# ==================================================
# Database: cinema
#   Table: film
#     Columns: film id, rank in series, number in season, title, directed by, original air date, production code
#   Table: cinema
#     Columns: cinema id, name, openning year, capacity, location
#   Table: schedule
#     Columns: cinema id, film id, date, show times per day, price
# ==================================================
# Database: decoration_competition
#   Table: college
#     Columns: college id, name, leader name, college location
#   Table: member
#     Columns: member id, name, country, college id
#   Table: round
#     Columns: round id, member id, decoration theme, rank in round
# ==================================================
# Database: phone_market
#   Table: phone
#     Columns: name, phone id, memory in g, carrier, price
#   Table: market
#     Columns: market id, district, num of employees, num of shops, ranking
#   Table: phone market
#     Columns: market id, phone id, num of stock
# ==================================================
# Database: store_product
#   Table: product
#     Columns: product id, product, dimensions, dpi, pages per minute color, max page size, interface
#   Table: store
#     Columns: store id, store name, type, area size, number of product category, ranking
#   Table: district
#     Columns: district id, district name, headquartered city, city population, city area
#   Table: store product
#     Columns: store id, product id
#   Table: store district
#     Columns: store id, district id
# ==================================================
# Database: assets_maintenance
#   Table: third party companies
#     Columns: company id, company type, company name, company address, other company details
#   Table: maintenance contracts
#     Columns: maintenance contract id, maintenance contract company id, contract start date, contract end date, other contract details
#   Table: parts
#     Columns: part id, part name, chargeable yn, chargeable amount, other part details
#   Table: skills
#     Columns: skill id, skill code, skill description
#   Table: staff
#     Columns: staff id, staff name, gender, other staff details
#   Table: assets
#     Columns: asset id, maintenance contract id, supplier company id, asset details, asset make, asset model, asset acquired date, asset disposed date, other asset details
#   Table: asset parts
#     Columns: asset id, part id
#   Table: maintenance engineers
#     Columns: engineer id, company id, first name, last name, other details
#   Table: engineer skills
#     Columns: engineer id, skill id
#   Table: fault log
#     Columns: fault log entry id, asset id, recorded by staff id, fault log entry datetime, fault description, other fault details
#   Table: engineer visits
#     Columns: engineer visit id, contact staff id, engineer id, fault log entry id, fault status, visit start datetime, visit end datetime, other visit details
#   Table: part faults
#     Columns: part fault id, part id, fault short name, fault description, other fault details
#   Table: fault log parts
#     Columns: fault log entry id, part fault id, fault status
#   Table: skills required to fix
#     Columns: part fault id, skill id
# ==================================================
# Database: student_assessment
#   Table: addresses
#     Columns: address id, line 1, line 2, city, zip postcode, state province county, country
#   Table: people
#     Columns: person id, first name, middle name, last name, cell mobile number, email address, login name, password
#   Table: students
#     Columns: student id, student details
#   Table: courses
#     Columns: course id, course name, course description, other details
#   Table: people addresses
#     Columns: person address id, person id, address id, date from, date to
#   Table: student course registrations
#     Columns: student id, course id, registration date
#   Table: student course attendance
#     Columns: student id, course id, date of attendance
#   Table: candidates
#     Columns: candidate id, candidate details
#   Table: candidate assessments
#     Columns: candidate id, qualification, assessment date, asessment outcome code
# ==================================================
# Database: dog_kennels
#   Table: breeds
#     Columns: breed code, breed name
#   Table: charges
#     Columns: charge id, charge type, charge amount
#   Table: sizes
#     Columns: size code, size description
#   Table: treatment types
#     Columns: treatment type code, treatment type description
#   Table: owners
#     Columns: owner id, first name, last name, street, city, state, zip code, email address, home phone, cell number
#   Table: dogs
#     Columns: dog id, owner id, abandoned yes or no, breed code, size code, name, age, date of birth, gender, weight, date arrived, date adopted, date departed
#   Table: professionals
#     Columns: professional id, role code, first name, street, city, state, zip code, last name, email address, home phone, cell number
#   Table: treatments
#     Columns: treatment id, dog id, professional id, treatment type code, date of treatment, cost of treatment
# ==================================================
# Database: music_1
#   Table: genre
#     Columns: genre name, rating, most popular in
#   Table: artist
#     Columns: artist name, country, gender, preferred genre
#   Table: files
#     Columns: song id, artist name, file size, duration, formats
#   Table: song
#     Columns: song name, artist name, country, song id, genre is, rating, languages, releasedate, resolution
# ==================================================
# Database: company_employee
#   Table: people
#     Columns: people id, age, name, nationality, graduation college
#   Table: company
#     Columns: company id, name, headquarters, industry, sales in billion, profits in billion, assets in billion, market value in billion
#   Table: employment
#     Columns: company id, people id, year working
# ==================================================
# Database: farm
#   Table: city
#     Columns: city id, official name, status, area km 2, population, census ranking
#   Table: farm
#     Columns: farm id, year, total horses, working horses, total cattle, oxen, bulls, cows, pigs, sheep and goats
#   Table: farm competition
#     Columns: competition id, year, theme, host city id, hosts
#   Table: competition record
#     Columns: competition id, farm id, rank
# ==================================================
# Database: solvency_ii
#   Table: addresses
#     Columns: address id, address details
#   Table: locations
#     Columns: location id, other details
#   Table: products
#     Columns: product id, product type code, product name, product price
#   Table: parties
#     Columns: party id, party details
#   Table: assets
#     Columns: asset id, other details
#   Table: channels
#     Columns: channel id, other details
#   Table: finances
#     Columns: finance id, other details
#   Table: events
#     Columns: event id, address id, channel id, event type code, finance id, location id
#   Table: products in events
#     Columns: product in event id, event id, product id
#   Table: parties in events
#     Columns: party id, event id, role code
#   Table: agreements
#     Columns: document id, event id
#   Table: assets in events
#     Columns: asset id, event id
# ==================================================
# Database: city_record
#   Table: city
#     Columns: city id, city, hanzi, hanyu pinyin, regional population, gdp
#   Table: match
#     Columns: match id, date, venue, score, result, competition
#   Table: temperature
#     Columns: city id, jan, feb, mar, apr, jun, jul, aug, sep, oct, nov, dec
#   Table: hosting city
#     Columns: year, match id, host city
# ==================================================
# Database: swimming
#   Table: swimmer
#     Columns: id, name, nationality, meter 100, meter 200, meter 300, meter 400, meter 500, meter 600, meter 700, time
#   Table: stadium
#     Columns: id, name, capacity, city, country, opening year
#   Table: event
#     Columns: id, name, stadium id, year
#   Table: record
#     Columns: id, result, swimmer id, event id
# ==================================================
# Database: flight_2
#   Table: airlines
#     Columns: airline id, airline name, abbreviation, country
#   Table: airports
#     Columns: city, airport code, airport name, country, country abbrev
#   Table: flights
#     Columns: airline, flight number, source airport, destination airport
# ==================================================
# Database: election
#   Table: county
#     Columns: county id, county name, population, zip code
#   Table: party
#     Columns: party id, year, party, governor, lieutenant governor, comptroller, attorney general, us senate
#   Table: election
#     Columns: election id, counties represented, district, delegate, party, first elected, committee
# ==================================================
# Database: manufactory_1
#   Table: manufacturers
#     Columns: code, name, headquarter, founder, revenue
#   Table: products
#     Columns: code, name, price, manufacturer
# ==================================================
# Database: debate
#   Table: people
#     Columns: people id, district, name, party, age
#   Table: debate
#     Columns: debate id, date, venue, num of audience
#   Table: debate people
#     Columns: debate id, affirmative, negative, if affirmative win
# ==================================================
# Database: network_2
#   Table: person
#     Columns: name, age, city, gender, job
#   Table: person friend
#     Columns: name, friend, year
# ==================================================
# Database: local_govt_in_alabama
#   Table: services
#     Columns: service id, service type code
#   Table: participants
#     Columns: participant id, participant type code, participant details
#   Table: events
#     Columns: event id, service id, event details
#   Table: participants in events
#     Columns: event id, participant id
# ==================================================
# Database: climbing
#   Table: mountain
#     Columns: mountain id, name, height, prominence, range, country
#   Table: climber
#     Columns: climber id, name, country, time, points, mountain id
# ==================================================
# Database: e_learning
#   Table: course authors and tutors
#     Columns: author id, author tutor atb, login name, password, personal name, middle name, family name, gender mf, address line 1
#   Table: students
#     Columns: student id, date of registration, date of latest logon, login name, password, personal name, middle name, family name
#   Table: subjects
#     Columns: subject id, subject name
#   Table: courses
#     Columns: course id, author id, subject id, course name, course description
#   Table: student course enrolment
#     Columns: registration id, student id, course id, date of enrolment, date of completion
#   Table: student tests taken
#     Columns: registration id, date test taken, test result
# ==================================================
# Database: scientist_1
#   Table: scientists
#     Columns: ssn, name
#   Table: projects
#     Columns: code, name, hours
#   Table: assigned to
#     Columns: scientist, project
# ==================================================
# Database: ship_1
#   Table: captain
#     Columns: captain id, name, ship id, age, class, rank
#   Table: ship
#     Columns: ship id, name, type, built year, class, flag
# ==================================================
# Database: entertainment_awards
#   Table: festival detail
#     Columns: festival id, festival name, chair name, location, year, num of audience
#   Table: artwork
#     Columns: artwork id, type, name
#   Table: nomination
#     Columns: artwork id, festival id, result
# ==================================================
# Database: allergy_1
#   Table: allergy type
#     Columns: allergy name, allergy type
#   Table: has allergy
#     Columns: stuid, allergy
#   Table: student
#     Columns: stuid, last name, first name, age, sex, major, advisor, city code
# ==================================================
# Database: imdb
#   Table: actor
#     Columns: aid, gender, name, nationality, birth city, birth year
#   Table: copyright
#     Columns: id, msid, cid
#   Table: cast
#     Columns: id, msid, aid, role
#   Table: genre
#     Columns: gid, genre
#   Table: classification
#     Columns: id, msid, gid
#   Table: company
#     Columns: id, name, country code
#   Table: director
#     Columns: did, gender, name, nationality, birth city, birth year
#   Table: producer
#     Columns: pid, gender, name, nationality, birth city, birth year
#   Table: directed by
#     Columns: id, msid, did
#   Table: keyword
#     Columns: id, keyword
#   Table: made by
#     Columns: id, msid, pid
#   Table: movie
#     Columns: mid, title, release year, title aka, budget
#   Table: tags
#     Columns: id, msid, kid
#   Table: tv series
#     Columns: sid, title, release year, num of seasons, num of episodes, title aka, budget
#   Table: writer
#     Columns: wid, gender, name, nationality, num of episodes, birth city, birth year
#   Table: written by
#     Columns: id, msid, wid
# ==================================================
# Database: products_for_hire
#   Table: discount coupons
#     Columns: coupon id, date issued, coupon amount
#   Table: customers
#     Columns: customer id, coupon id, good or bad customer, first name, last name, gender, date became customer, date last hire
#   Table: bookings
#     Columns: booking id, customer id, booking status code, returned damaged yes or no, booking start date, booking end date, count hired, amount payable, amount of discount, amount outstanding, amount of refund
#   Table: products for hire
#     Columns: product id, product type code, daily hire cost, product name, product description
#   Table: payments
#     Columns: payment id, booking id, customer id, payment type code, amount paid in full yn, payment date, amount due, amount paid
#   Table: products booked
#     Columns: booking id, product id, returned yes or no, returned late yes or no, booked count, booked amount
#   Table: view product availability
#     Columns: product id, booking id, status date, available yes or no
# ==================================================
# Database: candidate_poll
#   Table: candidate
#     Columns: candidate id, people id, poll source, date, support rate, consider rate, oppose rate, unsure rate
#   Table: people
#     Columns: people id, sex, name, date of birth, height, weight
# ==================================================
# Database: chinook_1
#   Table: album
#     Columns: album id, title, artist id
#   Table: artist
#     Columns: artist id, name
#   Table: customer
#     Columns: customer id, first name, last name, company, address, city, state, country, postal code, phone, fax, email, support representative id
#   Table: employee
#     Columns: employee id, last name, first name, title, reports to, birth date, hire date, address, city, state, country, postal code, phone, fax, email
#   Table: genre
#     Columns: genre id, name
#   Table: invoice
#     Columns: invoice id, customer id, invoice date, billing address, billing city, billing state, billing country, billing postal code, total
#   Table: invoice line
#     Columns: invoice line id, invoice id, track id, unit price, quantity
#   Table: media type
#     Columns: media type id, name
#   Table: playlist
#     Columns: play list id, name
#   Table: playlist track
#     Columns: play list id, track id
#   Table: track
#     Columns: track id, name, album id, media type id, genre id, composer, milliseconds, bytes, unit price
# ==================================================
# Database: flight_4
#   Table: routes
#     Columns: route id, destination airport id, destination airport, source airport id, source airport, airline id, airline, code share
#   Table: airports
#     Columns: airport id, name, city, country, x, y, elevation, iata, icao
#   Table: airlines
#     Columns: airline id, name, iata, icao, call sign, country, active
# ==================================================
# Database: pets_1
#   Table: student
#     Columns: student id, last name, first name, age, sex, major, advisor, city code
#   Table: has pet
#     Columns: student id, pet id
#   Table: pets
#     Columns: pet id, pet type, pet age, weight
# ==================================================
# Database: dorm_1
#   Table: student
#     Columns: student id, last name, first name, age, sex, major, advisor, city code
#   Table: dorm
#     Columns: dorm id, dorm name, student capacity, gender
#   Table: dorm amenity
#     Columns: amenity id, amenity name
#   Table: has amenity
#     Columns: dorm id, amenity id
#   Table: lives in
#     Columns: student id, dorm id, room number
# ==================================================
# Database: journal_committee
#   Table: journal
#     Columns: journal id, date, theme, sales
#   Table: editor
#     Columns: editor id, name, age
#   Table: journal committee
#     Columns: editor id, journal id, work type
# ==================================================
# Database: flight_1
#   Table: flight
#     Columns: flight number, origin, destination, distance, departure date, arrival date, price, airline id
#   Table: aircraft
#     Columns: airline id, name, distance
#   Table: employee
#     Columns: employee id, name, salary
#   Table: certificate
#     Columns: employee id, airline id
# ==================================================
# Database: medicine_enzyme_interaction
#   Table: medicine
#     Columns: id, name, trade name, fda approved
#   Table: enzyme
#     Columns: id, name, location, product, chromosome, omim, porphyria
#   Table: medicine enzyme interaction
#     Columns: enzyme id, medicine id, interaction type
# ==================================================
# Database: local_govt_and_lot
#   Table: customers
#     Columns: customer id, customer details
#   Table: properties
#     Columns: property id, property type code, property address, other details
#   Table: residents
#     Columns: resident id, property id, date moved in, date moved out, other details
#   Table: organizations
#     Columns: organization id, parent organization id, organization details
#   Table: services
#     Columns: service id, organization id, service type code, service details
#   Table: residents services
#     Columns: resident id, service id, date moved in, property id, date requested, date provided, other details
#   Table: things
#     Columns: thing id, organization id, type of thing code, service type code, service details
#   Table: customer events
#     Columns: customer event id, customer id, date moved in, property id, resident id, thing id
#   Table: customer event notes
#     Columns: customer event note id, customer event id, service type code, resident id, property id, date moved in
#   Table: timed status of things
#     Columns: thing id, date and date, status of thing code
#   Table: timed locations of things
#     Columns: thing id, date and time, location code
# ==================================================
# Database: station_weather
#   Table: train
#     Columns: id, train number, name, origin, destination, time, interval
#   Table: station
#     Columns: id, network name, services, local authority
#   Table: route
#     Columns: train id, station id
#   Table: weekly weather
#     Columns: station id, day of week, high temperature, low temperature, precipitation, wind speed mph
# ==================================================
# Database: shop_membership
#   Table: member
#     Columns: member id, card number, name, hometown, level
#   Table: branch
#     Columns: branch id, name, open year, address road, city, membership amount
#   Table: membership register branch
#     Columns: member id, branch id, register year
#   Table: purchase
#     Columns: member id, branch id, year, total pounds
# ==================================================
# Database: driving_school
#   Table: addresses
#     Columns: address id, line 1 number building, city, zip postcode, state province county, country
#   Table: staff
#     Columns: staff id, staff address id, nickname, first name, middle name, last name, date of birth, date joined staff, date left staff
#   Table: vehicles
#     Columns: vehicle id, vehicle details
#   Table: customers
#     Columns: customer id, customer address id, customer status code, date became customer, date of birth, first name, last name, amount outstanding, email address, phone number, cell mobile phone number
#   Table: customer payments
#     Columns: customer id, datetime payment, payment method code, amount payment
#   Table: lessons
#     Columns: lesson id, customer id, lesson status code, staff id, vehicle id, lesson date, lesson time, price
# ==================================================
# Database: concert_singer
#   Table: stadium
#     Columns: stadium id, location, name, capacity, highest, lowest, average
#   Table: singer
#     Columns: singer id, name, country, song name, song release year, age, is male
#   Table: concert
#     Columns: concert id, concert name, theme, stadium id, year
#   Table: singer in concert
#     Columns: concert id, singer id
# ==================================================
# Database: music_2
#   Table: songs
#     Columns: song id, title
#   Table: albums
#     Columns: aid, title, year, label, type
#   Table: band
#     Columns: id, first name, last name
#   Table: instruments
#     Columns: song id, bandmate id, instrument
#   Table: performance
#     Columns: song id, bandmate, stage position
#   Table: track lists
#     Columns: album id, position, song id
#   Table: vocals
#     Columns: song id, bandmate, type
# ==================================================
# Database: sports_competition
#   Table: club
#     Columns: club id, name, region, start year
#   Table: club rank
#     Columns: rank, club id, gold, silver, bronze, total
#   Table: player
#     Columns: player id, name, position, club id, apps, tries, goals, points
#   Table: competition
#     Columns: competition id, year, competition type, country
#   Table: competition result
#     Columns: competition id, club id 1, club id 2, score
# ==================================================
# Database: railway
#   Table: railway
#     Columns: railway id, railway, builder, built, wheels, location, objectnumber
#   Table: train
#     Columns: train id, train num, name, from, arrival, railway id
#   Table: manager
#     Columns: manager id, name, country, working year starts, age, level
#   Table: railway manage
#     Columns: railway id, manager id, from year
# ==================================================
# Database: inn_1
#   Table: rooms
#     Columns: room id, room name, beds, bed type, max occupancy, base price, decor
#   Table: reservations
#     Columns: code, room, check in, check out, rate, last name, first name, adults, kids
# ==================================================
# Database: museum_visit
#   Table: museum
#     Columns: museum id, name, num of staff, open year
#   Table: customer
#     Columns: customer id, name, level of membership, age
#   Table: visit
#     Columns: museum id, customer id, num of ticket, total spent
# ==================================================
# Database: browser_web
#   Table: web client accelerator
#     Columns: id, name, operating system, client, connection
#   Table: browser
#     Columns: id, name, market share
#   Table: accelerator compatible browser
#     Columns: accelerator id, browser id, compatible since year
# ==================================================
# Database: baseball_1
#   Table: all star
#     Columns: player id, year, game num, game id, team id, league id, gp, starting pos
#   Table: appearances
#     Columns: year, team id, league id, player id, g all, gs, g batting, g defense, g p, g c, g 1b, g 2b, g 3b, g ss, g lf, g cf, g rf, g of, g dh, g ph, g pr
#   Table: manager award
#     Columns: player id, award id, year, league id, tie, notes
#   Table: player award
#     Columns: player id, award id, year, league id, tie, notes
#   Table: manager award vote
#     Columns: award id, year, league id, player id, points won, points max, votes first
#   Table: player award vote
#     Columns: award id, year, league id, player id, points won, points max, votes first
#   Table: batting
#     Columns: player id, year, stint, team id, league id, g, ab, r, h, double, triple, hr, rbi, sb, cs, bb, so, ibb, hbp, sh, sf, g idp
#   Table: batting postseason
#     Columns: year, round, player id, team id, league id, g, ab, r, h, double, triple, hr, rbi, sb, cs, bb, so, ibb, hbp, sh, sf, g idp
#   Table: player college
#     Columns: player id, college id, year
#   Table: fielding
#     Columns: player id, year, stint, team id, league id, pos, g, gs, inn outs, po, a, e, dp, pb, wp, sb, cs, zr
#   Table: fielding outfield
#     Columns: player id, year, stint, glf, gcf, grf
#   Table: fielding postseason
#     Columns: player id, year, team id, league id, round, pos, g, gs, inn outs, po, a, e, dp, tp, pb, sb, cs
#   Table: hall of fame
#     Columns: player id, yearid, votedby, ballots, needed, votes, inducted, category, needed note
#   Table: home game
#     Columns: year, league id, team id, park id, span first, span last, games, openings, attendance
#   Table: manager
#     Columns: player id, year, team id, league id, inseason, g, w, l, rank, plyr mgr
#   Table: manager half
#     Columns: player id, year, team id, league id, inseason, half, g, w, l, rank
#   Table: player
#     Columns: player id, birth year, birth month, birth day, birth country, birth state, birth city, death year, death month, death day, death country, death state, death city, name first, name last, name given, weight, height, bats, throws, debut, final game, retro id, bbref id
#   Table: park
#     Columns: park id, park name, park alias, city, state, country
#   Table: pitching
#     Columns: player id, year, stint, team id, league id, w, l, g, gs, cg, sho, sv, ipouts, h, er, hr, bb, so, baopp, era, ibb, wp, hbp, bk, bfp, gf, r, sh, sf, g idp
#   Table: pitching postseason
#     Columns: player id, year, round, team id, league id, w, l, g, gs, cg, sho, sv, ipouts, h, er, hr, bb, so, baopp, era, ibb, wp, hbp, bk, bfp, gf, r, sh, sf, g idp
#   Table: salary
#     Columns: year, team id, league id, player id, salary
#   Table: college
#     Columns: college id, name full, city, state, country
#   Table: postseason
#     Columns: year, round, team id winner, league id winner, team id loser, league id loser, wins, losses, ties
#   Table: team
#     Columns: year, league id, team id, franchise id, div id, rank, g, ghome, w, l, div win, wc win, lg win, ws win, r, ab, h, double, triple, hr, bb, so, sb, cs, hbp, sf, ra, er, era, cg, sho, sv, ipouts, ha, hra, bba, soa, e, dp, fp, name, park, attendance, bpf, ppf, team id br, team id lahman45, team id retro
#   Table: team franchise
#     Columns: franchise id, franchise name, active, na assoc
#   Table: team half
#     Columns: year, league id, team id, half, div id, div win, rank, g, w, l
# ==================================================
# Database: architecture
#   Table: architect
#     Columns: id, name, nationality, gender
#   Table: bridge
#     Columns: architect id, id, name, location, length meters, length feet
#   Table: mill
#     Columns: architect id, id, location, name, type, built year, notes
# ==================================================
# Database: csu_1
#   Table: campuses
#     Columns: id, campus, location, county, year
#   Table: csu fees
#     Columns: campus, year, campus fee
#   Table: degrees
#     Columns: year, campus, degrees
#   Table: discipline enrollments
#     Columns: campus, discipline, year, undergraduate, graduate
#   Table: enrollments
#     Columns: campus, year, totalenrollment ay, fte ay
#   Table: faculty
#     Columns: campus, year, faculty
# ==================================================
# Database: tracking_orders
#   Table: customers
#     Columns: customer id, customer name, customer details
#   Table: invoices
#     Columns: invoice number, invoice date, invoice details
#   Table: orders
#     Columns: order id, customer id, order status, date order placed, order details
#   Table: products
#     Columns: product id, product name, product details
#   Table: order items
#     Columns: order item id, product id, order id, order item status, order item details
#   Table: shipments
#     Columns: shipment id, order id, invoice number, shipment tracking number, shipment date, other shipment details
#   Table: shipment items
#     Columns: shipment id, order item id
# ==================================================
# Database: insurance_policies
#   Table: customers
#     Columns: customer id, customer details
#   Table: customer policies
#     Columns: policy id, customer id, policy type code, start date, end date
#   Table: claims
#     Columns: claim id, policy id, date claim made, date claim settled, amount claimed, amount settled
#   Table: settlements
#     Columns: settlement id, claim id, date claim made, date claim settled, amount claimed, amount settled, customer policy id
#   Table: payments
#     Columns: payment id, settlement id, payment method code, date payment made, amount payment
# ==================================================
# Database: gas_company
#   Table: company
#     Columns: company id, rank, company, headquarters, main industry, sales billion, profits billion, assets billion, market value
#   Table: gas station
#     Columns: station id, open year, location, manager name, vice manager name, representative name
#   Table: station company
#     Columns: station id, company id, rank of the year
# ==================================================
# Database: e_government
#   Table: addresses
#     Columns: address id, line 1 number building, town city, zip postcode, state province county, country
#   Table: services
#     Columns: service id, service type code, service name, service descriptio
#   Table: forms
#     Columns: form id, form type code, service id, form number, form name, form description
#   Table: individuals
#     Columns: individual id, individual first name, individual middle name, inidividual phone, individual email, individual address, individual last name
#   Table: organizations
#     Columns: organization id, date formed, organization name, uk vat number
#   Table: parties
#     Columns: party id, payment method code, party phone, party email
#   Table: organization contact individuals
#     Columns: individual id, organization id, date contact from, date contact to
#   Table: party addresses
#     Columns: party id, address id, date address from, address type code, date address to
#   Table: party forms
#     Columns: party id, form id, date completion started, form status code, date fully completed
#   Table: party services
#     Columns: booking id, customer id, service id, service datetime, booking made date
# ==================================================
# Database: school_bus
#   Table: driver
#     Columns: driver id, name, party, home city, age
#   Table: school
#     Columns: school id, grade, school, location, type
#   Table: school bus
#     Columns: school id, driver id, years working, if full time
# ==================================================
# Database: machine_repair
#   Table: repair
#     Columns: repair id, name, launch date, notes
#   Table: machine
#     Columns: machine id, making year, class, team, machine series, value points, quality rank
#   Table: technician
#     Columns: technician id, name, team, starting year, age
#   Table: repair assignment
#     Columns: technician id, repair id, machine id
# ==================================================
# Database: theme_gallery
#   Table: artist
#     Columns: artist id, name, country, year join, age
#   Table: exhibition
#     Columns: exhibition id, year, theme, artist id, ticket price
#   Table: exhibition record
#     Columns: exhibition id, date, attendance
# ==================================================
# Database: film_rank
#   Table: film
#     Columns: film id, title, studio, director, gross in dollar
#   Table: market
#     Columns: market id, country, number cities
#   Table: film market estimation
#     Columns: estimation id, low estimate, high estimate, film id, type, market id, year
# ==================================================
# Database: party_people
#   Table: region
#     Columns: region id, region name, date, label, format, catalogue
#   Table: party
#     Columns: party id, minister, took office, left office, region id, party name
#   Table: member
#     Columns: member id, member name, party id, in office
#   Table: party events
#     Columns: event id, event name, party id, member in charge id
# ==================================================
# Database: hospital_1
#   Table: physician
#     Columns: employee id, name, position, ssn
#   Table: department
#     Columns: departmentid, name, head
#   Table: affiliated with
#     Columns: physician, department, primary affiliation
#   Table: procedures
#     Columns: code, name, cost
#   Table: trained in
#     Columns: physician, treatment, certification date, certification expires
#   Table: patient
#     Columns: ssn, name, address, phone, insurance id, pcp
#   Table: nurse
#     Columns: employee id, name, position, registered, ssn
#   Table: appointment
#     Columns: appointment id, patient, prep nurse, physician, start, end, examination room
#   Table: medication
#     Columns: code, name, brand, description
#   Table: prescribes
#     Columns: physician, patient, medication, date, appointment, dose
#   Table: block
#     Columns: block floor, block code
#   Table: room
#     Columns: roomnumber, room type, block floor, block code, unavailable
#   Table: on call
#     Columns: nurse, block floor, block code, oncall start, oncall end
#   Table: stay
#     Columns: stay id, patient, room, stay start, stay end
#   Table: undergoes
#     Columns: patient, procedures, stay, date undergoes, physician, assisting nurse
# ==================================================
# Database: customers_campaigns_ecommerce
#   Table: premises
#     Columns: premise id, premises type, premise details
#   Table: products
#     Columns: product id, product category, product name
#   Table: customers
#     Columns: customer id, payment method, customer name, customer phone, customer email, customer address, customer login, customer password
#   Table: mailshot campaigns
#     Columns: mailshot id, product category, mailshot name, mailshot start date, mailshot end date
#   Table: customer addresses
#     Columns: customer id, premise id, date address from, address type code, date address to
#   Table: customer orders
#     Columns: order id, customer id, order status code, shipping method code, order placed datetime, order delivered datetime, order shipping charges
#   Table: mailshot customers
#     Columns: mailshot id, customer id, outcome code, mailshot customer date
#   Table: order items
#     Columns: item id, order item status code, order id, product id, item status code, item delivered datetime, item order quantity
# ==================================================
# Database: gymnast
#   Table: gymnast
#     Columns: gymnast id, floor exercise points, pommel horse points, rings points, vault points, parallel bars points, horizontal bar points, total points
#   Table: people
#     Columns: people id, name, age, height, hometown
# ==================================================
# Database: restaurants
#   Table: geographic
#     Columns: city name, county, region
#   Table: restaurant
#     Columns: id, name, food type, city name, rating
#   Table: location
#     Columns: restaurant id, house number, street name, city name
# ==================================================
# Database: mountain_photos
#   Table: mountain
#     Columns: id, name, height, prominence, range, country
#   Table: camera lens
#     Columns: id, brand, name, focal length mm, max aperture
#   Table: photos
#     Columns: id, camera lens id, mountain id, color, name
# ==================================================
# Database: battle_death
#   Table: battle
#     Columns: id, name, date, bulgarian commander, latin commander, result
#   Table: ship
#     Columns: lost in battle, id, name, tonnage, ship type, location, disposition of ship
#   Table: death
#     Columns: caused by ship id, id, note, killed, injured
# ==================================================
# Database: cre_Doc_Control_Systems
#   Table: reference document types
#     Columns: document type code, document type description
#   Table: roles
#     Columns: role code, role description
#   Table: addresses
#     Columns: address id, address details
#   Table: reference document status
#     Columns: document status code, document status description
#   Table: reference shipping agents
#     Columns: shipping agent code, shipping agent name, shipping agent description
#   Table: documents
#     Columns: document id, document status code, document type code, shipping agent code, receipt date, receipt number, other details
#   Table: employees
#     Columns: employee id, role code, employee name, other details
#   Table: document drafts
#     Columns: document id, draft number, draft details
#   Table: draft copies
#     Columns: document id, draft number, copy number
#   Table: circulation history
#     Columns: document id, draft number, copy number, employee id
#   Table: documents mailed
#     Columns: document id, mailed to address id, mailing date
# ==================================================
# Database: tracking_share_transactions
#   Table: investors
#     Columns: investor id, investor details
#   Table: lots
#     Columns: lot id, investor id, lot details
#   Table: reference transaction types
#     Columns: transaction type code, transaction type description
#   Table: transactions
#     Columns: transaction id, investor id, transaction type code, date of transaction, amount of transaction, share count, other details
#   Table: sales
#     Columns: sales transaction id, sales details
#   Table: purchases
#     Columns: purchase transaction id, purchase details
#   Table: transactions lots
#     Columns: transaction id, lot id
# ==================================================
# Database: apartment_rentals
#   Table: apartment buildings
#     Columns: building id, building short name, building full name, building description, building address, building manager, building phone
#   Table: apartments
#     Columns: apartment id, building id, apartment type code, apartment number, bathroom count, bedroom count, room count
#   Table: apartment facilities
#     Columns: apartment id, facility code
#   Table: guests
#     Columns: guest id, gender code, guest first name, guest last name, date of birth
#   Table: apartment bookings
#     Columns: apartment booking id, apartment id, guest id, booking status code, booking start date, booking end date
#   Table: view unit status
#     Columns: apartment id, apartment booking id, status date, available yes or no
# ==================================================
# Database: student_transcripts_tracking
#   Table: addresses
#     Columns: address id, line 1, line 2, line 3, city, zip postcode, state province county, country, other address details
#   Table: courses
#     Columns: course id, course name, course description, other details
#   Table: departments
#     Columns: department id, department name, department description, other details
#   Table: degree programs
#     Columns: degree program id, department id, degree summary name, degree summary description, other details
#   Table: sections
#     Columns: section id, course id, section name, section description, other details
#   Table: semesters
#     Columns: semester id, semester name, semester description, other details
#   Table: students
#     Columns: student id, current address id, permanent address id, first name, middle name, last name, cell mobile number, email address, ssn, date first registered, date left, other student details
#   Table: student enrolment
#     Columns: student enrolment id, degree program id, semester id, student id, other details
#   Table: student enrolment courses
#     Columns: student course id, course id, student enrolment id
#   Table: transcripts
#     Columns: transcript id, transcript date, other details
#   Table: transcript contents
#     Columns: student course id, transcript id
# ==================================================
# Database: cre_Docs_and_Epenses
#   Table: reference document types
#     Columns: document type code, document type name, document type description
#   Table: reference budget codes
#     Columns: budget type code, budget type description
#   Table: projects
#     Columns: project id, project details
#   Table: documents
#     Columns: document id, document type code, project id, document date, document name, document description, other details
#   Table: statements
#     Columns: statement id, statement details
#   Table: documents with expenses
#     Columns: document id, budget type code, document details
#   Table: accounts
#     Columns: account id, statement id, account details
# ==================================================
# Database: ship_mission
#   Table: mission
#     Columns: mission id, ship id, code, launched year, location, speed knots, fate
#   Table: ship
#     Columns: ship id, name, type, nationality, tonnage
# ==================================================
# Database: company_office
#   Table: buildings
#     Columns: id, name, city, height, stories, status
#   Table: companies
#     Columns: id, name, headquarters, industry, sales billion, profits billion, assets billion, market value billion
#   Table: office locations
#     Columns: building id, company id, move in year
# ==================================================
# Database: tracking_software_problems
#   Table: problem category codes
#     Columns: problem category code, problem category description
#   Table: problem log
#     Columns: problem log id, assigned to staff id, problem id, problem category code, problem status code, log entry date, log entry description, log entry fix, other log details
#   Table: problem status codes
#     Columns: problem status code, problem status description
#   Table: product
#     Columns: product id, product name, product details
#   Table: staff
#     Columns: staff id, staff first name, staff last name, other staff details
#   Table: problems
#     Columns: problem id, product id, closure authorised by staff id, reported by staff id, date problem reported, date problem closed, problem description, other problem details
# ==================================================
# Database: products_gen_characteristics
#   Table: reference characteristic types
#     Columns: characteristic type code, characteristic type description
#   Table: reference colors
#     Columns: color code, color description
#   Table: reference product categories
#     Columns: product category code, product category description, unit of measure
#   Table: characteristics
# ...
#   Table: bookings
#     Columns: booking id, customer id, workshop group id, status code, store id, order date, planned delivery date, actual delivery date, other order details
#   Table: performers in bookings
#     Columns: order id, performer id
#   Table: customer orders
#     Columns: order id, customer id, store id, order date, planned delivery date, actual delivery date, other order details
#   Table: order items
#     Columns: order item id, order id, product id, order quantity, other item details
#   Table: invoices
#     Columns: invoice id, order id, payment method code, product id, order quantity, other item details, order item id
#   Table: services
#     Columns: service id, service type code, workshop group id, product description, product name, product price, other product service details
#   Table: bookings services
#     Columns: order id, product id
#   Table: invoice items
#     Columns: invoice item id, invoice id, order id, order item id, product id, order quantity, other item details
# ==================================================
# Database: car_1
#   Table: continents
#     Columns: cont id, continent
#   Table: countries
#     Columns: country id, country name, continent
#   Table: car makers
#     Columns: id, maker, full name, country
#   Table: model list
#     Columns: model id, maker, model
#   Table: car names
#     Columns: make id, model, make
#   Table: cars data
#     Columns: id, mpg, cylinders, edispl, horsepower, weight, accelerate, year
# ==================================================
# Database: geo
#   Table: state
#     Columns: state name, population, area, country name, capital, density
#   Table: city
#     Columns: city name, population, country name, state name
#   Table: border info
#     Columns: state name, border
#   Table: highlow
#     Columns: state name, highest elevation, lowest point, highest point, lowest elevation
#   Table: lake
#     Columns: lake name, area, country name, state name
#   Table: mountain
#     Columns: mountain name, mountain altitude, country name, state name
#   Table: river
#     Columns: river name, length, country name, traverse
# ==================================================
# Database: behavior_monitoring
#   Table: reference address types
#     Columns: address type code, address type description
#   Table: reference detention type
#     Columns: detention type code, detention type description
#   Table: reference incident type
#     Columns: incident type code, incident type description
#   Table: addresses
#     Columns: address id, line 1, line 2, line 3, city, zip postcode, state province county, country, other address details
#   Table: students
#     Columns: student id, address id, first name, middle name, last name, cell mobile number, email address, date first rental, date left university, other student details
#   Table: teachers
#     Columns: teacher id, address id, first name, middle name, last name, gender, cell mobile number, email address, other details
#   Table: assessment notes
#     Columns: notes id, student id, teacher id, date of notes, text of notes, other details
#   Table: behavior incident
#     Columns: incident id, incident type code, student id, date incident start, date incident end, incident summary, recommendations, other details
#   Table: detention
#     Columns: detention id, detention type code, teacher id, datetime detention start, datetime detention end, detention summary, other details
#   Table: student addresses
#     Columns: student id, address id, date address from, date address to, monthly rental, other details
#   Table: students in detention
#     Columns: student id, detention id, incident id
# ==================================================
# Database: cre_Doc_Tracking_DB
#   Table: reference document types
#     Columns: document type code, document type name, document type description
#   Table: reference calendar
#     Columns: calendar date, day number
#   Table: reference locations
#     Columns: location code, location name, location description
#   Table: roles
#     Columns: role code, role name, role description
#   Table: all documents
#     Columns: document id, date stored, document type code, document name, document description, other details
#   Table: employees
#     Columns: employee id, role code, employee name, gender mfu, date of birth, other details
#   Table: document locations
#     Columns: document id, location code, date in location from, date in locaton to
#   Table: documents to be destroyed
#     Columns: document id, destruction authorised by employee id, destroyed by employee id, planned destruction date, actual destruction date, other details
# ==================================================
# Database: university_basketball
#   Table: basketball match
#     Columns: team id, school id, team name, acc regular season, acc percent, acc home, acc road, all games, all games percent, all home, all road, all neutral
#   Table: university
#     Columns: school id, school, location, founded, affiliation, enrollment, nickname, primary conference
# ==================================================
# Database: soccer_2
#   Table: college
#     Columns: college name, state, enrollment
#   Table: player
#     Columns: player id, player name, yes card, training hours
#   Table: tryout
#     Columns: player id, college name, player position, decision
# ==================================================
# Database: activity_1
#   Table: activity
#     Columns: activity id, activity name
#   Table: participates in
#     Columns: student id, activity id
#   Table: faculty participates in
#     Columns: faculty id, activity id
#   Table: student
#     Columns: student id, last name, first name, age, sex, major, advisor, city code
#   Table: faculty
#     Columns: faculty id, last name, first name, rank, sex, phone, room, building
# ==================================================
# Database: cre_Theme_park
#   Table: ref hotel star ratings
#     Columns: star rating code, star rating description
#   Table: locations
#     Columns: location id, location name, address, other details
#   Table: ref attraction types
#     Columns: attraction type code, attraction type description
#   Table: visitors
#     Columns: tourist id, tourist details
#   Table: features
#     Columns: feature id, feature details
#   Table: hotels
#     Columns: hotel id, star rating code, pets allowed yn, price range, other hotel details
#   Table: tourist attractions
#     Columns: tourist attraction id, attraction type code, location id, how to get there, name, description, opening hours, other details
#   Table: street markets
#     Columns: market id, market details
#   Table: shops
#     Columns: shop id, shop details
#   Table: museums
#     Columns: museum id, museum details
#   Table: royal family
#     Columns: royal family id, royal family details
#   Table: theme parks
#     Columns: theme park id, theme park details
#   Table: visits
#     Columns: visit id, tourist attraction id, tourist id, visit date, visit details
#   Table: photos
#     Columns: photo id, tourist attraction id, name, description, filename, other details
#   Table: staff
#     Columns: staff id, tourist attraction id, name, other details
#   Table: tourist attraction features
#     Columns: tourist attraction id, feature id
# ==================================================
# Database: twitter_1
#   Table: follows
#     Columns: user id, follower id
#   Table: tweets
#     Columns: id, user id, text, create date
#   Table: user profiles
#     Columns: uid, name, email, partition id, followers
# ==================================================
# Database: election_representative
#   Table: election
#     Columns: election id, representative id, date, votes, vote percent, seats, place
#   Table: representative
#     Columns: representative id, name, state, party, lifespan
# ==================================================
# Database: voter_2
#   Table: student
#     Columns: student id, last name, first name, age, sex, major, advisor, city code
#   Table: voting record
#     Columns: student id, registration date, election cycle, president vote, vice president vote, secretary vote, treasurer vote, class president vote, class senator vote
# ==================================================
# Database: wedding
#   Table: people
#     Columns: people id, name, country, is male, age
#   Table: church
#     Columns: church id, name, organized by, open date, continuation of
#   Table: wedding
#     Columns: church id, male id, female id, year
# ==================================================
# Database: news_report
#   Table: event
#     Columns: event id, date, venue, name, event attendance
#   Table: journalist
#     Columns: journalist id, name, nationality, age, years working
#   Table: news report
#     Columns: journalist id, event id, work type
# ==================================================
# Database: wine_1
#   Table: grapes
#     Columns: id, grape, color
#   Table: appellations
#     Columns: no, appelation, county, state, area, isava
#   Table: wine
#     Columns: no, grape, winery, appelation, state, name, year, price, score, cases, drink
# ==================================================
# Database: customers_and_addresses
#   Table: addresses
#     Columns: address id, address content, city, zip postcode, state province county, country, other address details
#   Table: products
#     Columns: product id, product details
#   Table: customers
#     Columns: customer id, payment method, customer name, date became customer, other customer details
#   Table: customer addresses
#     Columns: customer id, address id, date address from, address type, date address to
#   Table: customer contact channels
#     Columns: customer id, channel code, active from date, active to date, contact number
#   Table: customer orders
#     Columns: order id, customer id, order status, order date, order details
#   Table: order items
#     Columns: order id, product id, order quantity
# ==================================================
# Database: protein_institute
#   Table: building
#     Columns: building id, name, street address, years as tallest, height feet, floors
#   Table: institution
#     Columns: institution id, institution, location, founded, type, enrollment, team, primary conference, building id
#   Table: protein
#     Columns: common name, protein name, divergence from human lineage, accession number, sequence length, sequence identity to human protein, institution id
# ==================================================
# Database: school_player
#   Table: school
#     Columns: school id, school, location, enrollment, founded, denomination, boys or girls, day or boarding, year entered competition, school colors
#   Table: school details
#     Columns: school id, nickname, colors, league, class, division
#   Table: school performance
#     Columns: school id, school year, class a, class aa
#   Table: player
#     Columns: player id, player, team, age, position, school id
# ==================================================
# Database: phone_1
#   Table: chip model
#     Columns: model name, launch year, ram mib, rom mib, slots, wifi, bluetooth
#   Table: screen mode
#     Columns: graphics mode, char cells, pixels, hardware colours, used kb, map, type
#   Table: phone
#     Columns: company name, hardware model name, accreditation type, accreditation level, date, chip model, screen mode
# ==================================================
# Database: tvshow
#   Table: tv channel
#     Columns: id, series name, country, language, content, pixel aspect ratio par, hight definition tv, pay per view ppv, package option
#   Table: tv series
#     Columns: id, episode, air date, rating, share, 18 49 rating share, viewers m, weekly rank, channel
#   Table: cartoon
#     Columns: id, title, directed by, written by, original air date, production code, channel
# ==================================================
# Database: wrestler
#   Table: wrestler
#     Columns: wrestler id, name, reign, days held, location, event
#   Table: elimination
#     Columns: elimination id, wrestler id, team, eliminated by, elimination move, time
# ==================================================
# Database: customer_complaints
#   Table: staff
#     Columns: staff id, gender, first name, last name, email address, phone number
#   Table: customers
#     Columns: customer id, customer type code, address line 1, address line 2, town city, state, email address, phone number
#   Table: products
#     Columns: product id, parent product id, product category code, date product first available, date product discontinued, product name, product description, product price
#   Table: complaints
#     Columns: complaint id, product id, customer id, complaint outcome code, complaint status code, complaint type code, date complaint raised, date complaint closed, staff id
# ==================================================
# Database: department_management
#   Table: department
#     Columns: department id, name, creation, ranking, budget in billions, num employees
#   Table: head
#     Columns: head id, name, born state, age
#   Table: management
#     Columns: department id, head id, temporary acting
# ==================================================
# Database: customers_and_products_contacts
#   Table: addresses
#     Columns: address id, line 1 number building, city, zip postcode, state province county, country
#   Table: products
#     Columns: product id, product type code, product name, product price
#   Table: customers
#     Columns: customer id, payment method code, customer number, customer name, customer address, customer phone, customer email
#   Table: contacts
#     Columns: contact id, customer id, gender, first name, last name, contact phone
#   Table: customer address history
#     Columns: customer id, address id, date from, date to
#   Table: customer orders
#     Columns: order id, customer id, order date, order status code
#   Table: order items
#     Columns: order item id, order id, product id, order quantity
# ==================================================
# Database: company_1
#   Table: works on
#     Columns: employee ssn, project number, hours
#   Table: employee
#     Columns: first name, minit, last name, ssn, birth date, address, sex, salary, super ssn, department no
#   Table: department
#     Columns: department name, department number, manager ssn, manager start date
#   Table: project
#     Columns: dependent name, dependent number, dependent location, department number
#   Table: dependent
#     Columns: employee ssn, dependent name, sex, birth date, relationship
#   Table: department locations
#     Columns: department number, department location
# ==================================================
# Database: workshop_paper
#   Table: workshop
#     Columns: workshop id, date, venue, name
#   Table: submission
#     Columns: submission id, scores, author, college
#   Table: acceptance
#     Columns: submission id, workshop id, result
# ==================================================
# Database: epinions_1
#   Table: item
#     Columns: item id, title
#   Table: review
#     Columns: a id, user id, item id, rating, rank
#   Table: useracct
#     Columns: user id, name
#   Table: trust
#     Columns: source user id, target user id, trust
# ==================================================
# Database: party_host
#   Table: party
#     Columns: party id, party theme, location, first year, last year, number of hosts
#   Table: host
#     Columns: host id, name, nationality, age
#   Table: party host
#     Columns: party id, host id, is main in charge
# ==================================================
# Database: product_catalog
#   Table: attribute definitions
#     Columns: attribute id, attribute name, attribute data type
#   Table: catalogs
#     Columns: catalog id, catalog name, catalog publisher, date of publication, date of latest revision
#   Table: catalog structure
#     Columns: catalog level number, catalog id, catalog level name
#   Table: catalog contents
#     Columns: catalog entry id, catalog level number, parent entry id, previous entry id, next entry id, catalog entry name, product stock number, price in dollars, price in euros, price in pounds, capacity, length, height, width
#   Table: catalog contents additional attributes
#     Columns: catalog entry id, catalog level number, attribute id, attribute value
# ==================================================

# %% [markdown]
# ### Below part is to redefining and reshaping essential_schemas to better suit for LLM

# %%
essential_schemas_reshape = {}
for db in essential_schemas: 
    db_name = db.get("database_name", "unknown")
    table_columns = []
    for idx, table_name in enumerate(db["table_names"]):
        cols = [col for t_idx, col in db["column_names"] if t_idx == idx]
        table_columns.append([table_name, cols])
    essential_schemas_reshape[db_name] = table_columns

essential_schemas_reshape
# Out:
# {'perpetrator': [['perpetrator',
#    ['perpetrator id',
#     'people id',
#     'date',
#     'year',
#     'location',
#     'country',
#     'killed',
#     'injured']],
#   ['people', ['people id', 'name', 'height', 'weight', 'home town']]],
#  'college_2': [['classroom', ['building', 'room number', 'capacity']],
#   ['department', ['department name', 'building', 'budget']],
#   ['course', ['course id', 'title', 'department name', 'credits']],
#   ['instructor', ['id', 'name', 'department name', 'salary']],
#   ['section',
#    ['course id',
#     'section id',
#     'semester',
#     'year',
#     'building',
#     'room number',
#     'time slot id']],
#   ['teaches', ['id', 'course id', 'section id', 'semester', 'year']],
#   ['student', ['id', 'name', 'department name', 'total credits']],
#   ['takes classes',
#    ['id', 'course id', 'section id', 'semester', 'year', 'grade']],
#   ['advisor', ['student id', 'instructor id']],
#   ['time slot',
#    ['time slot id',
#     'day',
#     'start hour',
#     'start minute',
#     'end hour',
#     'end minute']],
#   ['prerequisite', ['course id', 'prerequisite id']]],
#  'flight_company': [['airport',
#    ['id', 'city', 'country', 'iata', 'icao', 'name']],
#   ['operate company',
#    ['id',
#     'name',
#     'type',
#     'principal activities',
#     'incorporated in',
#     'group equity shareholding']],
#   ['flight',
#    ['id',
#     'vehicle flight number',
#     'date',
#     'pilot',
#     'velocity',
#     'altitude',
#     'airport id',
#     'company id']]],
#  'icfp_1': [['institution', ['institution id', 'name', 'country']],
#   ['authors', ['author id', 'last name', 'first name']],
#   ['papers', ['paper id', 'title']],
#   ['authorship count',
#    ['author id', 'institution id', 'paper id', 'author count']]],
#  'body_builder': [['body builder',
#    ['body builder id', 'people id', 'snatch', 'clean jerk', 'total']],
#   ['people',
#    ['people id', 'name', 'height', 'weight', 'birth date', 'birth place']]],
#  'storm_record': [['storm',
#    ['storm id',
#     'name',
#     'dates active',
#     'max speed',
#     'damage millions usd',
#     'number deaths']],
#   ['region', ['region id', 'region code', 'region name']],
#   ['affected region', ['region id', 'storm id', 'number city affected']]],
#  'pilot_record': [['aircraft',
#    ['aircraft id',
#     'order year',
#     'manufacturer',
#     'model',
#     'fleet series',
#     'powertrain',
#     'fuel propulsion']],
#   ['pilot',
#    ['pilot id',
#     'pilot name',
#     'rank',
#     'age',
#     'nationality',
#     'position',
#     'join year',
#     'team']],
#   ['pilot record', ['record id', 'pilot id', 'aircraft id', 'date']]],
#  'race_track': [['race', ['race id', 'name', 'class', 'date', 'track id']],
#   ['track', ['track id', 'name', 'location', 'seating', 'year opened']]],
#  'academic': [['author', ['aid', 'homepage', 'name', 'oid']],
#   ['conference', ['cid', 'homepage', 'name']],
#   ['domain', ['did', 'name']],
#   ['domain author', ['aid', 'did']],
#   ['domain conference', ['cid', 'did']],
#   ['journal', ['homepage', 'jid', 'name']],
#   ['domain journal', ['did', 'jid']],
#   ['keyword', ['keyword', 'kid']],
#   ['domain keyword', ['did', 'kid']],
#   ['publication',
#    ['abstract',
#     'cid',
#     'citation num',
#     'jid',
#     'pid',
#     'reference num',
#     'title',
#     'year']],
#   ['domain publication', ['did', 'pid']],
#   ['organization', ['continent', 'homepage', 'name', 'oid']],
#   ['publication keyword', ['pid', 'kid']],
#   ['writes', ['aid', 'pid']],
#   ['cite', ['cited', 'citing']]],
#  'department_store': [['addresses', ['address id', 'address details']],
#   ['staff', ['staff id', 'staff gender', 'staff name']],
#   ['suppliers', ['supplier id', 'supplier name', 'supplier phone']],
#   ['department store chain',
#    ['department store chain id', 'department store chain name']],
#   ['customers',
#    ['customer id',
#     'payment method code',
#     'customer code',
#     'customer name',
#     'customer address',
#     'customer phone',
#     'customer email']],
#   ['products',
#    ['product id', 'product type code', 'product name', 'product price']],
#   ['supplier addresses',
#    ['supplier id', 'address id', 'date from', 'date to']],
#   ['customer addresses',
#    ['customer id', 'address id', 'date from', 'date to']],
#   ['customer orders',
#    ['order id', 'customer id', 'order status code', 'order date']],
#   ['department stores',
#    ['department store id',
#     'department store chain id',
#     'store name',
#     'store address',
#     'store phone',
#     'store email']],
#   ['departments', ['department id', 'department store id', 'department name']],
#   ['order items', ['order item id', 'order id', 'product id']],
#   ['product suppliers',
#    ['product id',
#     'supplier id',
#     'date supplied from',
#     'date supplied to',
#     'total amount purchased',
#     'total value purchased']],
#   ['staff department assignments',
#    ['staff id',
#     'department id',
#     'date assigned from',
#     'job title code',
#     'date assigned to']]],
#  'music_4': [['artist',
#    ['artist id', 'artist', 'age', 'famous title', 'famous release date']],
#   ['volume',
#    ['volume id',
#     'volume issue',
#     'issue date',
#     'weeks on top',
#     'song',
#     'artist id']],
#   ['music festival',
#    ['id',
#     'music festival',
#     'date of ceremony',
#     'category',
#     'volume',
#     'result']]],
#  'insurance_fnol': [['customers', ['customer id', 'customer name']],
#   ['services', ['service id', 'service name']],
#   ['available policies', ['policy id', 'policy type code', 'customer phone']],
#   ['customers policies',
#    ['customer id', 'policy id', 'date opened', 'date closed']],
#   ['first notification of loss',
#    ['fnol id', 'customer id', 'policy id', 'service id']],
#   ['claims', ['claim id', 'fnol id', 'effective date']],
#   ['settlements',
#    ['settlement id', 'claim id', 'effective date', 'settlement amount']]],
#  'cinema': [['film',
#    ['film id',
#     'rank in series',
#     'number in season',
#     'title',
#     'directed by',
#     'original air date',
#     'production code']],
#   ['cinema', ['cinema id', 'name', 'openning year', 'capacity', 'location']],
#   ['schedule',
#    ['cinema id', 'film id', 'date', 'show times per day', 'price']]],
#  'decoration_competition': [['college',
#    ['college id', 'name', 'leader name', 'college location']],
#   ['member', ['member id', 'name', 'country', 'college id']],
#   ['round', ['round id', 'member id', 'decoration theme', 'rank in round']]],
#  'phone_market': [['phone',
#    ['name', 'phone id', 'memory in g', 'carrier', 'price']],
#   ['market',
#    ['market id', 'district', 'num of employees', 'num of shops', 'ranking']],
#   ['phone market', ['market id', 'phone id', 'num of stock']]],
#  'store_product': [['product',
#    ['product id',
#     'product',
#     'dimensions',
#     'dpi',
#     'pages per minute color',
#     'max page size',
#     'interface']],
#   ['store',
#    ['store id',
#     'store name',
#     'type',
#     'area size',
#     'number of product category',
#     'ranking']],
#   ['district',
#    ['district id',
#     'district name',
#     'headquartered city',
#     'city population',
#     'city area']],
#   ['store product', ['store id', 'product id']],
#   ['store district', ['store id', 'district id']]],
#  'assets_maintenance': [['third party companies',
#    ['company id',
#     'company type',
#     'company name',
#     'company address',
#     'other company details']],
#   ['maintenance contracts',
#    ['maintenance contract id',
#     'maintenance contract company id',
#     'contract start date',
#     'contract end date',
#     'other contract details']],
#   ['parts',
#    ['part id',
#     'part name',
#     'chargeable yn',
#     'chargeable amount',
#     'other part details']],
#   ['skills', ['skill id', 'skill code', 'skill description']],
#   ['staff', ['staff id', 'staff name', 'gender', 'other staff details']],
#   ['assets',
#    ['asset id',
#     'maintenance contract id',
#     'supplier company id',
#     'asset details',
#     'asset make',
#     'asset model',
#     'asset acquired date',
#     'asset disposed date',
#     'other asset details']],
#   ['asset parts', ['asset id', 'part id']],
#   ['maintenance engineers',
#    ['engineer id', 'company id', 'first name', 'last name', 'other details']],
#   ['engineer skills', ['engineer id', 'skill id']],
#   ['fault log',
#    ['fault log entry id',
#     'asset id',
#     'recorded by staff id',
#     'fault log entry datetime',
#     'fault description',
#     'other fault details']],
#   ['engineer visits',
#    ['engineer visit id',
#     'contact staff id',
#     'engineer id',
#     'fault log entry id',
#     'fault status',
#     'visit start datetime',
#     'visit end datetime',
#     'other visit details']],
#   ['part faults',
#    ['part fault id',
#     'part id',
#     'fault short name',
#     'fault description',
#     'other fault details']],
#   ['fault log parts', ['fault log entry id', 'part fault id', 'fault status']],
#   ['skills required to fix', ['part fault id', 'skill id']]],
#  'student_assessment': [['addresses',
#    ['address id',
#     'line 1',
#     'line 2',
#     'city',
#     'zip postcode',
#     'state province county',
#     'country']],
#   ['people',
#    ['person id',
#     'first name',
#     'middle name',
#     'last name',
#     'cell mobile number',
#     'email address',
#     'login name',
#     'password']],
#   ['students', ['student id', 'student details']],
#   ['courses',
#    ['course id', 'course name', 'course description', 'other details']],
#   ['people addresses',
#    ['person address id', 'person id', 'address id', 'date from', 'date to']],
#   ['student course registrations',
#    ['student id', 'course id', 'registration date']],
#   ['student course attendance',
#    ['student id', 'course id', 'date of attendance']],
#   ['candidates', ['candidate id', 'candidate details']],
#   ['candidate assessments',
#    ['candidate id',
#     'qualification',
#     'assessment date',
#     'asessment outcome code']]],
#  'dog_kennels': [['breeds', ['breed code', 'breed name']],
#   ['charges', ['charge id', 'charge type', 'charge amount']],
#   ['sizes', ['size code', 'size description']],
#   ['treatment types', ['treatment type code', 'treatment type description']],
#   ['owners',
#    ['owner id',
#     'first name',
#     'last name',
#     'street',
#     'city',
#     'state',
#     'zip code',
#     'email address',
#     'home phone',
#     'cell number']],
#   ['dogs',
#    ['dog id',
#     'owner id',
#     'abandoned yes or no',
#     'breed code',
#     'size code',
#     'name',
#     'age',
#     'date of birth',
#     'gender',
#     'weight',
#     'date arrived',
#     'date adopted',
#     'date departed']],
#   ['professionals',
#    ['professional id',
#     'role code',
#     'first name',
#     'street',
#     'city',
#     'state',
#     'zip code',
#     'last name',
#     'email address',
#     'home phone',
#     'cell number']],
#   ['treatments',
#    ['treatment id',
#     'dog id',
#     'professional id',
#     'treatment type code',
#     'date of treatment',
#     'cost of treatment']]],
#  'music_1': [['genre', ['genre name', 'rating', 'most popular in']],
#   ['artist', ['artist name', 'country', 'gender', 'preferred genre']],
#   ['files', ['song id', 'artist name', 'file size', 'duration', 'formats']],
#   ['song',
#    ['song name',
#     'artist name',
#     'country',
#     'song id',
#     'genre is',
#     'rating',
#     'languages',
#     'releasedate',
#     'resolution']]],
#  'company_employee': [['people',
#    ['people id', 'age', 'name', 'nationality', 'graduation college']],
#   ['company',
#    ['company id',
#     'name',
#     'headquarters',
#     'industry',
#     'sales in billion',
#     'profits in billion',
#     'assets in billion',
#     'market value in billion']],
#   ['employment', ['company id', 'people id', 'year working']]],
#  'farm': [['city',
#    ['city id',
#     'official name',
#     'status',
#     'area km 2',
#     'population',
#     'census ranking']],
#   ['farm',
#    ['farm id',
#     'year',
#     'total horses',
#     'working horses',
#     'total cattle',
#     'oxen',
#     'bulls',
#     'cows',
#     'pigs',
#     'sheep and goats']],
#   ['farm competition',
#    ['competition id', 'year', 'theme', 'host city id', 'hosts']],
#   ['competition record', ['competition id', 'farm id', 'rank']]],
#  'solvency_ii': [['addresses', ['address id', 'address details']],
#   ['locations', ['location id', 'other details']],
#   ['products',
#    ['product id', 'product type code', 'product name', 'product price']],
#   ['parties', ['party id', 'party details']],
#   ['assets', ['asset id', 'other details']],
#   ['channels', ['channel id', 'other details']],
#   ['finances', ['finance id', 'other details']],
#   ['events',
#    ['event id',
#     'address id',
#     'channel id',
#     'event type code',
#     'finance id',
#     'location id']],
#   ['products in events', ['product in event id', 'event id', 'product id']],
#   ['parties in events', ['party id', 'event id', 'role code']],
#   ['agreements', ['document id', 'event id']],
#   ['assets in events', ['asset id', 'event id']]],
#  'city_record': [['city',
#    ['city id', 'city', 'hanzi', 'hanyu pinyin', 'regional population', 'gdp']],
#   ['match', ['match id', 'date', 'venue', 'score', 'result', 'competition']],
#   ['temperature',
#    ['city id',
#     'jan',
#     'feb',
#     'mar',
#     'apr',
#     'jun',
#     'jul',
#     'aug',
#     'sep',
#     'oct',
#     'nov',
#     'dec']],
#   ['hosting city', ['year', 'match id', 'host city']]],
#  'swimming': [['swimmer',
#    ['id',
#     'name',
#     'nationality',
#     'meter 100',
#     'meter 200',
#     'meter 300',
#     'meter 400',
#     'meter 500',
#     'meter 600',
#     'meter 700',
#     'time']],
#   ['stadium', ['id', 'name', 'capacity', 'city', 'country', 'opening year']],
#   ['event', ['id', 'name', 'stadium id', 'year']],
#   ['record', ['id', 'result', 'swimmer id', 'event id']]],
#  'flight_2': [['airlines',
#    ['airline id', 'airline name', 'abbreviation', 'country']],
#   ['airports',
#    ['city', 'airport code', 'airport name', 'country', 'country abbrev']],
#   ['flights',
#    ['airline', 'flight number', 'source airport', 'destination airport']]],
#  'election': [['county',
#    ['county id', 'county name', 'population', 'zip code']],
#   ['party',
#    ['party id',
#     'year',
#     'party',
#     'governor',
#     'lieutenant governor',
#     'comptroller',
#     'attorney general',
#     'us senate']],
#   ['election',
#    ['election id',
#     'counties represented',
#     'district',
#     'delegate',
#     'party',
#     'first elected',
#     'committee']]],
#  'manufactory_1': [['manufacturers',
#    ['code', 'name', 'headquarter', 'founder', 'revenue']],
#   ['products', ['code', 'name', 'price', 'manufacturer']]],
#  'debate': [['people', ['people id', 'district', 'name', 'party', 'age']],
#   ['debate', ['debate id', 'date', 'venue', 'num of audience']],
#   ['debate people',
#    ['debate id', 'affirmative', 'negative', 'if affirmative win']]],
#  'network_2': [['person', ['name', 'age', 'city', 'gender', 'job']],
#   ['person friend', ['name', 'friend', 'year']]],
#  'local_govt_in_alabama': [['services', ['service id', 'service type code']],
#   ['participants',
#    ['participant id', 'participant type code', 'participant details']],
#   ['events', ['event id', 'service id', 'event details']],
#   ['participants in events', ['event id', 'participant id']]],
#  'climbing': [['mountain',
#    ['mountain id', 'name', 'height', 'prominence', 'range', 'country']],
#   ['climber',
#    ['climber id', 'name', 'country', 'time', 'points', 'mountain id']]],
#  'e_learning': [['course authors and tutors',
#    ['author id',
#     'author tutor atb',
#     'login name',
#     'password',
#     'personal name',
#     'middle name',
#     'family name',
#     'gender mf',
#     'address line 1']],
#   ['students',
#    ['student id',
#     'date of registration',
#     'date of latest logon',
#     'login name',
#     'password',
#     'personal name',
#     'middle name',
#     'family name']],
#   ['subjects', ['subject id', 'subject name']],
#   ['courses',
#    ['course id',
#     'author id',
#     'subject id',
#     'course name',
#     'course description']],
#   ['student course enrolment',
#    ['registration id',
#     'student id',
#     'course id',
#     'date of enrolment',
#     'date of completion']],
#   ['student tests taken',
#    ['registration id', 'date test taken', 'test result']]],
#  'scientist_1': [['scientists', ['ssn', 'name']],
#   ['projects', ['code', 'name', 'hours']],
#   ['assigned to', ['scientist', 'project']]],
#  'ship_1': [['captain',
#    ['captain id', 'name', 'ship id', 'age', 'class', 'rank']],
#   ['ship', ['ship id', 'name', 'type', 'built year', 'class', 'flag']]],
#  'entertainment_awards': [['festival detail',
#    ['festival id',
#     'festival name',
#     'chair name',
#     'location',
#     'year',
#     'num of audience']],
#   ['artwork', ['artwork id', 'type', 'name']],
#   ['nomination', ['artwork id', 'festival id', 'result']]],
#  'allergy_1': [['allergy type', ['allergy name', 'allergy type']],
#   ['has allergy', ['stuid', 'allergy']],
#   ['student',
#    ['stuid',
#     'last name',
#     'first name',
#     'age',
#     'sex',
#     'major',
#     'advisor',
#     'city code']]],
#  'imdb': [['actor',
#    ['aid', 'gender', 'name', 'nationality', 'birth city', 'birth year']],
#   ['copyright', ['id', 'msid', 'cid']],
#   ['cast', ['id', 'msid', 'aid', 'role']],
#   ['genre', ['gid', 'genre']],
#   ['classification', ['id', 'msid', 'gid']],
#   ['company', ['id', 'name', 'country code']],
#   ['director',
#    ['did', 'gender', 'name', 'nationality', 'birth city', 'birth year']],
#   ['producer',
#    ['pid', 'gender', 'name', 'nationality', 'birth city', 'birth year']],
#   ['directed by', ['id', 'msid', 'did']],
#   ['keyword', ['id', 'keyword']],
#   ['made by', ['id', 'msid', 'pid']],
#   ['movie', ['mid', 'title', 'release year', 'title aka', 'budget']],
#   ['tags', ['id', 'msid', 'kid']],
#   ['tv series',
#    ['sid',
#     'title',
#     'release year',
#     'num of seasons',
#     'num of episodes',
#     'title aka',
#     'budget']],
#   ['writer',
#    ['wid',
#     'gender',
#     'name',
#     'nationality',
#     'num of episodes',
#     'birth city',
#     'birth year']],
#   ['written by', ['id', 'msid', 'wid']]],
#  'products_for_hire': [['discount coupons',
#    ['coupon id', 'date issued', 'coupon amount']],
#   ['customers',
#    ['customer id',
#     'coupon id',
#     'good or bad customer',
#     'first name',
#     'last name',
#     'gender',
#     'date became customer',
#     'date last hire']],
#   ['bookings',
#    ['booking id',
#     'customer id',
#     'booking status code',
#     'returned damaged yes or no',
#     'booking start date',
#     'booking end date',
#     'count hired',
#     'amount payable',
#     'amount of discount',
#     'amount outstanding',
#     'amount of refund']],
#   ['products for hire',
#    ['product id',
#     'product type code',
#     'daily hire cost',
#     'product name',
#     'product description']],
#   ['payments',
#    ['payment id',
#     'booking id',
#     'customer id',
#     'payment type code',
#     'amount paid in full yn',
#     'payment date',
#     'amount due',
#     'amount paid']],
#   ['products booked',
#    ['booking id',
#     'product id',
#     'returned yes or no',
#     'returned late yes or no',
#     'booked count',
#     'booked amount']],
#   ['view product availability',
#    ['product id', 'booking id', 'status date', 'available yes or no']]],
#  'candidate_poll': [['candidate',
#    ['candidate id',
#     'people id',
#     'poll source',
#     'date',
#     'support rate',
#     'consider rate',
#     'oppose rate',
#     'unsure rate']],
#   ['people',
#    ['people id', 'sex', 'name', 'date of birth', 'height', 'weight']]],
#  'chinook_1': [['album', ['album id', 'title', 'artist id']],
#   ['artist', ['artist id', 'name']],
#   ['customer',
#    ['customer id',
#     'first name',
#     'last name',
#     'company',
#     'address',
#     'city',
#     'state',
#     'country',
#     'postal code',
#     'phone',
#     'fax',
#     'email',
#     'support representative id']],
#   ['employee',
#    ['employee id',
#     'last name',
#     'first name',
#     'title',
#     'reports to',
#     'birth date',
#     'hire date',
#     'address',
#     'city',
#     'state',
#     'country',
#     'postal code',
#     'phone',
#     'fax',
#     'email']],
#   ['genre', ['genre id', 'name']],
#   ['invoice',
#    ['invoice id',
#     'customer id',
#     'invoice date',
#     'billing address',
#     'billing city',
#     'billing state',
#     'billing country',
#     'billing postal code',
#     'total']],
#   ['invoice line',
#    ['invoice line id', 'invoice id', 'track id', 'unit price', 'quantity']],
#   ['media type', ['media type id', 'name']],
#   ['playlist', ['play list id', 'name']],
#   ['playlist track', ['play list id', 'track id']],
#   ['track',
#    ['track id',
#     'name',
#     'album id',
#     'media type id',
#     'genre id',
#     'composer',
#     'milliseconds',
#     'bytes',
#     'unit price']]],
#  'flight_4': [['routes',
#    ['route id',
#     'destination airport id',
#     'destination airport',
#     'source airport id',
#     'source airport',
#     'airline id',
#     'airline',
#     'code share']],
#   ['airports',
#    ['airport id',
#     'name',
#     'city',
#     'country',
#     'x',
#     'y',
#     'elevation',
#     'iata',
#     'icao']],
#   ['airlines',
#    ['airline id', 'name', 'iata', 'icao', 'call sign', 'country', 'active']]],
#  'pets_1': [['student',
#    ['student id',
#     'last name',
#     'first name',
#     'age',
#     'sex',
#     'major',
#     'advisor',
#     'city code']],
#   ['has pet', ['student id', 'pet id']],
#   ['pets', ['pet id', 'pet type', 'pet age', 'weight']]],
#  'dorm_1': [['student',
#    ['student id',
#     'last name',
#     'first name',
#     'age',
#     'sex',
#     'major',
#     'advisor',
#     'city code']],
#   ['dorm', ['dorm id', 'dorm name', 'student capacity', 'gender']],
#   ['dorm amenity', ['amenity id', 'amenity name']],
#   ['has amenity', ['dorm id', 'amenity id']],
#   ['lives in', ['student id', 'dorm id', 'room number']]],
#  'journal_committee': [['journal', ['journal id', 'date', 'theme', 'sales']],
#   ['editor', ['editor id', 'name', 'age']],
#   ['journal committee', ['editor id', 'journal id', 'work type']]],
#  'flight_1': [['flight',
#    ['flight number',
#     'origin',
#     'destination',
#     'distance',
#     'departure date',
#     'arrival date',
#     'price',
#     'airline id']],
#   ['aircraft', ['airline id', 'name', 'distance']],
#   ['employee', ['employee id', 'name', 'salary']],
#   ['certificate', ['employee id', 'airline id']]],
#  'medicine_enzyme_interaction': [['medicine',
#    ['id', 'name', 'trade name', 'fda approved']],
#   ['enzyme',
#    ['id', 'name', 'location', 'product', 'chromosome', 'omim', 'porphyria']],
#   ['medicine enzyme interaction',
#    ['enzyme id', 'medicine id', 'interaction type']]],
#  'local_govt_and_lot': [['customers', ['customer id', 'customer details']],
#   ['properties',
#    ['property id', 'property type code', 'property address', 'other details']],
#   ['residents',
#    ['resident id',
#     'property id',
#     'date moved in',
#     'date moved out',
#     'other details']],
#   ['organizations',
#    ['organization id', 'parent organization id', 'organization details']],
#   ['services',
#    ['service id', 'organization id', 'service type code', 'service details']],
#   ['residents services',
#    ['resident id',
#     'service id',
#     'date moved in',
#     'property id',
#     'date requested',
#     'date provided',
#     'other details']],
#   ['things',
#    ['thing id',
#     'organization id',
#     'type of thing code',
#     'service type code',
#     'service details']],
#   ['customer events',
#    ['customer event id',
#     'customer id',
#     'date moved in',
#     'property id',
#     'resident id',
#     'thing id']],
#   ['customer event notes',
#    ['customer event note id',
#     'customer event id',
#     'service type code',
#     'resident id',
#     'property id',
#     'date moved in']],
#   ['timed status of things',
#    ['thing id', 'date and date', 'status of thing code']],
#   ['timed locations of things',
#    ['thing id', 'date and time', 'location code']]],
#  'station_weather': [['train',
#    ['id',
#     'train number',
#     'name',
#     'origin',
#     'destination',
#     'time',
#     'interval']],
#   ['station', ['id', 'network name', 'services', 'local authority']],
#   ['route', ['train id', 'station id']],
#   ['weekly weather',
#    ['station id',
#     'day of week',
#     'high temperature',
#     'low temperature',
#     'precipitation',
#     'wind speed mph']]],
#  'shop_membership': [['member',
#    ['member id', 'card number', 'name', 'hometown', 'level']],
#   ['branch',
#    ['branch id',
#     'name',
#     'open year',
#     'address road',
#     'city',
#     'membership amount']],
#   ['membership register branch', ['member id', 'branch id', 'register year']],
#   ['purchase', ['member id', 'branch id', 'year', 'total pounds']]],
#  'driving_school': [['addresses',
#    ['address id',
#     'line 1 number building',
#     'city',
#     'zip postcode',
#     'state province county',
#     'country']],
#   ['staff',
#    ['staff id',
#     'staff address id',
#     'nickname',
#     'first name',
#     'middle name',
#     'last name',
#     'date of birth',
#     'date joined staff',
#     'date left staff']],
#   ['vehicles', ['vehicle id', 'vehicle details']],
#   ['customers',
#    ['customer id',
#     'customer address id',
#     'customer status code',
#     'date became customer',
#     'date of birth',
#     'first name',
#     'last name',
#     'amount outstanding',
#     'email address',
#     'phone number',
#     'cell mobile phone number']],
#   ['customer payments',
#    ['customer id',
#     'datetime payment',
#     'payment method code',
#     'amount payment']],
#   ['lessons',
#    ['lesson id',
#     'customer id',
#     'lesson status code',
#     'staff id',
#     'vehicle id',
#     'lesson date',
#     'lesson time',
#     'price']]],
#  'concert_singer': [['stadium',
#    ['stadium id',
#     'location',
#     'name',
#     'capacity',
#     'highest',
#     'lowest',
#     'average']],
#   ['singer',
#    ['singer id',
#     'name',
#     'country',
#     'song name',
#     'song release year',
#     'age',
#     'is male']],
#   ['concert', ['concert id', 'concert name', 'theme', 'stadium id', 'year']],
#   ['singer in concert', ['concert id', 'singer id']]],
#  'music_2': [['songs', ['song id', 'title']],
#   ['albums', ['aid', 'title', 'year', 'label', 'type']],
#   ['band', ['id', 'first name', 'last name']],
#   ['instruments', ['song id', 'bandmate id', 'instrument']],
#   ['performance', ['song id', 'bandmate', 'stage position']],
#   ['track lists', ['album id', 'position', 'song id']],
#   ['vocals', ['song id', 'bandmate', 'type']]],
#  'sports_competition': [['club', ['club id', 'name', 'region', 'start year']],
#   ['club rank', ['rank', 'club id', 'gold', 'silver', 'bronze', 'total']],
#   ['player',
#    ['player id',
#     'name',
#     'position',
#     'club id',
#     'apps',
#     'tries',
#     'goals',
#     'points']],
#   ['competition', ['competition id', 'year', 'competition type', 'country']],
#   ['competition result',
#    ['competition id', 'club id 1', 'club id 2', 'score']]],
#  'railway': [['railway',
#    ['railway id',
#     'railway',
#     'builder',
#     'built',
#     'wheels',
#     'location',
#     'objectnumber']],
#   ['train',
#    ['train id', 'train num', 'name', 'from', 'arrival', 'railway id']],
#   ['manager',
#    ['manager id', 'name', 'country', 'working year starts', 'age', 'level']],
#   ['railway manage', ['railway id', 'manager id', 'from year']]],
#  'inn_1': [['rooms',
#    ['room id',
#     'room name',
#     'beds',
#     'bed type',
#     'max occupancy',
#     'base price',
#     'decor']],
#   ['reservations',
#    ['code',
#     'room',
#     'check in',
#     'check out',
#     'rate',
#     'last name',
#     'first name',
#     'adults',
#     'kids']]],
#  'museum_visit': [['museum',
#    ['museum id', 'name', 'num of staff', 'open year']],
#   ['customer', ['customer id', 'name', 'level of membership', 'age']],
#   ['visit', ['museum id', 'customer id', 'num of ticket', 'total spent']]],
#  'browser_web': [['web client accelerator',
#    ['id', 'name', 'operating system', 'client', 'connection']],
#   ['browser', ['id', 'name', 'market share']],
#   ['accelerator compatible browser',
#    ['accelerator id', 'browser id', 'compatible since year']]],
#  'baseball_1': [['all star',
#    ['player id',
#     'year',
#     'game num',
#     'game id',
#     'team id',
#     'league id',
#     'gp',
#     'starting pos']],
#   ['appearances',
#    ['year',
#     'team id',
#     'league id',
#     'player id',
#     'g all',
#     'gs',
#     'g batting',
#     'g defense',
#     'g p',
#     'g c',
#     'g 1b',
#     'g 2b',
#     'g 3b',
#     'g ss',
#     'g lf',
#     'g cf',
#     'g rf',
#     'g of',
#     'g dh',
#     'g ph',
#     'g pr']],
#   ['manager award',
#    ['player id', 'award id', 'year', 'league id', 'tie', 'notes']],
#   ['player award',
#    ['player id', 'award id', 'year', 'league id', 'tie', 'notes']],
#   ['manager award vote',
#    ['award id',
#     'year',
#     'league id',
#     'player id',
#     'points won',
#     'points max',
#     'votes first']],
#   ['player award vote',
#    ['award id',
#     'year',
#     'league id',
#     'player id',
#     'points won',
#     'points max',
#     'votes first']],
#   ['batting',
#    ['player id',
#     'year',
#     'stint',
#     'team id',
#     'league id',
#     'g',
#     'ab',
#     'r',
#     'h',
#     'double',
#     'triple',
#     'hr',
#     'rbi',
#     'sb',
#     'cs',
#     'bb',
#     'so',
#     'ibb',
#     'hbp',
#     'sh',
#     'sf',
#     'g idp']],
#   ['batting postseason',
#    ['year',
#     'round',
#     'player id',
#     'team id',
#     'league id',
#     'g',
#     'ab',
#     'r',
#     'h',
#     'double',
#     'triple',
#     'hr',
#     'rbi',
#     'sb',
#     'cs',
#     'bb',
#     'so',
#     'ibb',
#     'hbp',
#     'sh',
#     'sf',
#     'g idp']],
#   ['player college', ['player id', 'college id', 'year']],
#   ['fielding',
#    ['player id',
#     'year',
#     'stint',
#     'team id',
#     'league id',
#     'pos',
#     'g',
#     'gs',
#     'inn outs',
#     'po',
#     'a',
#     'e',
#     'dp',
#     'pb',
#     'wp',
#     'sb',
#     'cs',
#     'zr']],
#   ['fielding outfield', ['player id', 'year', 'stint', 'glf', 'gcf', 'grf']],
#   ['fielding postseason',
#    ['player id',
#     'year',
#     'team id',
#     'league id',
#     'round',
#     'pos',
#     'g',
#     'gs',
#     'inn outs',
#     'po',
#     'a',
#     'e',
#     'dp',
#     'tp',
#     'pb',
#     'sb',
#     'cs']],
#   ['hall of fame',
#    ['player id',
#     'yearid',
#     'votedby',
#     'ballots',
#     'needed',
#     'votes',
#     'inducted',
#     'category',
#     'needed note']],
#   ['home game',
#    ['year',
#     'league id',
#     'team id',
#     'park id',
#     'span first',
#     'span last',
#     'games',
#     'openings',
#     'attendance']],
#   ['manager',
#    ['player id',
#     'year',
#     'team id',
#     'league id',
#     'inseason',
#     'g',
#     'w',
#     'l',
#     'rank',
#     'plyr mgr']],
#   ['manager half',
#    ['player id',
#     'year',
#     'team id',
#     'league id',
#     'inseason',
#     'half',
#     'g',
#     'w',
#     'l',
#     'rank']],
#   ['player',
#    ['player id',
#     'birth year',
#     'birth month',
#     'birth day',
#     'birth country',
#     'birth state',
#     'birth city',
#     'death year',
#     'death month',
#     'death day',
#     'death country',
#     'death state',
#     'death city',
#     'name first',
#     'name last',
#     'name given',
#     'weight',
#     'height',
#     'bats',
#     'throws',
#     'debut',
#     'final game',
#     'retro id',
#     'bbref id']],
#   ['park', ['park id', 'park name', 'park alias', 'city', 'state', 'country']],
#   ['pitching',
#    ['player id',
#     'year',
#     'stint',
#     'team id',
#     'league id',
#     'w',
#     'l',
#     'g',
#     'gs',
#     'cg',
#     'sho',
#     'sv',
#     'ipouts',
#     'h',
#     'er',
#     'hr',
#     'bb',
#     'so',
#     'baopp',
#     'era',
#     'ibb',
#     'wp',
#     'hbp',
#     'bk',
#     'bfp',
#     'gf',
#     'r',
#     'sh',
#     'sf',
#     'g idp']],
#   ['pitching postseason',
#    ['player id',
#     'year',
#     'round',
#     'team id',
#     'league id',
#     'w',
#     'l',
#     'g',
#     'gs',
#     'cg',
#     'sho',
#     'sv',
#     'ipouts',
#     'h',
#     'er',
#     'hr',
#     'bb',
#     'so',
#     'baopp',
#     'era',
#     'ibb',
#     'wp',
#     'hbp',
#     'bk',
#     'bfp',
#     'gf',
#     'r',
#     'sh',
#     'sf',
#     'g idp']],
#   ['salary', ['year', 'team id', 'league id', 'player id', 'salary']],
#   ['college', ['college id', 'name full', 'city', 'state', 'country']],
#   ['postseason',
#    ['year',
#     'round',
#     'team id winner',
#     'league id winner',
#     'team id loser',
#     'league id loser',
#     'wins',
#     'losses',
#     'ties']],
#   ['team',
#    ['year',
#     'league id',
#     'team id',
#     'franchise id',
#     'div id',
#     'rank',
#     'g',
#     'ghome',
#     'w',
#     'l',
#     'div win',
#     'wc win',
#     'lg win',
#     'ws win',
#     'r',
#     'ab',
#     'h',
#     'double',
#     'triple',
#     'hr',
#     'bb',
#     'so',
#     'sb',
#     'cs',
#     'hbp',
#     'sf',
#     'ra',
#     'er',
#     'era',
#     'cg',
#     'sho',
#     'sv',
#     'ipouts',
#     'ha',
#     'hra',
#     'bba',
#     'soa',
#     'e',
#     'dp',
#     'fp',
#     'name',
#     'park',
#     'attendance',
#     'bpf',
#     'ppf',
#     'team id br',
#     'team id lahman45',
#     'team id retro']],
#   ['team franchise', ['franchise id', 'franchise name', 'active', 'na assoc']],
#   ['team half',
#    ['year',
#     'league id',
#     'team id',
#     'half',
#     'div id',
#     'div win',
#     'rank',
#     'g',
#     'w',
#     'l']]],
#  'architecture': [['architect', ['id', 'name', 'nationality', 'gender']],
#   ['bridge',
#    ['architect id', 'id', 'name', 'location', 'length meters', 'length feet']],
#   ['mill',
#    ['architect id', 'id', 'location', 'name', 'type', 'built year', 'notes']]],
#  'csu_1': [['campuses', ['id', 'campus', 'location', 'county', 'year']],
#   ['csu fees', ['campus', 'year', 'campus fee']],
#   ['degrees', ['year', 'campus', 'degrees']],
#   ['discipline enrollments',
#    ['campus', 'discipline', 'year', 'undergraduate', 'graduate']],
#   ['enrollments', ['campus', 'year', 'totalenrollment ay', 'fte ay']],
#   ['faculty', ['campus', 'year', 'faculty']]],
#  'tracking_orders': [['customers',
#    ['customer id', 'customer name', 'customer details']],
#   ['invoices', ['invoice number', 'invoice date', 'invoice details']],
#   ['orders',
#    ['order id',
#     'customer id',
#     'order status',
#     'date order placed',
#     'order details']],
#   ['products', ['product id', 'product name', 'product details']],
#   ['order items',
#    ['order item id',
#     'product id',
#     'order id',
#     'order item status',
#     'order item details']],
#   ['shipments',
#    ['shipment id',
#     'order id',
#     'invoice number',
#     'shipment tracking number',
#     'shipment date',
#     'other shipment details']],
#   ['shipment items', ['shipment id', 'order item id']]],
#  'insurance_policies': [['customers', ['customer id', 'customer details']],
#   ['customer policies',
#    ['policy id', 'customer id', 'policy type code', 'start date', 'end date']],
#   ['claims',
#    ['claim id',
#     'policy id',
#     'date claim made',
#     'date claim settled',
#     'amount claimed',
#     'amount settled']],
#   ['settlements',
#    ['settlement id',
#     'claim id',
#     'date claim made',
#     'date claim settled',
#     'amount claimed',
#     'amount settled',
#     'customer policy id']],
#   ['payments',
#    ['payment id',
#     'settlement id',
#     'payment method code',
#     'date payment made',
#     'amount payment']]],
#  'gas_company': [['company',
#    ['company id',
#     'rank',
#     'company',
#     'headquarters',
#     'main industry',
#     'sales billion',
#     'profits billion',
#     'assets billion',
#     'market value']],
#   ['gas station',
#    ['station id',
#     'open year',
#     'location',
#     'manager name',
#     'vice manager name',
#     'representative name']],
#   ['station company', ['station id', 'company id', 'rank of the year']]],
#  'e_government': [['addresses',
#    ['address id',
#     'line 1 number building',
#     'town city',
#     'zip postcode',
#     'state province county',
#     'country']],
#   ['services',
#    ['service id', 'service type code', 'service name', 'service descriptio']],
#   ['forms',
#    ['form id',
#     'form type code',
#     'service id',
#     'form number',
#     'form name',
#     'form description']],
#   ['individuals',
#    ['individual id',
#     'individual first name',
#     'individual middle name',
#     'inidividual phone',
#     'individual email',
#     'individual address',
#     'individual last name']],
#   ['organizations',
#    ['organization id', 'date formed', 'organization name', 'uk vat number']],
#   ['parties',
#    ['party id', 'payment method code', 'party phone', 'party email']],
#   ['organization contact individuals',
#    ['individual id',
#     'organization id',
#     'date contact from',
#     'date contact to']],
#   ['party addresses',
#    ['party id',
#     'address id',
#     'date address from',
#     'address type code',
#     'date address to']],
#   ['party forms',
#    ['party id',
#     'form id',
#     'date completion started',
#     'form status code',
#     'date fully completed']],
#   ['party services',
#    ['booking id',
#     'customer id',
#     'service id',
#     'service datetime',
#     'booking made date']]],
#  'school_bus': [['driver', ['driver id', 'name', 'party', 'home city', 'age']],
#   ['school', ['school id', 'grade', 'school', 'location', 'type']],
#   ['school bus', ['school id', 'driver id', 'years working', 'if full time']]],
#  'machine_repair': [['repair', ['repair id', 'name', 'launch date', 'notes']],
#   ['machine',
#    ['machine id',
#     'making year',
#     'class',
#     'team',
#     'machine series',
#     'value points',
#     'quality rank']],
#   ['technician', ['technician id', 'name', 'team', 'starting year', 'age']],
#   ['repair assignment', ['technician id', 'repair id', 'machine id']]],
#  'theme_gallery': [['artist',
#    ['artist id', 'name', 'country', 'year join', 'age']],
#   ['exhibition',
#    ['exhibition id', 'year', 'theme', 'artist id', 'ticket price']],
#   ['exhibition record', ['exhibition id', 'date', 'attendance']]],
#  'film_rank': [['film',
#    ['film id', 'title', 'studio', 'director', 'gross in dollar']],
#   ['market', ['market id', 'country', 'number cities']],
#   ['film market estimation',
#    ['estimation id',
#     'low estimate',
#     'high estimate',
#     'film id',
#     'type',
#     'market id',
#     'year']]],
#  'party_people': [['region',
#    ['region id', 'region name', 'date', 'label', 'format', 'catalogue']],
#   ['party',
#    ['party id',
#     'minister',
#     'took office',
#     'left office',
#     'region id',
#     'party name']],
#   ['member', ['member id', 'member name', 'party id', 'in office']],
#   ['party events',
#    ['event id', 'event name', 'party id', 'member in charge id']]],
#  'hospital_1': [['physician', ['employee id', 'name', 'position', 'ssn']],
#   ['department', ['departmentid', 'name', 'head']],
#   ['affiliated with', ['physician', 'department', 'primary affiliation']],
#   ['procedures', ['code', 'name', 'cost']],
#   ['trained in',
#    ['physician', 'treatment', 'certification date', 'certification expires']],
#   ['patient', ['ssn', 'name', 'address', 'phone', 'insurance id', 'pcp']],
#   ['nurse', ['employee id', 'name', 'position', 'registered', 'ssn']],
#   ['appointment',
#    ['appointment id',
#     'patient',
#     'prep nurse',
#     'physician',
#     'start',
#     'end',
#     'examination room']],
#   ['medication', ['code', 'name', 'brand', 'description']],
#   ['prescribes',
#    ['physician', 'patient', 'medication', 'date', 'appointment', 'dose']],
#   ['block', ['block floor', 'block code']],
#   ['room',
#    ['roomnumber', 'room type', 'block floor', 'block code', 'unavailable']],
#   ['on call',
#    ['nurse', 'block floor', 'block code', 'oncall start', 'oncall end']],
#   ['stay', ['stay id', 'patient', 'room', 'stay start', 'stay end']],
#   ['undergoes',
#    ['patient',
#     'procedures',
#     'stay',
#     'date undergoes',
#     'physician',
#     'assisting nurse']]],
#  'customers_campaigns_ecommerce': [['premises',
#    ['premise id', 'premises type', 'premise details']],
#   ['products', ['product id', 'product category', 'product name']],
#   ['customers',
#    ['customer id',
#     'payment method',
#     'customer name',
#     'customer phone',
#     'customer email',
#     'customer address',
#     'customer login',
#     'customer password']],
#   ['mailshot campaigns',
#    ['mailshot id',
#     'product category',
#     'mailshot name',
#     'mailshot start date',
#     'mailshot end date']],
#   ['customer addresses',
#    ['customer id',
#     'premise id',
#     'date address from',
#     'address type code',
#     'date address to']],
#   ['customer orders',
#    ['order id',
#     'customer id',
#     'order status code',
#     'shipping method code',
#     'order placed datetime',
#     'order delivered datetime',
#     'order shipping charges']],
#   ['mailshot customers',
#    ['mailshot id', 'customer id', 'outcome code', 'mailshot customer date']],
#   ['order items',
#    ['item id',
#     'order item status code',
#     'order id',
#     'product id',
#     'item status code',
#     'item delivered datetime',
#     'item order quantity']]],
#  'gymnast': [['gymnast',
#    ['gymnast id',
#     'floor exercise points',
#     'pommel horse points',
#     'rings points',
#     'vault points',
#     'parallel bars points',
#     'horizontal bar points',
#     'total points']],
#   ['people', ['people id', 'name', 'age', 'height', 'hometown']]],
#  'restaurants': [['geographic', ['city name', 'county', 'region']],
#   ['restaurant', ['id', 'name', 'food type', 'city name', 'rating']],
#   ['location', ['restaurant id', 'house number', 'street name', 'city name']]],
#  'mountain_photos': [['mountain',
#    ['id', 'name', 'height', 'prominence', 'range', 'country']],
#   ['camera lens', ['id', 'brand', 'name', 'focal length mm', 'max aperture']],
#   ['photos', ['id', 'camera lens id', 'mountain id', 'color', 'name']]],
#  'battle_death': [['battle',
#    ['id', 'name', 'date', 'bulgarian commander', 'latin commander', 'result']],
#   ['ship',
#    ['lost in battle',
#     'id',
#     'name',
#     'tonnage',
#     'ship type',
#     'location',
#     'disposition of ship']],
#   ['death', ['caused by ship id', 'id', 'note', 'killed', 'injured']]],
#  'cre_Doc_Control_Systems': [['reference document types',
#    ['document type code', 'document type description']],
#   ['roles', ['role code', 'role description']],
#   ['addresses', ['address id', 'address details']],
#   ['reference document status',
#    ['document status code', 'document status description']],
#   ['reference shipping agents',
#    ['shipping agent code',
#     'shipping agent name',
#     'shipping agent description']],
#   ['documents',
#    ['document id',
#     'document status code',
#     'document type code',
#     'shipping agent code',
#     'receipt date',
#     'receipt number',
#     'other details']],
#   ['employees',
#    ['employee id', 'role code', 'employee name', 'other details']],
#   ['document drafts', ['document id', 'draft number', 'draft details']],
#   ['draft copies', ['document id', 'draft number', 'copy number']],
#   ['circulation history',
#    ['document id', 'draft number', 'copy number', 'employee id']],
#   ['documents mailed',
#    ['document id', 'mailed to address id', 'mailing date']]],
#  'tracking_share_transactions': [['investors',
#    ['investor id', 'investor details']],
#   ['lots', ['lot id', 'investor id', 'lot details']],
#   ['reference transaction types',
#    ['transaction type code', 'transaction type description']],
#   ['transactions',
#    ['transaction id',
#     'investor id',
#     'transaction type code',
#     'date of transaction',
#     'amount of transaction',
#     'share count',
#     'other details']],
#   ['sales', ['sales transaction id', 'sales details']],
#   ['purchases', ['purchase transaction id', 'purchase details']],
#   ['transactions lots', ['transaction id', 'lot id']]],
#  'apartment_rentals': [['apartment buildings',
#    ['building id',
#     'building short name',
#     'building full name',
#     'building description',
#     'building address',
#     'building manager',
#     'building phone']],
#   ['apartments',
#    ['apartment id',
#     'building id',
#     'apartment type code',
#     'apartment number',
#     'bathroom count',
#     'bedroom count',
#     'room count']],
#   ['apartment facilities', ['apartment id', 'facility code']],
#   ['guests',
#    ['guest id',
#     'gender code',
#     'guest first name',
#     'guest last name',
#     'date of birth']],
#   ['apartment bookings',
#    ['apartment booking id',
#     'apartment id',
#     'guest id',
#     'booking status code',
#     'booking start date',
#     'booking end date']],
#   ['view unit status',
#    ['apartment id',
#     'apartment booking id',
#     'status date',
#     'available yes or no']]],
#  'student_transcripts_tracking': [['addresses',
#    ['address id',
#     'line 1',
#     'line 2',
#     'line 3',
#     'city',
#     'zip postcode',
#     'state province county',
#     'country',
#     'other address details']],
#   ['courses',
#    ['course id', 'course name', 'course description', 'other details']],
#   ['departments',
#    ['department id',
#     'department name',
#     'department description',
#     'other details']],
#   ['degree programs',
#    ['degree program id',
#     'department id',
#     'degree summary name',
#     'degree summary description',
#     'other details']],
#   ['sections',
#    ['section id',
#     'course id',
#     'section name',
#     'section description',
#     'other details']],
#   ['semesters',
#    ['semester id', 'semester name', 'semester description', 'other details']],
#   ['students',
#    ['student id',
#     'current address id',
#     'permanent address id',
#     'first name',
#     'middle name',
#     'last name',
#     'cell mobile number',
#     'email address',
#     'ssn',
#     'date first registered',
#     'date left',
#     'other student details']],
#   ['student enrolment',
#    ['student enrolment id',
#     'degree program id',
#     'semester id',
#     'student id',
#     'other details']],
#   ['student enrolment courses',
#    ['student course id', 'course id', 'student enrolment id']],
#   ['transcripts', ['transcript id', 'transcript date', 'other details']],
#   ['transcript contents', ['student course id', 'transcript id']]],
#  'cre_Docs_and_Epenses': [['reference document types',
#    ['document type code', 'document type name', 'document type description']],
#   ['reference budget codes', ['budget type code', 'budget type description']],
#   ['projects', ['project id', 'project details']],
#   ['documents',
#    ['document id',
#     'document type code',
#     'project id',
#     'document date',
#     'document name',
#     'document description',
#     'other details']],
#   ['statements', ['statement id', 'statement details']],
#   ['documents with expenses',
#    ['document id', 'budget type code', 'document details']],
#   ['accounts', ['account id', 'statement id', 'account details']]],
#  'ship_mission': [['mission',
#    ['mission id',
#     'ship id',
#     'code',
#     'launched year',
#     'location',
#     'speed knots',
#     'fate']],
#   ['ship', ['ship id', 'name', 'type', 'nationality', 'tonnage']]],
#  'company_office': [['buildings',
#    ['id', 'name', 'city', 'height', 'stories', 'status']],
#   ['companies',
#    ['id',
#     'name',
#     'headquarters',
#     'industry',
#     'sales billion',
#     'profits billion',
#     'assets billion',
#     'market value billion']],
#   ['office locations', ['building id', 'company id', 'move in year']]],
#  'tracking_software_problems': [['problem category codes',
#    ['problem category code', 'problem category description']],
#   ['problem log',
#    ['problem log id',
#     'assigned to staff id',
#     'problem id',
#     'problem category code',
#     'problem status code',
#     'log entry date',
#     'log entry description',
#     'log entry fix',
#     'other log details']],
#   ['problem status codes',
#    ['problem status code', 'problem status description']],
#   ['product', ['product id', 'product name', 'product details']],
#   ['staff',
#    ['staff id', 'staff first name', 'staff last name', 'other staff details']],
#   ['problems',
#    ['problem id',
#     'product id',
#     'closure authorised by staff id',
#     'reported by staff id',
#     'date problem reported',
#     'date problem closed',
#     'problem description',
#     'other problem details']]],
#  'products_gen_characteristics': [['reference characteristic types',
#    ['characteristic type code', 'characteristic type description']],
#   ['reference colors', ['color code', 'color description']],
#   ['reference product categories',
#    ['product category code',
#     'product category description',
#     'unit of measure']],
#   ['characteristics',
#    ['characteristic id',
#     'characteristic type code',
#     'characteristic data type',
#     'characteristic name',
#     'other characteristic details']],
#   ['products',
#    ['product id',
#     'color code',
#     'product category code',
#     'product name',
#     'typical buying price',
#     'typical selling price',
#     'product description',
#     'other product details']],
#   ['product characteristics',
#    ['product id', 'characteristic id', 'product characteristic value']]],
#  'coffee_shop': [['shop',
#    ['shop id', 'address', 'num of staff', 'score', 'open year']],
#   ['member',
#    ['member id',
# ...
#     'other details']],
#   ['stores',
#    ['store id',
#     'address id',
#     'marketing region code',
#     'store name',
#     'store phone',
#     'store email address',
#     'other details']],
#   ['bookings',
#    ['booking id',
#     'customer id',
#     'workshop group id',
#     'status code',
#     'store id',
#     'order date',
#     'planned delivery date',
#     'actual delivery date',
#     'other order details']],
#   ['performers in bookings', ['order id', 'performer id']],
#   ['customer orders',
#    ['order id',
#     'customer id',
#     'store id',
#     'order date',
#     'planned delivery date',
#     'actual delivery date',
#     'other order details']],
#   ['order items',
#    ['order item id',
#     'order id',
#     'product id',
#     'order quantity',
#     'other item details']],
#   ['invoices',
#    ['invoice id',
#     'order id',
#     'payment method code',
#     'product id',
#     'order quantity',
#     'other item details',
#     'order item id']],
#   ['services',
#    ['service id',
#     'service type code',
#     'workshop group id',
#     'product description',
#     'product name',
#     'product price',
#     'other product service details']],
#   ['bookings services', ['order id', 'product id']],
#   ['invoice items',
#    ['invoice item id',
#     'invoice id',
#     'order id',
#     'order item id',
#     'product id',
#     'order quantity',
#     'other item details']]],
#  'car_1': [['continents', ['cont id', 'continent']],
#   ['countries', ['country id', 'country name', 'continent']],
#   ['car makers', ['id', 'maker', 'full name', 'country']],
#   ['model list', ['model id', 'maker', 'model']],
#   ['car names', ['make id', 'model', 'make']],
#   ['cars data',
#    ['id',
#     'mpg',
#     'cylinders',
#     'edispl',
#     'horsepower',
#     'weight',
#     'accelerate',
#     'year']]],
#  'geo': [['state',
#    ['state name', 'population', 'area', 'country name', 'capital', 'density']],
#   ['city', ['city name', 'population', 'country name', 'state name']],
#   ['border info', ['state name', 'border']],
#   ['highlow',
#    ['state name',
#     'highest elevation',
#     'lowest point',
#     'highest point',
#     'lowest elevation']],
#   ['lake', ['lake name', 'area', 'country name', 'state name']],
#   ['mountain',
#    ['mountain name', 'mountain altitude', 'country name', 'state name']],
#   ['river', ['river name', 'length', 'country name', 'traverse']]],
#  'behavior_monitoring': [['reference address types',
#    ['address type code', 'address type description']],
#   ['reference detention type',
#    ['detention type code', 'detention type description']],
#   ['reference incident type',
#    ['incident type code', 'incident type description']],
#   ['addresses',
#    ['address id',
#     'line 1',
#     'line 2',
#     'line 3',
#     'city',
#     'zip postcode',
#     'state province county',
#     'country',
#     'other address details']],
#   ['students',
#    ['student id',
#     'address id',
#     'first name',
#     'middle name',
#     'last name',
#     'cell mobile number',
#     'email address',
#     'date first rental',
#     'date left university',
#     'other student details']],
#   ['teachers',
#    ['teacher id',
#     'address id',
#     'first name',
#     'middle name',
#     'last name',
#     'gender',
#     'cell mobile number',
#     'email address',
#     'other details']],
#   ['assessment notes',
#    ['notes id',
#     'student id',
#     'teacher id',
#     'date of notes',
#     'text of notes',
#     'other details']],
#   ['behavior incident',
#    ['incident id',
#     'incident type code',
#     'student id',
#     'date incident start',
#     'date incident end',
#     'incident summary',
#     'recommendations',
#     'other details']],
#   ['detention',
#    ['detention id',
#     'detention type code',
#     'teacher id',
#     'datetime detention start',
#     'datetime detention end',
#     'detention summary',
#     'other details']],
#   ['student addresses',
#    ['student id',
#     'address id',
#     'date address from',
#     'date address to',
#     'monthly rental',
#     'other details']],
#   ['students in detention', ['student id', 'detention id', 'incident id']]],
#  'cre_Doc_Tracking_DB': [['reference document types',
#    ['document type code', 'document type name', 'document type description']],
#   ['reference calendar', ['calendar date', 'day number']],
#   ['reference locations',
#    ['location code', 'location name', 'location description']],
#   ['roles', ['role code', 'role name', 'role description']],
#   ['all documents',
#    ['document id',
#     'date stored',
#     'document type code',
#     'document name',
#     'document description',
#     'other details']],
#   ['employees',
#    ['employee id',
#     'role code',
#     'employee name',
#     'gender mfu',
#     'date of birth',
#     'other details']],
#   ['document locations',
#    ['document id',
#     'location code',
#     'date in location from',
#     'date in locaton to']],
#   ['documents to be destroyed',
#    ['document id',
#     'destruction authorised by employee id',
#     'destroyed by employee id',
#     'planned destruction date',
#     'actual destruction date',
#     'other details']]],
#  'university_basketball': [['basketball match',
#    ['team id',
#     'school id',
#     'team name',
#     'acc regular season',
#     'acc percent',
#     'acc home',
#     'acc road',
#     'all games',
#     'all games percent',
#     'all home',
#     'all road',
#     'all neutral']],
#   ['university',
#    ['school id',
#     'school',
#     'location',
#     'founded',
#     'affiliation',
#     'enrollment',
#     'nickname',
#     'primary conference']]],
#  'soccer_2': [['college', ['college name', 'state', 'enrollment']],
#   ['player', ['player id', 'player name', 'yes card', 'training hours']],
#   ['tryout', ['player id', 'college name', 'player position', 'decision']]],
#  'activity_1': [['activity', ['activity id', 'activity name']],
#   ['participates in', ['student id', 'activity id']],
#   ['faculty participates in', ['faculty id', 'activity id']],
#   ['student',
#    ['student id',
#     'last name',
#     'first name',
#     'age',
#     'sex',
#     'major',
#     'advisor',
#     'city code']],
#   ['faculty',
#    ['faculty id',
#     'last name',
#     'first name',
#     'rank',
#     'sex',
#     'phone',
#     'room',
#     'building']]],
#  'cre_Theme_park': [['ref hotel star ratings',
#    ['star rating code', 'star rating description']],
#   ['locations', ['location id', 'location name', 'address', 'other details']],
#   ['ref attraction types',
#    ['attraction type code', 'attraction type description']],
#   ['visitors', ['tourist id', 'tourist details']],
#   ['features', ['feature id', 'feature details']],
#   ['hotels',
#    ['hotel id',
#     'star rating code',
#     'pets allowed yn',
#     'price range',
#     'other hotel details']],
#   ['tourist attractions',
#    ['tourist attraction id',
#     'attraction type code',
#     'location id',
#     'how to get there',
#     'name',
#     'description',
#     'opening hours',
#     'other details']],
#   ['street markets', ['market id', 'market details']],
#   ['shops', ['shop id', 'shop details']],
#   ['museums', ['museum id', 'museum details']],
#   ['royal family', ['royal family id', 'royal family details']],
#   ['theme parks', ['theme park id', 'theme park details']],
#   ['visits',
#    ['visit id',
#     'tourist attraction id',
#     'tourist id',
#     'visit date',
#     'visit details']],
#   ['photos',
#    ['photo id',
#     'tourist attraction id',
#     'name',
#     'description',
#     'filename',
#     'other details']],
#   ['staff', ['staff id', 'tourist attraction id', 'name', 'other details']],
#   ['tourist attraction features', ['tourist attraction id', 'feature id']]],
#  'twitter_1': [['follows', ['user id', 'follower id']],
#   ['tweets', ['id', 'user id', 'text', 'create date']],
#   ['user profiles', ['uid', 'name', 'email', 'partition id', 'followers']]],
#  'election_representative': [['election',
#    ['election id',
#     'representative id',
#     'date',
#     'votes',
#     'vote percent',
#     'seats',
#     'place']],
#   ['representative',
#    ['representative id', 'name', 'state', 'party', 'lifespan']]],
#  'voter_2': [['student',
#    ['student id',
#     'last name',
#     'first name',
#     'age',
#     'sex',
#     'major',
#     'advisor',
#     'city code']],
#   ['voting record',
#    ['student id',
#     'registration date',
#     'election cycle',
#     'president vote',
#     'vice president vote',
#     'secretary vote',
#     'treasurer vote',
#     'class president vote',
#     'class senator vote']]],
#  'wedding': [['people', ['people id', 'name', 'country', 'is male', 'age']],
#   ['church',
#    ['church id', 'name', 'organized by', 'open date', 'continuation of']],
#   ['wedding', ['church id', 'male id', 'female id', 'year']]],
#  'news_report': [['event',
#    ['event id', 'date', 'venue', 'name', 'event attendance']],
#   ['journalist',
#    ['journalist id', 'name', 'nationality', 'age', 'years working']],
#   ['news report', ['journalist id', 'event id', 'work type']]],
#  'wine_1': [['grapes', ['id', 'grape', 'color']],
#   ['appellations', ['no', 'appelation', 'county', 'state', 'area', 'isava']],
#   ['wine',
#    ['no',
#     'grape',
#     'winery',
#     'appelation',
#     'state',
#     'name',
#     'year',
#     'price',
#     'score',
#     'cases',
#     'drink']]],
#  'customers_and_addresses': [['addresses',
#    ['address id',
#     'address content',
#     'city',
#     'zip postcode',
#     'state province county',
#     'country',
#     'other address details']],
#   ['products', ['product id', 'product details']],
#   ['customers',
#    ['customer id',
#     'payment method',
#     'customer name',
#     'date became customer',
#     'other customer details']],
#   ['customer addresses',
#    ['customer id',
#     'address id',
#     'date address from',
#     'address type',
#     'date address to']],
#   ['customer contact channels',
#    ['customer id',
#     'channel code',
#     'active from date',
#     'active to date',
#     'contact number']],
#   ['customer orders',
#    ['order id', 'customer id', 'order status', 'order date', 'order details']],
#   ['order items', ['order id', 'product id', 'order quantity']]],
#  'protein_institute': [['building',
#    ['building id',
#     'name',
#     'street address',
#     'years as tallest',
#     'height feet',
#     'floors']],
#   ['institution',
#    ['institution id',
#     'institution',
#     'location',
#     'founded',
#     'type',
#     'enrollment',
#     'team',
#     'primary conference',
#     'building id']],
#   ['protein',
#    ['common name',
#     'protein name',
#     'divergence from human lineage',
#     'accession number',
#     'sequence length',
#     'sequence identity to human protein',
#     'institution id']]],
#  'school_player': [['school',
#    ['school id',
#     'school',
#     'location',
#     'enrollment',
#     'founded',
#     'denomination',
#     'boys or girls',
#     'day or boarding',
#     'year entered competition',
#     'school colors']],
#   ['school details',
#    ['school id', 'nickname', 'colors', 'league', 'class', 'division']],
#   ['school performance', ['school id', 'school year', 'class a', 'class aa']],
#   ['player', ['player id', 'player', 'team', 'age', 'position', 'school id']]],
#  'phone_1': [['chip model',
#    ['model name',
#     'launch year',
#     'ram mib',
#     'rom mib',
#     'slots',
#     'wifi',
#     'bluetooth']],
#   ['screen mode',
#    ['graphics mode',
#     'char cells',
#     'pixels',
#     'hardware colours',
#     'used kb',
#     'map',
#     'type']],
#   ['phone',
#    ['company name',
#     'hardware model name',
#     'accreditation type',
#     'accreditation level',
#     'date',
#     'chip model',
#     'screen mode']]],
#  'tvshow': [['tv channel',
#    ['id',
#     'series name',
#     'country',
#     'language',
#     'content',
#     'pixel aspect ratio par',
#     'hight definition tv',
#     'pay per view ppv',
#     'package option']],
#   ['tv series',
#    ['id',
#     'episode',
#     'air date',
#     'rating',
#     'share',
#     '18 49 rating share',
#     'viewers m',
#     'weekly rank',
#     'channel']],
#   ['cartoon',
#    ['id',
#     'title',
#     'directed by',
#     'written by',
#     'original air date',
#     'production code',
#     'channel']]],
#  'wrestler': [['wrestler',
#    ['wrestler id', 'name', 'reign', 'days held', 'location', 'event']],
#   ['elimination',
#    ['elimination id',
#     'wrestler id',
#     'team',
#     'eliminated by',
#     'elimination move',
#     'time']]],
#  'customer_complaints': [['staff',
#    ['staff id',
#     'gender',
#     'first name',
#     'last name',
#     'email address',
#     'phone number']],
#   ['customers',
#    ['customer id',
#     'customer type code',
#     'address line 1',
#     'address line 2',
#     'town city',
#     'state',
#     'email address',
#     'phone number']],
#   ['products',
#    ['product id',
#     'parent product id',
#     'product category code',
#     'date product first available',
#     'date product discontinued',
#     'product name',
#     'product description',
#     'product price']],
#   ['complaints',
#    ['complaint id',
#     'product id',
#     'customer id',
#     'complaint outcome code',
#     'complaint status code',
#     'complaint type code',
#     'date complaint raised',
#     'date complaint closed',
#     'staff id']]],
#  'department_management': [['department',
#    ['department id',
#     'name',
#     'creation',
#     'ranking',
#     'budget in billions',
#     'num employees']],
#   ['head', ['head id', 'name', 'born state', 'age']],
#   ['management', ['department id', 'head id', 'temporary acting']]],
#  'customers_and_products_contacts': [['addresses',
#    ['address id',
#     'line 1 number building',
#     'city',
#     'zip postcode',
#     'state province county',
#     'country']],
#   ['products',
#    ['product id', 'product type code', 'product name', 'product price']],
#   ['customers',
#    ['customer id',
#     'payment method code',
#     'customer number',
#     'customer name',
#     'customer address',
#     'customer phone',
#     'customer email']],
#   ['contacts',
#    ['contact id',
#     'customer id',
#     'gender',
#     'first name',
#     'last name',
#     'contact phone']],
#   ['customer address history',
#    ['customer id', 'address id', 'date from', 'date to']],
#   ['customer orders',
#    ['order id', 'customer id', 'order date', 'order status code']],
#   ['order items',
#    ['order item id', 'order id', 'product id', 'order quantity']]],
#  'company_1': [['works on', ['employee ssn', 'project number', 'hours']],
#   ['employee',
#    ['first name',
#     'minit',
#     'last name',
#     'ssn',
#     'birth date',
#     'address',
#     'sex',
#     'salary',
#     'super ssn',
#     'department no']],
#   ['department',
#    ['department name',
#     'department number',
#     'manager ssn',
#     'manager start date']],
#   ['project',
#    ['dependent name',
#     'dependent number',
#     'dependent location',
#     'department number']],
#   ['dependent',
#    ['employee ssn', 'dependent name', 'sex', 'birth date', 'relationship']],
#   ['department locations', ['department number', 'department location']]],
#  'workshop_paper': [['workshop', ['workshop id', 'date', 'venue', 'name']],
#   ['submission', ['submission id', 'scores', 'author', 'college']],
#   ['acceptance', ['submission id', 'workshop id', 'result']]],
#  'epinions_1': [['item', ['item id', 'title']],
#   ['review', ['a id', 'user id', 'item id', 'rating', 'rank']],
#   ['useracct', ['user id', 'name']],
#   ['trust', ['source user id', 'target user id', 'trust']]],
#  'party_host': [['party',
#    ['party id',
#     'party theme',
#     'location',
#     'first year',
#     'last year',
#     'number of hosts']],
#   ['host', ['host id', 'name', 'nationality', 'age']],
#   ['party host', ['party id', 'host id', 'is main in charge']]],
#  'product_catalog': [['attribute definitions',
#    ['attribute id', 'attribute name', 'attribute data type']],
#   ['catalogs',
#    ['catalog id',
#     'catalog name',
#     'catalog publisher',
#     'date of publication',
#     'date of latest revision']],
#   ['catalog structure',
#    ['catalog level number', 'catalog id', 'catalog level name']],
#   ['catalog contents',
#    ['catalog entry id',
#     'catalog level number',
#     'parent entry id',
#     'previous entry id',
#     'next entry id',
#     'catalog entry name',
#     'product stock number',
#     'price in dollars',
#     'price in euros',
#     'price in pounds',
#     'capacity',
#     'length',
#     'height',
#     'width']],
#   ['catalog contents additional attributes',
#    ['catalog entry id',
#     'catalog level number',
#     'attribute id',
#     'attribute value']]]}

# %%
# here I've trying to add headings like database/table_name etc, to be more descriptive, LLM may not able to identify which one is database, which one is table and column name from above.
def reshape_with_headings(essential_schemas):
    out = {}
    # I didn't use the counter in the end, orginally just trying to index the database. 
    counter = 0
    for db in essential_schemas:
        order_ = 'database ' + str(counter)
        db_name =  db.get("database_name", "unknown")
        table_names = list(db.get("table_names", []))
        col_specs   = list(db.get("column_names", []))
        tables = []
        for idx, table_name in enumerate(table_names):
            cols = []
            for pair in col_specs:
                if not isinstance(pair, (list, tuple)) or len(pair) != 2:
                    continue
                t_idx, col = pair
                try:
                    t_idx = int(t_idx)
                except (ValueError, TypeError):
                    continue
                if t_idx != idx:
                    continue
                if col is None or str(col).strip() == "*" or t_idx < 0:
                    continue
                cols.append(str(col))

            tables.append({
                "table_name": table_name,
                "columns": cols,
            })

        out[db_name] = {
           "database_name": db_name,
            "tables": tables
        }
        counter += 1

    return out

# %%
reshaped_essential_schemas = reshape_with_headings(essential_schemas)
reshaped_essential_schemas
# Out:
# {'perpetrator': {'database_name': 'perpetrator',
#   'tables': [{'table_name': 'perpetrator',
#     'columns': ['perpetrator id',
#      'people id',
#      'date',
#      'year',
#      'location',
#      'country',
#      'killed',
#      'injured']},
#    {'table_name': 'people',
#     'columns': ['people id', 'name', 'height', 'weight', 'home town']}]},
#  'college_2': {'database_name': 'college_2',
#   'tables': [{'table_name': 'classroom',
#     'columns': ['building', 'room number', 'capacity']},
#    {'table_name': 'department',
#     'columns': ['department name', 'building', 'budget']},
#    {'table_name': 'course',
#     'columns': ['course id', 'title', 'department name', 'credits']},
#    {'table_name': 'instructor',
#     'columns': ['id', 'name', 'department name', 'salary']},
#    {'table_name': 'section',
#     'columns': ['course id',
#      'section id',
#      'semester',
#      'year',
#      'building',
#      'room number',
#      'time slot id']},
#    {'table_name': 'teaches',
#     'columns': ['id', 'course id', 'section id', 'semester', 'year']},
#    {'table_name': 'student',
#     'columns': ['id', 'name', 'department name', 'total credits']},
#    {'table_name': 'takes classes',
#     'columns': ['id', 'course id', 'section id', 'semester', 'year', 'grade']},
#    {'table_name': 'advisor', 'columns': ['student id', 'instructor id']},
#    {'table_name': 'time slot',
#     'columns': ['time slot id',
#      'day',
#      'start hour',
#      'start minute',
#      'end hour',
#      'end minute']},
#    {'table_name': 'prerequisite',
#     'columns': ['course id', 'prerequisite id']}]},
#  'flight_company': {'database_name': 'flight_company',
#   'tables': [{'table_name': 'airport',
#     'columns': ['id', 'city', 'country', 'iata', 'icao', 'name']},
#    {'table_name': 'operate company',
#     'columns': ['id',
#      'name',
#      'type',
#      'principal activities',
#      'incorporated in',
#      'group equity shareholding']},
#    {'table_name': 'flight',
#     'columns': ['id',
#      'vehicle flight number',
#      'date',
#      'pilot',
#      'velocity',
#      'altitude',
#      'airport id',
#      'company id']}]},
#  'icfp_1': {'database_name': 'icfp_1',
#   'tables': [{'table_name': 'institution',
#     'columns': ['institution id', 'name', 'country']},
#    {'table_name': 'authors',
#     'columns': ['author id', 'last name', 'first name']},
#    {'table_name': 'papers', 'columns': ['paper id', 'title']},
#    {'table_name': 'authorship count',
#     'columns': ['author id', 'institution id', 'paper id', 'author count']}]},
#  'body_builder': {'database_name': 'body_builder',
#   'tables': [{'table_name': 'body builder',
#     'columns': ['body builder id',
#      'people id',
#      'snatch',
#      'clean jerk',
#      'total']},
#    {'table_name': 'people',
#     'columns': ['people id',
#      'name',
#      'height',
#      'weight',
#      'birth date',
#      'birth place']}]},
#  'storm_record': {'database_name': 'storm_record',
#   'tables': [{'table_name': 'storm',
#     'columns': ['storm id',
#      'name',
#      'dates active',
#      'max speed',
#      'damage millions usd',
#      'number deaths']},
#    {'table_name': 'region',
#     'columns': ['region id', 'region code', 'region name']},
#    {'table_name': 'affected region',
#     'columns': ['region id', 'storm id', 'number city affected']}]},
#  'pilot_record': {'database_name': 'pilot_record',
#   'tables': [{'table_name': 'aircraft',
#     'columns': ['aircraft id',
#      'order year',
#      'manufacturer',
#      'model',
#      'fleet series',
#      'powertrain',
#      'fuel propulsion']},
#    {'table_name': 'pilot',
#     'columns': ['pilot id',
#      'pilot name',
#      'rank',
#      'age',
#      'nationality',
#      'position',
#      'join year',
#      'team']},
#    {'table_name': 'pilot record',
#     'columns': ['record id', 'pilot id', 'aircraft id', 'date']}]},
#  'race_track': {'database_name': 'race_track',
#   'tables': [{'table_name': 'race',
#     'columns': ['race id', 'name', 'class', 'date', 'track id']},
#    {'table_name': 'track',
#     'columns': ['track id', 'name', 'location', 'seating', 'year opened']}]},
#  'academic': {'database_name': 'academic',
#   'tables': [{'table_name': 'author',
#     'columns': ['aid', 'homepage', 'name', 'oid']},
#    {'table_name': 'conference', 'columns': ['cid', 'homepage', 'name']},
#    {'table_name': 'domain', 'columns': ['did', 'name']},
#    {'table_name': 'domain author', 'columns': ['aid', 'did']},
#    {'table_name': 'domain conference', 'columns': ['cid', 'did']},
#    {'table_name': 'journal', 'columns': ['homepage', 'jid', 'name']},
#    {'table_name': 'domain journal', 'columns': ['did', 'jid']},
#    {'table_name': 'keyword', 'columns': ['keyword', 'kid']},
#    {'table_name': 'domain keyword', 'columns': ['did', 'kid']},
#    {'table_name': 'publication',
#     'columns': ['abstract',
#      'cid',
#      'citation num',
#      'jid',
#      'pid',
#      'reference num',
#      'title',
#      'year']},
#    {'table_name': 'domain publication', 'columns': ['did', 'pid']},
#    {'table_name': 'organization',
#     'columns': ['continent', 'homepage', 'name', 'oid']},
#    {'table_name': 'publication keyword', 'columns': ['pid', 'kid']},
#    {'table_name': 'writes', 'columns': ['aid', 'pid']},
#    {'table_name': 'cite', 'columns': ['cited', 'citing']}]},
#  'department_store': {'database_name': 'department_store',
#   'tables': [{'table_name': 'addresses',
#     'columns': ['address id', 'address details']},
#    {'table_name': 'staff',
#     'columns': ['staff id', 'staff gender', 'staff name']},
#    {'table_name': 'suppliers',
#     'columns': ['supplier id', 'supplier name', 'supplier phone']},
#    {'table_name': 'department store chain',
#     'columns': ['department store chain id', 'department store chain name']},
#    {'table_name': 'customers',
#     'columns': ['customer id',
#      'payment method code',
#      'customer code',
#      'customer name',
#      'customer address',
#      'customer phone',
#      'customer email']},
#    {'table_name': 'products',
#     'columns': ['product id',
#      'product type code',
#      'product name',
#      'product price']},
#    {'table_name': 'supplier addresses',
#     'columns': ['supplier id', 'address id', 'date from', 'date to']},
#    {'table_name': 'customer addresses',
#     'columns': ['customer id', 'address id', 'date from', 'date to']},
#    {'table_name': 'customer orders',
#     'columns': ['order id', 'customer id', 'order status code', 'order date']},
#    {'table_name': 'department stores',
#     'columns': ['department store id',
#      'department store chain id',
#      'store name',
#      'store address',
#      'store phone',
#      'store email']},
#    {'table_name': 'departments',
#     'columns': ['department id', 'department store id', 'department name']},
#    {'table_name': 'order items',
#     'columns': ['order item id', 'order id', 'product id']},
#    {'table_name': 'product suppliers',
#     'columns': ['product id',
#      'supplier id',
#      'date supplied from',
#      'date supplied to',
#      'total amount purchased',
#      'total value purchased']},
#    {'table_name': 'staff department assignments',
#     'columns': ['staff id',
#      'department id',
#      'date assigned from',
#      'job title code',
#      'date assigned to']}]},
#  'music_4': {'database_name': 'music_4',
#   'tables': [{'table_name': 'artist',
#     'columns': ['artist id',
#      'artist',
#      'age',
#      'famous title',
#      'famous release date']},
#    {'table_name': 'volume',
#     'columns': ['volume id',
#      'volume issue',
#      'issue date',
#      'weeks on top',
#      'song',
#      'artist id']},
#    {'table_name': 'music festival',
#     'columns': ['id',
#      'music festival',
#      'date of ceremony',
#      'category',
#      'volume',
#      'result']}]},
#  'insurance_fnol': {'database_name': 'insurance_fnol',
#   'tables': [{'table_name': 'customers',
#     'columns': ['customer id', 'customer name']},
#    {'table_name': 'services', 'columns': ['service id', 'service name']},
#    {'table_name': 'available policies',
#     'columns': ['policy id', 'policy type code', 'customer phone']},
#    {'table_name': 'customers policies',
#     'columns': ['customer id', 'policy id', 'date opened', 'date closed']},
#    {'table_name': 'first notification of loss',
#     'columns': ['fnol id', 'customer id', 'policy id', 'service id']},
#    {'table_name': 'claims',
#     'columns': ['claim id', 'fnol id', 'effective date']},
#    {'table_name': 'settlements',
#     'columns': ['settlement id',
#      'claim id',
#      'effective date',
#      'settlement amount']}]},
#  'cinema': {'database_name': 'cinema',
#   'tables': [{'table_name': 'film',
#     'columns': ['film id',
#      'rank in series',
#      'number in season',
#      'title',
#      'directed by',
#      'original air date',
#      'production code']},
#    {'table_name': 'cinema',
#     'columns': ['cinema id', 'name', 'openning year', 'capacity', 'location']},
#    {'table_name': 'schedule',
#     'columns': ['cinema id',
#      'film id',
#      'date',
#      'show times per day',
#      'price']}]},
#  'decoration_competition': {'database_name': 'decoration_competition',
#   'tables': [{'table_name': 'college',
#     'columns': ['college id', 'name', 'leader name', 'college location']},
#    {'table_name': 'member',
#     'columns': ['member id', 'name', 'country', 'college id']},
#    {'table_name': 'round',
#     'columns': ['round id',
#      'member id',
#      'decoration theme',
#      'rank in round']}]},
#  'phone_market': {'database_name': 'phone_market',
#   'tables': [{'table_name': 'phone',
#     'columns': ['name', 'phone id', 'memory in g', 'carrier', 'price']},
#    {'table_name': 'market',
#     'columns': ['market id',
#      'district',
#      'num of employees',
#      'num of shops',
#      'ranking']},
#    {'table_name': 'phone market',
#     'columns': ['market id', 'phone id', 'num of stock']}]},
#  'store_product': {'database_name': 'store_product',
#   'tables': [{'table_name': 'product',
#     'columns': ['product id',
#      'product',
#      'dimensions',
#      'dpi',
#      'pages per minute color',
#      'max page size',
#      'interface']},
#    {'table_name': 'store',
#     'columns': ['store id',
#      'store name',
#      'type',
#      'area size',
#      'number of product category',
#      'ranking']},
#    {'table_name': 'district',
#     'columns': ['district id',
#      'district name',
#      'headquartered city',
#      'city population',
#      'city area']},
#    {'table_name': 'store product', 'columns': ['store id', 'product id']},
#    {'table_name': 'store district', 'columns': ['store id', 'district id']}]},
#  'assets_maintenance': {'database_name': 'assets_maintenance',
#   'tables': [{'table_name': 'third party companies',
#     'columns': ['company id',
#      'company type',
#      'company name',
#      'company address',
#      'other company details']},
#    {'table_name': 'maintenance contracts',
#     'columns': ['maintenance contract id',
#      'maintenance contract company id',
#      'contract start date',
#      'contract end date',
#      'other contract details']},
#    {'table_name': 'parts',
#     'columns': ['part id',
#      'part name',
#      'chargeable yn',
#      'chargeable amount',
#      'other part details']},
#    {'table_name': 'skills',
#     'columns': ['skill id', 'skill code', 'skill description']},
#    {'table_name': 'staff',
#     'columns': ['staff id', 'staff name', 'gender', 'other staff details']},
#    {'table_name': 'assets',
#     'columns': ['asset id',
#      'maintenance contract id',
#      'supplier company id',
#      'asset details',
#      'asset make',
#      'asset model',
#      'asset acquired date',
#      'asset disposed date',
#      'other asset details']},
#    {'table_name': 'asset parts', 'columns': ['asset id', 'part id']},
#    {'table_name': 'maintenance engineers',
#     'columns': ['engineer id',
#      'company id',
#      'first name',
#      'last name',
#      'other details']},
#    {'table_name': 'engineer skills', 'columns': ['engineer id', 'skill id']},
#    {'table_name': 'fault log',
#     'columns': ['fault log entry id',
#      'asset id',
#      'recorded by staff id',
#      'fault log entry datetime',
#      'fault description',
#      'other fault details']},
#    {'table_name': 'engineer visits',
#     'columns': ['engineer visit id',
#      'contact staff id',
#      'engineer id',
#      'fault log entry id',
#      'fault status',
#      'visit start datetime',
#      'visit end datetime',
#      'other visit details']},
#    {'table_name': 'part faults',
#     'columns': ['part fault id',
#      'part id',
#      'fault short name',
#      'fault description',
#      'other fault details']},
#    {'table_name': 'fault log parts',
#     'columns': ['fault log entry id', 'part fault id', 'fault status']},
#    {'table_name': 'skills required to fix',
#     'columns': ['part fault id', 'skill id']}]},
#  'student_assessment': {'database_name': 'student_assessment',
#   'tables': [{'table_name': 'addresses',
#     'columns': ['address id',
#      'line 1',
#      'line 2',
#      'city',
#      'zip postcode',
#      'state province county',
#      'country']},
#    {'table_name': 'people',
#     'columns': ['person id',
#      'first name',
#      'middle name',
#      'last name',
#      'cell mobile number',
#      'email address',
#      'login name',
#      'password']},
#    {'table_name': 'students', 'columns': ['student id', 'student details']},
#    {'table_name': 'courses',
#     'columns': ['course id',
#      'course name',
#      'course description',
#      'other details']},
#    {'table_name': 'people addresses',
#     'columns': ['person address id',
#      'person id',
#      'address id',
#      'date from',
#      'date to']},
#    {'table_name': 'student course registrations',
#     'columns': ['student id', 'course id', 'registration date']},
#    {'table_name': 'student course attendance',
#     'columns': ['student id', 'course id', 'date of attendance']},
#    {'table_name': 'candidates',
#     'columns': ['candidate id', 'candidate details']},
#    {'table_name': 'candidate assessments',
#     'columns': ['candidate id',
#      'qualification',
#      'assessment date',
#      'asessment outcome code']}]},
#  'dog_kennels': {'database_name': 'dog_kennels',
#   'tables': [{'table_name': 'breeds', 'columns': ['breed code', 'breed name']},
#    {'table_name': 'charges',
#     'columns': ['charge id', 'charge type', 'charge amount']},
#    {'table_name': 'sizes', 'columns': ['size code', 'size description']},
#    {'table_name': 'treatment types',
#     'columns': ['treatment type code', 'treatment type description']},
#    {'table_name': 'owners',
#     'columns': ['owner id',
#      'first name',
#      'last name',
#      'street',
#      'city',
#      'state',
#      'zip code',
#      'email address',
#      'home phone',
#      'cell number']},
#    {'table_name': 'dogs',
#     'columns': ['dog id',
#      'owner id',
#      'abandoned yes or no',
#      'breed code',
#      'size code',
#      'name',
#      'age',
#      'date of birth',
#      'gender',
#      'weight',
#      'date arrived',
#      'date adopted',
#      'date departed']},
#    {'table_name': 'professionals',
#     'columns': ['professional id',
#      'role code',
#      'first name',
#      'street',
#      'city',
#      'state',
#      'zip code',
#      'last name',
#      'email address',
#      'home phone',
#      'cell number']},
#    {'table_name': 'treatments',
#     'columns': ['treatment id',
#      'dog id',
#      'professional id',
#      'treatment type code',
#      'date of treatment',
#      'cost of treatment']}]},
#  'music_1': {'database_name': 'music_1',
#   'tables': [{'table_name': 'genre',
#     'columns': ['genre name', 'rating', 'most popular in']},
#    {'table_name': 'artist',
#     'columns': ['artist name', 'country', 'gender', 'preferred genre']},
#    {'table_name': 'files',
#     'columns': ['song id', 'artist name', 'file size', 'duration', 'formats']},
#    {'table_name': 'song',
#     'columns': ['song name',
#      'artist name',
#      'country',
#      'song id',
#      'genre is',
#      'rating',
#      'languages',
#      'releasedate',
#      'resolution']}]},
#  'company_employee': {'database_name': 'company_employee',
#   'tables': [{'table_name': 'people',
#     'columns': ['people id',
#      'age',
#      'name',
#      'nationality',
#      'graduation college']},
#    {'table_name': 'company',
#     'columns': ['company id',
#      'name',
#      'headquarters',
#      'industry',
#      'sales in billion',
#      'profits in billion',
#      'assets in billion',
#      'market value in billion']},
#    {'table_name': 'employment',
#     'columns': ['company id', 'people id', 'year working']}]},
#  'farm': {'database_name': 'farm',
#   'tables': [{'table_name': 'city',
#     'columns': ['city id',
#      'official name',
#      'status',
#      'area km 2',
#      'population',
#      'census ranking']},
#    {'table_name': 'farm',
#     'columns': ['farm id',
#      'year',
#      'total horses',
#      'working horses',
#      'total cattle',
#      'oxen',
#      'bulls',
#      'cows',
#      'pigs',
#      'sheep and goats']},
#    {'table_name': 'farm competition',
#     'columns': ['competition id', 'year', 'theme', 'host city id', 'hosts']},
#    {'table_name': 'competition record',
#     'columns': ['competition id', 'farm id', 'rank']}]},
#  'solvency_ii': {'database_name': 'solvency_ii',
#   'tables': [{'table_name': 'addresses',
#     'columns': ['address id', 'address details']},
#    {'table_name': 'locations', 'columns': ['location id', 'other details']},
#    {'table_name': 'products',
#     'columns': ['product id',
#      'product type code',
#      'product name',
#      'product price']},
#    {'table_name': 'parties', 'columns': ['party id', 'party details']},
#    {'table_name': 'assets', 'columns': ['asset id', 'other details']},
#    {'table_name': 'channels', 'columns': ['channel id', 'other details']},
#    {'table_name': 'finances', 'columns': ['finance id', 'other details']},
#    {'table_name': 'events',
#     'columns': ['event id',
#      'address id',
#      'channel id',
#      'event type code',
#      'finance id',
#      'location id']},
#    {'table_name': 'products in events',
#     'columns': ['product in event id', 'event id', 'product id']},
#    {'table_name': 'parties in events',
#     'columns': ['party id', 'event id', 'role code']},
#    {'table_name': 'agreements', 'columns': ['document id', 'event id']},
#    {'table_name': 'assets in events', 'columns': ['asset id', 'event id']}]},
#  'city_record': {'database_name': 'city_record',
#   'tables': [{'table_name': 'city',
#     'columns': ['city id',
#      'city',
#      'hanzi',
#      'hanyu pinyin',
#      'regional population',
#      'gdp']},
#    {'table_name': 'match',
#     'columns': ['match id',
#      'date',
#      'venue',
#      'score',
#      'result',
#      'competition']},
#    {'table_name': 'temperature',
#     'columns': ['city id',
#      'jan',
#      'feb',
#      'mar',
#      'apr',
#      'jun',
#      'jul',
#      'aug',
#      'sep',
#      'oct',
#      'nov',
#      'dec']},
#    {'table_name': 'hosting city',
#     'columns': ['year', 'match id', 'host city']}]},
#  'swimming': {'database_name': 'swimming',
#   'tables': [{'table_name': 'swimmer',
#     'columns': ['id',
#      'name',
#      'nationality',
#      'meter 100',
#      'meter 200',
#      'meter 300',
#      'meter 400',
#      'meter 500',
#      'meter 600',
#      'meter 700',
#      'time']},
#    {'table_name': 'stadium',
#     'columns': ['id', 'name', 'capacity', 'city', 'country', 'opening year']},
#    {'table_name': 'event', 'columns': ['id', 'name', 'stadium id', 'year']},
#    {'table_name': 'record',
#     'columns': ['id', 'result', 'swimmer id', 'event id']}]},
#  'flight_2': {'database_name': 'flight_2',
#   'tables': [{'table_name': 'airlines',
#     'columns': ['airline id', 'airline name', 'abbreviation', 'country']},
#    {'table_name': 'airports',
#     'columns': ['city',
#      'airport code',
#      'airport name',
#      'country',
#      'country abbrev']},
#    {'table_name': 'flights',
#     'columns': ['airline',
#      'flight number',
#      'source airport',
#      'destination airport']}]},
#  'election': {'database_name': 'election',
#   'tables': [{'table_name': 'county',
#     'columns': ['county id', 'county name', 'population', 'zip code']},
#    {'table_name': 'party',
#     'columns': ['party id',
#      'year',
#      'party',
#      'governor',
#      'lieutenant governor',
#      'comptroller',
#      'attorney general',
#      'us senate']},
#    {'table_name': 'election',
#     'columns': ['election id',
#      'counties represented',
#      'district',
#      'delegate',
#      'party',
#      'first elected',
#      'committee']}]},
#  'manufactory_1': {'database_name': 'manufactory_1',
#   'tables': [{'table_name': 'manufacturers',
#     'columns': ['code', 'name', 'headquarter', 'founder', 'revenue']},
#    {'table_name': 'products',
#     'columns': ['code', 'name', 'price', 'manufacturer']}]},
#  'debate': {'database_name': 'debate',
#   'tables': [{'table_name': 'people',
#     'columns': ['people id', 'district', 'name', 'party', 'age']},
#    {'table_name': 'debate',
#     'columns': ['debate id', 'date', 'venue', 'num of audience']},
#    {'table_name': 'debate people',
#     'columns': ['debate id',
#      'affirmative',
#      'negative',
#      'if affirmative win']}]},
#  'network_2': {'database_name': 'network_2',
#   'tables': [{'table_name': 'person',
#     'columns': ['name', 'age', 'city', 'gender', 'job']},
#    {'table_name': 'person friend', 'columns': ['name', 'friend', 'year']}]},
#  'local_govt_in_alabama': {'database_name': 'local_govt_in_alabama',
#   'tables': [{'table_name': 'services',
#     'columns': ['service id', 'service type code']},
#    {'table_name': 'participants',
#     'columns': ['participant id',
#      'participant type code',
#      'participant details']},
#    {'table_name': 'events',
#     'columns': ['event id', 'service id', 'event details']},
#    {'table_name': 'participants in events',
#     'columns': ['event id', 'participant id']}]},
#  'climbing': {'database_name': 'climbing',
#   'tables': [{'table_name': 'mountain',
#     'columns': ['mountain id',
#      'name',
#      'height',
#      'prominence',
#      'range',
#      'country']},
#    {'table_name': 'climber',
#     'columns': ['climber id',
#      'name',
#      'country',
#      'time',
#      'points',
#      'mountain id']}]},
#  'e_learning': {'database_name': 'e_learning',
#   'tables': [{'table_name': 'course authors and tutors',
#     'columns': ['author id',
#      'author tutor atb',
#      'login name',
#      'password',
#      'personal name',
#      'middle name',
#      'family name',
#      'gender mf',
#      'address line 1']},
#    {'table_name': 'students',
#     'columns': ['student id',
#      'date of registration',
#      'date of latest logon',
#      'login name',
#      'password',
#      'personal name',
#      'middle name',
#      'family name']},
#    {'table_name': 'subjects', 'columns': ['subject id', 'subject name']},
#    {'table_name': 'courses',
#     'columns': ['course id',
#      'author id',
#      'subject id',
#      'course name',
#      'course description']},
#    {'table_name': 'student course enrolment',
#     'columns': ['registration id',
#      'student id',
#      'course id',
#      'date of enrolment',
#      'date of completion']},
#    {'table_name': 'student tests taken',
#     'columns': ['registration id', 'date test taken', 'test result']}]},
#  'scientist_1': {'database_name': 'scientist_1',
#   'tables': [{'table_name': 'scientists', 'columns': ['ssn', 'name']},
#    {'table_name': 'projects', 'columns': ['code', 'name', 'hours']},
#    {'table_name': 'assigned to', 'columns': ['scientist', 'project']}]},
#  'ship_1': {'database_name': 'ship_1',
#   'tables': [{'table_name': 'captain',
#     'columns': ['captain id', 'name', 'ship id', 'age', 'class', 'rank']},
#    {'table_name': 'ship',
#     'columns': ['ship id', 'name', 'type', 'built year', 'class', 'flag']}]},
#  'entertainment_awards': {'database_name': 'entertainment_awards',
#   'tables': [{'table_name': 'festival detail',
#     'columns': ['festival id',
#      'festival name',
#      'chair name',
#      'location',
#      'year',
#      'num of audience']},
#    {'table_name': 'artwork', 'columns': ['artwork id', 'type', 'name']},
#    {'table_name': 'nomination',
#     'columns': ['artwork id', 'festival id', 'result']}]},
#  'allergy_1': {'database_name': 'allergy_1',
#   'tables': [{'table_name': 'allergy type',
#     'columns': ['allergy name', 'allergy type']},
#    {'table_name': 'has allergy', 'columns': ['stuid', 'allergy']},
#    {'table_name': 'student',
#     'columns': ['stuid',
#      'last name',
#      'first name',
#      'age',
#      'sex',
#      'major',
#      'advisor',
#      'city code']}]},
#  'imdb': {'database_name': 'imdb',
#   'tables': [{'table_name': 'actor',
#     'columns': ['aid',
#      'gender',
#      'name',
#      'nationality',
#      'birth city',
#      'birth year']},
#    {'table_name': 'copyright', 'columns': ['id', 'msid', 'cid']},
#    {'table_name': 'cast', 'columns': ['id', 'msid', 'aid', 'role']},
#    {'table_name': 'genre', 'columns': ['gid', 'genre']},
#    {'table_name': 'classification', 'columns': ['id', 'msid', 'gid']},
#    {'table_name': 'company', 'columns': ['id', 'name', 'country code']},
#    {'table_name': 'director',
#     'columns': ['did',
#      'gender',
#      'name',
#      'nationality',
#      'birth city',
#      'birth year']},
#    {'table_name': 'producer',
#     'columns': ['pid',
#      'gender',
#      'name',
#      'nationality',
#      'birth city',
#      'birth year']},
#    {'table_name': 'directed by', 'columns': ['id', 'msid', 'did']},
#    {'table_name': 'keyword', 'columns': ['id', 'keyword']},
#    {'table_name': 'made by', 'columns': ['id', 'msid', 'pid']},
#    {'table_name': 'movie',
#     'columns': ['mid', 'title', 'release year', 'title aka', 'budget']},
#    {'table_name': 'tags', 'columns': ['id', 'msid', 'kid']},
#    {'table_name': 'tv series',
#     'columns': ['sid',
#      'title',
#      'release year',
#      'num of seasons',
#      'num of episodes',
#      'title aka',
#      'budget']},
#    {'table_name': 'writer',
#     'columns': ['wid',
#      'gender',
#      'name',
#      'nationality',
#      'num of episodes',
#      'birth city',
#      'birth year']},
#    {'table_name': 'written by', 'columns': ['id', 'msid', 'wid']}]},
#  'products_for_hire': {'database_name': 'products_for_hire',
#   'tables': [{'table_name': 'discount coupons',
#     'columns': ['coupon id', 'date issued', 'coupon amount']},
#    {'table_name': 'customers',
#     'columns': ['customer id',
#      'coupon id',
#      'good or bad customer',
#      'first name',
#      'last name',
#      'gender',
#      'date became customer',
#      'date last hire']},
#    {'table_name': 'bookings',
#     'columns': ['booking id',
#      'customer id',
#      'booking status code',
#      'returned damaged yes or no',
#      'booking start date',
#      'booking end date',
#      'count hired',
#      'amount payable',
#      'amount of discount',
#      'amount outstanding',
#      'amount of refund']},
#    {'table_name': 'products for hire',
#     'columns': ['product id',
#      'product type code',
#      'daily hire cost',
#      'product name',
#      'product description']},
#    {'table_name': 'payments',
#     'columns': ['payment id',
#      'booking id',
#      'customer id',
#      'payment type code',
#      'amount paid in full yn',
#      'payment date',
#      'amount due',
#      'amount paid']},
#    {'table_name': 'products booked',
#     'columns': ['booking id',
#      'product id',
#      'returned yes or no',
#      'returned late yes or no',
#      'booked count',
#      'booked amount']},
#    {'table_name': 'view product availability',
#     'columns': ['product id',
#      'booking id',
#      'status date',
#      'available yes or no']}]},
#  'candidate_poll': {'database_name': 'candidate_poll',
#   'tables': [{'table_name': 'candidate',
#     'columns': ['candidate id',
#      'people id',
#      'poll source',
#      'date',
#      'support rate',
#      'consider rate',
#      'oppose rate',
#      'unsure rate']},
#    {'table_name': 'people',
#     'columns': ['people id',
#      'sex',
#      'name',
#      'date of birth',
#      'height',
#      'weight']}]},
#  'chinook_1': {'database_name': 'chinook_1',
#   'tables': [{'table_name': 'album',
#     'columns': ['album id', 'title', 'artist id']},
#    {'table_name': 'artist', 'columns': ['artist id', 'name']},
#    {'table_name': 'customer',
#     'columns': ['customer id',
#      'first name',
#      'last name',
#      'company',
#      'address',
#      'city',
#      'state',
#      'country',
#      'postal code',
#      'phone',
#      'fax',
#      'email',
#      'support representative id']},
#    {'table_name': 'employee',
#     'columns': ['employee id',
#      'last name',
#      'first name',
#      'title',
#      'reports to',
#      'birth date',
#      'hire date',
#      'address',
#      'city',
#      'state',
#      'country',
#      'postal code',
#      'phone',
#      'fax',
#      'email']},
#    {'table_name': 'genre', 'columns': ['genre id', 'name']},
#    {'table_name': 'invoice',
#     'columns': ['invoice id',
#      'customer id',
#      'invoice date',
#      'billing address',
#      'billing city',
#      'billing state',
#      'billing country',
#      'billing postal code',
#      'total']},
#    {'table_name': 'invoice line',
#     'columns': ['invoice line id',
#      'invoice id',
#      'track id',
#      'unit price',
#      'quantity']},
#    {'table_name': 'media type', 'columns': ['media type id', 'name']},
#    {'table_name': 'playlist', 'columns': ['play list id', 'name']},
#    {'table_name': 'playlist track', 'columns': ['play list id', 'track id']},
#    {'table_name': 'track',
#     'columns': ['track id',
#      'name',
#      'album id',
#      'media type id',
#      'genre id',
#      'composer',
#      'milliseconds',
#      'bytes',
#      'unit price']}]},
#  'flight_4': {'database_name': 'flight_4',
#   'tables': [{'table_name': 'routes',
#     'columns': ['route id',
#      'destination airport id',
#      'destination airport',
#      'source airport id',
#      'source airport',
#      'airline id',
#      'airline',
#      'code share']},
#    {'table_name': 'airports',
#     'columns': ['airport id',
#      'name',
#      'city',
#      'country',
#      'x',
#      'y',
#      'elevation',
#      'iata',
#      'icao']},
#    {'table_name': 'airlines',
#     'columns': ['airline id',
#      'name',
#      'iata',
#      'icao',
#      'call sign',
#      'country',
#      'active']}]},
#  'pets_1': {'database_name': 'pets_1',
#   'tables': [{'table_name': 'student',
#     'columns': ['student id',
#      'last name',
#      'first name',
#      'age',
#      'sex',
#      'major',
#      'advisor',
#      'city code']},
#    {'table_name': 'has pet', 'columns': ['student id', 'pet id']},
#    {'table_name': 'pets',
#     'columns': ['pet id', 'pet type', 'pet age', 'weight']}]},
#  'dorm_1': {'database_name': 'dorm_1',
#   'tables': [{'table_name': 'student',
#     'columns': ['student id',
#      'last name',
#      'first name',
#      'age',
#      'sex',
#      'major',
#      'advisor',
#      'city code']},
#    {'table_name': 'dorm',
#     'columns': ['dorm id', 'dorm name', 'student capacity', 'gender']},
#    {'table_name': 'dorm amenity', 'columns': ['amenity id', 'amenity name']},
#    {'table_name': 'has amenity', 'columns': ['dorm id', 'amenity id']},
#    {'table_name': 'lives in',
#     'columns': ['student id', 'dorm id', 'room number']}]},
#  'journal_committee': {'database_name': 'journal_committee',
#   'tables': [{'table_name': 'journal',
#     'columns': ['journal id', 'date', 'theme', 'sales']},
#    {'table_name': 'editor', 'columns': ['editor id', 'name', 'age']},
#    {'table_name': 'journal committee',
#     'columns': ['editor id', 'journal id', 'work type']}]},
#  'flight_1': {'database_name': 'flight_1',
#   'tables': [{'table_name': 'flight',
#     'columns': ['flight number',
#      'origin',
#      'destination',
#      'distance',
#      'departure date',
#      'arrival date',
#      'price',
#      'airline id']},
#    {'table_name': 'aircraft', 'columns': ['airline id', 'name', 'distance']},
#    {'table_name': 'employee', 'columns': ['employee id', 'name', 'salary']},
#    {'table_name': 'certificate', 'columns': ['employee id', 'airline id']}]},
#  'medicine_enzyme_interaction': {'database_name': 'medicine_enzyme_interaction',
#   'tables': [{'table_name': 'medicine',
#     'columns': ['id', 'name', 'trade name', 'fda approved']},
#    {'table_name': 'enzyme',
#     'columns': ['id',
#      'name',
#      'location',
#      'product',
#      'chromosome',
#      'omim',
#      'porphyria']},
#    {'table_name': 'medicine enzyme interaction',
#     'columns': ['enzyme id', 'medicine id', 'interaction type']}]},
#  'local_govt_and_lot': {'database_name': 'local_govt_and_lot',
#   'tables': [{'table_name': 'customers',
#     'columns': ['customer id', 'customer details']},
#    {'table_name': 'properties',
#     'columns': ['property id',
#      'property type code',
#      'property address',
#      'other details']},
#    {'table_name': 'residents',
#     'columns': ['resident id',
#      'property id',
#      'date moved in',
#      'date moved out',
#      'other details']},
#    {'table_name': 'organizations',
#     'columns': ['organization id',
#      'parent organization id',
#      'organization details']},
#    {'table_name': 'services',
#     'columns': ['service id',
#      'organization id',
#      'service type code',
#      'service details']},
#    {'table_name': 'residents services',
#     'columns': ['resident id',
#      'service id',
#      'date moved in',
#      'property id',
#      'date requested',
#      'date provided',
#      'other details']},
#    {'table_name': 'things',
#     'columns': ['thing id',
#      'organization id',
#      'type of thing code',
#      'service type code',
#      'service details']},
#    {'table_name': 'customer events',
#     'columns': ['customer event id',
#      'customer id',
#      'date moved in',
#      'property id',
#      'resident id',
#      'thing id']},
#    {'table_name': 'customer event notes',
#     'columns': ['customer event note id',
#      'customer event id',
#      'service type code',
#      'resident id',
#      'property id',
#      'date moved in']},
#    {'table_name': 'timed status of things',
#     'columns': ['thing id', 'date and date', 'status of thing code']},
#    {'table_name': 'timed locations of things',
#     'columns': ['thing id', 'date and time', 'location code']}]},
#  'station_weather': {'database_name': 'station_weather',
#   'tables': [{'table_name': 'train',
#     'columns': ['id',
#      'train number',
#      'name',
#      'origin',
#      'destination',
#      'time',
#      'interval']},
#    {'table_name': 'station',
#     'columns': ['id', 'network name', 'services', 'local authority']},
#    {'table_name': 'route', 'columns': ['train id', 'station id']},
#    {'table_name': 'weekly weather',
#     'columns': ['station id',
#      'day of week',
#      'high temperature',
#      'low temperature',
#      'precipitation',
#      'wind speed mph']}]},
#  'shop_membership': {'database_name': 'shop_membership',
#   'tables': [{'table_name': 'member',
#     'columns': ['member id', 'card number', 'name', 'hometown', 'level']},
#    {'table_name': 'branch',
#     'columns': ['branch id',
#      'name',
#      'open year',
#      'address road',
#      'city',
#      'membership amount']},
#    {'table_name': 'membership register branch',
#     'columns': ['member id', 'branch id', 'register year']},
#    {'table_name': 'purchase',
#     'columns': ['member id', 'branch id', 'year', 'total pounds']}]},
#  'driving_school': {'database_name': 'driving_school',
#   'tables': [{'table_name': 'addresses',
#     'columns': ['address id',
#      'line 1 number building',
#      'city',
#      'zip postcode',
#      'state province county',
#      'country']},
#    {'table_name': 'staff',
#     'columns': ['staff id',
#      'staff address id',
#      'nickname',
#      'first name',
#      'middle name',
#      'last name',
#      'date of birth',
#      'date joined staff',
#      'date left staff']},
#    {'table_name': 'vehicles', 'columns': ['vehicle id', 'vehicle details']},
#    {'table_name': 'customers',
#     'columns': ['customer id',
#      'customer address id',
#      'customer status code',
#      'date became customer',
#      'date of birth',
#      'first name',
#      'last name',
#      'amount outstanding',
#      'email address',
#      'phone number',
#      'cell mobile phone number']},
#    {'table_name': 'customer payments',
#     'columns': ['customer id',
#      'datetime payment',
#      'payment method code',
#      'amount payment']},
#    {'table_name': 'lessons',
#     'columns': ['lesson id',
#      'customer id',
#      'lesson status code',
#      'staff id',
#      'vehicle id',
#      'lesson date',
#      'lesson time',
#      'price']}]},
#  'concert_singer': {'database_name': 'concert_singer',
#   'tables': [{'table_name': 'stadium',
#     'columns': ['stadium id',
#      'location',
#      'name',
#      'capacity',
#      'highest',
#      'lowest',
#      'average']},
#    {'table_name': 'singer',
#     'columns': ['singer id',
#      'name',
#      'country',
#      'song name',
#      'song release year',
#      'age',
#      'is male']},
#    {'table_name': 'concert',
#     'columns': ['concert id', 'concert name', 'theme', 'stadium id', 'year']},
#    {'table_name': 'singer in concert',
#     'columns': ['concert id', 'singer id']}]},
#  'music_2': {'database_name': 'music_2',
#   'tables': [{'table_name': 'songs', 'columns': ['song id', 'title']},
#    {'table_name': 'albums',
#     'columns': ['aid', 'title', 'year', 'label', 'type']},
#    {'table_name': 'band', 'columns': ['id', 'first name', 'last name']},
#    {'table_name': 'instruments',
#     'columns': ['song id', 'bandmate id', 'instrument']},
#    {'table_name': 'performance',
#     'columns': ['song id', 'bandmate', 'stage position']},
#    {'table_name': 'track lists',
#     'columns': ['album id', 'position', 'song id']},
#    {'table_name': 'vocals', 'columns': ['song id', 'bandmate', 'type']}]},
#  'sports_competition': {'database_name': 'sports_competition',
#   'tables': [{'table_name': 'club',
#     'columns': ['club id', 'name', 'region', 'start year']},
#    {'table_name': 'club rank',
#     'columns': ['rank', 'club id', 'gold', 'silver', 'bronze', 'total']},
#    {'table_name': 'player',
#     'columns': ['player id',
#      'name',
#      'position',
#      'club id',
#      'apps',
#      'tries',
#      'goals',
#      'points']},
#    {'table_name': 'competition',
#     'columns': ['competition id', 'year', 'competition type', 'country']},
#    {'table_name': 'competition result',
#     'columns': ['competition id', 'club id 1', 'club id 2', 'score']}]},
#  'railway': {'database_name': 'railway',
#   'tables': [{'table_name': 'railway',
#     'columns': ['railway id',
#      'railway',
#      'builder',
#      'built',
#      'wheels',
#      'location',
#      'objectnumber']},
#    {'table_name': 'train',
#     'columns': ['train id',
#      'train num',
#      'name',
#      'from',
#      'arrival',
#      'railway id']},
#    {'table_name': 'manager',
#     'columns': ['manager id',
#      'name',
#      'country',
#      'working year starts',
#      'age',
#      'level']},
#    {'table_name': 'railway manage',
#     'columns': ['railway id', 'manager id', 'from year']}]},
#  'inn_1': {'database_name': 'inn_1',
#   'tables': [{'table_name': 'rooms',
#     'columns': ['room id',
#      'room name',
#      'beds',
#      'bed type',
#      'max occupancy',
#      'base price',
#      'decor']},
#    {'table_name': 'reservations',
#     'columns': ['code',
#      'room',
#      'check in',
#      'check out',
#      'rate',
#      'last name',
#      'first name',
#      'adults',
#      'kids']}]},
#  'museum_visit': {'database_name': 'museum_visit',
#   'tables': [{'table_name': 'museum',
#     'columns': ['museum id', 'name', 'num of staff', 'open year']},
#    {'table_name': 'customer',
#     'columns': ['customer id', 'name', 'level of membership', 'age']},
#    {'table_name': 'visit',
#     'columns': ['museum id', 'customer id', 'num of ticket', 'total spent']}]},
#  'browser_web': {'database_name': 'browser_web',
#   'tables': [{'table_name': 'web client accelerator',
#     'columns': ['id', 'name', 'operating system', 'client', 'connection']},
#    {'table_name': 'browser', 'columns': ['id', 'name', 'market share']},
#    {'table_name': 'accelerator compatible browser',
#     'columns': ['accelerator id', 'browser id', 'compatible since year']}]},
#  'baseball_1': {'database_name': 'baseball_1',
#   'tables': [{'table_name': 'all star',
#     'columns': ['player id',
#      'year',
#      'game num',
#      'game id',
#      'team id',
#      'league id',
#      'gp',
#      'starting pos']},
#    {'table_name': 'appearances',
#     'columns': ['year',
#      'team id',
#      'league id',
#      'player id',
#      'g all',
#      'gs',
#      'g batting',
#      'g defense',
#      'g p',
#      'g c',
#      'g 1b',
#      'g 2b',
#      'g 3b',
#      'g ss',
#      'g lf',
#      'g cf',
#      'g rf',
#      'g of',
#      'g dh',
#      'g ph',
#      'g pr']},
#    {'table_name': 'manager award',
#     'columns': ['player id', 'award id', 'year', 'league id', 'tie', 'notes']},
#    {'table_name': 'player award',
#     'columns': ['player id', 'award id', 'year', 'league id', 'tie', 'notes']},
#    {'table_name': 'manager award vote',
#     'columns': ['award id',
#      'year',
#      'league id',
#      'player id',
#      'points won',
#      'points max',
#      'votes first']},
#    {'table_name': 'player award vote',
#     'columns': ['award id',
#      'year',
#      'league id',
#      'player id',
#      'points won',
#      'points max',
#      'votes first']},
#    {'table_name': 'batting',
#     'columns': ['player id',
#      'year',
#      'stint',
#      'team id',
#      'league id',
#      'g',
#      'ab',
#      'r',
#      'h',
#      'double',
#      'triple',
#      'hr',
#      'rbi',
#      'sb',
#      'cs',
#      'bb',
#      'so',
#      'ibb',
#      'hbp',
#      'sh',
#      'sf',
#      'g idp']},
#    {'table_name': 'batting postseason',
#     'columns': ['year',
#      'round',
#      'player id',
#      'team id',
#      'league id',
#      'g',
#      'ab',
#      'r',
#      'h',
#      'double',
#      'triple',
#      'hr',
#      'rbi',
#      'sb',
#      'cs',
#      'bb',
#      'so',
#      'ibb',
#      'hbp',
#      'sh',
#      'sf',
#      'g idp']},
#    {'table_name': 'player college',
#     'columns': ['player id', 'college id', 'year']},
#    {'table_name': 'fielding',
#     'columns': ['player id',
#      'year',
#      'stint',
#      'team id',
#      'league id',
#      'pos',
#      'g',
#      'gs',
#      'inn outs',
#      'po',
#      'a',
#      'e',
#      'dp',
#      'pb',
#      'wp',
#      'sb',
#      'cs',
#      'zr']},
#    {'table_name': 'fielding outfield',
#     'columns': ['player id', 'year', 'stint', 'glf', 'gcf', 'grf']},
#    {'table_name': 'fielding postseason',
#     'columns': ['player id',
#      'year',
#      'team id',
#      'league id',
#      'round',
#      'pos',
#      'g',
#      'gs',
#      'inn outs',
#      'po',
#      'a',
#      'e',
#      'dp',
#      'tp',
#      'pb',
#      'sb',
#      'cs']},
#    {'table_name': 'hall of fame',
#     'columns': ['player id',
#      'yearid',
#      'votedby',
#      'ballots',
#      'needed',
#      'votes',
#      'inducted',
#      'category',
#      'needed note']},
#    {'table_name': 'home game',
#     'columns': ['year',
#      'league id',
#      'team id',
#      'park id',
#      'span first',
#      'span last',
#      'games',
#      'openings',
#      'attendance']},
#    {'table_name': 'manager',
#     'columns': ['player id',
#      'year',
#      'team id',
#      'league id',
#      'inseason',
#      'g',
#      'w',
#      'l',
#      'rank',
#      'plyr mgr']},
#    {'table_name': 'manager half',
#     'columns': ['player id',
#      'year',
#      'team id',
#      'league id',
#      'inseason',
#      'half',
#      'g',
#      'w',
#      'l',
#      'rank']},
#    {'table_name': 'player',
#     'columns': ['player id',
#      'birth year',
#      'birth month',
#      'birth day',
#      'birth country',
#      'birth state',
#      'birth city',
#      'death year',
#      'death month',
#      'death day',
#      'death country',
#      'death state',
#      'death city',
#      'name first',
#      'name last',
#      'name given',
#      'weight',
#      'height',
#      'bats',
#      'throws',
#      'debut',
#      'final game',
#      'retro id',
#      'bbref id']},
#    {'table_name': 'park',
#     'columns': ['park id',
#      'park name',
#      'park alias',
#      'city',
#      'state',
#      'country']},
#    {'table_name': 'pitching',
#     'columns': ['player id',
#      'year',
#      'stint',
#      'team id',
#      'league id',
#      'w',
#      'l',
#      'g',
#      'gs',
#      'cg',
#      'sho',
#      'sv',
#      'ipouts',
#      'h',
#      'er',
#      'hr',
#      'bb',
#      'so',
#      'baopp',
#      'era',
#      'ibb',
#      'wp',
#      'hbp',
#      'bk',
#      'bfp',
#      'gf',
#      'r',
#      'sh',
#      'sf',
#      'g idp']},
#    {'table_name': 'pitching postseason',
#     'columns': ['player id',
#      'year',
#      'round',
#      'team id',
#      'league id',
#      'w',
#      'l',
#      'g',
#      'gs',
#      'cg',
#      'sho',
#      'sv',
#      'ipouts',
#      'h',
#      'er',
#      'hr',
#      'bb',
#      'so',
#      'baopp',
#      'era',
#      'ibb',
#      'wp',
#      'hbp',
#      'bk',
#      'bfp',
#      'gf',
#      'r',
#      'sh',
#      'sf',
#      'g idp']},
#    {'table_name': 'salary',
#     'columns': ['year', 'team id', 'league id', 'player id', 'salary']},
#    {'table_name': 'college',
#     'columns': ['college id', 'name full', 'city', 'state', 'country']},
#    {'table_name': 'postseason',
#     'columns': ['year',
#      'round',
#      'team id winner',
#      'league id winner',
#      'team id loser',
#      'league id loser',
#      'wins',
#      'losses',
#      'ties']},
#    {'table_name': 'team',
#     'columns': ['year',
#      'league id',
#      'team id',
#      'franchise id',
#      'div id',
#      'rank',
#      'g',
#      'ghome',
#      'w',
#      'l',
#      'div win',
#      'wc win',
#      'lg win',
#      'ws win',
#      'r',
#      'ab',
#      'h',
#      'double',
#      'triple',
#      'hr',
#      'bb',
#      'so',
#      'sb',
#      'cs',
#      'hbp',
#      'sf',
#      'ra',
#      'er',
#      'era',
#      'cg',
#      'sho',
#      'sv',
#      'ipouts',
#      'ha',
#      'hra',
#      'bba',
#      'soa',
#      'e',
#      'dp',
#      'fp',
#      'name',
#      'park',
#      'attendance',
#      'bpf',
#      'ppf',
#      'team id br',
#      'team id lahman45',
#      'team id retro']},
#    {'table_name': 'team franchise',
#     'columns': ['franchise id', 'franchise name', 'active', 'na assoc']},
#    {'table_name': 'team half',
#     'columns': ['year',
#      'league id',
#      'team id',
#      'half',
#      'div id',
#      'div win',
#      'rank',
#      'g',
#      'w',
#      'l']}]},
#  'architecture': {'database_name': 'architecture',
#   'tables': [{'table_name': 'architect',
#     'columns': ['id', 'name', 'nationality', 'gender']},
#    {'table_name': 'bridge',
#     'columns': ['architect id',
#      'id',
#      'name',
#      'location',
#      'length meters',
#      'length feet']},
#    {'table_name': 'mill',
#     'columns': ['architect id',
#      'id',
#      'location',
#      'name',
#      'type',
#      'built year',
#      'notes']}]},
#  'csu_1': {'database_name': 'csu_1',
#   'tables': [{'table_name': 'campuses',
#     'columns': ['id', 'campus', 'location', 'county', 'year']},
#    {'table_name': 'csu fees', 'columns': ['campus', 'year', 'campus fee']},
#    {'table_name': 'degrees', 'columns': ['year', 'campus', 'degrees']},
#    {'table_name': 'discipline enrollments',
#     'columns': ['campus', 'discipline', 'year', 'undergraduate', 'graduate']},
#    {'table_name': 'enrollments',
#     'columns': ['campus', 'year', 'totalenrollment ay', 'fte ay']},
#    {'table_name': 'faculty', 'columns': ['campus', 'year', 'faculty']}]},
#  'tracking_orders': {'database_name': 'tracking_orders',
#   'tables': [{'table_name': 'customers',
#     'columns': ['customer id', 'customer name', 'customer details']},
#    {'table_name': 'invoices',
#     'columns': ['invoice number', 'invoice date', 'invoice details']},
#    {'table_name': 'orders',
#     'columns': ['order id',
#      'customer id',
#      'order status',
#      'date order placed',
#      'order details']},
#    {'table_name': 'products',
#     'columns': ['product id', 'product name', 'product details']},
#    {'table_name': 'order items',
#     'columns': ['order item id',
#      'product id',
#      'order id',
#      'order item status',
#      'order item details']},
#    {'table_name': 'shipments',
#     'columns': ['shipment id',
#      'order id',
#      'invoice number',
#      'shipment tracking number',
#      'shipment date',
#      'other shipment details']},
#    {'table_name': 'shipment items',
#     'columns': ['shipment id', 'order item id']}]},
#  'insurance_policies': {'database_name': 'insurance_policies',
#   'tables': [{'table_name': 'customers',
#     'columns': ['customer id', 'customer details']},
#    {'table_name': 'customer policies',
#     'columns': ['policy id',
#      'customer id',
#      'policy type code',
#      'start date',
#      'end date']},
#    {'table_name': 'claims',
#     'columns': ['claim id',
#      'policy id',
#      'date claim made',
#      'date claim settled',
#      'amount claimed',
#      'amount settled']},
#    {'table_name': 'settlements',
# ...
#      'other details']},
#    {'table_name': 'employees',
#     'columns': ['employee id',
#      'role code',
#      'employee name',
#      'gender mfu',
#      'date of birth',
#      'other details']},
#    {'table_name': 'document locations',
#     'columns': ['document id',
#      'location code',
#      'date in location from',
#      'date in locaton to']},
#    {'table_name': 'documents to be destroyed',
#     'columns': ['document id',
#      'destruction authorised by employee id',
#      'destroyed by employee id',
#      'planned destruction date',
#      'actual destruction date',
#      'other details']}]},
#  'university_basketball': {'database_name': 'university_basketball',
#   'tables': [{'table_name': 'basketball match',
#     'columns': ['team id',
#      'school id',
#      'team name',
#      'acc regular season',
#      'acc percent',
#      'acc home',
#      'acc road',
#      'all games',
#      'all games percent',
#      'all home',
#      'all road',
#      'all neutral']},
#    {'table_name': 'university',
#     'columns': ['school id',
#      'school',
#      'location',
#      'founded',
#      'affiliation',
#      'enrollment',
#      'nickname',
#      'primary conference']}]},
#  'soccer_2': {'database_name': 'soccer_2',
#   'tables': [{'table_name': 'college',
#     'columns': ['college name', 'state', 'enrollment']},
#    {'table_name': 'player',
#     'columns': ['player id', 'player name', 'yes card', 'training hours']},
#    {'table_name': 'tryout',
#     'columns': ['player id', 'college name', 'player position', 'decision']}]},
#  'activity_1': {'database_name': 'activity_1',
#   'tables': [{'table_name': 'activity',
#     'columns': ['activity id', 'activity name']},
#    {'table_name': 'participates in', 'columns': ['student id', 'activity id']},
#    {'table_name': 'faculty participates in',
#     'columns': ['faculty id', 'activity id']},
#    {'table_name': 'student',
#     'columns': ['student id',
#      'last name',
#      'first name',
#      'age',
#      'sex',
#      'major',
#      'advisor',
#      'city code']},
#    {'table_name': 'faculty',
#     'columns': ['faculty id',
#      'last name',
#      'first name',
#      'rank',
#      'sex',
#      'phone',
#      'room',
#      'building']}]},
#  'cre_Theme_park': {'database_name': 'cre_Theme_park',
#   'tables': [{'table_name': 'ref hotel star ratings',
#     'columns': ['star rating code', 'star rating description']},
#    {'table_name': 'locations',
#     'columns': ['location id', 'location name', 'address', 'other details']},
#    {'table_name': 'ref attraction types',
#     'columns': ['attraction type code', 'attraction type description']},
#    {'table_name': 'visitors', 'columns': ['tourist id', 'tourist details']},
#    {'table_name': 'features', 'columns': ['feature id', 'feature details']},
#    {'table_name': 'hotels',
#     'columns': ['hotel id',
#      'star rating code',
#      'pets allowed yn',
#      'price range',
#      'other hotel details']},
#    {'table_name': 'tourist attractions',
#     'columns': ['tourist attraction id',
#      'attraction type code',
#      'location id',
#      'how to get there',
#      'name',
#      'description',
#      'opening hours',
#      'other details']},
#    {'table_name': 'street markets',
#     'columns': ['market id', 'market details']},
#    {'table_name': 'shops', 'columns': ['shop id', 'shop details']},
#    {'table_name': 'museums', 'columns': ['museum id', 'museum details']},
#    {'table_name': 'royal family',
#     'columns': ['royal family id', 'royal family details']},
#    {'table_name': 'theme parks',
#     'columns': ['theme park id', 'theme park details']},
#    {'table_name': 'visits',
#     'columns': ['visit id',
#      'tourist attraction id',
#      'tourist id',
#      'visit date',
#      'visit details']},
#    {'table_name': 'photos',
#     'columns': ['photo id',
#      'tourist attraction id',
#      'name',
#      'description',
#      'filename',
#      'other details']},
#    {'table_name': 'staff',
#     'columns': ['staff id', 'tourist attraction id', 'name', 'other details']},
#    {'table_name': 'tourist attraction features',
#     'columns': ['tourist attraction id', 'feature id']}]},
#  'twitter_1': {'database_name': 'twitter_1',
#   'tables': [{'table_name': 'follows', 'columns': ['user id', 'follower id']},
#    {'table_name': 'tweets',
#     'columns': ['id', 'user id', 'text', 'create date']},
#    {'table_name': 'user profiles',
#     'columns': ['uid', 'name', 'email', 'partition id', 'followers']}]},
#  'election_representative': {'database_name': 'election_representative',
#   'tables': [{'table_name': 'election',
#     'columns': ['election id',
#      'representative id',
#      'date',
#      'votes',
#      'vote percent',
#      'seats',
#      'place']},
#    {'table_name': 'representative',
#     'columns': ['representative id', 'name', 'state', 'party', 'lifespan']}]},
#  'voter_2': {'database_name': 'voter_2',
#   'tables': [{'table_name': 'student',
#     'columns': ['student id',
#      'last name',
#      'first name',
#      'age',
#      'sex',
#      'major',
#      'advisor',
#      'city code']},
#    {'table_name': 'voting record',
#     'columns': ['student id',
#      'registration date',
#      'election cycle',
#      'president vote',
#      'vice president vote',
#      'secretary vote',
#      'treasurer vote',
#      'class president vote',
#      'class senator vote']}]},
#  'wedding': {'database_name': 'wedding',
#   'tables': [{'table_name': 'people',
#     'columns': ['people id', 'name', 'country', 'is male', 'age']},
#    {'table_name': 'church',
#     'columns': ['church id',
#      'name',
#      'organized by',
#      'open date',
#      'continuation of']},
#    {'table_name': 'wedding',
#     'columns': ['church id', 'male id', 'female id', 'year']}]},
#  'news_report': {'database_name': 'news_report',
#   'tables': [{'table_name': 'event',
#     'columns': ['event id', 'date', 'venue', 'name', 'event attendance']},
#    {'table_name': 'journalist',
#     'columns': ['journalist id',
#      'name',
#      'nationality',
#      'age',
#      'years working']},
#    {'table_name': 'news report',
#     'columns': ['journalist id', 'event id', 'work type']}]},
#  'wine_1': {'database_name': 'wine_1',
#   'tables': [{'table_name': 'grapes', 'columns': ['id', 'grape', 'color']},
#    {'table_name': 'appellations',
#     'columns': ['no', 'appelation', 'county', 'state', 'area', 'isava']},
#    {'table_name': 'wine',
#     'columns': ['no',
#      'grape',
#      'winery',
#      'appelation',
#      'state',
#      'name',
#      'year',
#      'price',
#      'score',
#      'cases',
#      'drink']}]},
#  'customers_and_addresses': {'database_name': 'customers_and_addresses',
#   'tables': [{'table_name': 'addresses',
#     'columns': ['address id',
#      'address content',
#      'city',
#      'zip postcode',
#      'state province county',
#      'country',
#      'other address details']},
#    {'table_name': 'products', 'columns': ['product id', 'product details']},
#    {'table_name': 'customers',
#     'columns': ['customer id',
#      'payment method',
#      'customer name',
#      'date became customer',
#      'other customer details']},
#    {'table_name': 'customer addresses',
#     'columns': ['customer id',
#      'address id',
#      'date address from',
#      'address type',
#      'date address to']},
#    {'table_name': 'customer contact channels',
#     'columns': ['customer id',
#      'channel code',
#      'active from date',
#      'active to date',
#      'contact number']},
#    {'table_name': 'customer orders',
#     'columns': ['order id',
#      'customer id',
#      'order status',
#      'order date',
#      'order details']},
#    {'table_name': 'order items',
#     'columns': ['order id', 'product id', 'order quantity']}]},
#  'protein_institute': {'database_name': 'protein_institute',
#   'tables': [{'table_name': 'building',
#     'columns': ['building id',
#      'name',
#      'street address',
#      'years as tallest',
#      'height feet',
#      'floors']},
#    {'table_name': 'institution',
#     'columns': ['institution id',
#      'institution',
#      'location',
#      'founded',
#      'type',
#      'enrollment',
#      'team',
#      'primary conference',
#      'building id']},
#    {'table_name': 'protein',
#     'columns': ['common name',
#      'protein name',
#      'divergence from human lineage',
#      'accession number',
#      'sequence length',
#      'sequence identity to human protein',
#      'institution id']}]},
#  'school_player': {'database_name': 'school_player',
#   'tables': [{'table_name': 'school',
#     'columns': ['school id',
#      'school',
#      'location',
#      'enrollment',
#      'founded',
#      'denomination',
#      'boys or girls',
#      'day or boarding',
#      'year entered competition',
#      'school colors']},
#    {'table_name': 'school details',
#     'columns': ['school id',
#      'nickname',
#      'colors',
#      'league',
#      'class',
#      'division']},
#    {'table_name': 'school performance',
#     'columns': ['school id', 'school year', 'class a', 'class aa']},
#    {'table_name': 'player',
#     'columns': ['player id',
#      'player',
#      'team',
#      'age',
#      'position',
#      'school id']}]},
#  'phone_1': {'database_name': 'phone_1',
#   'tables': [{'table_name': 'chip model',
#     'columns': ['model name',
#      'launch year',
#      'ram mib',
#      'rom mib',
#      'slots',
#      'wifi',
#      'bluetooth']},
#    {'table_name': 'screen mode',
#     'columns': ['graphics mode',
#      'char cells',
#      'pixels',
#      'hardware colours',
#      'used kb',
#      'map',
#      'type']},
#    {'table_name': 'phone',
#     'columns': ['company name',
#      'hardware model name',
#      'accreditation type',
#      'accreditation level',
#      'date',
#      'chip model',
#      'screen mode']}]},
#  'tvshow': {'database_name': 'tvshow',
#   'tables': [{'table_name': 'tv channel',
#     'columns': ['id',
#      'series name',
#      'country',
#      'language',
#      'content',
#      'pixel aspect ratio par',
#      'hight definition tv',
#      'pay per view ppv',
#      'package option']},
#    {'table_name': 'tv series',
#     'columns': ['id',
#      'episode',
#      'air date',
#      'rating',
#      'share',
#      '18 49 rating share',
#      'viewers m',
#      'weekly rank',
#      'channel']},
#    {'table_name': 'cartoon',
#     'columns': ['id',
#      'title',
#      'directed by',
#      'written by',
#      'original air date',
#      'production code',
#      'channel']}]},
#  'wrestler': {'database_name': 'wrestler',
#   'tables': [{'table_name': 'wrestler',
#     'columns': ['wrestler id',
#      'name',
#      'reign',
#      'days held',
#      'location',
#      'event']},
#    {'table_name': 'elimination',
#     'columns': ['elimination id',
#      'wrestler id',
#      'team',
#      'eliminated by',
#      'elimination move',
#      'time']}]},
#  'customer_complaints': {'database_name': 'customer_complaints',
#   'tables': [{'table_name': 'staff',
#     'columns': ['staff id',
#      'gender',
#      'first name',
#      'last name',
#      'email address',
#      'phone number']},
#    {'table_name': 'customers',
#     'columns': ['customer id',
#      'customer type code',
#      'address line 1',
#      'address line 2',
#      'town city',
#      'state',
#      'email address',
#      'phone number']},
#    {'table_name': 'products',
#     'columns': ['product id',
#      'parent product id',
#      'product category code',
#      'date product first available',
#      'date product discontinued',
#      'product name',
#      'product description',
#      'product price']},
#    {'table_name': 'complaints',
#     'columns': ['complaint id',
#      'product id',
#      'customer id',
#      'complaint outcome code',
#      'complaint status code',
#      'complaint type code',
#      'date complaint raised',
#      'date complaint closed',
#      'staff id']}]},
#  'department_management': {'database_name': 'department_management',
#   'tables': [{'table_name': 'department',
#     'columns': ['department id',
#      'name',
#      'creation',
#      'ranking',
#      'budget in billions',
#      'num employees']},
#    {'table_name': 'head', 'columns': ['head id', 'name', 'born state', 'age']},
#    {'table_name': 'management',
#     'columns': ['department id', 'head id', 'temporary acting']}]},
#  'customers_and_products_contacts': {'database_name': 'customers_and_products_contacts',
#   'tables': [{'table_name': 'addresses',
#     'columns': ['address id',
#      'line 1 number building',
#      'city',
#      'zip postcode',
#      'state province county',
#      'country']},
#    {'table_name': 'products',
#     'columns': ['product id',
#      'product type code',
#      'product name',
#      'product price']},
#    {'table_name': 'customers',
#     'columns': ['customer id',
#      'payment method code',
#      'customer number',
#      'customer name',
#      'customer address',
#      'customer phone',
#      'customer email']},
#    {'table_name': 'contacts',
#     'columns': ['contact id',
#      'customer id',
#      'gender',
#      'first name',
#      'last name',
#      'contact phone']},
#    {'table_name': 'customer address history',
#     'columns': ['customer id', 'address id', 'date from', 'date to']},
#    {'table_name': 'customer orders',
#     'columns': ['order id', 'customer id', 'order date', 'order status code']},
#    {'table_name': 'order items',
#     'columns': ['order item id',
#      'order id',
#      'product id',
#      'order quantity']}]},
#  'company_1': {'database_name': 'company_1',
#   'tables': [{'table_name': 'works on',
#     'columns': ['employee ssn', 'project number', 'hours']},
#    {'table_name': 'employee',
#     'columns': ['first name',
#      'minit',
#      'last name',
#      'ssn',
#      'birth date',
#      'address',
#      'sex',
#      'salary',
#      'super ssn',
#      'department no']},
#    {'table_name': 'department',
#     'columns': ['department name',
#      'department number',
#      'manager ssn',
#      'manager start date']},
#    {'table_name': 'project',
#     'columns': ['dependent name',
#      'dependent number',
#      'dependent location',
#      'department number']},
#    {'table_name': 'dependent',
#     'columns': ['employee ssn',
#      'dependent name',
#      'sex',
#      'birth date',
#      'relationship']},
#    {'table_name': 'department locations',
#     'columns': ['department number', 'department location']}]},
#  'workshop_paper': {'database_name': 'workshop_paper',
#   'tables': [{'table_name': 'workshop',
#     'columns': ['workshop id', 'date', 'venue', 'name']},
#    {'table_name': 'submission',
#     'columns': ['submission id', 'scores', 'author', 'college']},
#    {'table_name': 'acceptance',
#     'columns': ['submission id', 'workshop id', 'result']}]},
#  'epinions_1': {'database_name': 'epinions_1',
#   'tables': [{'table_name': 'item', 'columns': ['item id', 'title']},
#    {'table_name': 'review',
#     'columns': ['a id', 'user id', 'item id', 'rating', 'rank']},
#    {'table_name': 'useracct', 'columns': ['user id', 'name']},
#    {'table_name': 'trust',
#     'columns': ['source user id', 'target user id', 'trust']}]},
#  'party_host': {'database_name': 'party_host',
#   'tables': [{'table_name': 'party',
#     'columns': ['party id',
#      'party theme',
#      'location',
#      'first year',
#      'last year',
#      'number of hosts']},
#    {'table_name': 'host',
#     'columns': ['host id', 'name', 'nationality', 'age']},
#    {'table_name': 'party host',
#     'columns': ['party id', 'host id', 'is main in charge']}]},
#  'product_catalog': {'database_name': 'product_catalog',
#   'tables': [{'table_name': 'attribute definitions',
#     'columns': ['attribute id', 'attribute name', 'attribute data type']},
#    {'table_name': 'catalogs',
#     'columns': ['catalog id',
#      'catalog name',
#      'catalog publisher',
#      'date of publication',
#      'date of latest revision']},
#    {'table_name': 'catalog structure',
#     'columns': ['catalog level number', 'catalog id', 'catalog level name']},
#    {'table_name': 'catalog contents',
#     'columns': ['catalog entry id',
#      'catalog level number',
#      'parent entry id',
#      'previous entry id',
#      'next entry id',
#      'catalog entry name',
#      'product stock number',
#      'price in dollars',
#      'price in euros',
#      'price in pounds',
#      'capacity',
#      'length',
#      'height',
#      'width']},
#    {'table_name': 'catalog contents additional attributes',
#     'columns': ['catalog entry id',
#      'catalog level number',
#      'attribute id',
#      'attribute value']}]}}

# %%
#Below function to finalise the format of the schema, into DB-TABLE-Column names format
def format_schema_jsonish(reshaped_essential_schemas):
    lines = []
    for _, db in reshaped_essential_schemas.items():
        db_name = db.get("database_name", "unknown")
        for t in db.get("tables", []):
            obj = {
                "database": db_name,
                "table": t.get("table_name", "unknown"),
                "columns": t.get("columns", [])
            }
            lines.append(json.dumps(obj, ensure_ascii=False, separators=(",", ":")))
    return lines

# %%
final_schema_result = format_schema_jsonish(reshaped_essential_schemas)

# %%
final_schema_result [:10]
# Out:
# ['{"database":"perpetrator","table":"perpetrator","columns":["perpetrator id","people id","date","year","location","country","killed","injured"]}',
#  '{"database":"perpetrator","table":"people","columns":["people id","name","height","weight","home town"]}',
#  '{"database":"college_2","table":"classroom","columns":["building","room number","capacity"]}',
#  '{"database":"college_2","table":"department","columns":["department name","building","budget"]}',
#  '{"database":"college_2","table":"course","columns":["course id","title","department name","credits"]}',
#  '{"database":"college_2","table":"instructor","columns":["id","name","department name","salary"]}',
#  '{"database":"college_2","table":"section","columns":["course id","section id","semester","year","building","room number","time slot id"]}',
#  '{"database":"college_2","table":"teaches","columns":["id","course id","section id","semester","year"]}',
#  '{"database":"college_2","table":"student","columns":["id","name","department name","total credits"]}',
#  '{"database":"college_2","table":"takes classes","columns":["id","course id","section id","semester","year","grade"]}']

# %% [markdown]
# ### Below Embedding the full prepared  Final_Schema_Result

# %%
embeddings = OpenAIEmbeddings()  
vectorstore_2 = FAISS.from_texts(final_schema_result, embeddings)

# %% [markdown]
# ## Agent 1 Database Selection

# %% [markdown]
# #### Set up LLM

# %%
llm = ChatOpenAI(
    model="gpt-5-mini",   
    temperature=0
)

# %% [markdown]
# #### Set up Agent A prompt template . Note : I've used the new function call with '|', the hashed line of code is by using the old syntax, still working now but will be depreciated in v.1.0

# %%
prompt_db = PromptTemplate(
    input_variables=["query", "retrieved_schema"],
    template="""
Please selects the most relevant database and table in order to answer user's query.
User query: {query}
Schema info: {retrieved_schema}
Which database and tables has the most relevant information for this query? Selecting 1 database only. Respond the database name, table and column infomation in JSON format: {{ "db_name": "...", "tables": ["..."], "columns":["..."]}}
"""
)
#db_chain = LLMChain(llm=llm, prompt=prompt_db)
db_chain = prompt_db | llm

# %% [markdown]
# #### Set up the main agent A function call with natural language question input, updated from 'db_chain.run' to 'db_chain.invoke', as above I updated 'LLMChain(llm=llm, prompt=prompt_db)' to 'db_chain = prompt_db | llm'

# %%
def database_selection_agent(user_query, top_k=5):
    print(f" User Query: '{user_query}'")

    # Step 1: Retrieve relevant schemas using vector search (Here the default is L2 Euclidean distances, I have had a quick look this 
    # can be updated, but not in a very easy / parameter way )
    relevant_docs = vectorstore_2.similarity_search_with_score(user_query, k=top_k)

    #print(f"\n Step 2: LLM Database Selection")

    selected_schema = ""
    for doc, score in relevant_docs:
        selected_schema += f"score: {score}, content: {doc.page_content}\n"

    #return selected_schema with a score 


    # Step 2: Use LLM to select the best database and tables
    response = db_chain.invoke({
         "query": user_query,
         "retrieved_schema": selected_schema
     })
    #print(f"LLM Response: {response}")
    
    return {
        "user_query": user_query,
        "retrieved_schemas":  selected_schema,
        "llm_selection": response
    }

# %% [markdown]
# ### A list of test queries

# %%
test_queries = [
    "Count the number of rooms that are not in the Lamberton building",
    "Find the name of all students who were in the tryout sorted in alphabetic order",
    "Find the average price of all product clothes.",
    "Show the names of artworks in ascending order of the year they are nominated in.",
    "What is the name of the department with the student that has the lowest GPA?",
    "What are the names and years of the movies that has the top 3 highest rating star?",
    "How many students does each advisor have?",
    "Count flights departing from Dallas in 2017",
    "What are the distinct creation years of the departments managed by a secretary born in state 'Alabama'?",
    "List courses worth more than 3 credits and their departments",
    "For each customer, compute total order value and sort desc.",
    "select all the deaths caused by ship",
    "Show me information about singers and their concerts",
    "I want to see student enrollment data",
    "Find information about car manufacturers and models",
    "What data do you have about movies and actors?",
    "Show me employee salary information",
    "Which produce has the most complaints where the status are still open"
]

# %% [markdown]
# #### This block can pull question from test query list and return all the process result. Would be ideal the top_k parameter can be designed for user to set up a value, if the top 5 do not return desire result.

# %%
test_query = test_queries[1]  
result = database_selection_agent(test_query,top_k=10)
print(result['user_query'])
print(result['retrieved_schemas'])
print(result['llm_selection'])
# Out:
#  User Query: 'Find the name of all students who were in the tryout sorted in alphabetic order'
# Find the name of all students who were in the tryout sorted in alphabetic order
# score: 0.48499494791030884, content: {"database":"school_player","table":"school","columns":["school id","school","location","enrollment","founded","denomination","boys or girls","day or boarding","year entered competition","school colors"]}
# score: 0.49317601323127747, content: {"database":"e_learning","table":"students","columns":["student id","date of registration","date of latest logon","login name","password","personal name","middle name","family name"]}
# score: 0.4965997338294983, content: {"database":"soccer_2","table":"tryout","columns":["player id","college name","player position","decision"]}
# score: 0.5064314603805542, content: {"database":"school_player","table":"school performance","columns":["school id","school year","class a","class aa"]}
# score: 0.5085306167602539, content: {"database":"student_1","table":"teachers","columns":["last name","first name","class room"]}
# score: 0.5114345550537109, content: {"database":"school_player","table":"school details","columns":["school id","nickname","colors","league","class","division"]}
# score: 0.511690616607666, content: {"database":"college_1","table":"student","columns":["student num","student last name","student first name","student init","student date of birth","student class hours took","student class","student gpa","student transfer","department code","student phone","professor number"]}
# score: 0.513981819152832, content: {"database":"student_1","table":"list","columns":["last name","first name","grade","class room"]}
# score: 0.5147340297698975, content: {"database":"game_1","table":"student","columns":["student id","last name","first name","age","sex","major","advisor","city code"]}
# score: 0.517266571521759, content: {"database":"student_assessment","table":"students","columns":["student id","student details"]}
#
# content='{ "db_name": "soccer_2", "tables": ["tryout"], "columns": ["player id", "college name", "player position", "decision"] }' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 174, 'prompt_tokens': 549, 'total_tokens': 723, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CI5E4bysfC34HgwBKbLZQOuyAdXAL', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--0ccfd1b8-9546-4c97-a9a6-6b7fc76a0587-0' usage_metadata={'input_tokens': 549, 'output_tokens': 174, 'total_tokens': 723, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}

# %% [markdown]
# ####  Again, as I've updated the Langchain call from Run to Invoke above, below hashed code suitable for the old Run command only

# %%
#db_name = str(json.loads(result['llm_selection'])["db_name"])
llm_output = result['llm_selection'].content if hasattr(result['llm_selection'], 'content') else str(result['llm_selection'])
db_name = str(json.loads(llm_output)["db_name"])
db_name
# Out:
# 'soccer_2'

# %% [markdown]
# # Agent 2

# %%
# quickly inspect what table the selected database contain.
reshaped_essential_schemas[db_name]['tables']
# Out:
# [{'table_name': 'college', 'columns': ['college name', 'state', 'enrollment']},
#  {'table_name': 'player',
#   'columns': ['player id', 'player name', 'yes card', 'training hours']},
#  {'table_name': 'tryout',
#   'columns': ['player id', 'college name', 'player position', 'decision']}]

# %% [markdown]
# #### Again I have updated the chain call function to use '|', same with agent 1.

# %%
list_tables_prompt = PromptTemplate(
    input_variables=["user_query", "db_schema_json"],
    template=(
        "Given the selected database schema, return ONLY valid JSON with exactly these keys"
        '  "relevant_tables": ["..."],\n'
        '  "reasons": "..." \n\n'
        #'  "SQL Code": "..." \n\n'
        "User query: {user_query}\n"
        "DB schema JSON: {db_schema_json}\n"
        "Do not wrap all_tables in an extra list. Do not include any text outside JSON."
    ),
)
#db_chain_2 = LLMChain(llm=llm, prompt=list_tables_prompt)
db_chain_2 = list_tables_prompt | llm

# %% [markdown]
# #### Here used db_chain_2 from above and generating the response_2 for Agent B

# %%
def table_selection_agent(user_query, db_name):
    #selecting ALL table information from selected database from agent A 
    full_schema = reshaped_essential_schemas[db_name]['tables']
    response_2 = db_chain_2.invoke({
        "user_query": user_query,
        "db_schema_json": full_schema
    })

    return {
        "User Query:" : user_query,
        "Database Name:" : db_name,
        "llm_result": response_2
    }

# %% [markdown]
# #### I've updated below due to the invoke funtion update from the run. The result_2 contains all the neccessary information from the agent 2, which contains questions, and selected database name from agent A. Then converted the LLM output to be JSON format as well to be able to be called via the keys.

# %%
result_2 = table_selection_agent(user_query=test_query, db_name = db_name)
llm_result = result_2['llm_result'].content if hasattr(result_2['llm_result'], 'content') else str(result_2['llm_result'])
result_2_JSON = json.loads(llm_result)
print(f"User Query : " + result_2['User Query:'])
print(f"Selected DB from Agent1 : " + result_2['Database Name:'])
print(f"Selected Tables: " + str(result_2_JSON['relevant_tables']))
print(f"Reason: " + result_2_JSON['reasons'])
#print(f"SQL code: " + result_2_JSON['SQL Code'])
# Out:
# User Query : Find the name of all students who were in the tryout sorted in alphabetic order
# Selected DB from Agent1 : soccer_2
# Selected Tables: ['player', 'tryout']
# Reason: The tryout table identifies which players participated (player id). The player table contains the player name (player name) which is required for the output. Join tryout to player on player id to get names of participants, then sort the names alphabetically.

# %% [markdown]
# # Agent 3

# %%
#loading JSON (schema file) from my local drive
complete_combined_schema = r"C:\Users\Sachith\OneDrive - UWA\SEM4\CITS5553-Group_Project\project\spider_data\combined_schema.json"
if os.path.exists(complete_combined_schema):
    with open(complete_combined_schema, 'r', encoding='utf-8') as f:
        complete_schema = json.load(f)
    print(f"Number of tables/schemas: {len(complete_schema)}")
else:
    print("error.")
# Out:
# Number of tables/schemas: 4

# %%
result_2_JSON['relevant_tables']
# Out:
# ['player', 'tryout']

# %%
# Here getting all the tables from database, not just selected from Agent 2.
complete_schema['schema'][db_name]['tables']
# Out:
# {'College': {'columns': ['cName', 'state', 'enr'],
#   'primary_key': ['cName'],
#   'foreign_keys': []},
#  'Player': {'columns': ['pID', 'pName', 'yCard', 'HS'],
#   'primary_key': ['pID'],
#   'foreign_keys': []},
#  'Tryout': {'columns': ['pID', 'cName', 'pPos', 'decision'],
#   'primary_key': ['pID', 'cName'],
#   'foreign_keys': [{'from_column': 'cName',
#     'ref_table': 'College',
#     'ref_column': 'cName'},
#    {'from_column': 'pID', 'ref_table': 'Player', 'ref_column': 'pID'}]}}

# %%
# The prompt need to add 'case insensitive' as the Spider.JSON are all lower case where our own schema used upper case.
produce_sql_prompt = PromptTemplate(
    input_variables=["user_query", "db_schema_json", "selected_tables"],
    template=(
        "Given the selected database schema and selected table names, please be case insensitive, return ONLY valid JSON with exactly these keys"
        '  "relevant_tables": ["..."],\n'
        '  "SQL Code": "..." \n\n'
        '  "reasons": "..." \n\n'
        "User query: {user_query}\n"
        "DB schema JSON: {db_schema_json}\n"
        "Selected tables: {selected_tables}\n"
        "Do not wrap all_tables in an extra list. Do not include any text outside JSON."
    ),
)
db_chain_3 = produce_sql_prompt | llm

# %%
def sql_production_agent(user_query, db_name, selected_tables):
    final_schema = complete_schema['schema'][db_name]['tables']
    response_3 = db_chain_3.invoke({
        "user_query": user_query,
        "db_schema_json": final_schema,
        "selected_tables": selected_tables
    })
    return {
        "User Query:" : user_query,
        "Database Name:" : db_name,
        "llm_result": response_3
    }

# %%
# Below is the return of the result, by using the selected db, question and All the table schemas from that database.
result_3 = sql_production_agent(user_query=test_query, db_name = db_name,selected_tables = result_2_JSON['relevant_tables'])
llm_result = result_3['llm_result'].content if hasattr(result_3['llm_result'], 'content') else str(result_3['llm_result'])
result_3_JSON = json.loads(llm_result)
print(f"User Query : " + result_3['User Query:'])
print(f"Selected DB from Agent1 : " + result_3['Database Name:'])
print(f"Selected Tables: " + str(result_3_JSON['relevant_tables']))
print(f"SQL code: " + result_3_JSON['SQL Code'])
print(f"Reason: " + result_3_JSON['reasons'])
# Out:
# User Query : Find the name of all students who were in the tryout sorted in alphabetic order
# Selected DB from Agent1 : soccer_2
# Selected Tables: ['player', 'tryout']
# SQL code: SELECT DISTINCT player.pName FROM player JOIN tryout ON player.pID = tryout.pID ORDER BY player.pName ASC;
# Reason: Join player to tryout on pID to get players who participated in tryouts; DISTINCT removes duplicate names if a player appears multiple times; ORDER BY pName ASC sorts names alphabetically. Table names are treated case-insensitively.

# %% [markdown]
# ### Testing, below systematically testing with Train data by using the question + database + SQL code. Please be mindful for the client's cost, and ensure we are not testing all the 7,000 question from the training.

# %%
tables_json_path_2 = r"C:\Users\Sachith\OneDrive - UWA\SEM4\CITS5553-Group_Project\project\spider_data\train_spider.json"
if os.path.exists(tables_json_path_2):
    with open(tables_json_path_2, 'r', encoding='utf-8') as f:
        train_data = json.load(f)
    print(f"Number of tables/schemas: {len(train_data)}")
    if train_data :
        first_entry = train_data[5] 
        print(f"Keys: {list(first_entry.keys()) if isinstance(first_entry, dict) else 'Not a dictionary'}")
else:
    print("error.")
# Out:
# Number of tables/schemas: 7000
# Keys: ['db_id', 'query', 'query_toks', 'query_toks_no_value', 'question', 'question_toks', 'sql']

# %%
# pull only the question + database + SQL code from the training data
dbid_question_list = [
    {'db_id': entry.get('db_id'), 'question': entry.get('question'), 'query': entry.get('query')}
    for entry in train_data if isinstance(entry, dict)
]
len(dbid_question_list)
# Out:
# 7000

# %%
# selecting every x of the question/db pair, as there are 7,000 training, we do not want to use all of them. 
every_x_th = dbid_question_list[:500]
# checking how many in total to be tested
len(every_x_th)
# Out:
# 500

# %%
# printing the question + db + sql code from testing data.
for item in every_x_th:
    print(item['question'])
    print(item['db_id'])
    print(item['query'])
# Out:
# How many heads of the departments are older than 56 ?
# department_management
# SELECT count(*) FROM head WHERE age  >  56
# List the name, born state and age of the heads of departments ordered by age.
# department_management
# SELECT name ,  born_state ,  age FROM head ORDER BY age
# List the creation year, name and budget of each department.
# department_management
# SELECT creation ,  name ,  budget_in_billions FROM department
# What are the maximum and minimum budget of the departments?
# department_management
# SELECT max(budget_in_billions) ,  min(budget_in_billions) FROM department
# What is the average number of employees of the departments whose rank is between 10 and 15?
# department_management
# SELECT avg(num_employees) FROM department WHERE ranking BETWEEN 10 AND 15
# What are the names of the heads who are born outside the California state?
# department_management
# SELECT name FROM head WHERE born_state != 'California'
# What are the distinct creation years of the departments managed by a secretary born in state 'Alabama'?
# department_management
# SELECT DISTINCT T1.creation FROM department AS T1 JOIN management AS T2 ON T1.department_id  =  T2.department_id JOIN head AS T3 ON T2.head_id  =  T3.head_id WHERE T3.born_state  =  'Alabama'
# What are the names of the states where at least 3 heads were born?
# department_management
# SELECT born_state FROM head GROUP BY born_state HAVING count(*)  >=  3
# In which year were most departments established?
# department_management
# SELECT creation FROM department GROUP BY creation ORDER BY count(*) DESC LIMIT 1
# Show the name and number of employees for the departments managed by heads whose temporary acting value is 'Yes'?
# department_management
# SELECT T1.name ,  T1.num_employees FROM department AS T1 JOIN management AS T2 ON T1.department_id  =  T2.department_id WHERE T2.temporary_acting  =  'Yes'
# How many acting statuses are there?
# department_management
# SELECT count(DISTINCT temporary_acting) FROM management
# How many departments are led by heads who are not mentioned?
# department_management
# SELECT count(*) FROM department WHERE department_id NOT IN (SELECT department_id FROM management);
# What are the distinct ages of the heads who are acting?
# department_management
# SELECT DISTINCT T1.age FROM management AS T2 JOIN head AS T1 ON T1.head_id  =  T2.head_id WHERE T2.temporary_acting  =  'Yes'
# List the states where both the secretary of 'Treasury' department and the secretary of 'Homeland Security' were born.
# department_management
# SELECT T3.born_state FROM department AS T1 JOIN management AS T2 ON T1.department_id  =  T2.department_id JOIN head AS T3 ON T2.head_id  =  T3.head_id WHERE T1.name  =  'Treasury' INTERSECT SELECT T3.born_state FROM department AS T1 JOIN management AS T2 ON T1.department_id  =  T2.department_id JOIN head AS T3 ON T2.head_id  =  T3.head_id WHERE T1.name  =  'Homeland Security'
# Which department has more than 1 head at a time? List the id, name and the number of heads.
# department_management
# SELECT T1.department_id ,  T1.name ,  count(*) FROM management AS T2 JOIN department AS T1 ON T1.department_id  =  T2.department_id GROUP BY T1.department_id HAVING count(*)  >  1
# Which head's name has the substring 'Ha'? List the id and name.
# department_management
# SELECT head_id ,  name FROM head WHERE name LIKE '%Ha%'
# How many farms are there?
# farm
# SELECT count(*) FROM farm
# Count the number of farms.
# farm
# SELECT count(*) FROM farm
# List the total number of horses on farms in ascending order.
# farm
# SELECT Total_Horses FROM farm ORDER BY Total_Horses ASC
# What is the total horses record for each farm, sorted ascending?
# farm
# SELECT Total_Horses FROM farm ORDER BY Total_Horses ASC
# What are the hosts of competitions whose theme is not "Aliens"?
# farm
# SELECT Hosts FROM farm_competition WHERE Theme !=  'Aliens'
# Return the hosts of competitions for which the theme is not Aliens?
# farm
# SELECT Hosts FROM farm_competition WHERE Theme !=  'Aliens'
# What are the themes of farm competitions sorted by year in ascending order?
# farm
# SELECT Theme FROM farm_competition ORDER BY YEAR ASC
# Return the themes of farm competitions, sorted by year ascending.
# farm
# SELECT Theme FROM farm_competition ORDER BY YEAR ASC
# What is the average number of working horses of farms with more than 5000 total number of horses?
# farm
# SELECT avg(Working_Horses) FROM farm WHERE Total_Horses  >  5000
# Give the average number of working horses on farms with more than 5000 total horses.
# farm
# SELECT avg(Working_Horses) FROM farm WHERE Total_Horses  >  5000
# What are the maximum and minimum number of cows across all farms.
# farm
# SELECT max(Cows) ,  min(Cows) FROM farm
# Return the maximum and minimum number of cows across all farms.
# farm
# SELECT max(Cows) ,  min(Cows) FROM farm
# How many different statuses do cities have?
# farm
# SELECT count(DISTINCT Status) FROM city
# Count the number of different statuses.
# farm
# SELECT count(DISTINCT Status) FROM city
# List official names of cities in descending order of population.
# farm
# SELECT Official_Name FROM city ORDER BY Population DESC
# What are the official names of cities, ordered descending by population?
# farm
# SELECT Official_Name FROM city ORDER BY Population DESC
# List the official name and status of the city with the largest population.
# farm
# SELECT Official_Name ,  Status FROM city ORDER BY Population DESC LIMIT 1
# What is the official name and status of the city with the most residents?
# farm
# SELECT Official_Name ,  Status FROM city ORDER BY Population DESC LIMIT 1
# Show the years and the official names of the host cities of competitions.
# farm
# SELECT T2.Year ,  T1.Official_Name FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID  =  T2.Host_city_ID
# Give the years and official names of the cities of each competition.
# farm
# SELECT T2.Year ,  T1.Official_Name FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID  =  T2.Host_city_ID
# Show the official names of the cities that have hosted more than one competition.
# farm
# SELECT T1.Official_Name FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID  =  T2.Host_city_ID GROUP BY T2.Host_city_ID HAVING COUNT(*)  >  1
# What are the official names of cities that have hosted more than one competition?
# farm
# SELECT T1.Official_Name FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID  =  T2.Host_city_ID GROUP BY T2.Host_city_ID HAVING COUNT(*)  >  1
# Show the status of the city that has hosted the greatest number of competitions.
# farm
# SELECT T1.Status FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID  =  T2.Host_city_ID GROUP BY T2.Host_city_ID ORDER BY COUNT(*) DESC LIMIT 1
# What is the status of the city that has hosted the most competitions?
# farm
# SELECT T1.Status FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID  =  T2.Host_city_ID GROUP BY T2.Host_city_ID ORDER BY COUNT(*) DESC LIMIT 1
# Please show the themes of competitions with host cities having populations larger than 1000.
# farm
# SELECT T2.Theme FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID  =  T2.Host_city_ID WHERE T1.Population  >  1000
# What are the themes of competitions that have corresponding host cities with more than 1000 residents?
# farm
# SELECT T2.Theme FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID  =  T2.Host_city_ID WHERE T1.Population  >  1000
# Please show the different statuses of cities and the average population of cities with each status.
# farm
# SELECT Status ,  avg(Population) FROM city GROUP BY Status
# What are the statuses and average populations of each city?
# farm
# SELECT Status ,  avg(Population) FROM city GROUP BY Status
# Please show the different statuses, ordered by the number of cities that have each.
# farm
# SELECT Status FROM city GROUP BY Status ORDER BY COUNT(*) ASC
# Return the different statuses of cities, ascending by frequency.
# farm
# SELECT Status FROM city GROUP BY Status ORDER BY COUNT(*) ASC
# List the most common type of Status across cities.
# farm
# SELECT Status FROM city GROUP BY Status ORDER BY COUNT(*) DESC LIMIT 1
# What is the most common status across all cities?
# farm
# SELECT Status FROM city GROUP BY Status ORDER BY COUNT(*) DESC LIMIT 1
# List the official names of cities that have not held any competition.
# farm
# SELECT Official_Name FROM city WHERE City_ID NOT IN (SELECT Host_city_ID FROM farm_competition)
# What are the official names of cities that have not hosted a farm competition?
# farm
# SELECT Official_Name FROM city WHERE City_ID NOT IN (SELECT Host_city_ID FROM farm_competition)
# Show the status shared by cities with population bigger than 1500 and smaller than 500.
# farm
# SELECT Status FROM city WHERE Population  >  1500 INTERSECT SELECT Status FROM city WHERE Population  <  500
# Which statuses correspond to both cities that have a population over 1500 and cities that have a population lower than 500?
# farm
# SELECT Status FROM city WHERE Population  >  1500 INTERSECT SELECT Status FROM city WHERE Population  <  500
# Find the official names of cities with population bigger than 1500 or smaller than 500.
# farm
# SELECT Official_Name FROM city WHERE Population  >  1500 OR Population  <  500
# What are the official names of cities that have population over 1500 or less than 500?
# farm
# SELECT Official_Name FROM city WHERE Population  >  1500 OR Population  <  500
# Show the census ranking of cities whose status are not "Village".
# farm
# SELECT Census_Ranking FROM city WHERE Status !=  "Village"
# What are the census rankings of cities that do not have the status "Village"?
# farm
# SELECT Census_Ranking FROM city WHERE Status !=  "Village"
# which course has most number of registered students?
# student_assessment
# SELECT T1.course_name FROM courses AS T1 JOIN student_course_registrations AS T2 ON T1.course_id = T2.course_Id GROUP BY T1.course_id ORDER BY count(*) DESC LIMIT 1
# What is the name of the course with the most registered students?
# student_assessment
# SELECT T1.course_name FROM courses AS T1 JOIN student_course_registrations AS T2 ON T1.course_id = T2.course_Id GROUP BY T1.course_id ORDER BY count(*) DESC LIMIT 1
# what is id of students who registered some courses but the least number of courses in these students?
# student_assessment
# SELECT student_id FROM student_course_registrations GROUP BY student_id ORDER BY count(*) LIMIT 1
# What are the ids of the students who registered for some courses but had the least number of courses for all students?
# student_assessment
# SELECT student_id FROM student_course_registrations GROUP BY student_id ORDER BY count(*) LIMIT 1
# what are the first name and last name of all candidates?
# student_assessment
# SELECT T2.first_name ,  T2.last_name FROM candidates AS T1 JOIN people AS T2 ON T1.candidate_id = T2.person_id
# What are the first and last names of all the candidates?
# student_assessment
# SELECT T2.first_name ,  T2.last_name FROM candidates AS T1 JOIN people AS T2 ON T1.candidate_id = T2.person_id
# List the id of students who never attends courses?
# student_assessment
# SELECT student_id FROM students WHERE student_id NOT IN (SELECT student_id FROM student_course_attendance)
# What are the  ids of every student who has never attended a course?
# student_assessment
# SELECT student_id FROM students WHERE student_id NOT IN (SELECT student_id FROM student_course_attendance)
# List the id of students who attended some courses?
# student_assessment
# SELECT student_id FROM student_course_attendance
# What are the ids of all students who have attended at least one course?
# student_assessment
# SELECT student_id FROM student_course_attendance
# What are the ids of all students for courses and what are the names of those courses?
# student_assessment
# SELECT T1.student_id ,  T2.course_name FROM student_course_registrations AS T1 JOIN courses AS T2 ON T1.course_id = T2.course_id
# What is detail of the student who most recently registered course?
# student_assessment
# SELECT T2.student_details FROM student_course_registrations AS T1 JOIN students AS T2 ON T1.student_id = T2.student_id ORDER BY T1.registration_date DESC LIMIT 1
# What details do we have on the students who registered for courses most recently?
# student_assessment
# SELECT T2.student_details FROM student_course_registrations AS T1 JOIN students AS T2 ON T1.student_id = T2.student_id ORDER BY T1.registration_date DESC LIMIT 1
# How many students attend course English?
# student_assessment
# SELECT count(*) FROM courses AS T1 JOIN student_course_attendance AS T2 ON T1.course_id = T2.course_id WHERE T1.course_name = "English"
# How many students are attending English courses?
# student_assessment
# SELECT count(*) FROM courses AS T1 JOIN student_course_attendance AS T2 ON T1.course_id = T2.course_id WHERE T1.course_name = "English"
# How many courses do the student whose id is 171 attend?
# student_assessment
# SELECT count(*) FROM courses AS T1 JOIN student_course_attendance AS T2 ON T1.course_id = T2.course_id WHERE T2.student_id = 171
# How many courses does the student with id 171 actually attend?
# student_assessment
# SELECT count(*) FROM courses AS T1 JOIN student_course_attendance AS T2 ON T1.course_id = T2.course_id WHERE T2.student_id = 171
# Find id of the candidate whose email is stanley.monahan@example.org?
# student_assessment
# SELECT T2.candidate_id FROM people AS T1 JOIN candidates AS T2 ON T1.person_id = T2.candidate_id WHERE T1.email_address = "stanley.monahan@example.org"
# What is the id of the candidate whose email is stanley.monahan@example.org?
# student_assessment
# SELECT T2.candidate_id FROM people AS T1 JOIN candidates AS T2 ON T1.person_id = T2.candidate_id WHERE T1.email_address = "stanley.monahan@example.org"
# Find id of the candidate who most recently accessed the course?
# student_assessment
# SELECT candidate_id FROM candidate_assessments ORDER BY assessment_date DESC LIMIT 1
# What is the id of the candidate who most recently accessed the course?
# student_assessment
# SELECT candidate_id FROM candidate_assessments ORDER BY assessment_date DESC LIMIT 1
# What is detail of the student who registered the most number of courses?
# student_assessment
# SELECT T1.student_details FROM students AS T1 JOIN student_course_registrations AS T2 ON T1.student_id = T2.student_id GROUP BY T1.student_id ORDER BY count(*) DESC LIMIT 1
# What are the details of the student who registered for the most number of courses?
# student_assessment
# SELECT T1.student_details FROM students AS T1 JOIN student_course_registrations AS T2 ON T1.student_id = T2.student_id GROUP BY T1.student_id ORDER BY count(*) DESC LIMIT 1
# List the id of students who registered some courses and the number of their registered courses?
# student_assessment
# SELECT T1.student_id ,  count(*) FROM students AS T1 JOIN student_course_registrations AS T2 ON T1.student_id = T2.student_id GROUP BY T1.student_id
# For every student who is registered for some course, how many courses are they registered for?
# student_assessment
# SELECT T1.student_id ,  count(*) FROM students AS T1 JOIN student_course_registrations AS T2 ON T1.student_id = T2.student_id GROUP BY T1.student_id
# How many registed students do each course have? List course name and the number of their registered students?
# student_assessment
# SELECT T3.course_name ,  count(*) FROM students AS T1 JOIN student_course_registrations AS T2 ON T1.student_id = T2.student_id JOIN courses AS T3 ON T2.course_id = T3.course_id GROUP BY T2.course_id
# For each course id, how many students are registered and what are the course names?
# student_assessment
# SELECT T3.course_name ,  count(*) FROM students AS T1 JOIN student_course_registrations AS T2 ON T1.student_id = T2.student_id JOIN courses AS T3 ON T2.course_id = T3.course_id GROUP BY T2.course_id
# Find id of candidates whose assessment code is "Pass"?
# student_assessment
# SELECT candidate_id FROM candidate_assessments WHERE asessment_outcome_code = "Pass"
# What are the ids of the candidates that have an outcome code of Pass?
# student_assessment
# SELECT candidate_id FROM candidate_assessments WHERE asessment_outcome_code = "Pass"
# Find the cell mobile number of the candidates whose assessment code is "Fail"?
# student_assessment
# SELECT T3.cell_mobile_number FROM candidates AS T1 JOIN candidate_assessments AS T2 ON T1.candidate_id = T2.candidate_id JOIN people AS T3 ON T1.candidate_id = T3.person_id WHERE T2.asessment_outcome_code = "Fail"
# What are the cell phone numbers of the candidates that received an assessment code of "Fail"?
# student_assessment
# SELECT T3.cell_mobile_number FROM candidates AS T1 JOIN candidate_assessments AS T2 ON T1.candidate_id = T2.candidate_id JOIN people AS T3 ON T1.candidate_id = T3.person_id WHERE T2.asessment_outcome_code = "Fail"
# What are the id of students who registered course 301?
# student_assessment
# SELECT student_id FROM student_course_attendance WHERE course_id  =  301
# What are the ids of the students who registered for course 301?
# student_assessment
# SELECT student_id FROM student_course_attendance WHERE course_id  =  301
# What is the id of the student who most recently registered course 301?
# student_assessment
# SELECT student_id FROM student_course_attendance WHERE course_id = 301 ORDER BY date_of_attendance DESC LIMIT 1
# What are the ids of the students who registered for course 301 most recently?
# student_assessment
# SELECT student_id FROM student_course_attendance WHERE course_id = 301 ORDER BY date_of_attendance DESC LIMIT 1
# Find distinct cities of addresses of people?
# student_assessment
# SELECT DISTINCT T1.city FROM addresses AS T1 JOIN people_addresses AS T2 ON T1.address_id = T2.address_id
# What are the different cities where people live?
# student_assessment
# SELECT DISTINCT T1.city FROM addresses AS T1 JOIN people_addresses AS T2 ON T1.address_id = T2.address_id
# Find distinct cities of address of students?
# student_assessment
# SELECT DISTINCT T1.city FROM addresses AS T1 JOIN people_addresses AS T2 ON T1.address_id = T2.address_id JOIN students AS T3 ON T2.person_id = T3.student_id
# What are the different cities where students live?
# student_assessment
# SELECT DISTINCT T1.city FROM addresses AS T1 JOIN people_addresses AS T2 ON T1.address_id = T2.address_id JOIN students AS T3 ON T2.person_id = T3.student_id
# List the names of courses in alphabetical order?
# student_assessment
# SELECT course_name FROM courses ORDER BY course_name
# What are the names of the courses in alphabetical order?
# student_assessment
# SELECT course_name FROM courses ORDER BY course_name
# List the first names of people in alphabetical order?
# student_assessment
# SELECT first_name FROM people ORDER BY first_name
# What are the first names of the people in alphabetical order?
# student_assessment
# SELECT first_name FROM people ORDER BY first_name
# What are the id of students who registered courses or attended courses?
# student_assessment
# SELECT student_id FROM student_course_registrations UNION SELECT student_id FROM student_course_attendance

# %% [markdown]
# #### I've updated below that we can now feed both ground truth SQL code, as well as our prediction groud truth SQL code, to excute in our database then returned the results.

# %% [markdown]
# #### feed all the x number of questions into the agent A + agent B + agent C, and collect the results.

# %%
prediction_results = []
for item in every_x_th[:1]:
    question = item['question']
    result_1 = database_selection_agent(question)
    llm_output_1 = result_1['llm_selection'].content if hasattr(result_1['llm_selection'], 'content') else str(result_1['llm_selection'])
    db_name = str(json.loads(llm_output_1)["db_name"])
    result_2 = table_selection_agent(question, db_name = db_name)
    llm_result_2 = result_2['llm_result'].content if hasattr(result_2['llm_result'], 'content') else str(result_2['llm_result'])
    result_2_JSON = json.loads(llm_result_2)
    result_3 = sql_production_agent(user_query=question, db_name = db_name,selected_tables = result_2_JSON['relevant_tables'])
    llm_result_3 = result_3['llm_result'].content if hasattr(result_3['llm_result'], 'content') else str(result_3['llm_result'])
    result_3_JSON = json.loads(llm_result_3)
   
    prediction_results.append({'question': question, 'db_name': db_name, 'SQL_Code': result_3_JSON['SQL Code'] })

#print(db_name_results[:5])
# Out:
#  User Query: 'How many heads of the departments are older than 56 ?'

# %%
# visually inpect the prediction output
prediction_results
# Out:
# [{'question': 'How many heads of the departments are older than 56 ?',
#   'db_name': 'department_management',
#   'SQL_Code': 'SELECT COUNT(DISTINCT h.head_ID) AS num_heads_over_56\nFROM head h\nJOIN management m ON h.head_ID = m.head_ID\nWHERE h.age > 56;'}]

# %% [markdown]
# ## Below I am only compare the DB name from Truth and Prediction First with accuracy score. Then I am extracting the Truth SQL code and Prediction SQL code, connect both to the databases and return the excution results.

# %% [markdown]
# ### Compare database name first

# %%
# extracting only the database name from training and prediciton for accuracy checking. 
db_ground_truth=[]
for item in every_x_th:
    db_ground_truth.append(item['db_id'])
db_prediction=[]
for item in prediction_results:
    db_prediction.append(item['db_name'])

# %%
# printing last 5 for each list 
print(db_ground_truth [-5:])
print(db_prediction [-5:])
# Out:
# ['student_assessment', 'student_assessment', 'student_assessment', 'student_assessment', 'student_assessment']
# ['department_management']

# %%
comparison_results = [gt == pred for gt, pred in zip(db_ground_truth, db_prediction)]
print(comparison_results)
# Out:
# [True]

# %%
# below return percentage of correct prediction, out of X number of questions/db you choose for the testing. 
sum(comparison_results) / len (comparison_results)
# Out:
# 1.0

# %%
# printing all the incorrect database prediction 
false_indices = [i for i, val in enumerate(comparison_results) if not val]
for i in false_indices:
    question = every_x_th[i]['question']
    ground_truth = db_ground_truth[i]
    prediction = db_prediction[i]
    print(f"Q: {question}\nTruth: {ground_truth} | Pred: {prediction}\n{'-'*60}")

# %% [markdown]
# ### Compare SQL excution results from both Ground Truth and Prediction.

# %%
import importlib
import Create_Schema
importlib.reload(Create_Schema)

from Create_Schema import extract_sql_file_paths
import json
# Remember to put the data into data folder
sql_file_paths = extract_sql_file_paths(save_json=True)

# %%
from SQL_Connector import SQLite_Connector
from Create_Schema import schema_extractor

# Create the connector (For mutiple queries on multiple tables)
connector = SQLite_Connector(sql_file_paths)

def connect_and_query(data_name: str, query: str):
    connector.connect(data_name)
    return connector.execute_queries([query])

# %%
for item in every_x_th[:1]:
    db_name_Truth = item['db_id']
    query_Truth = item['query']
    question = item['question']
    print(query_Truth)
# Out:
# SELECT count(*) FROM head WHERE age  >  56

# %%
import json, math
from collections import Counter
from collections.abc import Mapping

def _flatten_rows(x):
    """Return a flat [ {col:val, ...}, ... ] from nested [ [ {...}, ... ] ] or JSON string."""
    if x is None: return []
    if isinstance(x, str):
        try: x = json.loads(x)
        except json.JSONDecodeError: return []
    out = []
    def walk(v):
        if isinstance(v, Mapping):
            out.append(dict(v))
        elif isinstance(v, (list, tuple)):
            for el in v: walk(el)
    walk(x)
    return out

def _round_num(v, tol=1e-6):
    if isinstance(v, float):
        return round(v, int(abs(math.log10(tol))))
    return v

def _row_key(row: dict, tol=1e-6):
    """Canonical hashable key for a row dict (ignores column order)."""
    return tuple(sorted((k.lower(), _round_num(v, tol)) for k, v in row.items()))

def compare_results(gt_obj, pred_obj, tol=1e-6):
    gt_rows  = _flatten_rows(gt_obj)
    pr_rows  = _flatten_rows(pred_obj)

    # Header check (use first row if present)
    gt_hdr = sorted(map(str.lower, gt_rows[0].keys())) if gt_rows else []
    pr_hdr = sorted(map(str.lower, pr_rows[0].keys())) if pr_rows else []
    header_match = (gt_hdr == pr_hdr)

    # Set comparison of rows (order-insensitive, duplicates respected)
    gt_set = Counter(_row_key(r, tol) for r in gt_rows)
    pr_set = Counter(_row_key(r, tol) for r in pr_rows)

    tp = sum((gt_set & pr_set).values())
    fp = sum((pr_set - gt_set).values())
    fn = sum((gt_set - pr_set).values())

    precision = tp / (tp + fp) if (tp + fp) else (1.0 if tp==0 and fp==0 else 0.0)
    recall    = tp / (tp + fn) if (tp + fn) else (1.0 if tp==0 and fn==0 else 0.0)
    f1        = 2*precision*recall / (precision+recall) if (precision+recall) else 0.0
    exec_match = (fp == 0 and fn == 0)

    return {
        "header_match": header_match,
        "exec_match": exec_match,       # 1/0 accuracy per example (exact set equality)
        "precision": precision,
        "recall": recall,
        "f1": f1,
        "gt_rows": len(gt_rows),
        "pred_rows": len(pr_rows),
        "gt_header": gt_hdr,
        "pred_header": pr_hdr,
    }

# %% [markdown]
# <b> Compare resulted query with ground truth result / Similarity Check </b>

# %%
# Here create an empty list to store the SQL excution ground truth results
training_result = []
predict_result = []
import os, contextlib


for item in every_x_th[15:16]:
    db_name_Truth = item['db_id']
    query_Truth = item['query']
    question = item['question']

    #ground truth
    print(query_Truth)
    with open(os.devnull, "w") as devnull, contextlib.redirect_stdout(devnull):
        training_result = connect_and_query(db_name_Truth, query_Truth)    
    print(training_result)

    
    #prediction
    result_1 = database_selection_agent(question)
    llm_output_1 = result_1['llm_selection'].content if hasattr(result_1['llm_selection'], 'content') else str(result_1['llm_selection'])    
    db_name = str(json.loads(llm_output_1)["db_name"])    
    result_2 = table_selection_agent(question, db_name = db_name)    
    llm_result_2 = result_2['llm_result'].content if hasattr(result_2['llm_result'], 'content') else str(result_2['llm_result'])
    result_2_JSON = json.loads(llm_result_2)    
    result_3 = sql_production_agent(user_query=question, db_name = db_name,selected_tables = result_2_JSON['relevant_tables'])    
    llm_result_3 = result_3['llm_result'].content if hasattr(result_3['llm_result'], 'content') else str(result_3['llm_result'])    
    result_3_JSON = json.loads(llm_result_3)
    predict_SQl = result_3_JSON['SQL Code'] 
    
    print("prediction")
    print(predict_SQl)
    with open(os.devnull, "w") as devnull, contextlib.redirect_stdout(devnull):
        predict_result = connect_and_query(db_name, predict_SQl)
    #predict_result = connect_and_query(db_name, predict_SQl)
    print(predict_result)

    print("NEXT")
# Out:
# SELECT head_id ,  name FROM head WHERE name LIKE '%Ha%'
# [
#     [
#         {
#             "head_ID": 4,
#             "name": "Dudley Hart"
#         },
#         {
#             "head_ID": 9,
#             "name": "P\u00e1draig Harrington"
#         },
#         {
#             "head_ID": 10,
#             "name": "Franklin Langham"
#         }
#     ]
# ]
#  User Query: 'Which head's name has the substring 'Ha'? List the id and name.'
# prediction
# SELECT head_ID, name FROM head WHERE LOWER(name) LIKE '%ha%';
# [
#     [
#         {
#             "head_ID": 4,
#             "name": "Dudley Hart"
#         },
#         {
#             "head_ID": 9,
#             "name": "P\u00e1draig Harrington"
#         },
#         {
#             "head_ID": 10,
#             "name": "Franklin Langham"
#         }
#     ]
# ]
# NEXT

# %%
len(every_x_th)
# Out:
# 100

# %% [markdown]
# <b>Similarity Check<b>

# %%
import re
import sqlglot
import sqlparse
from rapidfuzz import fuzz

def canonicalize_sql(sql: str) -> str:
    # standardize an SQL
    try:
        return sqlglot.parse_one(sql).sql(dialect="ansi", pretty=False)
    except Exception:
        return sqlparse.format(
            sql,
            keyword_case="lower",
            identifier_case="lower",
            strip_comments=True,
            reindent=False
        ).strip(" ;")

def compare_sql_similarity(ground_truth_sql: str, predicted_sql: str) -> dict:
    # Compare two SQL queries after canonicalization.    
    gt = canonicalize_sql(ground_truth_sql)
    pred = canonicalize_sql(predicted_sql)

    return {
        "exact_match": gt == pred,
        "fuzz_ratio": fuzz.ratio(gt, pred) / 100.0,
        "partial_ratio": fuzz.partial_ratio(gt, pred) / 100.0,
        "token_sort_ratio": fuzz.token_sort_ratio(gt, pred) / 100.0,
        "token_set_ratio": fuzz.token_set_ratio(gt, pred) / 100.0,
    }

# %%
def _get_content(x):
    return x.content if hasattr(x, "content") else str(x)
def _extract_sql_from_any(raw: str) -> str:
    try:
        obj = json.loads(raw)
        for k in ("SQL Code", "sql_code", "sql", "SQL"):
            if isinstance(obj, dict) and isinstance(obj.get(k), str):
                return obj[k]
    except Exception:
        pass
    m = _CODE_FENCE_RE.search(raw or "")
    return (m.group(1) if m else (raw or "")).strip()
def sql_similarity_lib(gt_sql: str, pred_sql: str, dialect: str = "ansi") -> dict:
    a = canon_sql(gt_sql,  dialect=dialect)
    b = canon_sql(pred_sql, dialect=dialect)
    return {
        "exact":      a == b,
        "ratio":      fuzz.ratio(a, b) / 100.0,         
        "partial":    fuzz.partial_ratio(a, b) / 100.0, 
        "token_sort": fuzz.token_sort_ratio(a, b) / 100.0,  
        "token_set":  fuzz.token_set_ratio(a, b) / 100.0,   
        "a_canon": a, "b_canon": b,                    
    }
def canon_sql(s: str, dialect: str = "ansi") -> str:
    if s is None:
        return ""
    try:
        return sqlglot.parse_one(s).sql(dialect=dialect, pretty=False)
    except Exception:
        return sqlparse.format(
            s, keyword_case="lower", identifier_case="lower",
            strip_comments=True, reindent=False
        ).strip(" ;")

# %%
import pandas as pd

def evaluate_sql_similarity_batch(examples):
    rows = []

    for ex in examples:
        question = ex.get("question", "")
        gt_sql   = ex.get("query", "")

        # agents 
        res1 = database_selection_agent(question)
        llm1 = _get_content(res1['llm_selection'])
        db_name_pred = str(json.loads(llm1)["db_name"])

        res2 = table_selection_agent(question, db_name=db_name_pred)
        llm2 = _get_content(res2['llm_result'])
        tables = json.loads(llm2)['relevant_tables']

        res3 = sql_production_agent(user_query=question, db_name=db_name_pred, selected_tables=tables)
        llm3 = _get_content(res3['llm_result'])
        try:
            pred_sql = json.loads(llm3)['SQL Code']
        except Exception:
            pred_sql = _fallback_sql(llm3)

        # similarity 
        sim = sql_similarity_lib(gt_sql, pred_sql)

        rows.append({
            "question": question,
            "gt_sql": gt_sql,
            "pred_sql": pred_sql,
            "sql_exact": sim["exact"],
            "token_set": sim["token_set"]
        })

    # Create DataFrame
    df = pd.DataFrame(rows)

    # Summary metrics 
    overall = {
        "num_examples": len(df),
        "exact_match_rate": df["sql_exact"].mean(),
        "avg_token_set": df["token_set"].mean(),
    }
    return df, overall

report_df, overall = evaluate_sql_similarity_batch(every_x_th)

print(overall)        
print(report_df.head())
# Out:
#  User Query: 'How many heads of the departments are older than 56 ?'
#  User Query: 'List the name, born state and age of the heads of departments ordered by age.'
#  User Query: 'List the creation year, name and budget of each department.'
#  User Query: 'What are the maximum and minimum budget of the departments?'
#  User Query: 'What is the average number of employees of the departments whose rank is between 10 and 15?'
#  User Query: 'What are the names of the heads who are born outside the California state?'
#  User Query: 'What are the distinct creation years of the departments managed by a secretary born in state 'Alabama'?'
#  User Query: 'What are the names of the states where at least 3 heads were born?'
#  User Query: 'In which year were most departments established?'
#  User Query: 'Show the name and number of employees for the departments managed by heads whose temporary acting value is 'Yes'?'
#  User Query: 'How many acting statuses are there?'
#  User Query: 'How many departments are led by heads who are not mentioned?'
#  User Query: 'What are the distinct ages of the heads who are acting?'
#  User Query: 'List the states where both the secretary of 'Treasury' department and the secretary of 'Homeland Security' were born.'
#  User Query: 'Which department has more than 1 head at a time? List the id, name and the number of heads.'
#  User Query: 'Which head's name has the substring 'Ha'? List the id and name.'
#  User Query: 'How many farms are there?'
#  User Query: 'Count the number of farms.'
#  User Query: 'List the total number of horses on farms in ascending order.'
#  User Query: 'What is the total horses record for each farm, sorted ascending?'
#  User Query: 'What are the hosts of competitions whose theme is not "Aliens"?'
#  User Query: 'Return the hosts of competitions for which the theme is not Aliens?'
#  User Query: 'What are the themes of farm competitions sorted by year in ascending order?'
#  User Query: 'Return the themes of farm competitions, sorted by year ascending.'
#  User Query: 'What is the average number of working horses of farms with more than 5000 total number of horses?'
#  User Query: 'Give the average number of working horses on farms with more than 5000 total horses.'
#  User Query: 'What are the maximum and minimum number of cows across all farms.'
#  User Query: 'Return the maximum and minimum number of cows across all farms.'
#  User Query: 'How many different statuses do cities have?'
#  User Query: 'Count the number of different statuses.'
#  User Query: 'List official names of cities in descending order of population.'
#  User Query: 'What are the official names of cities, ordered descending by population?'
#  User Query: 'List the official name and status of the city with the largest population.'
#  User Query: 'What is the official name and status of the city with the most residents?'
#  User Query: 'Show the years and the official names of the host cities of competitions.'
#  User Query: 'Give the years and official names of the cities of each competition.'
#  User Query: 'Show the official names of the cities that have hosted more than one competition.'
#  User Query: 'What are the official names of cities that have hosted more than one competition?'
#  User Query: 'Show the status of the city that has hosted the greatest number of competitions.'
#  User Query: 'What is the status of the city that has hosted the most competitions?'
#  User Query: 'Please show the themes of competitions with host cities having populations larger than 1000.'
#  User Query: 'What are the themes of competitions that have corresponding host cities with more than 1000 residents?'
#  User Query: 'Please show the different statuses of cities and the average population of cities with each status.'
#  User Query: 'What are the statuses and average populations of each city?'
#  User Query: 'Please show the different statuses, ordered by the number of cities that have each.'
#  User Query: 'Return the different statuses of cities, ascending by frequency.'
#  User Query: 'List the most common type of Status across cities.'
#  User Query: 'What is the most common status across all cities?'
#  User Query: 'List the official names of cities that have not held any competition.'
#  User Query: 'What are the official names of cities that have not hosted a farm competition?'
#  User Query: 'Show the status shared by cities with population bigger than 1500 and smaller than 500.'
#  User Query: 'Which statuses correspond to both cities that have a population over 1500 and cities that have a population lower than 500?'
#  User Query: 'Find the official names of cities with population bigger than 1500 or smaller than 500.'
#  User Query: 'What are the official names of cities that have population over 1500 or less than 500?'
#  User Query: 'Show the census ranking of cities whose status are not "Village".'
#  User Query: 'What are the census rankings of cities that do not have the status "Village"?'
#  User Query: 'which course has most number of registered students?'
#  User Query: 'What is the name of the course with the most registered students?'
#  User Query: 'what is id of students who registered some courses but the least number of courses in these students?'
#  User Query: 'What are the ids of the students who registered for some courses but had the least number of courses for all students?'
#  User Query: 'what are the first name and last name of all candidates?'
#  User Query: 'What are the first and last names of all the candidates?'
#  User Query: 'List the id of students who never attends courses?'
#  User Query: 'What are the  ids of every student who has never attended a course?'
#  User Query: 'List the id of students who attended some courses?'
#  User Query: 'What are the ids of all students who have attended at least one course?'
#  User Query: 'What are the ids of all students for courses and what are the names of those courses?'
#  User Query: 'What is detail of the student who most recently registered course?'
#  User Query: 'What details do we have on the students who registered for courses most recently?'
#  User Query: 'How many students attend course English?'
#  User Query: 'How many students are attending English courses?'
#  User Query: 'How many courses do the student whose id is 171 attend?'
#  User Query: 'How many courses does the student with id 171 actually attend?'
#  User Query: 'Find id of the candidate whose email is stanley.monahan@example.org?'
#  User Query: 'What is the id of the candidate whose email is stanley.monahan@example.org?'
#  User Query: 'Find id of the candidate who most recently accessed the course?'
#  User Query: 'What is the id of the candidate who most recently accessed the course?'
#  User Query: 'What is detail of the student who registered the most number of courses?'
#  User Query: 'What are the details of the student who registered for the most number of courses?'
#  User Query: 'List the id of students who registered some courses and the number of their registered courses?'
#  User Query: 'For every student who is registered for some course, how many courses are they registered for?'
#  User Query: 'How many registed students do each course have? List course name and the number of their registered students?'
#  User Query: 'For each course id, how many students are registered and what are the course names?'
#  User Query: 'Find id of candidates whose assessment code is "Pass"?'
#  User Query: 'What are the ids of the candidates that have an outcome code of Pass?'
#  User Query: 'Find the cell mobile number of the candidates whose assessment code is "Fail"?'
#  User Query: 'What are the cell phone numbers of the candidates that received an assessment code of "Fail"?'
#  User Query: 'What are the id of students who registered course 301?'
#  User Query: 'What are the ids of the students who registered for course 301?'
#  User Query: 'What is the id of the student who most recently registered course 301?'
#  User Query: 'What are the ids of the students who registered for course 301 most recently?'
#  User Query: 'Find distinct cities of addresses of people?'
#  User Query: 'What are the different cities where people live?'
#  User Query: 'Find distinct cities of address of students?'
#  User Query: 'What are the different cities where students live?'
#  User Query: 'List the names of courses in alphabetical order?'
#  User Query: 'What are the names of the courses in alphabetical order?'
#  User Query: 'List the first names of people in alphabetical order?'
#  User Query: 'What are the first names of the people in alphabetical order?'
#  User Query: 'What are the id of students who registered courses or attended courses?'
# {'num_examples': 100, 'exact_match_rate': 0.03, 'avg_token_set': 0.7818718913494184}
#                                             question  \
# 0  How many heads of the departments are older th...
# 1  List the name, born state and age of the heads...
# 2  List the creation year, name and budget of eac...
# 3  What are the maximum and minimum budget of the...
# 4  What is the average number of employees of the...
#
#                                               gt_sql  \
# 0         SELECT count(*) FROM head WHERE age  >  56
# 1  SELECT name ,  born_state ,  age FROM head ORD...
# 2  SELECT creation ,  name ,  budget_in_billions ...
# 3  SELECT max(budget_in_billions) ,  min(budget_i...
# 4  SELECT avg(num_employees) FROM department WHER...
#
#                                             pred_sql  sql_exact  token_set
# 0  SELECT COUNT(DISTINCT h.head_ID) AS heads_olde...      False   0.805970
# 1  SELECT DISTINCT h.name, h.born_state, h.age FR...      False   0.694444
# 2  SELECT Creation AS creation_year, Name AS name...      False   0.982143
# 3  SELECT MAX(budget) AS max_budget, MIN(budget) ...      False   0.708333
# 4  SELECT AVG(Num_Employees) AS average_num_emplo...      False   1.000000

# %%
report_df.head()
# Out:
#                                             question  \
# 0  How many heads of the departments are older th...
# 1  List the name, born state and age of the heads...
# 2  List the creation year, name and budget of eac...
# 3  What are the maximum and minimum budget of the...
# 4  What is the average number of employees of the...
#
#                                               gt_sql  \
# 0         SELECT count(*) FROM head WHERE age  >  56
# 1  SELECT name ,  born_state ,  age FROM head ORD...
# 2  SELECT creation ,  name ,  budget_in_billions ...
# 3  SELECT max(budget_in_billions) ,  min(budget_i...
# 4  SELECT avg(num_employees) FROM department WHER...
#
#                                             pred_sql  sql_exact  token_set
# 0  SELECT COUNT(DISTINCT h.head_ID) AS heads_olde...      False   0.805970
# 1  SELECT DISTINCT h.name, h.born_state, h.age FR...      False   0.694444
# 2  SELECT Creation AS creation_year, Name AS name...      False   0.982143
# 3  SELECT MAX(budget) AS max_budget, MIN(budget) ...      False   0.708333
# 4  SELECT AVG(Num_Employees) AS average_num_emplo...      False   1.000000

# %%
print(overall)
# Out:
# {'num_examples': 100, 'exact_match_rate': 0.03, 'avg_token_set': 0.7818718913494184}

# %%
len(every_x_th)
# Out:
# 500

# %% [markdown]
# For 500

# %%
report_df_500, overall_500 = evaluate_sql_similarity_batch(every_x_th)
# Out:
#  User Query: 'How many heads of the departments are older than 56 ?'
#  User Query: 'List the name, born state and age of the heads of departments ordered by age.'
#  User Query: 'List the creation year, name and budget of each department.'
#  User Query: 'What are the maximum and minimum budget of the departments?'
#  User Query: 'What is the average number of employees of the departments whose rank is between 10 and 15?'
#  User Query: 'What are the names of the heads who are born outside the California state?'
#  User Query: 'What are the distinct creation years of the departments managed by a secretary born in state 'Alabama'?'
#  User Query: 'What are the names of the states where at least 3 heads were born?'
#  User Query: 'In which year were most departments established?'
#  User Query: 'Show the name and number of employees for the departments managed by heads whose temporary acting value is 'Yes'?'
#  User Query: 'How many acting statuses are there?'
#  User Query: 'How many departments are led by heads who are not mentioned?'
#  User Query: 'What are the distinct ages of the heads who are acting?'
#  User Query: 'List the states where both the secretary of 'Treasury' department and the secretary of 'Homeland Security' were born.'
#  User Query: 'Which department has more than 1 head at a time? List the id, name and the number of heads.'
#  User Query: 'Which head's name has the substring 'Ha'? List the id and name.'
#  User Query: 'How many farms are there?'
#  User Query: 'Count the number of farms.'
#  User Query: 'List the total number of horses on farms in ascending order.'
#  User Query: 'What is the total horses record for each farm, sorted ascending?'
#  User Query: 'What are the hosts of competitions whose theme is not "Aliens"?'
#  User Query: 'Return the hosts of competitions for which the theme is not Aliens?'
#  User Query: 'What are the themes of farm competitions sorted by year in ascending order?'
#  User Query: 'Return the themes of farm competitions, sorted by year ascending.'
#  User Query: 'What is the average number of working horses of farms with more than 5000 total number of horses?'
#  User Query: 'Give the average number of working horses on farms with more than 5000 total horses.'
#  User Query: 'What are the maximum and minimum number of cows across all farms.'
#  User Query: 'Return the maximum and minimum number of cows across all farms.'
#  User Query: 'How many different statuses do cities have?'
#  User Query: 'Count the number of different statuses.'
#  User Query: 'List official names of cities in descending order of population.'
#  User Query: 'What are the official names of cities, ordered descending by population?'
#  User Query: 'List the official name and status of the city with the largest population.'
#  User Query: 'What is the official name and status of the city with the most residents?'
#  User Query: 'Show the years and the official names of the host cities of competitions.'
#  User Query: 'Give the years and official names of the cities of each competition.'
#  User Query: 'Show the official names of the cities that have hosted more than one competition.'
#  User Query: 'What are the official names of cities that have hosted more than one competition?'
#  User Query: 'Show the status of the city that has hosted the greatest number of competitions.'
#  User Query: 'What is the status of the city that has hosted the most competitions?'
#  User Query: 'Please show the themes of competitions with host cities having populations larger than 1000.'
#  User Query: 'What are the themes of competitions that have corresponding host cities with more than 1000 residents?'
#  User Query: 'Please show the different statuses of cities and the average population of cities with each status.'
#  User Query: 'What are the statuses and average populations of each city?'
#  User Query: 'Please show the different statuses, ordered by the number of cities that have each.'
#  User Query: 'Return the different statuses of cities, ascending by frequency.'
#  User Query: 'List the most common type of Status across cities.'
#  User Query: 'What is the most common status across all cities?'
#  User Query: 'List the official names of cities that have not held any competition.'
#  User Query: 'What are the official names of cities that have not hosted a farm competition?'
#  User Query: 'Show the status shared by cities with population bigger than 1500 and smaller than 500.'
#  User Query: 'Which statuses correspond to both cities that have a population over 1500 and cities that have a population lower than 500?'
#  User Query: 'Find the official names of cities with population bigger than 1500 or smaller than 500.'
#  User Query: 'What are the official names of cities that have population over 1500 or less than 500?'
#  User Query: 'Show the census ranking of cities whose status are not "Village".'
#  User Query: 'What are the census rankings of cities that do not have the status "Village"?'
#  User Query: 'which course has most number of registered students?'
#  User Query: 'What is the name of the course with the most registered students?'
#  User Query: 'what is id of students who registered some courses but the least number of courses in these students?'
#  User Query: 'What are the ids of the students who registered for some courses but had the least number of courses for all students?'
#  User Query: 'what are the first name and last name of all candidates?'
#  User Query: 'What are the first and last names of all the candidates?'
#  User Query: 'List the id of students who never attends courses?'
#  User Query: 'What are the  ids of every student who has never attended a course?'
#  User Query: 'List the id of students who attended some courses?'
#  User Query: 'What are the ids of all students who have attended at least one course?'
#  User Query: 'What are the ids of all students for courses and what are the names of those courses?'
#  User Query: 'What is detail of the student who most recently registered course?'
#  User Query: 'What details do we have on the students who registered for courses most recently?'
#  User Query: 'How many students attend course English?'
#  User Query: 'How many students are attending English courses?'
#  User Query: 'How many courses do the student whose id is 171 attend?'
#  User Query: 'How many courses does the student with id 171 actually attend?'
#  User Query: 'Find id of the candidate whose email is stanley.monahan@example.org?'
#  User Query: 'What is the id of the candidate whose email is stanley.monahan@example.org?'
#  User Query: 'Find id of the candidate who most recently accessed the course?'
#  User Query: 'What is the id of the candidate who most recently accessed the course?'
#  User Query: 'What is detail of the student who registered the most number of courses?'
#  User Query: 'What are the details of the student who registered for the most number of courses?'
#  User Query: 'List the id of students who registered some courses and the number of their registered courses?'
#  User Query: 'For every student who is registered for some course, how many courses are they registered for?'
#  User Query: 'How many registed students do each course have? List course name and the number of their registered students?'
#  User Query: 'For each course id, how many students are registered and what are the course names?'
#  User Query: 'Find id of candidates whose assessment code is "Pass"?'
#  User Query: 'What are the ids of the candidates that have an outcome code of Pass?'
#  User Query: 'Find the cell mobile number of the candidates whose assessment code is "Fail"?'
#  User Query: 'What are the cell phone numbers of the candidates that received an assessment code of "Fail"?'
#  User Query: 'What are the id of students who registered course 301?'
#  User Query: 'What are the ids of the students who registered for course 301?'
#  User Query: 'What is the id of the student who most recently registered course 301?'
#  User Query: 'What are the ids of the students who registered for course 301 most recently?'
#  User Query: 'Find distinct cities of addresses of people?'
#  User Query: 'What are the different cities where people live?'
#  User Query: 'Find distinct cities of address of students?'
#  User Query: 'What are the different cities where students live?'
#  User Query: 'List the names of courses in alphabetical order?'
#  User Query: 'What are the names of the courses in alphabetical order?'
#  User Query: 'List the first names of people in alphabetical order?'
#  User Query: 'What are the first names of the people in alphabetical order?'
#  User Query: 'What are the id of students who registered courses or attended courses?'
#  User Query: 'What are the ids of the students who either registered or attended a course?'
#  User Query: 'Find the id of courses which are registered or attended by student whose id is 121?'
#  User Query: 'What are the ids of the courses that are registered or attended by the student whose id is 121?'
#  User Query: 'What are all info of students who registered courses but not attended courses?'
#  User Query: 'What are all details of the students who registered but did not attend any course?'
#  User Query: 'List the id of students who registered course statistics in the order of registration date.'
#  User Query: 'What are the ids of the students who registered course statistics by order of registration date?'
#  User Query: 'List the id of students who attended  statistics courses in the order of attendance date.'
#  User Query: 'What are the ids of the students who attended courses in the statistics department in order of attendance date.'
#  User Query: 'Give me the dates when the max temperature was higher than 85.'
#  User Query: 'What are the dates with a maximum temperature higher than 85?'
#  User Query: 'What are the names of stations that have latitude lower than 37.5?'
#  User Query: 'What are the names of all stations with a latitude smaller than 37.5?'
#  User Query: 'For each city, return the highest latitude among its stations.'
#  User Query: 'For each city, what is the highest latitude for its stations?'
#  User Query: 'Give me the start station and end station for the trips with the three oldest id.'
#  User Query: 'What is the station station and end station for the trips with the three smallest ids?'
#  User Query: 'What is the average latitude and longitude of stations located in San Jose city?'
#  User Query: 'What is the average latitude and longitude in San Jose?'
#  User Query: 'What is the id of the trip that has the shortest duration?'
#  User Query: 'What is the id of the shortest trip?'
#  User Query: 'What is the total and maximum duration of trips with bike id 636?'
#  User Query: 'What is the total and maximum duration for all trips with the bike id 636?'
#  User Query: 'For each zip code, return the average mean temperature of August there.'
#  User Query: 'For each zip code, what is the average mean temperature for all dates that start with '8'?'
#  User Query: 'From the trip record, find the number of unique bikes.'
#  User Query: 'How many different bike ids are there?'
#  User Query: 'What is the number of distinct cities the stations are located at?'
#  User Query: 'How many different cities have these stations?'
#  User Query: 'How many stations does Mountain View city has?'
#  User Query: 'How many stations are in Mountain View?'
#  User Query: 'Return the unique name for stations that have ever had 7 bikes available.'
#  User Query: 'What are the different names for each station that has ever had 7 bikes available?'
#  User Query: 'Which start station had the most trips starting from August? Give me the name and id of the station.'
#  User Query: 'What are the start station's name and id for the one that had the most start trips in August?'
#  User Query: 'Which bike traveled the most often in zip code 94002?'
#  User Query: 'What is the id of the bike that traveled the most in 94002?'
#  User Query: 'How many days had both mean humidity above 50 and mean visibility above 8?'
#  User Query: 'What is the number of days that had an average humity above 50 and an average visibility above 8?'
#  User Query: 'What is the latitude, longitude, city of the station from which the shortest trip started?'
#  User Query: 'What is the latitude, longitude, and city of the station from which the trip with smallest duration started?'
#  User Query: 'What are the ids of stations that are located in San Francisco and have average bike availability above 10.'
#  User Query: 'What are the ids of the stations in San Francisco that normally have more than 10 bikes available?'
#  User Query: 'What are the names and ids of stations that had more than 14 bikes available on average or were installed in December?'
#  User Query: 'What are the names and ids of all stations that have more than 14 bikes available on average or had bikes installed in December?'
#  User Query: 'What is the 3 most common cloud cover rates in the region of zip code 94107?'
#  User Query: 'What are the 3 most common cloud covers in the zip code of 94107?'
#  User Query: 'What is the zip code in which the average mean sea level pressure is the lowest?'
#  User Query: 'What is the zip code that has the lowest average mean sea level pressure?'
#  User Query: 'What is the average bike availability in stations that are not located in Palo Alto?'
#  User Query: 'What is the average bike availablility for stations not in Palo Alto?'
#  User Query: 'What is the average longitude of stations that never had bike availability more than 10?'
#  User Query: 'What is the mean longitude for all stations that have never had more than 10 bikes available?'
#  User Query: 'When and in what zip code did max temperature reach 80?'
#  User Query: 'What zip codes have a station with a max temperature greater than or equal to 80 and when did it reach that temperature?'
#  User Query: 'Give me ids for all the trip that took place in a zip code area with average mean temperature above 60.'
#  User Query: 'For each zip code, find the ids of all trips that have a higher average mean temperature above 60?'
#  User Query: 'For each zip code, return how many times max wind speed reached 25?'
#  User Query: 'For each zip code, how many times has the maximum wind speed reached 25 mph?'
#  User Query: 'On which day and in which zip code was the min dew point lower than any day in zip code 94107?'
#  User Query: 'Which days had a minimum dew point smaller than any day in zip code 94107, and in which zip codes were those measurements taken?'
#  User Query: 'For each trip, return its ending station's installation date.'
#  User Query: 'What is the installation date for each ending station on all the trips?'
#  User Query: 'Which trip started from the station with the largest dock count? Give me the trip id.'
#  User Query: 'What is the id of the trip that started from the station with the highest dock count?'
#  User Query: 'Count the number of trips that did not end in San Francisco city.'
#  User Query: 'How many trips did not end in San Francisco?'
#  User Query: 'In zip code 94107, on which day neither Fog nor Rain was not observed?'
#  User Query: 'On which day has it neither been foggy nor rained in the zip code of 94107?'
#  User Query: 'What are the ids of stations that have latitude above 37.4 and never had bike availability below 7?'
#  User Query: 'What are the ids of all stations that have a latitude above 37.4 and have never had less than 7 bikes available?'
#  User Query: 'What are names of stations that have average bike availability above 10 and are not located in San Jose city?'
#  User Query: 'What are the names of all stations that have more than 10 bikes available and are not located in San Jose?'
#  User Query: 'What are the name, latitude, and city of the station with the lowest latitude?'
#  User Query: 'What is the name, latitude, and city of the station that is located the furthest South?'
#  User Query: 'What are the date, mean temperature and mean humidity for the top 3 days with the largest max gust speeds?'
#  User Query: 'What is the date, average temperature and mean humidity for the days with the 3 largest maximum gust speeds?'
#  User Query: 'List the name and the number of stations for all the cities that have at least 15 stations.'
#  User Query: 'What is the name of every city that has at least 15 stations and how many stations does it have?'
#  User Query: 'Find the ids and names of stations from which at least 200 trips started.'
#  User Query: 'What are the ids and names of all start stations that were the beginning of at least 200 trips?'
#  User Query: 'Find the zip code in which the average mean visibility is lower than 10.'
#  User Query: 'For each zip code, select all those that have an average mean visiblity below 10.'
#  User Query: 'List all the cities in a decreasing order of each city's stations' highest latitude.'
#  User Query: 'For each city, list their names in decreasing order by their highest station latitude.'
#  User Query: 'What are the dates that had the top 5 cloud cover rates? Also tell me the cloud cover rate.'
#  User Query: 'What are the dates that have the 5 highest cloud cover rates and what are the rates?'
#  User Query: 'What are the ids and durations of the trips with the top 3 durations?'
#  User Query: 'What are the ids of the trips that lasted the longest and how long did they last?'
#  User Query: 'For each station, return its longitude and the average duration of trips that started from the station.'
#  User Query: 'For each start station id, what is its name, longitude and average duration of trips started there?'
#  User Query: 'For each station, find its latitude and the minimum duration of trips that ended at the station.'
#  User Query: 'For each end station id, what is its name, latitude, and minimum duration for trips ended there?'
#  User Query: 'List all the distinct stations from which a trip of duration below 100 started.'
#  User Query: 'What are all the different start station names for a trip that lasted less than 100?'
#  User Query: 'Find all the zip codes in which the max dew point have never reached 70.'
#  User Query: 'What are all the different zip codes that have a maximum dew point that was always below 70?'
#  User Query: 'Find the id for the trips that lasted at least as long as the average duration of trips in zip code 94103.'
#  User Query: 'What are the ids of all trips that had a duration as long as the average trip duration in the zip code 94103?'
#  User Query: 'What are the dates in which the mean sea level pressure was between 30.3 and 31?'
#  User Query: 'What are the dates that have an average sea level pressure between 30.3 and 31?'
#  User Query: 'Find the day in which the difference between the max temperature and min temperature was the smallest. Also report the difference.'
#  User Query: 'What are the days that had the smallest temperature range, and what was that range?'
#  User Query: 'What are the id and name of the stations that have ever had more than 12 bikes available?'
#  User Query: 'What are the different ids and names of the stations that have had more than 12 bikes available?'
#  User Query: 'Give me the zip code where the average mean humidity is below 70 and at least 100 trips took place.'
#  User Query: 'What are the zip codes that have an average mean humidity below 70 and had at least 100 trips come through there?'
#  User Query: 'What are the names of stations that are located in Palo Alto city but have never been the ending point of trips more than 100 times?'
#  User Query: 'What are the names of the stations that are located in Palo Alto but have never been the ending point of the trips'
#  User Query: 'How many trips started from Mountain View city and ended at Palo Alto city?'
#  User Query: 'How many trips stated from  a station in Mountain View and ended at one in Palo Alto?'
#  User Query: 'What is the average latitude and longitude of the starting points of all trips?'
#  User Query: 'What is the average latitude and longitude of all starting stations for the trips?'
#  User Query: 'How many books are there?'
#  User Query: 'List the writers of the books in ascending alphabetical order.'
#  User Query: 'List the titles of the books in ascending order of issues.'
#  User Query: 'What are the titles of the books whose writer is not "Elaine Lee"?'
#  User Query: 'What are the title and issues of the books?'
#  User Query: 'What are the dates of publications in descending order of price?'
#  User Query: 'What are the distinct publishers of publications with price higher than 5000000?'
#  User Query: 'List the publisher of the publication with the highest price.'
#  User Query: 'List the publication dates of publications with 3 lowest prices.'
#  User Query: 'Show the title and publication dates of books.'
#  User Query: 'Show writers who have published a book with price more than 4000000.'
#  User Query: 'Show the titles of books in descending order of publication price.'
#  User Query: 'Show publishers that have more than one publication.'
#  User Query: 'Show different publishers together with the number of publications they have.'
#  User Query: 'Please show the most common publication date.'
#  User Query: 'List the writers who have written more than one book.'
#  User Query: 'List the titles of books that are not published.'
#  User Query: 'Show the publishers that have publications with price higher than 10000000 and publications with price lower than 5000000.'
#  User Query: 'What is the number of distinct publication dates?'
#  User Query: 'How many distinct publication dates are there in our record?'
#  User Query: 'Show the prices of publications whose publisher is either "Person" or "Wiley"'
#  User Query: 'How many actors are there?'
#  User Query: 'Count the number of actors.'
#  User Query: 'List the name of actors in ascending alphabetical order.'
#  User Query: 'What are the names of actors, ordered alphabetically?'
#  User Query: 'What are the characters and duration of actors?'
#  User Query: 'Return the characters and durations for each actor.'
#  User Query: 'List the name of actors whose age is not 20.'
#  User Query: 'What are the names of actors who are not 20 years old?'
#  User Query: 'What are the characters of actors in descending order of age?'
#  User Query: 'Return the characters for actors, ordered by age descending.'
#  User Query: 'What is the duration of the oldest actor?'
#  User Query: 'Return the duration of the actor with the greatest age.'
#  User Query: 'What are the names of musicals with nominee "Bob Fosse"?'
#  User Query: 'Return the names of musicals who have the nominee Bob Fosse.'
#  User Query: 'What are the distinct nominees of the musicals with the award that is not "Tony Award"?'
#  User Query: 'Return the different nominees of musicals that have an award that is not the Tony Award.'
#  User Query: 'Show names of actors and names of musicals they are in.'
#  User Query: 'What are the names of actors and the musicals that they are in?'
#  User Query: 'Show names of actors that have appeared in musical with name "The Phantom of the Opera".'
#  User Query: 'What are the names of actors who have been in the musical titled The Phantom of the Opera?'
#  User Query: 'Show names of actors in descending order of the year their musical is awarded.'
#  User Query: 'What are the names of actors ordered descending by the year in which their musical was awarded?'
#  User Query: 'Show names of musicals and the number of actors who have appeared in the musicals.'
#  User Query: 'How many actors have appeared in each musical?'
#  User Query: 'Show names of musicals which have at least three actors.'
#  User Query: 'What are the names of musicals who have at 3 or more actors?'
#  User Query: 'Show different nominees and the number of musicals they have been nominated.'
#  User Query: 'How many musicals has each nominee been nominated for?'
#  User Query: 'Please show the nominee who has been nominated the greatest number of times.'
#  User Query: 'Who is the nominee who has been nominated for the most musicals?'
#  User Query: 'List the most common result of the musicals.'
#  User Query: 'Return the most frequent result across all musicals.'
#  User Query: 'List the nominees that have been nominated more than two musicals.'
#  User Query: 'Who are the nominees who have been nominated more than two times?'
#  User Query: 'List the name of musicals that do not have actors.'
#  User Query: 'What are the names of musicals who have no actors?'
#  User Query: 'Show the nominees that have nominated musicals for both "Tony Award" and "Drama Desk Award".'
#  User Query: 'Who are the nominees who have been nominated for both a Tony Award and a Drama Desk Award?'
#  User Query: 'Show the musical nominee with award "Bob Fosse" or "Cleavant Derricks".'
#  User Query: 'Who are the nominees who were nominated for either of the Bob Fosse or Cleavant Derricks awards?'
#  User Query: 'Find the emails of the user named "Mary".'
#  User Query: 'What is the partition id of the user named "Iron Man".'
#  User Query: 'How many users are there?'
#  User Query: 'How many followers does each user have?'
#  User Query: 'Find the number of followers for each user.'
#  User Query: 'Find the number of tweets in record.'
#  User Query: 'Find the number of users who posted some tweets.'
#  User Query: 'Find the name and email of the user whose name contains the word ‘Swift’.'
#  User Query: 'Find the names of users whose emails contain ‘superstar’ or ‘edu’.'
#  User Query: 'Return the text of tweets about the topic 'intern'.'
#  User Query: 'Find the name and email of the users who have more than 1000 followers.'
#  User Query: 'Find the names of the users whose number of followers is greater than that of the user named "Tyler Swift".'
#  User Query: 'Find the name and email for the users who have more than one follower.'
#  User Query: 'Find the names of users who have more than one tweet.'
#  User Query: 'Find the id of users who are followed by Mary and Susan.'
#  User Query: 'Find the id of users who are followed by Mary or Susan.'
#  User Query: 'Find the name of the user who has the largest number of followers.'
#  User Query: 'Find the name and email of the user followed by the least number of people.'
#  User Query: 'List the name and number of followers for each user, and sort the results by the number of followers in descending order.'
#  User Query: 'List the names of 5 users followed by the largest number of other users.'
#  User Query: 'List the text of all tweets in the order of date.'
#  User Query: 'Find the name of each user and number of tweets tweeted by each of them.'
#  User Query: 'Find the name and partition id for users who tweeted less than twice.'
#  User Query: 'Find the name of the user who tweeted more than once, and number of tweets tweeted by them.'
#  User Query: 'Find the average number of followers for the users who do not have any tweet.'
#  User Query: 'Find the average number of followers for the users who had some tweets.'
#  User Query: 'Find the maximum and total number of followers of all users.'
#  User Query: 'Find the names of all the catalog entries.'
#  User Query: 'What are all the catalog entry names?'
#  User Query: 'Find the list of attribute data types possessed by more than 3 attribute definitions.'
#  User Query: 'What are the attribute data types with more than 3 attribute definitions?'
#  User Query: 'What is the attribute data type of the attribute with name "Green"?'
#  User Query: 'Find the attribute data type for the attribute named "Green".'
#  User Query: 'Find the name and level of catalog structure with level between 5 and 10.'
#  User Query: 'What are the name and level of catalog structure with level number between 5 and 10'
#  User Query: 'Find all the catalog publishers whose name contains "Murray"'
#  User Query: 'Which catalog publishers have substring "Murray" in their names?'
#  User Query: 'Which catalog publisher has published the most catalogs?'
#  User Query: 'Find the catalog publisher that has the most catalogs.'
#  User Query: 'Find the names and publication dates of all catalogs that have catalog level number greater than 5.'
#  User Query: 'What are the name and publication date of the catalogs with catalog level number above 5?'
#  User Query: 'What are the entry names of catalog with the attribute possessed by most entries.'
#  User Query: 'Find the entry names of the catalog with the attribute that have the most entries.'
#  User Query: 'What is the entry name of the most expensive catalog (in USD)?'
#  User Query: 'Find the entry name of the catalog with the highest price (in USD).'
#  User Query: 'What is the level name of the cheapest catalog (in USD)?'
#  User Query: 'Find the level name of the catalog with the lowest price (in USD).'
#  User Query: 'What are the average and minimum price (in Euro) of all products?'
#  User Query: 'Give me the average and minimum price (in Euro) of the products.'
#  User Query: 'What is the product with the highest height? Give me the catalog entry name.'
#  User Query: 'Which catalog content has the highest height? Give me the catalog entry name.'
#  User Query: 'Find the name of the product that has the smallest capacity.'
#  User Query: 'Which catalog content has the smallest capacity? Return the catalog entry name.'
#  User Query: 'Find the names of all the products whose stock number starts with "2".'
#  User Query: 'Which catalog contents have a product stock number that starts from "2"? Show the catalog entry names.'
#  User Query: 'Find the names of catalog entries with level number 8.'
#  User Query: 'What are the names of catalog entries with level number 8?'
#  User Query: 'Find the names of the products with length smaller than 3 or height greater than 5.'
#  User Query: 'Which catalog contents have length below 3 or above 5? Find the catalog entry names.'
#  User Query: 'Find the name and attribute ID of the attribute definitions with attribute value 0.'
#  User Query: 'Which attribute definitions have attribute value 0? Give me the attribute name and attribute ID.'
#  User Query: 'Find the name and capacity of products with price greater than 700 (in USD).'
#  User Query: 'Which catalog contents has price above 700 dollars? Show their catalog entry names and capacities.'
#  User Query: 'Find the dates on which more than one revisions were made.'
#  User Query: 'On which days more than one revisions were made on catalogs.'
#  User Query: 'How many products are there in the records?'
#  User Query: 'Find the total number of catalog contents.'
#  User Query: 'Name all the products with next entry ID greater than 8.'
#  User Query: 'What are the catalog entry names of the products with next entry ID above 8?'
#  User Query: 'How many aircrafts do we have?'
#  User Query: 'How many aircrafts exist in the database?'
#  User Query: 'Show name and distance for all aircrafts.'
#  User Query: 'What are the names and distances for all airplanes?'
#  User Query: 'Show ids for all aircrafts with more than 1000 distance.'
#  User Query: 'What are the ids of all aircrafts that can cover a distance of more than 1000?'
#  User Query: 'How many aircrafts have distance between 1000 and 5000?'
#  User Query: 'What is the count of aircrafts that have a distance between 1000 and 5000?'
#  User Query: 'What is the name and distance for aircraft with id 12?'
#  User Query: 'What is the name and distance for the aircraft that has an id of 12?'
#  User Query: 'What is the minimum, average, and maximum distance of all aircrafts.'
#  User Query: 'Return the minimum, average and maximum distances traveled across all aircrafts.'
#  User Query: 'Show the id and name of the aircraft with the maximum distance.'
#  User Query: 'What is the id and name of the aircraft that can cover the maximum distance?'
#  User Query: 'Show the name of aircrafts with top three lowest distances.'
#  User Query: 'What are the aircrafts with top 3 shortest lengthes? List their names.'
#  User Query: 'Show names for all aircrafts with distances more than the average.'
#  User Query: 'What are the names of all aircrafts that can cover more distances than average?'
#  User Query: 'How many employees do we have?'
#  User Query: 'What is the number of employees?'
#  User Query: 'Show name and salary for all employees sorted by salary.'
#  User Query: 'What is the name and salary of all employees in order of salary?'
#  User Query: 'Show ids for all employees with at least 100000 salary.'
#  User Query: 'What is the id of every employee who has at least a salary of  100000?'
#  User Query: 'How many employees have salary between 100000 and 200000?'
#  User Query: 'What is the number of employees that have a salary between 100000 and 200000?'
#  User Query: 'What is the name and salary for employee with id 242518965?'
#  User Query: 'What is the name and salary of the employee with the id 242518965?'
#  User Query: 'What is average and maximum salary of all employees.'
#  User Query: 'What is the average and largest salary of all employees?'
#  User Query: 'Show the id and name of the employee with maximum salary.'
#  User Query: 'What is the id and name of the employee with the highest salary?'
#  User Query: 'Show the name of employees with three lowest salaries.'
#  User Query: 'What is the name of the 3 employees who get paid the least?'
#  User Query: 'Show names for all employees with salary more than the average.'
#  User Query: 'What are the names of all employees who have a salary higher than average?'
#  User Query: 'Show the id and salary of Mark Young.'
#  User Query: 'What is the id and salary of the employee named Mark Young?'
#  User Query: 'How many flights do we have?'
#  User Query: 'What is the number of flights?'
#  User Query: 'Show flight number, origin, destination of all flights in the alphabetical order of the departure cities.'
#  User Query: 'What is the flight number, origin, and destination for all flights in alphabetical order by departure cities?'
#  User Query: 'Show all flight number from Los Angeles.'
#  User Query: 'What are the numbers of all flights coming from Los Angeles?'
#  User Query: 'Show origins of all flights with destination Honolulu.'
#  User Query: 'What are the origins of all flights that are headed to Honolulu?'
#  User Query: 'Show me the departure date and arrival date for all flights from Los Angeles to Honolulu.'
#  User Query: 'What are the departure and arrival dates of all flights from LA to Honolulu?'
#  User Query: 'Show flight number for all flights with more than 2000 distance.'
#  User Query: 'What are the numbers of all flights that can cover a distance of more than 2000?'
#  User Query: 'What is the average price for flights from Los Angeles to Honolulu.'
#  User Query: 'What is the average price for flights from LA to Honolulu?'
#  User Query: 'Show origin and destination for flights with price higher than 300.'
#  User Query: 'What is the origin and destination for all flights whose price is higher than 300?'
#  User Query: 'Show the flight number and distance of the flight with maximum price.'
#  User Query: 'What is the flight number and its distance for the one with the maximum price?'
#  User Query: 'Show the flight number of flights with three lowest distances.'
#  User Query: 'What are the numbers of the shortest flights?'
#  User Query: 'What is the average distance and average price for flights from Los Angeles.'
#  User Query: 'What is the average distance and price for all flights from LA?'
#  User Query: 'Show all origins and the number of flights from each origin.'
#  User Query: 'For each origin, how many flights came from there?'
#  User Query: 'Show all destinations and the number of flights to each destination.'
#  User Query: 'What are the destinations and number of flights to each one?'
#  User Query: 'Which origin has most number of flights?'
#  User Query: 'What place has the most flights coming from there?'
#  User Query: 'Which destination has least number of flights?'
#  User Query: 'What destination has the fewest number of flights?'
#  User Query: 'What is the aircraft name for the flight with number 99'
#  User Query: 'What is the name of the aircraft that was on flight number 99?'
#  User Query: 'Show all flight numbers with aircraft Airbus A340-300.'
#  User Query: 'What are the flight numbers for the aircraft Airbus A340-300?'
#  User Query: 'Show aircraft names and number of flights for each aircraft.'
#  User Query: 'What is the name of each aircraft and how many flights does each one complete?'
#  User Query: 'Show names for all aircraft with at least two flights.'
#  User Query: 'What are the names for all aircrafts with at least 2 flights?'
#  User Query: 'How many employees have certificate.'
#  User Query: 'What is the count of distinct employees with certificates?'
#  User Query: 'Show ids for all employees who don't have a certificate.'
#  User Query: 'What are the ids of all employees that don't have certificates?'
#  User Query: 'Show names for all aircrafts of which John Williams has certificates.'
#  User Query: 'What are the names of all aircrafts that John Williams have certificates to be able to fly?'
#  User Query: 'Show names for all employees who have certificate of Boeing 737-800.'
#  User Query: 'What are the names of all employees who have a certificate to fly Boeing 737-800?'
#  User Query: 'Show names for all employees who have certificates on both Boeing 737-800 and Airbus A340-300.'
#  User Query: 'What are the names of all employees who can fly both the Boeing 737-800 and the Airbus A340-300?'
#  User Query: 'Show names for all employees who do not have certificate of Boeing 737-800.'
#  User Query: 'What are the names of all employees who are not certified to fly Boeing 737-800s?'
#  User Query: 'Show the name of aircraft which fewest people have its certificate.'
#  User Query: 'What are the names of the aircraft that the least people are certified to fly?'
#  User Query: 'Show the name and distance of the aircrafts with more than 5000 distance and which at least 5 people have its certificate.'
#  User Query: 'What is the name and distance of every aircraft that can cover a distance of more than 5000 and which at least 5 people can fly?'
#  User Query: 'what is the salary and name of the employee who has the most number of aircraft certificates?'
#  User Query: 'What is the salaray and name of the employee that is certified to fly the most planes?'
#  User Query: 'What is the salary and name of the employee who has the most number of certificates on aircrafts with distance more than 5000?'
#  User Query: 'What is the salaray and name of the employee with the most certificates to fly planes more than 5000?'
#  User Query: 'How many allergies are there?'
#  User Query: 'How many allergy entries are there?'
#  User Query: 'How many different allergy types exist?'
#  User Query: 'How many distinct allergies are there?'
#  User Query: 'Show all allergy types.'
#  User Query: 'What are the different allergy types?'
#  User Query: 'Show all allergies and their types.'
#  User Query: 'What are the allergies and their types?'
#  User Query: 'Show all allergies with type food.'
#  User Query: 'What are all the different food allergies?'
#  User Query: 'What is the type of allergy Cat?'
#  User Query: 'What is allergy type of a cat allergy?'
#  User Query: 'How many allergies have type animal?'
#  User Query: 'How many animal type allergies exist?'
#  User Query: 'Show all allergy types and the number of allergies in each type.'
#  User Query: 'What are the allergy types and how many allergies correspond to each one?'
#  User Query: 'Which allergy type has most number of allergies?'
#  User Query: 'Which allergy type is most common?'
#  User Query: 'Which allergy type has least number of allergies?'
#  User Query: 'Which allergy type is the least common?'
#  User Query: 'How many students are there?'
#  User Query: 'What is the total number of students?'
#  User Query: 'Show first name and last name for all students.'
#  User Query: 'What are the full names of all students'
#  User Query: 'How many different advisors are listed?'
#  User Query: 'How many advisors are there?'
#  User Query: 'Show all majors.'
#  User Query: 'What are the different majors?'
#  User Query: 'Show all cities where students live.'
#  User Query: 'What cities do students live in?'
#  User Query: 'Show first name, last name, age for all female students. Their sex is F.'
#  User Query: 'What are the full names and ages for all female students whose sex is F?'
#  User Query: 'Show student ids for all male students.'
#  User Query: 'What are the student ids for all male students?'
#  User Query: 'How many students are age 18?'
#  User Query: 'How many students are 18 years old?'
#  User Query: 'Show all student ids who are older than 20.'
#  User Query: 'What are the student ids for students over 20 years old?'
#  User Query: 'Which city does the student whose last name is "Kim" live in?'
#  User Query: 'Give the city that the student whose family name is Kim lives in.'
#  User Query: 'Who is the advisor of student with ID 1004?'
#  User Query: 'Who advises student 1004?'
#  User Query: 'How many students live in HKG or CHI?'
#  User Query: 'Give the number of students living in either HKG or CHI.'
#  User Query: 'Show the minimum, average, and maximum age of all students.'
#  User Query: 'What is the minimum, mean, and maximum age across all students?'
#  User Query: 'What is the last name of the youngest student?'
#  User Query: 'Provide the last name of the youngest student.'
#  User Query: 'Show the student id of the oldest student.'
#  User Query: 'What student id corresponds to the oldest student?'
#  User Query: 'Show all majors and corresponding number of students.'
#  User Query: 'How many students are there for each major?'
#  User Query: 'Which major has most number of students?'
#  User Query: 'What is the largest major?'
#  User Query: 'Show all ages and corresponding number of students.'
#  User Query: 'How old is each student and how many students are each age?'
#  User Query: 'Show the average age for male and female students.'
#  User Query: 'What are the average ages for male and female students?'
#  User Query: 'Show all cities and corresponding number of students.'
#  User Query: 'How many students live in each city?'
#  User Query: 'Show all advisors and corresponding number of students.'

# %%
report_df_500.head()
# Out:
#                                             question  \
# 0  How many heads of the departments are older th...
# 1  List the name, born state and age of the heads...
# 2  List the creation year, name and budget of eac...
# 3  What are the maximum and minimum budget of the...
# 4  What is the average number of employees of the...
#
#                                               gt_sql  \
# 0         SELECT count(*) FROM head WHERE age  >  56
# 1  SELECT name ,  born_state ,  age FROM head ORD...
# 2  SELECT creation ,  name ,  budget_in_billions ...
# 3  SELECT max(budget_in_billions) ,  min(budget_i...
# 4  SELECT avg(num_employees) FROM department WHER...
#
#                                             pred_sql  sql_exact  token_set
# 0  SELECT COUNT(DISTINCT h.head_ID) AS num_heads_...      False   0.805970
# 1  SELECT DISTINCT h.name, h.born_state, h.age FR...      False   0.694444
# 2  SELECT Creation AS creation_year, Name AS name...      False   0.982143
# 3  SELECT MAX(budget) AS max_budget, MIN(budget) ...      False   0.708333
# 4  SELECT AVG(Num_Employees) AS avg_num_employees...      False   1.000000

# %%
print(overall_500)
# Out:
# {'num_examples': 500, 'exact_match_rate': 0.022, 'avg_token_set': 0.8236347789751408}
